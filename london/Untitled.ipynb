# %%
import os, subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "python-dotenv", "-q"])

# Load your code.env file
env_file = r"C:\Users\Abhijeet\code.env"

with open(env_file, "r") as f:
    for line in f:
        line = line.strip()
        if "=" in line and not line.startswith("#"):
            key, val = line.split("=", 1)
            os.environ[key.strip()] = val.strip().strip('"').strip("'")

print(f" Loaded from: {env_file}")

ok_openai = len(os.environ.get("OPENAI_API_KEY", "")) > 20
print(f"OpenAI : {' Loaded' if ok_openai else ' Not found'}")
# Out:
#  Loaded from: C:\Users\Abhijeet\code.env
# OpenAI :  Loaded

# %%
import os, subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "python-dotenv", "-q"],
               capture_output=True)

# Load from code.env
env_file = r"C:\Users\Abhijeet\code.env"
with open(env_file, "r") as f:
    for line in f:
        line = line.strip()
        if "=" in line and not line.startswith("#"):
            key, val = line.split("=", 1)
            os.environ[key.strip()] = val.strip().strip('"').strip("'")

# Anthropic not needed — set dummy so scraper skips quietly
if not os.environ.get("ANTHROPIC_API_KEY"):
    os.environ["ANTHROPIC_API_KEY"] = "not-used"

ok = len(os.environ.get("OPENAI_API_KEY", "")) > 20
print(f"OpenAI key : {' Ready' if ok else ' Not found — check code.env'}")
if ok:
    print(" Ready to run scraper")
# Out:
# OpenAI key :  Ready
#  Ready to run scraper

# %%
import asyncio
import re
import sys
import json
import urllib.request
import os
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from datetime import datetime


# ── SENTENCE-SAFE TRUNCATION ─────────────────────────────────────────────────

def clean_to_sentences(text: str, max_sentences: int = 2) -> str:
    """
    Return at most `max_sentences` complete sentences from text.
    Never cuts mid-sentence. Strips trailing incomplete fragments.
    """
    if not text:
        return ""
    text = re.sub(r'\s+', ' ', text).strip()
    # Split on sentence-ending punctuation followed by space or end-of-string
    sentences = re.split(r'(?<=[.!?])\s+', text)
    # Keep only complete sentences: must end with punctuation and have ≥6 words
    good = [
        s.strip() for s in sentences
        if len(s.strip().split()) >= 6 and re.search(r'[.!?]$', s.strip())
    ]
    return " ".join(good[:max_sentences])


# ── API KEY VALIDATION ────────────────────────────────────────────────────────
# Loads keys from .env file automatically — safe, never hardcode keys in code

try:
    from dotenv import load_dotenv
    load_dotenv()  # reads .env file from same folder as this script
except ImportError:
    pass  # dotenv not installed — keys must be set via os.environ manually

def _get_openai_key() -> str:
    return os.environ.get("OPENAI_API_KEY", "")

def _get_anthropic_key() -> str:
    return os.environ.get("ANTHROPIC_API_KEY", "")

def _check_key(key: str, name: str) -> bool:
    if not key or key.startswith("YOUR_") or len(key) < 20:
        print(f"  ⚠ {name} not set — add it to your .env file")
        return False
    return True

# ── HELPERS 

async def highlight_and_click(page, selector_or_locator, description="Action"):
    try:
        target = (
            page.locator(selector_or_locator).first
            if isinstance(selector_or_locator, str)
            else selector_or_locator
        )
        if await target.is_visible(timeout=2000):
            await target.evaluate(
                "el => { el.style.border = '4px solid #00FF00';"
                " el.style.backgroundColor = 'rgba(0,255,0,0.2)'; }"
            )
            await target.click()
            return True
    except Exception:
        pass
    return False


async def handle_cookies_automatically(page):
    cookie_selectors = [
        "text=Accept All", "text=Accept",
        "button:has-text('Accept')", "button:has-text('OK')",
        "button:has-text('I Agree')", "button:has-text('Close')",
        "button:has-text('Got it')", "button:has-text('Agree')",
    ]
    for selector in cookie_selectors:
        if await highlight_and_click(page, selector, "Cookie Banner"):
            break


async def smart_goto(page, url, timeout=90000):
    """Try networkidle first; fall back to domcontentloaded + commit."""
    try:
        await page.goto(url, wait_until="networkidle", timeout=timeout)
        return True
    except Exception as e:
        print(f"  ⚠ networkidle failed ({e.__class__.__name__}), retrying…")
    try:
        await page.goto(url, wait_until="domcontentloaded", timeout=timeout)
        await asyncio.sleep(6)
        try:
            await page.wait_for_function(
                "() => document.body && document.body.innerText.trim().length > 200",
                timeout=15000)
        except Exception:
            pass
        return True
    except Exception as e:
        try:
            await page.goto(url, wait_until="commit", timeout=timeout)
            await asyncio.sleep(8)
            return True
        except Exception:
            pass
        print(f"  ✗ Failed: {e}")
        return False


# ── CITY DETECTION ────────────────────────────────────────────────────────────

CITY_HINTS = {
    # London postcodes → borough
    "sw3": "Chelsea, London, UK",    "sw6": "Fulham, London, UK",
    "sw7": "South Kensington, London, UK", "sw10": "Chelsea, London, UK",
    "sw11": "Battersea, London, UK", "sw13": "Barnes, London, UK",
    "sw15": "Putney, London, UK",   "sw18": "Wandsworth, London, UK",
    "sw19": "Wimbledon, London, UK",
    "w4":  "Chiswick, London, UK",  "w5": "Ealing, London, UK",
    "w6":  "Hammersmith, London, UK","w8": "Kensington, London, UK",
    "w11": "Notting Hill, London, UK","w14": "West Kensington, London, UK",
    "w2":  "Bayswater, London, UK",
    "nw3": "Hampstead, London, UK", "nw8": "St John's Wood, London, UK",
    "n1":  "Islington, London, UK", "n6": "Highgate, London, UK",
    "n10": "Muswell Hill, London, UK",
    "se1": "Southwark, London, UK", "se21": "Dulwich, London, UK",
    "se22": "East Dulwich, London, UK",
    "ec1": "City of London, London, UK", "ec2": "City of London, London, UK",
    "wc2": "Covent Garden, London, UK",
    "ha":  "Harrow, London, UK",
    # Named areas
    "chelsea":       "Chelsea, London, UK",
    "hammersmith":   "Hammersmith, London, UK",
    "kensington":    "Kensington, London, UK",
    "wimbledon":     "Wimbledon, London, UK",
    "dulwich":       "Dulwich, London, UK",
    "hampstead":     "Hampstead, London, UK",
    "highgate":      "Highgate, London, UK",
    "putney":        "Putney, London, UK",
    "fulham":        "Fulham, London, UK",
    "westminster":   "Westminster, London, UK",
    "harrow":        "Harrow, London, UK",
    "islington":     "Islington, London, UK",
    "battersea":     "Battersea, London, UK",
    "notting hill":  "Notting Hill, London, UK",
    "ealing":        "Ealing, London, UK",
    # Other UK cities
    "oxford":        "Oxford, UK",
    "cambridge":     "Cambridge, UK",
    "bristol":       "Bristol, UK",
    "manchester":    "Manchester, UK",
    "edinburgh":     "Edinburgh, UK",
    "surrey":        "Surrey, UK",
    "berkshire":     "Berkshire, UK",
    "somerset":      "Somerset, UK",
    ".co.uk":        "London, UK",
    ".org.uk":       "London, UK",
    ".ac.uk":        "London, UK",
}

def detect_city(url: str, body_text: str) -> str:
    url_lower = url.lower()
    for hint, city in CITY_HINTS.items():
        if hint in url_lower:
            return city
    # Try postcode in body text
    import re as _re
    pc = _re.search(r'\b([A-Z]{1,2}\d{1,2}[A-Z]?)\s*\d[A-Z]{2}\b', body_text, _re.I)
    if pc:
        prefix = pc.group(1).upper()
        for hint, city in CITY_HINTS.items():
            if hint.upper() == prefix[:len(hint)]:
                return city
    sample = body_text[:3000].lower()
    for hint, city in CITY_HINTS.items():
        if hint in sample:
            return city
    return "London, UK"


# ── GARBAGE SITE DETECTION ────────────────────────────────────────────────────
# Skip sites that have been redirected to domain-sale/parking pages

GARBAGE_SIGNALS = [
    "hugedomains", "domain for sale", "buy this domain", "sedoparking",
    "this domain is for sale", "godaddy", "namecheap parking",
    "page not found", "account suspended", "coming soon",
    "under construction", "website coming soon",
]

def is_garbage_site(name: str, body_text: str) -> bool:
    combined = (name + " " + body_text[:500]).lower()
    return any(sig in combined for sig in GARBAGE_SIGNALS)


# ── JUNK PARAGRAPH FILTER ─────────────────────────────────────────────────────
# Sentences that should never appear as data — error messages, UI strings, legal boilerplate

JUNK_PATTERNS = [
    r"the site you are about to visit",
    r"page you requested no longer exists",
    r"managed independently",
    r"beginning of dialog window",
    r"escape will cancel",
    r"^d after this time",
    r"^d to new applications",
    r"^d when the permitted",
    r"^s, refine my essays",
    r"enquire now$",
    r"apply now$",
    r"watch the video",
    r"learn more$",
    r"find out more$",
    r"read more$",
    r"click here",
    r'"school" means the school',
    r"student.*means the child",
    r"parents.*guardians.*applying",
    r"single.elimination system",
    r"park ventures ecoplex",
    r"57 wireless road",
    r"please fill out the form",
    r"fill the registration form",
    r"enrol your child in \d+ easy steps",
    r"step \d+ - complete",
    r"^why do we do what we do",
    r"see our record.breaking class",
    r"view now we have helped",
    r"not sponsored by.*affiliated",
    r"mailing list.*keep you up to date",
    r"joining our mailing list",
    r"over 1\.25 million",
    r"million visitor",
    r"million patron",
    r"to progress your application we require",
    r"please see below the list of documents",
    r"documents that are mandatory to upload",
    r'"school" means the school providing',
    r"our system is limited to uploading",
    r"scans of multi-page documents",
    r"report lost items",
    r"recover belongings",
    r"tourist visa.*online",
    r"apply for your tourist visa",
]

def is_junk(text: str) -> bool:
    if not text:
        return True
    tl = text.lower().strip()
    return any(re.search(p, tl) for p in JUNK_PATTERNS)


# ── IMAGE HARVESTING (module-level — works on homepage AND all subpages) ──────

SKIP_IMG = [
    "logo", "icon", "svg", "1x1", "pixel", "spinner", "placeholder",
    "blank", "transparent", "avatar", "flag", "arrow", "bullet",
    "check", "star", "rating", "rs/facebook", "rs/linkedin", "rs/youtube",
    "loupe", "panier", "menu", "profil", "derouler", "derouler",
    "default_image", "black-beacon", "weather/128",
]
EXTS_IMG = [".jpg", ".jpeg", ".png", ".webp"]

async def harvest_images(pg, base_url: str, image_set: set):
    """Collect all content images from current page into image_set."""
    try:
        # Scroll slowly to trigger lazy-loaded images
        await pg.evaluate("""async () => {
            await new Promise(resolve => {
                let total = 0;
                const dist = 400;
                const timer = setInterval(() => {
                    window.scrollBy(0, dist);
                    total += dist;
                    if (total >= document.body.scrollHeight) {
                        clearInterval(timer);
                        window.scrollTo(0, 0);
                        resolve();
                    }
                }, 80);
            });
        }""")
        await asyncio.sleep(1)
    except Exception:
        pass

    try:
        # 1. <img> tags — all lazy-load attrs
        for img in await pg.query_selector_all("img"):
            for attr in ["src", "data-src", "data-lazy-src", "data-original",
                         "data-image", "data-bg", "data-lazy", "data-srcset"]:
                c = await img.get_attribute(attr)
                if c:
                    src = c.strip().split(" ")[0].split(",")[0].strip()
                    full = urljoin(base_url, src)
                    if (any(e in full.lower() for e in EXTS_IMG)
                            and not any(s in full.lower() for s in SKIP_IMG)
                            and len(full) > 25):
                        image_set.add(full)
            # srcset — take largest (last) candidate
            srcset = await img.get_attribute("srcset")
            if srcset:
                parts = [p.strip().split(" ")[0] for p in srcset.split(",") if p.strip()]
                if parts:
                    full = urljoin(base_url, parts[-1])
                    if (any(e in full.lower() for e in EXTS_IMG)
                            and not any(s in full.lower() for s in SKIP_IMG)):
                        image_set.add(full)

        # 2. og:image + twitter:image
        for sel in ['meta[property="og:image"]', 'meta[name="twitter:image"]',
                    'meta[property="og:image:url"]']:
            try:
                for og in await pg.evaluate(
                    f"() => Array.from(document.querySelectorAll('{sel}')).map(m=>m.content)"
                ):
                    if og and og.strip() and not any(s in og.lower() for s in SKIP_IMG):
                        image_set.add(og.strip())
            except Exception:
                pass

        # 3. CSS background-image on hero/banner/slider/section
        bg_urls = await pg.evaluate("""() => {
            const hits = [];
            const sels = [
                '[style*="background-image"]','[class*="hero"]','[class*="banner"]',
                '[class*="slider"]','[class*="slide"]','[class*="bg-image"]',
                '[class*="cover"]','section','header'
            ];
            sels.forEach(sel => {
                try {
                    document.querySelectorAll(sel).forEach(el => {
                        const s = el.style.backgroundImage ||
                                  getComputedStyle(el).backgroundImage || '';
                        const m = s.match(/url\\(["']?([^"')]+)["']?\\)/);
                        if (m && m[1]) hits.push(m[1]);
                    });
                } catch(e) {}
            });
            return [...new Set(hits)];
        }""")
        for bg in bg_urls:
            if bg:
                full = urljoin(base_url, bg.strip())
                if (any(e in full.lower() for e in EXTS_IMG)
                        and not any(s in full.lower() for s in SKIP_IMG)):
                    image_set.add(full)
    except Exception:
        pass  # Never crash on image errors


def generate_fallback(metric, text_pool):
    metric_keywords = {
        "Coaching Credentials":   ["qualified teacher", "certified", "credentials", "faculty", "expertise"],
        "Student Wellbeing":      ["wellbeing", "pastoral", "counselor", "mental health", "welfare"],
        "Academic Integration":   ["curriculum", "academic", "igcse", "a-level", "ib", "programme"],
        "Competitive Pathway":    ["university", "destination", "results", "examination", "achievement"],
        "Facilities & Resources": ["facilities", "campus", "library", "laboratory", "pool", "gymnasium"],
        "Ongoing Accountability": ["progress", "tracking", "monitoring", "feedback", "report"],
    }
    kws     = metric_keywords.get(metric, [])
    pool    = [p for p in text_pool if not is_junk(p)]
    matched = [p for p in pool if any(k in p.lower() for k in kws)]
    raw     = " ".join(matched[:2]) if matched else (" ".join(pool[:2]) if pool else "")
    return clean_to_sentences(raw, 2)


# ── QUOTE SCRAPER

def _word_count(text):
    return len(text.split())


def scrape_quote_from_soup(soup):
    SKIP_PHRASES = [
        "cookie", "menu", "nav", "©", "privacy", "terms",
        "subscribe", "sign up", "click", "read more", "javascript",
        "khda", "rated", "inspection", "watch the video", "watch video",
        "listen to", "testimonial", "share", "follow us", "contact us",
        "apply now", "find out more", "learn more", "get in touch",
        "download", "register", "book a", "visit us",
        # Legal / UI junk
        "means the child", "parents/guardians", "dialog window",
        "escape will cancel", "site you are about to visit",
        "no longer exists", "managed independently",
    ]
    selectors = [
        "blockquote", "q",
        "[class*='quote']", "[class*='pullquote']",
        "[class*='callout']",
        "[class*='hero'] p", "[class*='banner'] p",
        "[class*='mission'] p", "[class*='vision'] p",
        "figcaption",
    ]
    candidates = []
    for sel in selectors:
        for el in soup.select(sel):
            text = re.sub(r'\s+', ' ', el.get_text()).strip()
            text = text.strip('\u201c\u201d\u2018\u2019"\'')
            wc   = _word_count(text)
            if wc < 8 or wc > 35:
                continue
            if any(x in text.lower() for x in SKIP_PHRASES):
                continue
            if is_junk(text):
                continue
            # Must end with real sentence punctuation
            if not re.search(r'[.!?]$', text):
                continue
            candidates.append(text)
    if not candidates:
        return ""
    candidates.sort(key=lambda t: _word_count(t))
    return candidates[0]


# ── AI QUOTE — uses OpenAI (no Anthropic key needed)

def generate_ai_quote(school_name, school_type, city, about_text):
    key = _get_openai_key()
    if not _check_key(key, "OPENAI_API_KEY"):
        return f"Excellence, integrity, and curiosity — the pillars of {school_name}."
    prompt = (
        f"Write ONE short inspirational quote (1 sentence, 10–20 words) "
        f"that reflects the philosophy of {school_name}, a {school_type} in {city}. "
        f"Context: {about_text[:300]}. "
        f"Sound like the organisation's mission statement. "
        f"Return ONLY the quote text — no quotation marks, no attribution, no explanation."
    )
    payload = json.dumps({
        "model":       "gpt-4o",
        "max_tokens":  60,
        "temperature": 0.7,
        "messages":    [{"role": "user", "content": prompt}],
    }).encode("utf-8")
    req = urllib.request.Request(
        "https://api.openai.com/v1/chat/completions",
        data=payload,
        headers={
            "Content-Type":  "application/json",
            "Authorization": f"Bearer {key}",
        },
        method="POST",
    )
    try:
        with urllib.request.urlopen(req, timeout=15) as resp:
            data  = json.loads(resp.read())
            quote = data["choices"][0]["message"]["content"].strip().strip('"\'')
            words = quote.split()
            if len(words) > 25:
                quote = " ".join(words[:25])
            print(f"  ✓ AI quote generated for {school_name}")
            return quote
    except Exception as e:
        print(f"  ⚠ AI quote failed: {e}")
    return f"Excellence, integrity, and curiosity — the pillars of {school_name}."


# ── OpenAI gap-fill ───────────────────────────────────────────────────────────

def openai_fill_missing_fields(results: dict) -> dict:
    """
    After scraping, call OpenAI gpt-4o to fill any field that is still
    empty, 'N/A', or a placeholder.  Only missing fields are sent;
    already-scraped values are NEVER overwritten.
    """
    key = _get_openai_key()
    if not _check_key(key, "OPENAI_API_KEY"):
        return results

    entity_type = results.get("Type", "Independent School")
    is_school   = any(w in entity_type.lower() for w in ["school", "academy", "college", "education"])

    FILL_FIELDS = {
        "Founded":    "Year this organisation was founded (just the 4-digit year). If unknown reply N/A.",
        "Ages":       ("Student age range (e.g. '3–18'). If unknown reply N/A." if is_school
                       else "Age range of members/clients served. If not applicable reply N/A."),
        "Students":   ("Approximate enrolled students (e.g. '1200'). If unknown reply N/A." if is_school
                       else "Approximate number of members/clients/visitors annually. If unknown reply N/A."),
        "Ratio":      "Staff-to-student or staff-to-client ratio. If unknown reply N/A.",
        "Fees":       "Annual fee or membership cost with currency. If unknown reply 'See website'.",
        "About":      f"2 sentences max (≤40 words) describing {results.get('Name','this organisation')}'s identity and mission.",
        "Philosophy": f"2 sentences max (≤40 words) on {results.get('Name','this organisation')}'s approach or ethos.",
        "Outcomes":   f"2 sentences max (≤40 words) on what {results.get('Name','this organisation')} achieves for its members.",
        "Admissions": f"2 sentences max (≤40 words) on how to join or enrol at {results.get('Name','this organisation')}.",
        "Tagline":    f"One compelling tagline (≤20 words) for {results.get('Name','this organisation')}.",
    }

    PERF_FIELDS = {
        "Coaching Credentials":   f"2 UNIQUE sentences (≤35 words) on staff qualifications or expertise at {results.get('Name','')}.",
        "Student Wellbeing":      f"2 UNIQUE sentences (≤35 words) on how {results.get('Name','')} supports member/student wellbeing.",
        "Academic Integration":   f"2 UNIQUE sentences (≤35 words) on the programmes or curriculum at {results.get('Name','')}.",
        "Competitive Pathway":    f"2 UNIQUE sentences (≤35 words) on achievements, results or pathways at {results.get('Name','')}.",
        "Facilities & Resources": f"2 UNIQUE sentences (≤35 words) on facilities, venues or resources at {results.get('Name','')}.",
        "Ongoing Accountability": f"2 UNIQUE sentences (≤35 words) on how {results.get('Name','')} tracks progress or quality.",
    }

    # Build context from whatever was scraped successfully
    ctx_lines = []
    for k in ["Name", "Type", "City", "URL", "Tagline", "About", "Philosophy",
               "Outcomes", "Admissions", "Founded", "Ages", "Students", "Ratio", "Fees"]:
        v = results.get(k, "")
        if v:
            ctx_lines.append(f"{k}: {v}")
    for pk, pv in results.get("Performance", {}).items():
        if pv:
            ctx_lines.append(f"{pk}: {pv[:200]}")
    context = "\n".join(ctx_lines) or f"URL: {results.get('URL', '')}"

    # Decide which fields still need filling
    missing_main = {
        f: p for f, p in FILL_FIELDS.items()
        if not results.get(f) or results[f] in ("N/A", "See website", "Rolling admissions", "Year-round", "")
    }

    def _perf_needs_fill(val: str, name: str) -> bool:
        if not val or val.strip() in ("N/A", "", "N/a"):
            return True
        val_clean = re.sub(r'\s+', ' ', val).strip()
        if len(val_clean.split()) < 8:
            return True
        irrelevant = [
            # Generic junk
            "seven emirates","fishing village","tourist visa","arabian gulf",
            "no longer exists","site you are about to visit",
            # London-specific non-relevant content
            "uniform shop","alleycatz","school uniform",
            "some of the data collected by this provider",
            "for the purposes of personalization",
            "measuring advertising effectiveness",
            "music by jake heggie","libretto by terrence",
            "ola ince director","libby watson set",
            "cookie","privacy policy","gdpr",
            "course 1 (20","course 2 (27","violin, viola, cello",
        ]
        vl = val_clean.lower()
        return any(phrase in vl for phrase in irrelevant)

    missing_perf = {
        f: p for f, p in PERF_FIELDS.items()
        if _perf_needs_fill(results.get("Performance", {}).get(f, ""), f)
    }

    all_missing = {**missing_main, **missing_perf}
    if not all_missing:
        print("  ✓ All fields complete — OpenAI fill not needed.")
        return results
    print(f"  → OpenAI filling {len(all_missing)} missing field(s): {', '.join(all_missing.keys())}")

    # Build one compact prompt
    field_instructions = "\n".join(f'  "{k}": {v}' for k, v in all_missing.items())
    prompt = f"""You are a London education data analyst with knowledge of UK independent schools, conservatoires, and tutoring organisations.
Use the known data below AND your own knowledge to fill the missing fields accurately.

KNOWN DATA:
{context}

Fill ONLY these fields (reply with a JSON object, keys exactly as shown):
{field_instructions}

Rules:
- Use your knowledge of this London/UK institution to fill factual fields (Founded, Ages, Students, Fees in £).
- Fees: use £ and per year or per term. For UK schools typical range £15,000–£50,000 per year.
- Keep paragraph fields SHORT: max 2 sentences, ≤40 words total per field.
- Each performance field MUST describe a DIFFERENT aspect — no repeated sentences across fields.
- Each field must sound distinct — different vocabulary, different facts, different angle.
- Do NOT add commentary, markdown fences, or extra keys.
- Reply with valid JSON only."""

    payload = json.dumps({
        "model": "gpt-4o",
        "max_tokens": 2000,
        "temperature": 0.3,
        "messages": [{"role": "user", "content": prompt}],
    }).encode("utf-8")

    req = urllib.request.Request(
        "https://api.openai.com/v1/chat/completions",
        data=payload,
        headers={
            "Content-Type":  "application/json",
            "Authorization": f"Bearer {key}",
        },
        method="POST",
    )

    try:
        with urllib.request.urlopen(req, timeout=30) as resp:
            data  = json.loads(resp.read())
            raw   = data["choices"][0]["message"]["content"].strip()
            # Strip markdown fences if present
            raw   = re.sub(r"^```(?:json)?\s*", "", raw, flags=re.M)
            raw   = re.sub(r"\s*```$",           "", raw, flags=re.M).strip()
            filled = json.loads(raw)

            filled_keys = []
            for fkey, val in filled.items():
                if not val or val in ("N/A", "See website"):
                    continue
                if fkey in FILL_FIELDS:
                    if not results.get(fkey) or results[fkey] in (
                            "N/A", "See website", "Rolling admissions", "Year-round", ""):
                        results[fkey] = str(val).strip()
                        filled_keys.append(fkey)
                elif fkey in PERF_FIELDS:
                    # Overwrite if missing OR if it was junk
                    if _perf_needs_fill(results["Performance"].get(fkey, ""), fkey):
                        results["Performance"][fkey] = str(val).strip()
                        filled_keys.append(fkey)

            if filled_keys:
                print(f"  ✓ OpenAI filled: {', '.join(filled_keys)}")
            else:
                print("  ✓ OpenAI: nothing new to fill.")

    except json.JSONDecodeError as e:
        print(f"  ⚠ OpenAI fill JSON parse error: {e}")
    except Exception as e:
        print(f"  ⚠ OpenAI fill failed: {e}")

    return results


def generate_wp_blocks(r):
    school_name  = r.get("Name", "")
    description  = r.get("Tagline", "")
    age          = r.get("Ages", "")
    students     = r.get("Students", "")
    ratio        = r.get("Ratio", "")
    founded      = r.get("Founded", "")
    school_type  = r.get("Type", "")
    city         = r.get("City", "")
    annual_fee   = r.get("Fees", "")
    about        = r.get("About", "")
    philosophy   = r.get("Philosophy", "")
    outcomes     = r.get("Outcomes", "")
    quote        = r.get("Quote", "")
    website_url  = r.get("URL", "")
    admissions   = r.get("Admissions", "")
    images       = r.get("Images", [])
    perf         = r.get("Performance", {})
    enquiry_open = r.get("EnquiryOpen", "Year-round")
    app_deadline = r.get("AppDeadline", "Rolling admissions")

    website_display = website_url.replace("https://", "").replace("http://", "").rstrip("/")
    city_slug       = city.lower().replace(", ", "-").replace(" ", "-").replace(",", "")
    city_short      = city.split(",")[0].strip()

    img0 = images[0] if len(images) > 0 else ""
    img1 = images[1] if len(images) > 1 else img0
    img2 = images[2] if len(images) > 2 else img0
    img3 = images[3] if len(images) > 3 else img0
    img4 = images[4] if len(images) > 4 else img0

    coaching       = perf.get("Coaching Credentials", "")
    wellbeing      = perf.get("Student Wellbeing", "")
    academic       = perf.get("Academic Integration", "")
    competitive    = perf.get("Competitive Pathway", "")
    facilities     = perf.get("Facilities & Resources", "")
    accountability = perf.get("Ongoing Accountability", "")

    wp = f"""<!-- wp:image {{"id":440,"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img0}" alt="" class="wp-image-440"/></figure>
<!-- /wp:image -->

<!-- wp:paragraph -->
<p><a href="elite-home.html"><br>Elite</a>&#8250; <a href="elite-city-{city_slug}.html">{city_short}</a>&#8250; <a href="elite-program-academic.html">Elite Academic Programs</a></p>
<!-- /wp:paragraph -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Kidrovia Elite \u2014 Listed</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Elite Academic Programs</h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":1}} -->
<h1 class="wp-block-heading"><em>{school_name}</em></h1>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{description}</p>
<!-- /wp:paragraph -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{age}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ages</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{students}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Students</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{ratio}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ratio</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{founded}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Founded</h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column {{"width":"66.66%"}} -->
<div class="wp-block-column" style="flex-basis:66.66%"><!-- wp:heading -->
<h2 class="wp-block-heading">About <em>{school_name}</em></h2>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{about}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column {{"width":"33.33%"}} -->
<div class="wp-block-column" style="flex-basis:33.33%"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Institution Details</h5>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Type</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ages</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Students</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ratio </h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Founded</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">City</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Annual fee</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{school_type}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{age}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{students}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{ratio}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{founded}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{city}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{annual_fee}</h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Contact &amp; Enquiry</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading"><a href="{website_url}" target="_blank" rel="noreferrer noopener">{website_display} &#8594;</a></h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">Quotes</h5>
<!-- /wp:heading -->

<!-- wp:paragraph {{"align":"center"}} -->
<p class="has-text-align-center">&ldquo;{quote}&rdquo;</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">{school_name}</h5>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Philosophy</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">How they&nbsp;<em>teach</em></h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{philosophy}<br><br><br></p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Outcomes</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Where students&nbsp;<em>go</em></h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{outcomes}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":441,"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img1}" alt="" class="wp-image-441"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column {{"width":"100%"}} -->
<div class="wp-block-column" style="flex-basis:100%"><!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":449,"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img2}" alt="" class="wp-image-449"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":450,"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img3}" alt="" class="wp-image-450"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column --></div>
<!-- /wp:columns --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":451,"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img4}" alt="" class="wp-image-451"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":452,"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img0}" alt="" class="wp-image-452"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column --></div>
<!-- /wp:columns --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":4}} -->
<h4 class="wp-block-heading">Our Assessment</h4>
<!-- /wp:heading -->

<!-- wp:heading -->
<h2 class="wp-block-heading"><strong>How {school_name} performs</strong></h2>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Coaching Credentials</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{coaching}<br></p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Student Wellbeing</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{wellbeing}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Academic Integration</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{academic}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Competitive Pathway</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{competitive}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Facilities &amp; Resources</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{facilities}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Ongoing Accountability</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{accountability}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading -->
<h2 class="wp-block-heading">Admissions &amp;<br><em>How to Apply</em></h2>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{admissions}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Enquiries Open</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{enquiry_open}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Application Deadline</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{app_deadline}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Annual Fee</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{annual_fee}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Location</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{city}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Website</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p><a href="{website_url}" target="_blank" rel="noreferrer noopener">{website_display}</a></p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:paragraph {{"align":"center"}} -->
<p class="has-text-align-center">&ldquo;{quote}&rdquo;</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">{school_name}</h5>
<!-- /wp:heading -->
"""
    return wp


async def extract_school_data(url):
    async with async_playwright() as p:
        import platform
        headless = os.environ.get("HEADLESS","true" if platform.system()=="Linux" else "false").lower()=="true"
        browser  = await p.chromium.launch(headless=headless, slow_mo=0 if headless else 200)
        context  = await browser.new_context(viewport={"width": 1280, "height": 800})
        page     = await context.new_page()

        results = {
            "Name": "", "Tagline": "", "Founded": "",
            "City": "",
            "Ages": "", "Students": "", "Ratio": "", "Fees": "",
            "Type": "Independent School",
            "About": "", "Philosophy": "", "Outcomes": "",
            "Admissions": "", "Quote": "",
            "EnquiryOpen": "Year-round",
            "AppDeadline": "Rolling admissions",
            "Performance": {}, "URL": url, "Images": [],
        }

        global_text_pool = []

        FALLBACKS = {
            "Founded":  "",
            "Ages":     "",
            "Students": "",
            "Ratio":    "N/A",
            "Fees":     "See website",
        }

        # Fee patterns — £ / GBP / per term (annualised ×3)
        fee_patterns = [
            r'£\s*[\d,]+(?:\.\d{2})?\s*per\s*(?:term|year|annum|session)',
            r'£\s*[\d,]+(?:\.\d{2})?\s*(?:p\.a\.|pa\b)',
            r'fee[s]?\s*(?:of|is|are|:)?\s*£\s*[\d,]+',
            r'tuition\s*(?:fee)?s?\s*(?:of|is|:)?\s*£\s*[\d,]+',
            r'school\s+fee[s]?\s*[:\-]?\s*£\s*[\d,]+',
            r'charge[s]?\s*(?:of|:)?\s*£\s*[\d,]+',
            r'£\s*[\d,]+\s*per\s*term',
            r'£\s*[\d,]+',
        ]

        # FIX #3: Ratio — added 1:X and X:1 formats common in UAE
        ratio_patterns = [
            r'(\d+\s*:\s*\d+)\s*(?:student[- ]to[- ](?:faculty|teacher)|teacher[- ]to[- ]student|ratio)',
            r'ratio\s*(?:of\s*)?(\d+\s*:\s*\d+)',
            r'(\d+\s*:\s*\d+)\s*ratio',
            r'1\s*(?:teacher|member of staff|coach)\s+(?:to|per|:)\s+(\d+)\s*(?:students?|pupils?|learners?)',
            r'(\d+)\s*(?:students?|pupils?|learners?)\s+(?:per|to)\s+(?:every\s+)?(?:1\s+)?(?:teacher|tutor|coach)',
        ]

        # Age patterns — UK school system (Years, Forms, Prep)
        age_patterns = [
            r'students?\s+aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'ages?\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'from\s+age\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'boys?\s+aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'girls?\s+aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'(\d+)\s*(?:to|[\u2013\-])\s*(\d+)\s*years?\s*(?:old)?',
            r'year\s+(\d+)\s*(?:to|[\u2013\-])\s*year\s+(\d+)',
            r'year\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'(?:from|between)\s+(?:year\s+)?(\d+)\s*(?:to|[\u2013\-])\s*(?:year\s+)?(\d+)',
        ]

        # Student patterns — UK-specific
        student_patterns = [
            r'(?:school\s+)?(?:pupil\s+)?roll\s+of\s+([\d,]+)',
            r'on\s+roll[:\s]+([\d,]+)',
            r'total\s+(?:of\s+)?([\d,]+)\s+(?:pupils|students)',
            r'has\s+(?:over\s+|approximately\s+|around\s+)?([\d,]+)\s+(?:pupils|students|boys|girls)',
            r'(?:approximately|around|about|some|over|nearly|almost)\s+([\d,]+)\s+(?:pupils|students|boys|girls|children)',
            r'([\d,]+)\s+(?:pupils|students|boys|girls|children)\b',
            r'school\s+of\s+([\d,]+)',
            r'serves?\s+(?:over\s+|around\s+)?([\d,]+)\s+(?:students?|pupils?)',
            r'enrol(?:l(?:ing|ed|ment))?\s+(?:of\s+)?(?:approximately\s+)?([\d,]+)',
        ]

        print(f"Connecting to: {url}...")

        loaded = await smart_goto(page, url)
        if not loaded:
            print(f"  ✗ Could not load {url}, skipping.")
            await browser.close()
            return None

        try:
            await handle_cookies_automatically(page)

            # Name — prefer og:site_name / og:title over <title> which can return "Home"
            og_site  = await page.evaluate("() => { const m = document.querySelector('meta[property=\"og:site_name\"]'); return m ? m.content : ''; }")
            og_title = await page.evaluate("() => { const m = document.querySelector('meta[property=\"og:title\"]'); return m ? m.content : ''; }")
            raw_title = await page.title()

            REJECT_NAMES = {
                "home","welcome","homepage","index","main","","welcome to",
                "home: welcome to king's college school wimbledon",
            }
            REJECT_STARTS = ("welcome to ", "home -", "home |", "home: ")
            REJECT_LONG_PHRASES = ["london's top pre","ᐅ wetherby"]

            KNOWN_NAMES_LON = {
                "stpaulsschool.org.uk":    "St Paul's School",
                "spgs.org":                "St Paul's Girls' School",
                "westminster.org.uk":      "Westminster School",
                "harrowschool.org.uk":     "Harrow School",
                "thomas-s.co.uk":          "Thomas's London Day Schools",
                "wetherbyschool.co.uk":    "Wetherby School",
                "gardenhouseschool.co.uk": "Garden House School",
                "kcs.org.uk":              "King's College School Wimbledon",
                "latymer-upper.org":       "Latymer Upper School",
                "godolphinandlatymer.com": "Godolphin and Latymer School",
                "nlcs.org.uk":             "North London Collegiate School",
                "bespoketuition.com":      "Bespoke Tuition",
                "keystonetutors.com":      "Keystone Tutors",
                "theprofs.co.uk":          "The Profs Tutors",
                "tutors-international.com":"Tutors International",
                "nyo.org.uk":              "National Youth Orchestra",
                "royalballetschool.org.uk":"The Royal Ballet School",
                "menuhinschool.co.uk":     "Yehudi Menuhin School",
                "gsmd.ac.uk":              "Guildhall School of Music & Drama",
                "purcell-school.org":      "The Purcell School",
                "ram.ac.uk":               "Royal Academy of Music",
                "millfieldschool.com":     "Millfield School",
                "wellingtoncollege.org.uk":"Wellington College",
            }
            domain = url.split("/")[2].replace("www.", "")
            known = next((v for k, v in KNOWN_NAMES_LON.items() if k in domain), None)

            def clean_name(candidate: str) -> str:
                parts = re.split(r'\s*[|—]\s*', candidate)
                parts = [p.strip() for p in parts if p.strip()]
                GENERIC = {"home","welcome","index","main","page","site","portal","homepage",""}
                n = parts[0] if parts else candidate.strip()
                if n.lower() in GENERIC and len(parts) > 1:
                    n = parts[-1].strip()
                for prefix in ("welcome to ",):
                    if n.lower().startswith(prefix):
                        n = n[len(prefix):].strip()
                return n

            for candidate in [og_site, og_title, raw_title]:
                name = clean_name(candidate)
                if (name
                        and name.lower() not in REJECT_NAMES
                        and not any(name.lower().startswith(p) for p in REJECT_STARTS)
                        and not any(bad in name.lower() for bad in REJECT_LONG_PHRASES)
                        and len(name.split()) <= 8):
                    results["Name"] = name
                    break
            # Override with known name if scraped name is generic/junk
            if known and (not results["Name"] or results["Name"].lower() in REJECT_NAMES):
                results["Name"] = known
            if not results["Name"]:
                results["Name"] = known or clean_name(raw_title)
            body_text       = await page.inner_text("body")

            # JS-heavy sites: scroll to trigger rendering
            if len(body_text.strip()) < 300:
                print("  ⚠ Page body too short — scrolling to trigger JS render…")
                try:
                    await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
                    await asyncio.sleep(3)
                    await page.evaluate("window.scrollTo(0, 0)")
                    await asyncio.sleep(2)
                    body_text = await page.inner_text("body")
                    print(f"  Body after scroll: {len(body_text)} chars")
                except Exception:
                    try:
                        body_text = await page.inner_text("body")
                    except Exception:
                        pass

            results["City"] = detect_city(url, body_text)

            # Skip garbage/parked/domain-sale sites immediately
            if is_garbage_site(results["Name"], body_text):
                print(f"  ✗ Garbage/parked site detected — skipping {url}")
                await browser.close()
                return None

            def extract(pattern):
                m = re.search(pattern, body_text, re.IGNORECASE)
                return m.group(1).strip() if m else ""

            current_year = datetime.now().year

            # ── BUG FIX B: Founded — penalise pre-1900 years and sentences
            #   that are clearly about a UK/parent school, not this campus
            def extract_founded_from_text(text, existing_candidates=None):
                STRONG_KWS = [
                    "founded in", "established in", "was founded", "founding year",
                    "founded by", "foundress", "charter", "incorporated in",
                    "opened in", "opened its doors", "since", "est.",
                ]
                WEAK_KWS  = ["founded", "established", "foundation", "history", "began"]
                SKIP_WORDS = ["copyright", "©", "reserved", "updated", "revised",
                              "class of", "alumni", "graduate", "batch of"]
                # Sentences that refer to a PARENT / FOREIGN campus — not this school
                FOREIGN_CTX = [
                    "in the uk", "in england", "in derbyshire", "in scotland",
                    "in wales", "in ireland", "parent school", "sister school",
                    "original school", "home school",
                    "repton school in", "repton uk",
                    "in derbyshire, uk", "in london, uk",
                ]
                cands = existing_candidates if existing_candidates is not None else []
                clean = re.sub(r'\s+', ' ', text.lower())
                clean = re.sub(r'(copyright|©).*?\d{4}', '', clean)
                for sent in re.split(r'[.!?\n]', clean):
                    if any(w in sent for w in SKIP_WORDS):
                        continue
                    has_strong = any(k in sent for k in STRONG_KWS)
                    has_weak   = any(k in sent for k in WEAK_KWS)
                    if not (has_strong or has_weak):
                        continue
                    is_foreign = any(ctx in sent for ctx in FOREIGN_CTX)
                    for y in re.findall(r'\b(1[6-9]\d{2}|20[012]\d)\b', sent):
                        year = int(y)
                        if not (1600 <= year <= current_year - 1):
                            continue
                        score = 3 if has_strong else 1
                        # Pre-1900: almost certainly a UK/historic parent school
                        if year < 1900:
                            score -= 4
                        # Sentence explicitly about a foreign/parent school
                        if is_foreign:
                            score -= 3
                        # Too recent — probably not a founding year
                        if year >= current_year - 2:
                            score -= 3
                        cands.append((score, year))
                return cands

            founded_candidates = extract_founded_from_text(body_text)
            if founded_candidates:
                founded_candidates.sort(key=lambda x: (-x[0], x[1]))
                results["Founded"] = str(founded_candidates[0][1])

            # Collect ALL valid age ranges from page, pick the WIDEST (most complete)
            age_candidates = []
            for pat in age_patterns:
                for m in re.finditer(pat, body_text, re.I):
                    try:
                        g = m.groups()
                        if len(g) >= 2 and g[0] and g[1]:
                            lo, hi = int(g[0]), int(g[1])
                            if lo < hi and lo >= 2 and hi <= 25:
                                age_candidates.append((lo, hi))
                        elif len(g) == 1 and g[0]:
                            hi = int(g[0])
                            if 10 <= hi <= 25:
                                age_candidates.append((3, hi))
                    except Exception:
                        pass
            if age_candidates:
                # Pick the widest range (highest hi - lo) — gives full school span
                best = max(age_candidates, key=lambda x: x[1] - x[0])
                results["Ages"] = f"{best[0]}\u2013{best[1]}"

            if not results["Ages"]:
                AGE_MAP = {
                    "nursery": (3, 4), "reception": (4, 5), "pre-prep": (4, 8),
                    "prep school": (7, 13), "junior school": (7, 11),
                    "year 3": (7, 8), "year 4": (8, 9), "year 5": (9, 10),
                    "year 6": (10, 11), "year 7": (11, 12), "year 8": (12, 13),
                    "year 9": (13, 14), "year 10": (14, 15), "year 11": (15, 16),
                    "year 12": (16, 17), "year 13": (17, 18),
                    "third form": (13, 14), "fourth form": (14, 15),
                    "fifth form": (15, 16), "lower sixth": (16, 17),
                    "upper sixth": (17, 18), "sixth form": (16, 18),
                    "a-level": (16, 18), "a level": (16, 18), "gcse": (14, 16),
                    "all-through": (4, 18),
                }
                tl  = body_text.lower()
                fy  = [v for k, v in AGE_MAP.items() if k in tl]
                results["Ages"] = f"{min(x[0] for x in fy)}\u2013{max(x[1] for x in fy)}" if fy else ""

            # Students — UK patterns, reject percentage-adjacent numbers
            UK_STUDENT_PATS = [
                r'(?:pupil\s+)?roll\s+of\s+([\d,]+)',
                r'on\s+roll[:\s]+([\d,]+)',
                r'total\s+(?:of\s+)?([\d,]+)\s+(?:pupils|students)',
                r'has\s+(?:over\s+|around\s+)?([\d,]+)\s+(?:pupils|students|boys|girls)',
                r'(?:approximately|around|about|some|over|nearly)\s+([\d,]+)\s+(?:pupils|students|boys|girls|children)',
                r'([\d,]+)\s+(?:pupils|students|boys|girls|children)\b',
                r'school\s+of\s+([\d,]+)\b',
                r'serves?\s+(?:over\s+)?([\d,]+)\s+(?:students?|pupils?)',
                r'more\s+than\s+([\d,]+)\s+(?:pupils|students|children)',
            ]
            for pat in UK_STUDENT_PATS:
                for m in re.finditer(pat, body_text, re.I):
                    num_str = re.sub(r'[\s,]', '', m.group(1))
                    try:
                        num = int(num_str)
                        if not (50 <= num <= 10000):
                            continue
                        # Reject if % nearby (SPGS 88.7% matching as 88 students)
                        ctx = body_text[max(0, m.start()-8):m.end()+8]
                        if '%' in ctx or '.' in m.group(1):
                            continue
                        results["Students"] = num_str + ("+" if "+" in m.group(0) else "")
                        break
                    except ValueError:
                        pass
                if results["Students"]:
                    break

            for pat in ratio_patterns:
                m = re.search(pat, body_text, re.I)
                if m:
                    results["Ratio"] = m.group(1).replace(" ", "")
                    break

            # Fee — validate: reject if looks like a year
            for pat in fee_patterns:
                m = re.search(pat, body_text, re.I)
                if m:
                    fee_str = m.group(0).strip()
                    nums = re.findall(r'\d+', fee_str.replace(',',''))
                    if nums and 500 <= int(nums[0]) <= 100000 and not (2000 <= int(nums[0]) <= 2100):
                        # Annualise per-term fees
                        term_m = re.search(r'£\s*([\d,]+).*?per\s*term', fee_str, re.I)
                        if term_m:
                            raw = int(term_m.group(1).replace(',',''))
                            fee_str = f'£{raw*3:,} per year (£{term_m.group(1)} per term × 3)'
                        results["Fees"] = fee_str
                        break

            # Type detection — London UK school system
            tl = body_text.lower()
            url_l = url.lower()
            if "royalballetschool.org.uk" in url_l:
                results["Type"] = "Specialist Dance School"
            elif "menuhinschool.co.uk" in url_l or "purcell-school.org" in url_l:
                results["Type"] = "Specialist Music School"
            elif "gsmd.ac.uk" in url_l or "ram.ac.uk" in url_l or "guildhall" in tl:
                results["Type"] = "Conservatoire"
            elif "nyo.org.uk" in url_l:
                results["Type"] = "National Youth Orchestra"
            elif any(d in url_l for d in ["bespoketuition","keystonetutors","theprofs","tutors-international"]):
                results["Type"] = "Tutoring & Education Consultancy"
            elif "all-girls" in tl or "girls' school" in tl or "girls school" in tl:
                results["Type"] = "Independent All-Girls School"
            elif "all-boys" in tl or "boys' school" in tl or "boys school" in tl or ("boys aged" in tl and "girls" not in tl):
                results["Type"] = "Independent Boys' School"
            elif "ib world" in tl or "international baccalaureate" in tl:
                results["Type"] = "IB World School"
            elif "boarding" in tl and "day" in tl:
                results["Type"] = "Independent Boarding & Day School"
            elif "boarding" in tl:
                results["Type"] = "Independent Boarding School"
            elif "prep school" in tl or "preparatory school" in tl:
                results["Type"] = "Independent Prep School"
            elif "pre-prep" in tl or "pre prep" in tl:
                results["Type"] = "Independent Pre-Prep School"
            elif "day school" in tl or "day pupils" in tl:
                results["Type"] = "Independent Day School"
            elif "conservatoire" in tl or "conservatory" in tl:
                results["Type"] = "Conservatoire"
            elif "ballet" in tl or "dance school" in tl:
                results["Type"] = "Specialist Dance School"
            elif "music school" in tl or "music college" in tl:
                results["Type"] = "Specialist Music School"
            elif "performing arts" in tl:
                results["Type"] = "Specialist Performing Arts School"
            elif "tutor" in tl and ("agency" in tl or "company" in tl or "consultancy" in tl):
                results["Type"] = "Tutoring & Education Consultancy"
            else:
                results["Type"] = "Independent School"

            soup_home = BeautifulSoup(await page.content(), "html.parser")
            for attr in [{"name": "description"}, {"property": "og:description"}]:
                tag = soup_home.find("meta", attr)
                if tag and tag.get("content"):
                    results["Tagline"] = tag["content"][:200]
                    break
            if not results["Tagline"]:
                results["Tagline"] = extract(r"([A-Z][^.]{30,150}\.)")

            results["Quote"] = scrape_quote_from_soup(soup_home)

            # Images — use module-level harvest_images (scrolls + collects all sources)
            image_set = set()
            await harvest_images(page, url, image_set)
            results["Images"] = [img for img in image_set if img][:10]

        except Exception as e:
            print(f"Home page error: {e}")
            await browser.close()
            return None

        # ── SUBPAGE CRAWL 
        soup  = BeautifulSoup(await page.content(), "html.parser")
        links = soup.find_all("a", href=True)
        queue     = []
        seen_urls = {url.rstrip("/")}

        targets = {
            "about": [
                "about", "history", "welcome", "mission", "who-we-are",
                "our-story", "overview", "vision", "values", "ethos",
            ],
            "outcomes": [
                "results", "destination", "university", "leavers", "beyond",
                "sixth-form", "exam", "college", "achievements", "khda",
                "inspection", "academic-results",
            ],
            "fees": [
                "fees", "tuition", "financial", "cost", "charges",
                "fee-structure", "school-fees", "annual-fees", "pricing",
            ],
            "admission": [
                "admissions", "apply", "entry", "register", "enroll",
                "13-entry", "16-entry", "how-to-apply", "application",
                "join-us", "registration", "enrolment", "open-day",
            ],
            "facilities": [
                "facilities", "campus", "co-curriculum", "sport", "arts",
                "library", "infrastructure", "resources", "activities",
                "co-curricular", "extracurricular",
            ],
        }

        for link in links:
            href, text = link["href"], link.get_text().lower().strip()
            full_url   = urljoin(url, href).split("#")[0].rstrip("/")
            if full_url not in seen_urls and url.split("/")[2] in full_url:
                if any(k in text or k in href.lower() for cat in targets.values() for k in cat):
                    queue.append((full_url, text))
                    seen_urls.add(full_url)

        # Global sentence-level dedup — no sentence may appear in more than one field
        used_sentences: set = set()

        def _register(text: str):
            """Mark all sentences in text as used."""
            if not text:
                return
            for s in re.split(r'(?<=[.!?])\s+', text.strip()):
                key = re.sub(r'\s+', ' ', s.strip().lower())
                if key and len(key) > 20:   # only register meaningful sentences
                    used_sentences.add(key)

        def dedup_text(text: str) -> str:
            """Return only sentences not yet seen, and register new ones."""
            if not text:
                return text
            parts = re.split(r'(?<=[.!?])\s+', text.strip())
            fresh = []
            for s in parts:
                key = re.sub(r'\s+', ' ', s.strip().lower())
                if key and key not in used_sentences and not is_junk(s):
                    fresh.append(s.strip())
                    used_sentences.add(key)
            return " ".join(fresh)

        def assign_field(field_name: str, text: str, max_sent: int = 2):
            """Assign to results[field_name] only if empty, after deduping."""
            if results.get(field_name):
                return
            cleaned = dedup_text(clean_to_sentences(text, max_sent))
            if cleaned:
                results[field_name] = cleaned

        # Register ALL homepage content so subpages can't repeat any of it
        for _field in ["About", "Tagline", "Philosophy", "Outcomes", "Admissions", "Quote"]:
            _register(results.get(_field, ""))
        for _perf_val in results.get("Performance", {}).values():
            _register(_perf_val)

        # used_paras_global — prevents same raw paragraph appearing in multiple metrics
        used_paras_global: set = set()
        # Pre-register any performance values already scraped from homepage
        for _pv in results.get("Performance", {}).values():
            if _pv:
                used_paras_global.add(re.sub(r'\s+', ' ', _pv.strip().lower())[:200])

        for target_url, link_text in queue[:15]:
            try:
                await page.goto(target_url, wait_until="domcontentloaded", timeout=30000)
                await asyncio.sleep(2)
                main          = page.locator("main").first
                content_scope = main if await main.is_visible() else page
                paragraphs    = await content_scope.locator("p").all_text_contents()
                clean_paras   = [
                    t.strip() for t in paragraphs
                    if len(t.strip()) >= 80
                    and not any(x in t.lower() for x in ["cookie", "privacy", "menu", "navigation", "footer"])
                    and not is_junk(t)   # ← remove error messages, UI strings, boilerplate
                ]
                global_text_pool.extend(clean_paras)
                full_text = " ".join(clean_paras)
                page_text = await page.inner_text("body")
                sub_soup  = BeautifulSoup(await page.content(), "html.parser")

                # Harvest images from every subpage
                await harvest_images(page, url, image_set)
                results["Images"] = [img for img in image_set if img][:10]

                if any(k in link_text or k in target_url for k in targets["about"]):
                    # Filter out paragraphs that start with form/navigation content
                    clean_about = [p for p in clean_paras if not is_junk(p)
                                   and not p.lower().startswith(("please fill", "please note",
                                   "the admissions team", "fill the", "click here", "select"))]
                    assign_field("About", " ".join(clean_about), 2)
                    teach_kws  = ["curriculum", "teaching", "learning", "approach",
                                  "education", "ethos", "method", "ib", "igcse", "philosophy"]
                    teach_para = [p for p in clean_paras if any(k in p.lower() for k in teach_kws)]
                    assign_field("Philosophy", " ".join(teach_para), 2)
                    if not results["Quote"]:
                        results["Quote"] = scrape_quote_from_soup(sub_soup)
                    if not results["Founded"]:
                        sub_cands = extract_founded_from_text(page_text)
                        if sub_cands:
                            sub_cands.sort(key=lambda x: (-x[0], x[1]))
                            results["Founded"] = str(sub_cands[0][1])
                    if not results["City"]:
                        results["City"] = detect_city(url, page_text)

                # ── Students + Ratio: search EVERY subpage
                if not results["Students"]:
                    for pat in student_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            num_str = m.group(1).replace(",", "")
                            try:
                                num = int(num_str)
                                # Sanity: school enrollment between 50 and 10,000
                                if 50 <= num <= 10000:
                                    results["Students"] = num_str + ("+" if "+" in m.group(0) else "")
                                    break
                            except ValueError:
                                pass
                if not results["Ratio"]:
                    for pat in ratio_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            results["Ratio"] = m.group(1).replace(" ", "")
                            break

                if any(k in link_text or k in target_url for k in targets["outcomes"]):
                    assign_field("Outcomes", full_text, 2)
                    if not results["Quote"]:
                        results["Quote"] = scrape_quote_from_soup(sub_soup)

                if any(k in link_text or k in target_url for k in targets["fees"]):
                    for pat in fee_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            results["Fees"] = m.group(0).strip()
                            break
                    aed_fee = re.search(
                        r'(?:AED|Dhs?)\s*([\d,]+)(?:\.\d{2})?\s*(?:per\s*(?:term|year|annum))?',
                        page_text, re.I
                    )
                    if aed_fee and not results["Fees"]:
                        results["Fees"] = f"AED {aed_fee.group(1)}"
                    term_fee = re.search(r'[£\u00a3]([\d,]+)(?:\.\d{2})?\s*per\s*term', page_text, re.I)
                    if term_fee and not results["Fees"]:
                        results["Fees"] = f"£{term_fee.group(1)} per term"

                if any(k in link_text or k in target_url for k in targets["admission"]):
                    adm_kws  = ["apply", "application", "admission", "register",
                                "assessment", "entry", "enroll", "enrolment", "registration"]
                    filtered = [p for p in clean_paras if any(k in p.lower() for k in adm_kws)]
                    assign_field("Admissions", " ".join(filtered), 2)
                    dl = re.search(
                        r'(?:deadline|closes?|closing date)\s*[:\-]?\s*([^\n.]{10,60})',
                        page_text, re.I
                    )
                    if dl and results["AppDeadline"].startswith("Rolling"):
                        val = dl.group(1).strip()[:80]
                        has_month = re.search(
                            r'\b(january|february|march|april|may|june|july|august|'
                            r'september|october|november|december|jan|feb|mar|apr|'
                            r'jun|jul|aug|sep|oct|nov|dec)\b', val, re.I)
                        has_date = re.search(r'\b\d{1,2}[\/\-]\d{1,2}', val)
                        if (has_month or has_date) and not is_junk(val):
                            results["AppDeadline"] = val
                    if not results["Ages"]:
                        for pat in age_patterns:
                            m = re.search(pat, page_text, re.I)
                            if m:
                                try:
                                    g = m.groups()
                                    if len(g) >= 2 and g[0] and g[1]:
                                        lo, hi = int(g[0]), int(g[1])
                                        if lo < hi and lo >= 2 and hi <= 25:
                                            results["Ages"] = f"{lo}\u2013{hi}"
                                except Exception:
                                    pass
                                if results["Ages"]:
                                    break

                if any(k in link_text or k in target_url for k in targets["facilities"]):
                    perf_kws = {
                        "Coaching Credentials":   ["qualified teacher", "experienced staff",
                                                   "certified", "credentials", "housemaster",
                                                   "instructor", "faculty", "expertise"],
                        "Student Wellbeing":      ["wellbeing", "pastoral", "counselor",
                                                   "mental health", "welfare", "house system",
                                                   "nurturing", "support programme"],
                        "Academic Integration":   ["curriculum", "igcse", "a-level", "ib",
                                                   "programme of study", "academic programme",
                                                   "learning outcomes", "subject"],
                        "Competitive Pathway":    ["university", "destination", "oxford",
                                                   "cambridge", "russell group", "results",
                                                   "examination", "achievement", "ranking"],
                        "Facilities & Resources": ["facilities", "campus", "library",
                                                   "laboratory", "studio", "theatre",
                                                   "swimming pool", "gymnasium", "court"],
                        "Ongoing Accountability": ["progress", "tracking", "monitoring",
                                                   "feedback", "report", "review",
                                                   "assessment cycle", "parent portal"],
                    }
                    for key, kws in perf_kws.items():
                        if not results["Performance"].get(key):
                            matched = [
                                p for p in clean_paras
                                if any(k in p.lower() for k in kws)
                                and p not in used_paras_global   # global dedup
                                and not is_junk(p)
                            ]
                            if matched:
                                chosen = matched[:1]
                                val = dedup_text(clean_to_sentences(" ".join(chosen), 2))
                                if val:
                                    results["Performance"][key] = val
                                    used_paras_global.update(chosen)
                    if not results["Quote"]:
                        results["Quote"] = scrape_quote_from_soup(sub_soup)

            except Exception as e:
                print(f"  Skipping {target_url}: {e}")
                continue

        # ── APPLY FALLBACKS 
        results["Images"] = list(image_set)[:10]  # refresh after subpage harvesting
        for field, fallback in FALLBACKS.items():
            if not results.get(field):
                results[field] = fallback

        if not results["City"]:
            results["City"] = "London, UK"

        # ── FALLBACK PERFORMANCE
        for metric in [
            "Coaching Credentials", "Student Wellbeing", "Academic Integration",
            "Competitive Pathway", "Facilities & Resources", "Ongoing Accountability",
        ]:
            if not results["Performance"].get(metric):
                results["Performance"][metric] = generate_fallback(metric, global_text_pool)

        # ── QUOTE: AI fallback
        if not results["Quote"]:
            print(f"  No quote found on site — generating AI quote…")
            results["Quote"] = generate_ai_quote(
                results["Name"], results["Type"], results["City"], results["About"]
            )

        await browser.close()

        # ── FIX #3: OpenAI gap-fill — runs after scraping, fills only missing/N/A fields
        print(f"\n  Running OpenAI gap-fill for missing fields…")
        results = openai_fill_missing_fields(results)

        # ── POST-FILL DEDUP: ensure AI-filled performance fields don't repeat each other
        seen_perf = set()
        for metric in ["Coaching Credentials","Student Wellbeing","Academic Integration",
                       "Competitive Pathway","Facilities & Resources","Ongoing Accountability"]:
            val = results["Performance"].get(metric, "")
            if not val or val == "N/A":
                continue
            key = re.sub(r'\s+', ' ', val.strip().lower())[:120]
            if key in seen_perf:
                results["Performance"][metric] = ""  # will be re-filled by AI next run
            else:
                seen_perf.add(key)

        # ── POST-PROCESSING SANITIZATION
        PERF_METRICS = ["Coaching Credentials","Student Wellbeing","Academic Integration",
                        "Competitive Pathway","Facilities & Resources","Ongoing Accountability"]
        for field in ["Name","Tagline","Founded","City","Ages","Students","Ratio",
                      "Fees","Type","About","Philosophy","Outcomes","Admissions","Quote"]:
            if results.get(field):
                results[field] = re.sub(r'\s+', ' ', str(results[field])).strip()
        for field in ["About","Philosophy","Outcomes","Admissions"]:
            if results.get(field) and len(results[field].split()) > 50:
                results[field] = clean_to_sentences(results[field], 2)
        for metric in PERF_METRICS:
            val = results["Performance"].get(metric,"")
            if val and len(val.split()) > 50:
                results["Performance"][metric] = clean_to_sentences(val, 2)
        SEP        = "—" * 50
        city_short = results["City"].split(",")[0]
        print(f"\n{SEP}")
        print(f"Elite › {city_short} › {results['Name']}")
        print(SEP)
        print(
            f"\n{results['Ages'] or 'N/A':<14}{results['Students'] or 'N/A':<14}"
            f"{results['Ratio'] or 'N/A':<14}{results['Founded'] or 'N/A'}"
        )
        print(f"{'Ages':<14}{'Students':<14}{'Ratio':<14}Founded\n")
        print(f"Images Found: {len(results['Images'])}")
        for i, img in enumerate(results["Images"], 1):
            print(f"  {i}. {img}")
        print(f"\nAbout {results['Name']}\n{results['About']}")
        print(f"\nInstitution Details")
        print(f"  Type       : {results['Type']}")
        print(f"  Ages       : {results['Ages'] or 'N/A'}")
        print(f"  Students   : {results['Students'] or 'N/A'}")
        print(f"  Ratio      : {results['Ratio'] or 'N/A'}")
        print(f"  Founded    : {results['Founded'] or 'N/A'}")
        print(f"  City       : {results['City']}")
        print(f"  Annual Fee : {results['Fees']}")
        print(f"\nQuotes\n  \"{results['Quote']}\"")
        print(f"\nHow they teach\n{results['Philosophy']}")
        print(f"\nOutcomes: Where students go\n{results['Outcomes']}")
        print(f"\nAdmissions & How to Apply")
        print(f"  Enquiries Open : {results['EnquiryOpen']}")
        print(f"  App Deadline   : {results['AppDeadline']}")
        print(f"  Process        : {results['Admissions']}")
        print(f"\nHow {results['Name']} Performs")
        for k, v in results["Performance"].items():
            print(f"\n  {k}:\n  {v or 'N/A'}")
        print(f"\n  Location : {results['City']}")
        print(f"  Website  : {results['URL']}")
        print(SEP)

        # ── SAVE 
        wp_code     = generate_wp_blocks(results)
        school_slug = re.sub(r"[^a-z0-9]+", "_", results["Name"].lower())[:35].strip("_")
        out_wp      = f"{school_slug}_wp_blocks.txt"
        out_json    = f"{school_slug}_data.json"

        with open(out_wp, "w", encoding="utf-8") as f:
            f.write(wp_code)

        save_data = {k: v for k, v in results.items() if k != "Images"}
        save_data["ImageCount"] = len(results.get("Images", []))
        save_data["ImageURLs"]  = results.get("Images", [])
        with open(out_json, "w", encoding="utf-8") as f:
            json.dump(save_data, f, ensure_ascii=False, indent=2)

        print(f"\n WP blocks  → {out_wp}")
        print(f"School JSON → {out_json}")
        return results


# ── URLS

school_urls = [
    "https://www.stpaulsschool.org.uk/",
    "https://spgs.org",
    "https://westminster.org.uk",
    "https://www.harrowschool.org.uk/",
    "https://thomas-s.co.uk",
    "https://wetherbyschool.co.uk",
    "https://gardenhouseschool.co.uk/",
    "https://kcs.org.uk",
    "https://latymer-upper.org",
    "https://godolphinandlatymer.com",
    "https://nlcs.org.uk",
    "https://bespoketuition.com",
    "https://keystonetutors.com",
    "https://theprofs.co.uk",
    "https://tutors-international.com",
    "https://nyo.org.uk",
    "https://royalballetschool.org.uk",
    "https://www.menuhinschool.co.uk/",
    "https://gsmd.ac.uk",
    "https://purcell-school.org",
    "https://ram.ac.uk",
    "https://millfieldschool.com",
    "https://wellingtoncollege.org.uk",
]

async def run_multiple_schools():
    all_results = []
    for url in school_urls:
        print(f"\n{'=' * 60}")
        print(f" Scraping: {url}")
        print(f"{'=' * 60}")
        try:
            result = await extract_school_data(url)
            if result:
                all_results.append(result)
            await asyncio.sleep(3)
        except Exception as e:
            print(f" Failed: {url} → {e}")

    master_file = "all_schools_data_london.json"
    with open(master_file, "w", encoding="utf-8") as f:
        json.dump(all_results, f, ensure_ascii=False, indent=2)
    print(f"\n{'=' * 60}")
    print(f"All done! {len(all_results)} schools scraped.")
    print(f"Master JSON → {master_file}")
    print(f"{'=' * 60}")
    return all_results


if __name__ == "__main__":
    if sys.platform == "win32":
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    try:
        loop = asyncio.get_running_loop()
        import nest_asyncio
        nest_asyncio.apply()
        import concurrent.futures
        with concurrent.futures.ThreadPoolExecutor() as pool:
            future   = pool.submit(asyncio.run, run_multiple_schools())
            all_data = future.result()
    except RuntimeError:
        asyncio.run(run_multiple_schools())
# Out:
# ============================================================
#  Scraping: https://www.stpaulsschool.org.uk/
# ============================================================
# Connecting to: https://www.stpaulsschool.org.uk/...
#   ⚠ networkidle failed (Error), retrying…
#   ✗ Failed: Page.goto: net::ERR_CONNECTION_TIMED_OUT at https://www.stpaulsschool.org.uk/
# Call log:
#   - navigating to "https://www.stpaulsschool.org.uk/", waiting until "domcontentloaded"
#
#   ✗ Could not load https://www.stpaulsschool.org.uk/, skipping.
#
# ============================================================
#  Scraping: https://spgs.org
# ============================================================
# Connecting to: https://spgs.org...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Fees, Outcomes
#
# ——————————————————————————————————————————————————
# Elite › Hammersmith › St Paul's Girls' School
# ——————————————————————————————————————————————————
#
# 14–18         88            N/A           1904
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://spgs.org/wp-content/uploads/2026/04/Wreath-visual.png
#   2. https://spgs.org/wp-content/uploads/2026/04/Untitled-design-1-513x480.jpg
#   3. https://spgs.org/wp-content/uploads/2023/09/The-Week-Independent-Schools-Guide-2023-216x300.png
#   4. https://spgs.org/wp-content/uploads/2020/12/school-history-24-494x480.jpg
#   5. https://spgs.org/wp-content/uploads/2023/01/SPGS-2022-10-12-1933.jpg
#   6. https://spgs.org/wp-content/uploads/2021/04/First-students-1-1920x1390.jpg
#   7. https://spgs.org/wp-content/uploads/2021/04/Queen-mother-second-visit-1985-2-640x441.jpg
#   8. https://spgs.org/wp-content/uploads/2020/12/school-history-05.jpg
#   9. https://spgs.org/wp-content/uploads/2021/04/School-closure-1920x2110.jpg
#   10. https://spgs.org/wp-content/uploads/2021/04/Gala-evening-Aldwych-2-1-1920x2095.jpg
#
# About St Paul's Girls' School
# St Paul’s Girls’ School is an extraordinary school, offering a classical yet forward-thinking education. A shared love of academic discovery is enriched by broad co-curricular provision, the kindest and most individual of pastoral care and a commitment to partnerships and service to others.
#
# Institution Details
#   Type       : Independent All-Girls School
#   Ages       : 14–18
#   Students   : 88
#   Ratio      : N/A
#   Founded    : 1904
#   City       : Hammersmith, London, UK
#   Annual Fee : £27,831 per year
#
# Quotes
#   "Bringing the best of St Paul’s to the world, and the best of the world to St Paul’s."
#
# How they teach
# We throw ourselves into anything with enthusiasm, dedication and passion. We expect to be busy; getting involved and participating in as many activities as we can.
#
# Outcomes: Where students go
# St Paul's Girls' School consistently achieves outstanding academic results, with students gaining entry to top universities worldwide. The school fosters well-rounded individuals prepared for diverse future challenges.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : While all our students share a love of learning and a keen academic curiosity, there is no typical Paulina. Every year, students join us from a range of primary and prep schools.
#
# How St Paul's Girls' School Performs
#
#   Coaching Credentials:
#   St Paul’s Girls’ School is an extraordinary school, offering a classical yet forward-thinking education. A shared love of academic discovery is enriched by broad co-curricular provision, the kindest and most individual of pastoral care and a commitment to partnerships and service to others.
#
#   Student Wellbeing:
#   N/A
#
#   Academic Integration:
#   N/A
#
#   Competitive Pathway:
#   We throw ourselves into anything with enthusiasm, dedication and passion. We expect to be busy; getting involved and participating in as many activities as we can.
#
#   Facilities & Resources:
#   Mrs Munro’s development project was launched. The development included refurbishments and improvements to many parts of school, including a common room for the Senior School, a new geography wing, language laboratory, art studios, another dining room, an improved staff room and a new swimming pool.
#
#   Ongoing Accountability:
#   Since St Paul’s first opened its doors in 1904, the school has provided an ambitious, progressive education for generations of talented young women. At all stages throughout its history, the school has combined the best elements of a classical education with a commitment to innovation and a forward-looking approach.
#
#   Location : Hammersmith, London, UK
#   Website  : https://spgs.org
# ——————————————————————————————————————————————————
#
#  WP blocks  → st_paul_s_girls_school_wp_blocks.txt
# School JSON → st_paul_s_girls_school_data.json
#
# ============================================================
#  Scraping: https://westminster.org.uk
# ============================================================
# Connecting to: https://westminster.org.uk...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Fees
#   ✓ OpenAI filled: Ratio, Fees
#
# ——————————————————————————————————————————————————
# Elite › Westminster › Westminster School
# ——————————————————————————————————————————————————
#
# 4–18          2028          1:9           1868
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.westminster.org.uk/wp-content/uploads/2025/11/GWL_5704_gwl-scaled.jpg
#   2. https://www.westminster.org.uk/wp-content/uploads/2024/11/PSX_20241009_152344-v2-scaled.jpg
#   3. https://www.westminster.org.uk/wp-content/uploads/2025/05/Revised-Library-02-1.png
#   4. https://www.westminster.org.uk/wp-content/uploads/2025/05/classroom.png
#   5. https://www.westminster.org.uk/wp-content/uploads/2024/10/Dabrowski.png
#   6. https://www.westminster.org.uk/wp-content/uploads/2025/01/27NovemberAccidentalDeathofanAnarchistimages1105-scaled.jpg
#   7. https://www.westminster.org.uk/wp-content/uploads/2024/01/11-Tufton-Street-image-collage.png
#   8. https://www.westminster.org.uk/wp-content/uploads/2025/05/Revised-Hall.png
#   9. https://www.westminster.org.uk/wp-content/uploads/2024/10/Arif.png
#   10. https://www.westminster.org.uk/wp-content/uploads/2025/12/PSX_20251204_114454-scaled.jpg
#
# About Westminster School
# Each year Westminster School offers places to boys and girls at both 13+ and 16+ entry, while Westminster Under School admits pupils at the 4+, 7+, 8+ and 11+ entry points. Information regarding 4+, 7+, 8+ and 11+ entry can be found on the Under School’s website.
#
# Institution Details
#   Type       : Independent Boarding & Day School
#   Ages       : 4–18
#   Students   : 2028
#   Ratio      : 1:9
#   Founded    : 1868
#   City       : Westminster, London, UK
#   Annual Fee : £45,000 per year
#
# Quotes
#   "Online applications can be submitted from 1 October."
#
# How they teach
# The pages in this section of the website provide details specifically relating to 13+ and 16+ entry to Westminster School, outlining the application process, registration timelines, eligibility criteria, fees and opportunities for assistance with fees (Scholarships and Bursaries), to ensure that prospective pupils and their parents have everything needed to be able to apply for a place at the School. To support the application process, we have a dedicated and experienced admissions team, who are available to answer any questions applicants may have and who make applying to the School easy and undaunting.
#
# Outcomes: Where students go
# Following the two-and-a-half-day inspection by a nine-strong team of inspectors in February 2024, it has been found, very importantly, that Westminster School is fully compliant in all areas of school life. Moreover, the inspectors have clearly recognised what we are privileged to see and to be part of every single day: a truly outstanding school with a breadth of pupil excellence that demonstrates significant strength.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Admissions and Awards, Bursary, SEND) may be downloaded from the Policies and Reports page. Online applications can be submitted from two years before the proposed date of entry.
#
# How Westminster School Performs
#
#   Coaching Credentials:
#   Following the two-and-a-half-day inspection by a nine-strong team of inspectors in February 2024, it has been found, very importantly, that Westminster School is fully compliant in all areas of school life. Moreover, the inspectors have clearly recognised what we are privileged to see and to be part of every single day: a truly outstanding school with a breadth of pupil excellence that demonstrates significant strength.
#
#   Student Wellbeing:
#   Westminster was inspected using the ISI’s new Framework 23, which is much changed from previous formats. There are no longer overall judgements or grades, and instead more nuanced evaluations, with findings given using supporting evidence in five key areas: leadership, management and governance; quality of education, training and recreation; physical and mental health and emotional wellbeing; social and economic education and contribution to society; safeguarding.
#
#   Academic Integration:
#   Significant strength – pupil initiative, personal development and contribution to society Westminster was inspected using the ISI’s new Framework 23, which is much changed from previous formats. There are no longer overall judgements or grades, and instead more nuanced evaluations, with findings given using supporting evidence in five key areas: leadership, management and governance; quality of education, training and recreation; physical and mental health and emotional wellbeing; social and economic education and contribution to society; safeguarding.
#
#   Competitive Pathway:
#   The new reporting framework is less focused on teaching, learning and results than previously, instead concentrating more on school culture, promotion of wellbeing and pupil voice, planning and delivery of RSHE, and consideration given to the challenges pupils face in today’s world. During the inspection, the ISI team took a detailed look at our day-to-day operations, hearing from pupils, governors, management, teachers, and administrative and support staff, touring the site including boarding facilities, assessing lessons, surveying pupils, parents and staff, scrutinising and discussing samples of pupils’ work, and examining school records.
#
#   Facilities & Resources:
#   During the inspection, the ISI team took a detailed look at our day-to-day operations, hearing from pupils, governors, management, teachers, and administrative and support staff, touring the site including boarding facilities, assessing lessons, surveying pupils, parents and staff, scrutinising and discussing samples of pupils’ work, and examining school records. The results of their work can be read in the full report, but I’m very happy to highlight the below.
#
#   Ongoing Accountability:
#   I am pleased to report that Westminster is indeed one of only a handful of schools which has so far been found to have one of these ‘significant strengths’. The inspectors report: “The intellectual challenge of lessons provokes high levels of interest in pupils and consequently they organise a wide spectrum of initiatives organised by pupils.
#
#   Location : Westminster, London, UK
#   Website  : https://westminster.org.uk
# ——————————————————————————————————————————————————
#
#  WP blocks  → westminster_school_wp_blocks.txt
# School JSON → westminster_school_data.json
#
# ============================================================
#  Scraping: https://www.harrowschool.org.uk/
# ============================================================
# Connecting to: https://www.harrowschool.org.uk/...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Fees
#   ✓ OpenAI filled: Ratio, Fees
#
# ——————————————————————————————————————————————————
# Elite › Harrow › Harrow School
# ——————————————————————————————————————————————————
#
# 13–18         100           1:9           2025
# Ages          Students      Ratio         Founded
#
# Images Found: 0
#
# About Harrow School
# A boarding school for boys aged 13-18, founded in 1572 under a Royal Charter granted by Elizabeth I. Through the boarding model, we are able to use the whole day productively: the timings of games and lessons change with the seasons and the available light; groups and societies meet after prep and at weekends; and extra subjects find room around the timetable.
#
# Institution Details
#   Type       : Independent Boys' School
#   Ages       : 13–18
#   Students   : 100
#   Ratio      : 1:9
#   Founded    : 2025
#   City       : Harrow, London, UK
#   Annual Fee : £45,000 per year
#
# Quotes
#   "A scholarship is an award of excellence in academic study, the arts or sport. A scholarship award serves primarily as an acknowledgment of a boy’s achievement."
#
# How they teach
# Harrow’s 324 acres comprise six conservation areas, a registered park, a nine-hole golf course and even a working farm. Coupled with its buildings of special architectural and historic interest, the School has the quality of a village.
#
# Outcomes: Where students go
# Nearly one in three grades achieved the highest A* distinction, with over 65% awarded at either A* or A. Impressively, almost 90% of all results this year were at A*-B, reflecting outstanding achievement across the board.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Please note that the tour involves steep hills and steps and is therefore not suitable for prams, pushchairs, very young children or people who are not physically robust. Please contact the Admissions team should you have any specific access requirements.
#
# How Harrow School Performs
#
#   Student Wellbeing:
#   Participation in sport helps Harrovians to grow, learn and enjoy themselves, while nurturing their personal, physical and intellectual skills, and developing healthy minds and bodies. For growing boys, the value of being outside, expending energy and getting stuck into House and School teams is well recognised: through sport, they learn about teamwork and leadership, and how to conduct themselves with integrity.
#
#   Competitive Pathway:
#   The upper-end of our extensive team list (numbering over 20 in each of our major sports) regularly win county and national championships, and our elite sportsmen have an impressive record of achievement at the highest levels internationally; some go on to enjoy professional careers.
#
#   Facilities & Resources:
#   Surrounded by acres of sports fields, astroturf pitches, a golf course, a swimming pool, a sports centre, and numerous tennis, rackets and fives courts, we offer a breadth of sporting opportunities to match every interest and ability. Many boys play several sports, and unique occasions like the annual Cricket match versus Eton provide memorable highlights in the calendar.
#
#   Academic Integration:
#   All Shells are involved in House Drama productions, undertake a creative project, and have timetabled lessons in Music and Art. Exhibitions in the Art Schools are extremely well attended and boys' work adorns many of our communal spaces.
#
#   Coaching Credentials:
#   Professor Payne is a Reader and Royal Society University Research Fellow in the Faculty of Engineering at Imperial College London, and the Director of the Advanced Photoelectron Spectroscopy Laboratory. He is also strongly engaged with the Engineering and Physical Sciences Research Council (EPSRC), having been a member of the Strategic Advisory Team for Research Infrastructure since 2013, and more recently appointed to the EPSRC Big Ideas Advisory Group in 2017.
#
#   Ongoing Accountability:
#   Humility asks us to recognise that one's self is a work in progress and that struggling with one's weaknesses is essential to growth. Humility increases our awareness that talent and achievement alone, however impressive, are not sufficient to succeed as a human being – and that none of us is at the centre of the universe.
#
#   Location : Harrow, London, UK
#   Website  : https://www.harrowschool.org.uk/
# ——————————————————————————————————————————————————
#
#  WP blocks  → harrow_school_wp_blocks.txt
# School JSON → harrow_school_data.json
#
# ============================================================
#  Scraping: https://thomas-s.co.uk
# ============================================================
# Connecting to: https://thomas-s.co.uk...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Fees
#   ✓ OpenAI: nothing new to fill.
#
# ——————————————————————————————————————————————————
# Elite › London › Thomas's
# ——————————————————————————————————————————————————
#
# 11–13         2000          N/A           2005
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://cdn.thomas-s.co.uk/wp-content/uploads/2020/06/17192759/1981-480x630.jpg
#   2. https://cdn.thomas-s.co.uk/wp-content/uploads/2026/02/Campus-480x445.jpg
#   3. https://cdn.thomas-s.co.uk/wp-content/uploads/2026/02/Digital-Skills-analogue-childhood-480x227.jpg
#   4. https://cdn.thomas-s.co.uk/wp-content/uploads/2025/11/Reception-Y1-and-Y2.Our-Journey-Begins.jpg
#   5. https://cdn.thomas-s.co.uk/wp-content/uploads/2025/11/Y10-Our-Journey-Deepens.jpg
#   6. https://cdn.thomas-s.co.uk/wp-content/uploads/2020/08/17192651/David-Joanna-480x452.jpg
#   7. https://cdn.thomas-s.co.uk/wp-content/uploads/2022/11/B_Back-to-school_2021_497x643.jpg
#   8. https://cdn.thomas-s.co.uk/wp-content/uploads/2020/08/17192651/David-Joanna.jpg
#   9. https://cdn.thomas-s.co.uk/wp-content/uploads/2020/06/17192759/1981.jpg
#   10. https://cdn.thomas-s.co.uk/wp-content/uploads/2025/01/Richmond-Building-Facade-2-1-768x574.jpg
#
# About Thomas's
# We are a family-run group of co-educational independent schools, which seek to give an exceptional start in life to more than 2,000 children between the ages of two and eighteen. Every member of the Thomas’s community is expected to live by our most important school rule, which is simply to ‘Be kind’.
#
# Institution Details
#   Type       : Independent Boarding & Day School
#   Ages       : 11–13
#   Students   : 2000
#   Ratio      : N/A
#   Founded    : 2005
#   City       : London, UK
#   Annual Fee : See website
#
# Quotes
#   "Thomas’s London Day Schools is a family-run group of co-educational independent schools, which seek to give an exceptional start in life to more than 2,000 children between the ages of two and eighteen."
#
# How they teach
# Our vision is that every pupil at Thomas’s develops core values and a strong sense of social responsibility; inner strength, outward assurance and positive physical and mental health; academic success and a wide range of skills, interests and attributes; curiosity about the world and a love of learning. The overall goal of a Thomas’s education is to equip all of our pupils with optimism and readiness for the future, to become contributors to society, and to flourish as successful, conscientious and caring citizens of the world.
#
# Outcomes: Where students go
# On occasions these dates may vary a little for some year groups. Please check the school calendar or ask your class teacher for exact details.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : At Thomas’s we know that choosing the right school for your child is one of the most important decisions you can make, and our Admissions teams would be pleased to guide you through this sometimes bewildering process. Thomas’s Prep SchoolsOur schools offer a number of tours each term for parents.
#
# How Thomas's Performs
#
#   Coaching Credentials:
#   We are a family-run group of co-educational independent schools, which seek to give an exceptional start in life to more than 2,000 children between the ages of two and eighteen. Every member of the Thomas’s community is expected to live by our most important school rule, which is simply to ‘Be kind’.
#
#   Student Wellbeing:
#   Our vision is that every pupil at Thomas’s develops core values and a strong sense of social responsibility; inner strength, outward assurance and positive physical and mental health; academic success and a wide range of skills, interests and attributes; curiosity about the world and a love of learning. Every student develops core values and a strong sense of social responsibility; inner strength, outward assurance and positive physical and mental health; academic success and a wide range of skills, interests and attributes; curiosity about the world and a love of learning.
#
#   Academic Integration:
#   My parents’ founding vision developed in opposition to the prevailing educational landscape in London which they found to be more traditional, more narrow and less creative than they would have chosen for their own children. Over time, this vision crystallised around three core elements: a strong set of values, with kindness at the heart; a breadth of curriculum, full of art, dance, drama, music and sport; and academic excellence, achieved because of this approach to childhood, not in spite of it.
#
#   Competitive Pathway:
#   My family has been involved in educational leadership for more than fifty years, ever since my mother started a playgroup to keep me busy and interested when I was two years old. Over time, the playgroup became a kindergarten, the kindergarten became a prep school, the prep school became four prep schools and, with the opening of our senior school, we now offer a Thomas’s education from kindergarten to university.
#
#   Facilities & Resources:
#   The facilities of Thomas’s Kensington were further improved through the purchase of the buildings of the Prue Leith School of Cookery in St Albans Grove W8, then converted into a purpose built theatre, a gym and a dining room. Thomas’s acquired an educational site in Putney Vale, which became the home of the first Thomas’s Senior School for four years.
#
#   Ongoing Accountability:
#   N/A
#
#   Location : London, UK
#   Website  : https://thomas-s.co.uk
# ——————————————————————————————————————————————————
#
#  WP blocks  → thomas_s_wp_blocks.txt
# School JSON → thomas_s_data.json
#
# ============================================================
#  Scraping: https://wetherbyschool.co.uk
# ============================================================
# Connecting to: https://wetherbyschool.co.uk...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Wetherby School
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Facilities & Resources
#   ✓ OpenAI filled: Ratio, Facilities & Resources
#
# ——————————————————————————————————————————————————
# Elite › London › Wetherby School
# ——————————————————————————————————————————————————
#
# 4–13          90            1:6           1951
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/2024-06/wellbeing-respect_copy.png
#   2. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/styles/ins_card/public/2024-05/8444_gstaad_life_5.jpg.jpeg?itok=gaz8Om-w
#   3. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/styles/ins_card/public/2024-08/60103_wetherby-kensington-3-july-2024-navy-studios-school-photography-121of127_1.jpg.jpeg?itok=tYiPqABx
#   4. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/2024-06/rocket-future_0.png
#   5. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/2024-06/exam.png
#   6. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/styles/text_and_image_auto_height/public/2024-11/60070_wetherby_prep_school-81_1.jpg.jpeg?itok=0eLhtlWf
#   7. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/styles/ins_card/public/2025-11/79929_Wetherby_Notting_Hill-151.jpg.jpeg?itok=9DTJIMP9
#   8. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/styles/ins_banner_mobile/public/2025-11/79933_Wetherby_Notting_Hill-137.jpg.jpeg?itok=QSDdHW89
#   9. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/styles/ins_banner_mobile/public/2024-10/60017_wetherby-kensington-3-july-2024-navy-studios-school-photography-005of127.jpg.jpeg?itok=F2KmVqs6
#   10. https://d24d7vsshzrslo.cloudfront.net/sites/school3/files/2024-06/wellbeing-respect.png
#
# About Wetherby School
# The extensive list of inspiring success stories of former students embodies our vision for children to dream big and pursue their unique talents and personal growth. Wetherby provides an environment that promotes educational excellence and tradition through a forward-thinking, holistic curriculum, which meets the needs of individual pupils.
#
# Institution Details
#   Type       : Independent Boarding & Day School
#   Ages       : 4–13
#   Students   : 90
#   Ratio      : 1:6
#   Founded    : 1951
#   City       : London, UK
#   Annual Fee : £11,540 per term
#
# Quotes
#   "Empowering young minds to dream fearlessly, nurture talents, and achieve excellence through a tradition of innovation."
#
# How they teach
# With our individualised learning strategies, each boy learns to challenge himself, pursue high standards, and seek accomplishment in all he does so that his talents shine through.
#
# Outcomes: Where students go
# Through outstanding tuition and preparation at the pre-prep level, we empower students to excel in the 7+ and 8+ examinations and give their best in all they do. As a result, they advance smoothly into the best prep schools in the UK, including King’s College Junior School Wimbledon, St Paul’s Juniors and Westminster Under.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Thank you for your interest in Wetherby School. Places at our schools are in high demand, so we kindly encourage you to complete the registration of interest form below as soon as possible to begin the admissions process.
#
# How Wetherby School Performs
#
#   Student Wellbeing:
#   Building on the success of our Prep School, this natural expansion allows us to support boys from the very start of their school journey, nurturing their growth, curiosity, and confidence. Like our highly regarded Pre-Preps in Notting Hill and Kensington, the Pre Prep at Wetherby Marylebone will provide the strongest foundation for success in the 7+ and 8+ assessments.
#
#   Academic Integration:
#   As part of the Inspired Group, we are proud to offer a world-class education with the support and excellence of a global network, while maintaining the warm, vibrant, and close-knit community that makes Wetherby Marylebone so special.
#
#   Competitive Pathway:
#   At Wetherby Marylebone, we aim to bring out the very best in every boy, preparing them not just for the next step, but for a lifetime of achievement.
#
#   Coaching Credentials:
#   The extensive list of inspiring success stories of former students embodies our vision for children to dream big and pursue their unique talents and personal growth. Wetherby provides an environment that promotes educational excellence and tradition through a forward-thinking, holistic curriculum, which meets the needs of individual pupils.
#
#   Facilities & Resources:
#   Wetherby School boasts state-of-the-art classrooms equipped with interactive technology and a dedicated science lab. The school also features a spacious sports hall and a well-stocked library to support diverse learning experiences.
#
#   Ongoing Accountability:
#   Our firm commitment is to make sure each boy has a tailored path to help him progress efficiently and leave Wetherby with the practical and intellectual skill set and proactive mindset necessary to thrive in academics and well beyond, having built a solid foundation for success in all future endeavours. Through outstanding tuition and preparation at the pre-prep level, we empower students to excel in the 7+ and 8+ examinations and give their best in all they do.
#
#   Location : London, UK
#   Website  : https://wetherbyschool.co.uk
# ——————————————————————————————————————————————————
#
#  WP blocks  → wetherby_school_wp_blocks.txt
# School JSON → wetherby_school_data.json
#
# ============================================================
#  Scraping: https://gardenhouseschool.co.uk/
# ============================================================
# Connecting to: https://gardenhouseschool.co.uk/...
#   ⚠ Page body too short — scrolling to trigger JS render…
#   Body after scroll: 4 chars
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 4 missing field(s): Ages, Students, Ratio, Tagline
#   ✓ OpenAI filled: Ages, Students, Ratio, Tagline
#
# ——————————————————————————————————————————————————
# Elite › London › Garden House School - Home
# ——————————————————————————————————————————————————
#
# 3–11          250           1:10          1950
# Ages          Students      Ratio         Founded
#
# Images Found: 1
#   1. https://cdn.prod.website-files.com/5dd271d0b88d00b43451a289/5f883946cf44d39cab224e66_GHS Oct 2020--poster-00001.jpg
#
# About Garden House School - Home
# Garden House is a caring family-run school guided by the Principals, Mr Christian Warland and Mrs Sophie Strafford, both of whom attended Garden House School as children. Mr Warland was Head of Garden House Boys’ School for fourteen years.
#
# Institution Details
#   Type       : Independent School
#   Ages       : 3–11
#   Students   : 250
#   Ratio      : 1:10
#   Founded    : 1950
#   City       : London, UK
#   Annual Fee : £400 per term
#
# Quotes
#   "Bursaries and scholarships are available for boys joining at 8+."
#
# How they teach
# Boys may also join Garden House School at 8 years' of age. We encourage you to apply at least a year before your son is eligible to join.
#
# Outcomes: Where students go
# Garden House School is an independent day school for girls and boys located in the Royal Borough of Kensington and Chelsea in London, England.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : To claim the funding parents or guardians need to apply to The Royal Borough of Kensington and Chelsea by completing the Parental Declaration Form for Free Entitlement (please see below).
#
# How Garden House School - Home Performs
#
#   Coaching Credentials:
#   Garden House is a caring family-run school guided by the Principals, Mr Christian Warland and Mrs Sophie Strafford, both of whom attended Garden House School as children. Mr Warland was Head of Garden House Boys’ School for fourteen years.
#
#   Student Wellbeing:
#   Garden House School is a remarkably kind, caring and nurturing environment in which to learn. With the very best pastoral care, each child will reach their full potential.
#
#   Academic Integration:
#   Boys may also join Garden House School at 8 years' of age. We encourage you to apply at least a year before your son is eligible to join.
#
#   Competitive Pathway:
#   N/A
#
#   Facilities & Resources:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : London, UK
#   Website  : https://gardenhouseschool.co.uk/
# ——————————————————————————————————————————————————
#
#  WP blocks  → garden_house_school_home_wp_blocks.txt
# School JSON → garden_house_school_home_data.json
#
# ============================================================
#  Scraping: https://kcs.org.uk
# ============================================================
# Connecting to: https://kcs.org.uk...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 5 missing field(s): Students, Ratio, Fees, Admissions, Student Wellbeing
#   ✓ OpenAI filled: Students, Ratio, Fees, Admissions, Student Wellbeing
#
# ——————————————————————————————————————————————————
# Elite › London › King's College School Wimbledon
# ——————————————————————————————————————————————————
#
# 7–18          1400          1:10          1829
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://kcs.org.uk/media/14112/3c2a6997.jpg?crop=0.16888888888888889
#   2. https://kcs.org.uk/media/4970/3c2a2494.jpg?crop=0
#   3. https://kcs.org.uk/media/7725/kcsjune2022124.jpg?crop=0.057763639439362635,0.27187913886791526,0.013892155285166439,0.0036066530606974441&cropmode=percentage&width=1345&height=700&meta=false&rnd=133051999660000000
#   4. https://kcs.org.uk/media/7725/kcsjune2022124.jpg?center=0.58302583025830257
#   5. https://kcs.org.uk/media/14131/20251009-tedx-16.jpg?anchor=center&mode=crop&width=657&height=657&meta=false&rnd=134195204940000000
#   6. https://kcs.org.uk/media/1267/music-priory-guitar-ensemble.jpg?anchor=center&mode=crop&width=673&height=472&meta=false&rnd=131539297740000000
#   7. https://kcs.org.uk/media/7730/kcsjune202290.jpg?center=0.39664804469273746,0.47583643122676578&mode=crop&width=1345&height=700&meta=false&rnd=133052238760000000
#   8. https://kcs.org.uk/media/7729/kcsjune202274.jpg?center=0.34806629834254144,0.47970479704797048&mode=crop&width=456&height=296&meta=false&rnd=133052236690000000
#   9. https://kcs.org.uk/media/7752/drannecottonkcs-may2022053.jpg?crop=0.056196124474415708
#   10. https://kcs.org.uk/media/1806/img_6114.jpg?crop=0.0000000000000005052748343183,0,0,0.21956295525494304&cropmode=percentage&width=1345&height=700&meta=false&rnd=131540025780000000
#
# About King's College School Wimbledon
# I want all our pupils to look back on their time at King’s College Junior School and answer this question with a resounding ‘yes’. Our teachers work hard to ensure that life here - in the classroom and outside - is stimulating and exciting.
#
# Institution Details
#   Type       : Independent School
#   Ages       : 7–18
#   Students   : 1400
#   Ratio      : 1:10
#   Founded    : 1829
#   City       : London, UK
#   Annual Fee : £21,000 per year
#
# Quotes
#   "Sport The PE and Games programme is firmly based on inclusion."
#
# How they teach
# Education is not just about academic subjects and co-curricular activities - it is also about values. There is a simple saying which contains a great deal of truth: it is nice to be important, but more important to be nice.
#
# Outcomes: Where students go
# As one of the world’s leading schools, we go beyond academic excellence to develop the whole person. We look outwards, to the world beyond school and to life at 25, equipping pupils with the skills and values to live a fulfilled and purposeful life and to make a positive impact on their lives and on those around them.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students must sit an entrance exam and attend an interview. Applications are accepted online through the school's website.
#
# How King's College School Wimbledon Performs
#
#   Facilities & Resources:
#   Co-curricular activities (CCAs) play a key role in a student's life at King’s; this is reflected by our significant investment in music, sport and drama facilities. The emphasis, as elsewhere at King’s, is on variety, inclusion, and encouragement.
#
#   Academic Integration:
#   The curriculum is designed to meet the musical needs of all the pupils and provide them with a solid grounding in the history, theory and practical side of music. This includes the study of different styles and genres, theory and composition, singing, keyboard and percussive work.
#
#   Competitive Pathway:
#   All pupils are encouraged to sing, whether it be in class, assembly or in one of the five junior school choirs. We actively encourage boys to take up instrumental and/or vocal tuition with one of our many specialist visiting music teachers.
#
#   Ongoing Accountability:
#   For parents of our current junior school pupils, a live version of this term's clubs can be found on the parent portal.
#
#   Coaching Credentials:
#   As one of the world’s leading schools, we go beyond academic excellence to develop the whole person. We look outwards, to the world beyond school and to life at 25, equipping pupils with the skills and values to live a fulfilled and purposeful life and to make a positive impact on their lives and on those around them.
#
#   Student Wellbeing:
#   King's College School Wimbledon offers a comprehensive pastoral care system to support student wellbeing. The school provides access to counselling services and promotes a balanced lifestyle through various co-curricular activities.
#
#   Location : London, UK
#   Website  : https://kcs.org.uk
# ——————————————————————————————————————————————————
#
#  WP blocks  → king_s_college_school_wimbledon_wp_blocks.txt
# School JSON → king_s_college_school_wimbledon_data.json
#
# ============================================================
#  Scraping: https://latymer-upper.org
# ============================================================
# Connecting to: https://latymer-upper.org...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Latymer Upper School
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Ratio, Fees, Outcomes
#
# ——————————————————————————————————————————————————
# Elite › Hammersmith › Latymer Upper School
# ——————————————————————————————————————————————————
#
# 16–18         1440          1:10          2024
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.latymer-upper.org/wp-content/uploads/2018/12/Governors-9570-273x378.jpg
#   2. https://www.latymer-upper.org/wp-content/uploads/2025/03/Piazza_-1-1-1800x640.jpg
#   3. https://www.latymer-upper.org/wp-content/uploads/2024/02/2023.02.28_Brain_Tumour_Charity_Cheque-2-1-e1709207519587.jpg
#   4. https://www.latymer-upper.org/wp-content/uploads/2019/02/PP-fight-scene-1800x640.jpg
#   5. https://www.latymer-upper.org/wp-content/uploads/2024/02/2023.02.28_Brain_Tumour_Charity_Cheque-2-1-e1709207519587-273x378.jpg
#   6. https://www.latymer-upper.org/wp-content/uploads/2019/05/Latymer-Rachel-chemistry-n-1800x640.jpg
#   7. https://www.latymer-upper.org/wp-content/uploads/2022/09/9J5A9321-273x378.jpg
#   8. https://www.latymer-upper.org/wp-content/uploads/2023/04/Y8-Global-Teaching-pilot-project-4-1800x640.jpg
#   9. https://www.latymer-upper.org/wp-content/uploads/2019/03/SaturdaySchool2019-6-e1553761661155.jpg
#   10. https://www.latymer-upper.org/wp-content/uploads/2025/03/Piazza-54-1800x640.jpg
#
# About Latymer Upper School
# “Unpretentious, cosmopolitan community; highly academic; forward-thinking, with a deep-pocketed bursary programme and a fabulous real-world co-ed buzz.” As London’s leading fully co-educational school, with 1,400 girls and boys (11 to 18-year-olds) of very individual characters, Latymer Upper School is not a ‘one size fits all’ school. ‘Modern’, ‘traditional’, ‘academic’, ‘caring’, ‘ambitious’ and ‘grounded’ are some of the words most commonly used to describe the School.
#
# Institution Details
#   Type       : Independent Day School
#   Ages       : 16–18
#   Students   : 1440
#   Ratio      : 1:10
#   Founded    : 2024
#   City       : Hammersmith, London, UK
#   Annual Fee : £24,000 per year
#
# Quotes
#   "Embrace individuality and excellence in a vibrant, inclusive community, shaping future leaders with compassion and innovation."
#
# How they teach
# As London’s leading fully co-educational school, with 1,400 girls and boys (11 to 18-year-olds) of very individual characters, Latymer Upper School is not a ‘one size fits all’ school.
#
# Outcomes: Where students go
# Latymer Upper School consistently achieves high academic results, with students gaining entry to top universities worldwide. The school fosters well-rounded individuals prepared for diverse future pathways.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : We aim for our admissions process and communications to be as clear and easy to follow as possible. We very much look forward to sharing our vision and ethos with you.
#
# How Latymer Upper School Performs
#
#   Academic Integration:
#   Our wide-ranging co-curricular programme enhances our pupils’ academic curriculum, helping them to grow and mature both emotionally and socially, creating ‘all-rounders’ who enjoy life to the full.
#
#   Coaching Credentials:
#   As founding members of the West London Partnership, we work with five state secondary schools and sixth forms and four independent schools. WLP schools collaborate to share projects, resources and expertise, to address educational needs and to enrich learning for everyone.
#
#   Student Wellbeing:
#   Prior to that she was Deputy Head (Pastoral) at St Paul’s Girls’ School. Her stellar CV reflects her career progression at high profile and internationally renowned schools – co-ed, single sex, day and boarding.
#
#   Competitive Pathway:
#   As London’s leading fully co-educational school, with 1,400 girls and boys (11 to 18-year-olds) of very individual characters, Latymer Upper School is not a ‘one size fits all’ school. ‘Modern’, ‘traditional’, ‘academic’, ‘caring’, ‘ambitious’ and ‘grounded’ are some of the words most commonly used to describe the School.
#
#   Facilities & Resources:
#   Alongside a broad and stimulating curriculum and dedicated teaching, Latymer offers first-class facilities and a plethora of musical, artistic and sporting opportunities beyond the classroom. A wonderfully eclectic collection of buildings and facilities sit side by side on the campus.
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Hammersmith, London, UK
#   Website  : https://latymer-upper.org
# ——————————————————————————————————————————————————
#
#  WP blocks  → latymer_upper_school_wp_blocks.txt
# School JSON → latymer_upper_school_data.json
#
# ============================================================
#  Scraping: https://godolphinandlatymer.com
# ============================================================
# Connecting to: https://godolphinandlatymer.com...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Ratio, Fees, Outcomes
#
# ——————————————————————————————————————————————————
# Elite › Hammersmith › Godolphin and Latymer
# ——————————————————————————————————————————————————
#
# 11–18         800           1:10          1905
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.godolphinandlatymer.com/wp-content/uploads/2023/09/Spring-Choral-Concert-50-1024x683.jpg
#   2. https://www.godolphinandlatymer.com/wp-content/uploads/2019/07/9A8BE2A4-47F6-45F2-AECF9006497D1F9B_azslideronepic.jpg
#   3. https://www.godolphinandlatymer.com/wp-content/uploads/2019/07/A771E695-2C2F-4744-9483F3F275A2E477_azslideronepic.jpg
#   4. https://www.godolphinandlatymer.com/wp-content/uploads/2019/07/XT3F1937-1024x683.jpg
#   5. https://www.godolphinandlatymer.com/wp-content/uploads/2025/09/Education-Choices.png
#   6. https://www.godolphinandlatymer.com/wp-content/uploads/2023/09/Bridge-Outreach-1024x683.jpg
#   7. https://www.godolphinandlatymer.com/wp-content/uploads/2022/10/Enrichment-Session-header-1024x421.jpg
#   8. https://www.godolphinandlatymer.com/wp-content/uploads/2019/07/Facilities-Hire-XH10205-e1563802904784-1070x713.jpg
#   9. https://www.godolphinandlatymer.com/wp-content/uploads/2019/08/Frances-Ramsey-Signature.png
#   10. https://www.godolphinandlatymer.com/wp-content/uploads/2019/07/Facilities-Hire-XH10205-e1563802904784-441x350.jpg
#
# About Godolphin and Latymer
# The admissions process for a London day school can seem daunting at first, but we aim to make it as smooth and clear as possible. Godolphin and Latymer is academically selective and we are looking for intellectual potential and for girls who will thrive in a school that offers a wide range of curricular and extra-curricular opportunities.
#
# Institution Details
#   Type       : Independent School
#   Ages       : 11–18
#   Students   : 800
#   Ratio      : 1:10
#   Founded    : 1905
#   City       : Hammersmith, London, UK
#   Annual Fee : £24,000 per year
#
# Quotes
#   "Parents love Godolphin and Latymer not just for the academic success it brings their daughters, but for the school’s holistic approach to their education in the broadest sense."
#
# How they teach
# Godolphin and Latymer is an academically selective independent day school for girls aged 11-18. Girls who thrive here are curious and eager to learn and are ready to take advantage of the wide range of curricular and extra-curricular opportunities we offer.
#
# Outcomes: Where students go
# Godolphin and Latymer students consistently achieve outstanding academic results and gain entry to top universities worldwide, while also developing a strong sense of confidence and leadership skills.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : for Registration:	Noon on Friday 6 November 2026
#   Process        : We are very happy to receive applications from students with individual learning needs. Applicants who need extra time or other concessions for the entrance tests should fill in the relevant sections of the examination entry form, when this is issued in September/October, and should provide written evidence of their needs.
#
# How Godolphin and Latymer Performs
#
#   Academic Integration:
#   A converted church accommodates our versatile performing arts centre with a glass atrium providing light and open spaces. This connects to the modern music school with its rehearsal and practice rooms and a fully-equipped music suite.
#
#   Facilities & Resources:
#   Well-maintained historic buildings – including a converted church – sit side-by-side with modern facilities interconnected by tranquil lawns and courtyards.
#
#   Coaching Credentials:
#   The admissions process for a London day school can seem daunting at first, but we aim to make it as smooth and clear as possible. Godolphin and Latymer is academically selective and we are looking for intellectual potential and for girls who will thrive in a school that offers a wide range of curricular and extra-curricular opportunities.
#
#   Student Wellbeing:
#   Our pastoral care ensures that each individual girl is encouraged to be the best version of herself and is supported to be bold, have a go, and to bounce back when things don’t go to plan. We strive to be a caring, kind and inclusive school community and our means-tested bursary programme allows us to provide fee assistance for talented girls who otherwise wouldn’t be able to come to the school.
#
#   Competitive Pathway:
#   Godolphin and Latymer is academically selective and we are looking for intellectual potential and for girls who will thrive in a school that offers a wide range of curricular and extra-curricular opportunities. Entry is by examination and interview, normally at 11+ Entry (Year 7) or 16+ Entry (Lower Sixth) with some occasional places for Years 8, 9 and 10.
#
#   Ongoing Accountability:
#   The head, Miss Gertrude Clement, reported that the ODA was 'strong and lusty' in 1916 with over 200 members who met regularly, enjoyed a weekly OD gym class, lectures and playing school teams at hockey. This fund helped current and former Dolphins who were facing financial hardship in the Depression.
#
#   Location : Hammersmith, London, UK
#   Website  : https://godolphinandlatymer.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → godolphin_and_latymer_wp_blocks.txt
# School JSON → godolphin_and_latymer_data.json
#
# ============================================================
#  Scraping: https://nlcs.org.uk
# ============================================================
# Connecting to: https://nlcs.org.uk...
#   ⚠ networkidle failed (Error), retrying…
#   ✗ Failed: Page.goto: net::ERR_ABORTED at https://nlcs.org.uk/
# Call log:
#   - navigating to "https://nlcs.org.uk/", waiting until "domcontentloaded"
#
#   ✗ Could not load https://nlcs.org.uk, skipping.
#
# ============================================================
#  Scraping: https://bespoketuition.com
# ============================================================
# Connecting to: https://bespoketuition.com...
#   Skipping mailto:info@bespoketuition.com: Page.goto: net::ERR_ABORTED at mailto:info@bespoketuition.com
# Call log:
#   - navigating to "mailto:info@bespoketuition.com", waiting until "domcontentloaded"
#
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 6 missing field(s): Ages, Students, Ratio, Philosophy, Outcomes, Admissions
# ...
#
#   Location : Harrow, London, UK
#   Website  : https://purcell-school.org
# ——————————————————————————————————————————————————
#
#  WP blocks  → purcell_school_wp_blocks.txt
# School JSON → purcell_school_data.json
#
# ============================================================
#  Scraping: https://ram.ac.uk
# ============================================================
# Connecting to: https://ram.ac.uk...
#   ⚠ networkidle failed (Error), retrying…
#   ⚠ Page body too short — scrolling to trigger JS render…
#   Body after scroll: 75 chars
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Just a moment...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 15 missing field(s): Founded, Ages, Students, Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ OpenAI filled: Founded, Ages, Students, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › London › Just a moment...
# ——————————————————————————————————————————————————
#
# 18+           850           N/A           1822
# Ages          Students      Ratio         Founded
#
# Images Found: 0
#
# About Just a moment...
# The Royal Academy of Music is a prestigious conservatoire in London, dedicated to nurturing exceptional musical talent and fostering artistic excellence.
#
# Institution Details
#   Type       : Conservatoire
#   Ages       : 18+
#   Students   : 850
#   Ratio      : N/A
#   Founded    : 1822
#   City       : London, UK
#   Annual Fee : See website
#
# Quotes
#   "Nurturing creativity and excellence through the transformative power of music and the arts."
#
# How they teach
# The Academy emphasizes a holistic approach to music education, combining rigorous training with creative exploration to cultivate versatile musicians.
#
# Outcomes: Where students go
# Graduates of the Academy achieve success in diverse musical careers, from performance to composition, contributing significantly to the global music scene.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students must undergo a competitive audition process, demonstrating their musical proficiency and potential for growth.
#
# How Just a moment... Performs
#
#   Coaching Credentials:
#   The Academy's faculty includes renowned musicians and educators, offering unparalleled expertise and mentorship to students. Staff members are leaders in their fields, bringing real-world experience to their teaching.
#
#   Student Wellbeing:
#   The Academy provides comprehensive support services, ensuring students' mental and physical health are prioritized. A dedicated team offers counseling and wellness programs tailored to musicians' needs.
#
#   Academic Integration:
#   The curriculum integrates performance with academic study, offering courses in music theory, history, and technology. Students benefit from a balanced education that enhances their artistic and intellectual development.
#
#   Competitive Pathway:
#   The Academy's students regularly win prestigious competitions and awards, reflecting the high standard of training provided. Alumni have secured positions in leading orchestras and ensembles worldwide.
#
#   Facilities & Resources:
#   The Academy boasts state-of-the-art performance venues and practice facilities, including concert halls and recording studios. Students have access to an extensive library of musical scores and recordings.
#
#   Ongoing Accountability:
#   Progress is monitored through regular assessments and feedback, ensuring students meet their personal and professional goals. The Academy maintains high standards through continuous evaluation and quality assurance processes.
#
#   Location : London, UK
#   Website  : https://ram.ac.uk
# ——————————————————————————————————————————————————
#
#  WP blocks  → just_a_moment_wp_blocks.txt
# School JSON → just_a_moment_data.json
#
# ============================================================
#  Scraping: https://millfieldschool.com
# ============================================================
# Connecting to: https://millfieldschool.com...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Fees
#   ✓ OpenAI filled: Ratio, Fees
#
# ——————————————————————————————————————————————————
# Elite › Harrow › Millfield School
# ——————————————————————————————————————————————————
#
# 2–18          300           1:10          2022
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://resources.finalsite.net/videos/v1756890055/millfieldschoolcom/bv6kowxawkyzx9nanyuu/MillfieldHeroFilm2025.jpg
#   2. https://resources.finalsite.net/images/f_auto,q_auto/v1734021569/millfieldschoolcom/ibl0zexw7pmeyoybrikr/MathsatMillfield_crop2.jpg
#   3. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_3/v1580120532/millfieldschoolcom/pkkevqpekiiekdf6natx/InsideFrontCover3.jpg
#   4. https://www.juicer.io/api/posts/507490570/images.jpg?external_id=7633008639506271510&s=050b608f243903f71db2687251a790c23e8a2f2c
#   5. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_3/v1691759818/millfieldschoolcom/jlq3q2bzg5behlcjgz9o/Prep_26623_4011.jpg
#   6. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_3/v1737116681/millfieldschoolcom/g1jjlxgtgutvdvy8a9ko/Orchestr.jpg
#   7. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_2/v1582033978/millfieldschoolcom/f9qb5zkpadqargzuvdqb/PrepSportsPavilion.jpg
#   8. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_2/v1597410958/millfieldschoolcom/whto6v4d3oclzo4yp4xf/Millfield_Pool_2776_15.jpg
#   9. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_2/v1659089384/millfieldschoolcom/d7j6yvlqikc6qaoaxzve/Prep_Swimming.jpg
#   10. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_3/v1737116741/millfieldschoolcom/umdir8kvz0jetzoie66o/HouseSong2024.jpg
#
# About Millfield School
# We are delighted you are interested in a Millfield education for your child. Please follow the tabs below to guide you through the Admissions process for Millfield Pre-Prep, Millfield Prep and Millfield, view our prospectuses, or visit us by booking an Open Day or a Personal Visit.
#
# Institution Details
#   Type       : Independent Pre-Prep School
#   Ages       : 2–18
#   Students   : 300
#   Ratio      : 1:10
#   Founded    : 2022
#   City       : Harrow, London, UK
#   Annual Fee : £20,000 per year
#
# Quotes
#   "To be able train under the experienced coaches and to follow in the footsteps of the many great athletes who have passed through is incredible."
#
# How they teach
# "From first contact with Millfield the whole Open Day process, format and content was exceptional.
#
# Outcomes: Where students go
# At this exciting stage in your education, Millfield will provide you the opportunities and the stimulating environment that you need to be brilliant at whatever you choose to do. The Sixth Form is about enjoyment, excitement and discovery.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : To ensure a place at Millfield you will need to complete the Registration Form for each student you would like to register. Please complete this form using the browser Chrome, the form takes around 15 minutes to complete.
#
# How Millfield School Performs
#
#   Academic Integration:
#   Millfield's outstanding facilities create two extraordinary campuses which have inspired generations of students to immerse themselves in academic study, culture and sport to express their intellectual, creative and physical potential. Maintaining this calibre of learning environment has been achieved through the school's continued and significant capital investment, alongside generous donations from the wider Millfield community.
#
#   Competitive Pathway:
#   The latest addition to our facilities are the new indoor cricket and golf centres, with world-leading technology, including through motion tracking and simulation software, placing Millfield at the forefront of school and university facilities for both sports.
#
#   Facilities & Resources:
#   Millfield's vision for campus development is summarised in Millfield 2035, the school's campus masterplan which identifies future needs and priortises campus developments.
#
#   Coaching Credentials:
#   We are delighted you are interested in a Millfield education for your child. Please follow the tabs below to guide you through the Admissions process for Millfield Pre-Prep, Millfield Prep and Millfield, view our prospectuses, or visit us by booking an Open Day or a Personal Visit.
#
#   Student Wellbeing:
#   Each event offers the opportunity to gain a meaningful insight into our academic, sporting, pastoral and co-curricular life. You’ll meet the people, explore the spaces, and uncover the values that make Millfield distinctively different from other schools.
#
#   Ongoing Accountability:
#   Please complete this form using the browser Chrome, the form takes around 15 minutes to complete. When completing the personal details for parents please include the details of both parents.
#
#   Location : Harrow, London, UK
#   Website  : https://millfieldschool.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → millfield_school_wp_blocks.txt
# School JSON → millfield_school_data.json
#
# ============================================================
#  Scraping: https://wellingtoncollege.org.uk
# ============================================================
# Connecting to: https://wellingtoncollege.org.uk...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Fees
#   ✓ OpenAI filled: Ratio, Fees
#
# ——————————————————————————————————————————————————
# Elite › London › Wellington College
# ——————————————————————————————————————————————————
#
# 13–18         76            1:8           2006
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.wellingtoncollege.org.uk/wp-content/uploads/2026/04/55225581366_cb796e32e1_k-1280x853.jpg
#   2. https://www.wellingtoncollege.org.uk/wp-content/uploads/2025/08/1492919173-692d2aadc04fb5f6a0f5ac05f9a07c6fc24377f93d2307d0fc4d418fdae28971-d_640_regionus-400x211.jpeg
#   3. https://www.wellingtoncollege.org.uk/wp-content/uploads/2026/04/54612594346_a9aa8e9c15_k-1280x853.jpg
#   4. https://www.wellingtoncollege.org.uk/wp-content/uploads/2022/04/Wide-shot-of-college-on-a-sunny-day-1280x960.jpg
#   5. https://www.wellingtoncollege.org.uk/wp-content/uploads/2025/11/wellbeing-festival-2023_003-scaled-1.jpg
#   6. https://www.wellingtoncollege.org.uk/wp-content/uploads/2025/11/Above.-Beyond-1280x853.jpg
#   7. https://www.wellingtoncollege.org.uk/wp-content/uploads/2026/01/53164161255_e8a967cae7_k.jpg
#   8. https://www.wellingtoncollege.org.uk/wp-content/uploads/2022/04/Pupils-walking-across-the-Wellington-quad-1280x853.jpeg
#   9. https://www.wellingtoncollege.org.uk/wp-content/uploads/2025/08/Screenshot-2025-08-05-at-15.40.21-2100x1294.png
#   10. https://www.wellingtoncollege.org.uk/wp-content/uploads/2025/08/af95151220072bfa50e0d4d8f4d863f77f8b5e0a-640x305.png
#
# About Wellington College
# Wellington College is one of the UK’s — and indeed the world’s — great co-educational boarding and day schools. The College is set in 400 acres of beautiful parkland and is home to a blend of breathtaking original architecture and modern state-of-the-art facilities to provide the best possible educational environment for our pupils.
#
# Institution Details
#   Type       : Independent Boarding & Day School
#   Ages       : 13–18
#   Students   : 76
#   Ratio      : 1:8
#   Founded    : 2006
#   City       : London, UK
#   Annual Fee : £42,000 per year
#
# Quotes
#   "Wellington gives everyone the platform to explore and develop their own passions."
#
# How they teach
# True to the classical roots of the word ‘education’, the College aims to provide an ambitious and aspirational environment in which the potential of each pupil is ‘brought out’ and developed across all aspects of themselves as unique individuals. At Wellington the pervading culture of ambition and aspiration creates an atmosphere which not only encourages every pupil, teacher, and parent to believe anything is possible, but also recognises that each Wellingtonian has immense potential which must be nurtured and realised.
#
# Outcomes: Where students go
# “If I had to put my finger on the one aspect of Wellington College that excites me most, it is the all-pervading culture of ambition and aspiration, an atmosphere which encourages every pupil, teacher and parent to believe that anything is possible.” A thriving school of over 1,100 students, with 18 Houses that are small enough for each child to feel at home – a place where they are known, supported, and part of a close-knit community.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : "Discovering whether Wellington is the right fit for your child lies at the heart of our admissions process. We want to offer places to children who will be really happy here, and who have the desire and determination to make the most of all the opportunities on offer to them." We are delighted that a restructuring of our boarding houses has enabled us to create a small number of places for entry at 14+.
#
# How Wellington College Performs
#
#   Coaching Credentials:
#   Kate is a graduate of Durham University and is Chief Financial Officer of Burberry Plc. She is a highly experienced CFO having held roles in both public and private companies including Dixons Carphone Plc, TalkTalk Plc and McLaren Group.
#
#   Student Wellbeing:
#   At Wellington, students don’t have to choose between being an academic, an artist, an athlete, or a leader. They can be all of them or any of them, as they embark on a journey of self-discovery in an environment that encourages every passion to flourish.
#
#   Academic Integration:
#   “If I had to put my finger on the one aspect of Wellington College that excites me most, it is the all-pervading culture of ambition and aspiration, an atmosphere which encourages every pupil, teacher and parent to believe that anything is possible.” At Wellington, students don’t have to choose between being an academic, an artist, an athlete, or a leader. They can be all of them or any of them, as they embark on a journey of self-discovery in an environment that encourages every passion to flourish.
#
#   Competitive Pathway:
#   Academic excellence is just the beginning at Wellington. We empower students to achieve GCSE, A Level and IB results that are simply outstanding, not just nationally, but globally.
#
#   Facilities & Resources:
#   With 400 acres of stunning grounds, Wellington offers the space to breathe, the time to think and the environment to be yourself. Whether it’s exploring an academic passion, enjoying a particular sport, or getting lost in the arts, students have the freedom to discover who they are.
#
#   Ongoing Accountability:
#   The report itself acknowledges the positive, purposeful, unified and integrated school community, one where “pupils’ wellbeing is at the centre of leaders’ decision-making”. The curriculum is described as “rich and challenging” with the result that “pupils achieve high grades at GCSE and A level and in the IB”.
#
#   Location : London, UK
#   Website  : https://wellingtoncollege.org.uk
# ——————————————————————————————————————————————————
#
#  WP blocks  → wellington_college_wp_blocks.txt
# School JSON → wellington_college_data.json
#
# ============================================================
# All done! 21 schools scraped.
# Master JSON → all_schools_data_london.json
# ============================================================
