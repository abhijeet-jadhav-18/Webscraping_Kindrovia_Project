# %%
import os, subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "python-dotenv", "-q"])

# Load your code.env file
env_file = r"C:\Users\Abhijeet\code.env"

with open(env_file, "r") as f:
    for line in f:
        line = line.strip()
        if "=" in line and not line.startswith("#"):
            key, val = line.split("=", 1)
            os.environ[key.strip()] = val.strip().strip('"').strip("'")

print(f" Loaded from: {env_file}")

ok_openai = len(os.environ.get("OPENAI_API_KEY", "")) > 20
print(f"OpenAI : {' Loaded' if ok_openai else ' Not found'}")
# Out:
#  Loaded from: C:\Users\Abhijeet\code.env
# OpenAI :  Loaded

# %%
import os, subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "python-dotenv", "-q"],
               capture_output=True)

# Load from code.env
env_file = r"C:\Users\Abhijeet\code.env"
with open(env_file, "r") as f:
    for line in f:
        line = line.strip()
        if "=" in line and not line.startswith("#"):
            key, val = line.split("=", 1)
            os.environ[key.strip()] = val.strip().strip('"').strip("'")

# Anthropic not needed — set dummy so scraper skips quietly
if not os.environ.get("ANTHROPIC_API_KEY"):
    os.environ["ANTHROPIC_API_KEY"] = "not-used"

ok = len(os.environ.get("OPENAI_API_KEY", "")) > 20
print(f"OpenAI key : {' Ready' if ok else ' Not found — check code.env'}")
if ok:
    print(" Ready to run scraper")
# Out:
# OpenAI key :  Ready
#  Ready to run scraper

# %%
# Out:
# ============================================================
#  Scraping: https://www.harrowhongkong.hk/
# ============================================================
# Connecting to: https://www.harrowhongkong.hk/...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Harrow International School Hong Kong
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 12 missing field(s): Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ OpenAI filled: Ratio, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Harrow International School Hong Kong
# ——————————————————————————————————————————————————
#
# 3–18          1650          1:10          2012
# Ages          Students      Ratio         Founded
#
# Images Found: 0
#
# About Harrow International School Hong Kong
# Harrow International School Hong Kong is a leading British independent school providing a holistic education for students aged 3 to 18. It emphasizes academic excellence, character development, and leadership skills.
#
# Institution Details
#   Type       : British Independent School
#   Ages       : 3–18
#   Students   : 1650
#   Ratio      : 1:10
#   Founded    : 2012
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Empowering leaders of tomorrow through academic excellence, character building, and a global perspective."
#
# How they teach
# The school fosters a nurturing environment that encourages curiosity, resilience, and a lifelong love of learning. It aims to develop well-rounded individuals prepared for global citizenship.
#
# Outcomes: Where students go
# Students graduate with strong academic credentials and leadership skills, ready for top universities worldwide. The school cultivates confident, articulate, and compassionate individuals.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students undergo a comprehensive application process, including assessments and interviews. The school seeks candidates who demonstrate academic potential and alignment with its values.
#
# How Harrow International School Hong Kong Performs
#
#   Coaching Credentials:
#   Harrow Hong Kong's faculty includes experienced educators with advanced degrees and international teaching experience. Staff regularly participate in professional development to stay abreast of educational innovations.
#
#   Student Wellbeing:
#   The school offers robust pastoral care, ensuring each student's emotional and social needs are met. A dedicated team provides support through counseling services and wellbeing programs.
#
#   Academic Integration:
#   The curriculum integrates traditional British education with innovative teaching methods. Students engage in a broad range of subjects, fostering critical thinking and creativity.
#
#   Competitive Pathway:
#   Harrow students consistently achieve outstanding results in public examinations. Graduates gain entry to prestigious universities, reflecting the school's commitment to academic excellence.
#
#   Facilities & Resources:
#   The campus features state-of-the-art facilities, including science labs, art studios, and sports complexes. Resources support a diverse range of extracurricular activities and academic pursuits.
#
#   Ongoing Accountability:
#   Regular assessments and feedback ensure continuous improvement in teaching and learning. The school maintains high standards through rigorous internal and external evaluations.
#
#   Location : Hong Kong
#   Website  : https://www.harrowhongkong.hk/
# ——————————————————————————————————————————————————
#
#  WP blocks  → harrow_international_school_hong_ko_wp_blocks.txt
# School JSON → harrow_international_school_hong_ko_data.json
#
# ============================================================
#  Scraping: https://kellettschool.com
# ============================================================
# Connecting to: https://kellettschool.com...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Fees
#   ✓ OpenAI filled: Ratio
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Kellett School
# ——————————————————————————————————————————————————
#
# 5–18          1550          1:10          1976
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.kellettschool.com/userfiles/kellettv2mvc/image/header/ea%20at%20prep%20header.jpg?command_1=resize&width_1=1200
#   2. https://kellettschool.com/userfiles/kellettv2mvc/PFL/KLB/KKBP_08Oct19_1394.jpg
#   3. https://kellettschool.com/userfiles/kellettv2mvc/PFL/KLB/20250207-KLT_6767.jpg
#   4. https://kellettschool.com/userfiles/kellettv2mvc/Image/header/Kellett%20Vision%202035.png
#   5. https://kellettschool.com/userfiles/kellettv2mvc/Image/stats/family-2.png
#   6. https://www.kellettschool.com/userfiles/kellettv2mvc/image/img_7655.jpg?command_1=resize&width_1=1200
#   7. https://kellettschool.com/userfiles/kellettv2mvc/Image/Definitions/Learning.jpg
#   8. https://kellettschool.com/userfiles/kellettv2mvc/20240823-KLT_0788%20-%20APPROVED.jpg
#   9. https://kellettschool.com/userfiles/kellettv2mvc/Image/Definitions/Respect.jpg?webp=true
#   10. https://www.kellettschool.com/userfiles/kellettv2mvc/image/header/kellett.jpg?command_1=resize&width_1=400
#
# About Kellett School
# Tours at Pok Fu Lam and Kowloon Bay run regularly, the schedule for three schools are as below. Numbers are limited, please contact tours@kellettschool.com to check availability.
#
# Institution Details
#   Type       : Independent School
#   Ages       : 5–18
#   Students   : 1550
#   Ratio      : 1:10
#   Founded    : 1976
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "For Admissions enquiries, please let us know the following information along with your question(s)."
#
# How they teach
# We aim to make applications to Kellett School, The British International School in Hong Kong, as easy as possible.
#
# Outcomes: Where students go
# Offering small classes and a low student-teacher ratio, coupled with exciting and engaging teaching of the English Curriculum, Kellett Senior School and Sixth Form students achieve fantastic public examination results, and attend some of the very best universities in the world. Beyond the classroom, overseas educational visits, countless expressive arts and sporting opportunities, alongside world-class wellbeing provision, prepare our students for a future beyond academia.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : s, but you may wish to check with the Admissions Office if t
#   Process        : You can apply at any time during the year, and our waitlists are fluid, so it is always best to get in touch if you are interested in applying.
#
# How Kellett School Performs
#
#   Academic Integration:
#   The premises provide an enviable range of facilities rarely found in a preparatory school of its size, including a large multi-use auditorium, a gymnasium and a well-resourced school library, a fully equipped science lab, dance and drama studio, ICT suite, language lab, SEN learning support base, music rooms, art studio and a children’s bookshop. The “covered area” provides a large indoor space for the Reception and Y1 children to take part in structured collaboration and play activities.
#
#   Facilities & Resources:
#   Kellett School has two campuses, the Pok Fu Lam campus on Hong Kong Island and Kowloon Bay campus just over the harbour in the Kowloon Peninsula.
#
#   Ongoing Accountability:
#   Having two Prep schools often allows our Prep students the opportunity to compete against each other across the two campuses. When they progress to the Senior School, this friendly competition continues as students compete in inter-house competitions.
#
#   Coaching Credentials:
#   These beautiful facilities form just part of the excellence that makes up the Expressive Arts at Kellett School. The breadth of the curriculum, the extensive extra-curricular activities offered and the strength in teaching expertise in this area give Expressive Arts at Kellett School its strong and enviable reputation.
#
#   Student Wellbeing:
#   Beyond the classroom, overseas educational visits, countless expressive arts and sporting opportunities, alongside world-class wellbeing provision, prepare our students for a future beyond academia. Kellett Senior School, on Kellett's Kowloon Bay campus, has been in operation since 2007.
#
#   Competitive Pathway:
#   Offering small classes and a low student-teacher ratio, coupled with exciting and engaging teaching of the English Curriculum, Kellett Senior School and Sixth Form students achieve fantastic public examination results, and attend some of the very best universities in the world.
#
#   Location : Hong Kong
#   Website  : https://kellettschool.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → kellett_school_wp_blocks.txt
# School JSON → kellett_school_data.json
#
# ============================================================
#  Scraping: https://hkis.edu.hk
# ============================================================
# Connecting to: https://hkis.edu.hk...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Ratio, Outcomes
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong International School
# ——————————————————————————————————————————————————
#
# 6–18          600           1:10          1966
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://hkis.edu.hk/userfiles/hkismvc/images/cards/ASA_Card_Culinary%20Arts.jpg?command_1=resize&width_1=500&webp=true
#   2. https://hkis.edu.hk/Images/1px.jpg?command_1=url&url_1=https%3A%2F%2Fscontent-lhr6-1.cdninstagram.com%2Fv%2Ft51.82787-15%2F604026687_18544089748036912_1170861236485005111_n.jpg%3Fstp%3Ddst-jpg_e35_tt6%26_nc_cat%3D109%26ccb%3D7-5%26_nc_sid%3D18de74%26efg%3DeyJlZmdfdGFnIjoiQ0xJUFMuYmVzdF9pbWFnZV91cmxnZW4uQzMifQ%253D%253D%26_nc_ohc%3Dgz5NfZGCkfQQ7kNvwEtGysI%26_nc_oc%3DAdog1-SD5mAZuIZpTCOhnF-G8H1RohArErn_3Oc3JdjRHX_5saoOFMbIgnQiqBB7I0TpUpPpjuHObHKPlAMBcjgf%26_nc_zt%3D23%26_nc_ht%3Dscontent-lhr6-1.cdninstagram.com%26edm%3DANo9K5cEAAAA%26_nc_gid%3DZOw120CiSLu4RKUqxlSgIA%26_nc_tpa%3DQ5bMBQGnAf029kDt5zb6Zh5isZcx8FwtlMbZpOYwzUEeQ6ZMPfZFXPYmc58do9z2sZfoBDIH1jEsrRiPew%26oh%3D00_Af0H5--EsWfpNw-g1bTgH1PLqWshXGPT1sFnc-3vGJqhsQ%26oe%3D69F42C87&command_2=resize&width_2=380&command_3=default&default_3=/Images/default-thumbs/instagram.jpg&webp=true
#   3. https://www.hkis.edu.hk/userfiles/hkismvc/images/body/01-about-hkis/our%20facilities/dcaa/hkis%20new%20website%20banner.png?command_1=resize&width_1=1200
#   4. https://hkis.edu.hk/userfiles/hkismvc/images/affiliations/WASC%20colour.png
#   5. https://www.hkis.edu.hk/userfiles/hkismvc/homepage/01-hkis-grow/10-compassion-classroom-bg.jpg?command_1=resize&width_1=400
#   6. https://hkis.edu.hk/Images/assets/ribbons/ribbon-k4.png
#   7. https://hkis.edu.hk/userfiles/hkismvc/images/cards/ASA_Card_STEAM.jpg?command_1=resize&width_1=500&webp=true
#   8. https://hkis.edu.hk/Images/assets/ribbons/ribbon-g.png?command_1=resize&height_1=1515
#   9. https://hkis.edu.hk/userfiles/hkismvc/images/body/01-about-hkis/Our%20Facilities/History%20Wall_2.jpg
#   10. https://hkis.edu.hk/Images/1px.jpg?command_1=url&url_1=https%3A%2F%2Fi.ytimg.com%2Fvi%2Fl7ZZBraG2PQ%2Fsddefault.jpg&command_2=resize&width_2=380&command_3=default&default_3=/Images/default-thumbs/youtube.jpg&webp=true
#
# About Hong Kong International School
# In-person tours are available annually from mid-October through early-April and are led by student or parent ambassadors, followed by an info session with the Director of Enrollment Management. In the meantime, please explore our virtual tours below.
#
# Institution Details
#   Type       : Independent School
#   Ages       : 6–18
#   Students   : 600
#   Ratio      : 1:10
#   Founded    : 1966
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Dedicating our minds to inquiry, our hearts to compassion, and our lives to service and global understanding. An American-style education grounded in the Christian faith and respecting the spiritual lives of all."
#
# How they teach
# Each student’s ability to achieve success in an atmosphere of high expectations and an environment of self-discipline and responsibility to the school community is carefully assessed. HKIS implements a Dual Language Immersion program starting in the 2025-2026 school year.
#
# Outcomes: Where students go
# Hong Kong International School prepares students for global citizenship with a strong academic foundation. Graduates are equipped with critical thinking skills and a commitment to community service.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Thank you for your interest in applying to Hong Kong International School. We serve students from Reception One (pre-kindergarten) to Grade 12 across four divisions.
#
# How Hong Kong International School Performs
#
#   Academic Integration:
#   If you are an overseas relocating family and would like to inquire about a tour during your visit to Hong Kong, please indicate so in the subject line and email admissions@hkis.edu.hk.
#
#   Facilities & Resources:
#   The Aquatics Academy is the after-school program offered by the HKIS Aquatics Department, whose mission is to provide a developmentally appropriate aquatics program for students on both the Repulse Bay and Tai Tam campuses. Similar to its curricular goals and practice, students in the Academy are offered swim lessons and a variety of aquatics activities at their level & ability, thus ensuring students experience success, enjoyment, improvement of their skills, and development of their knowledge & understanding of water safety concepts & skills.
#
#   Ongoing Accountability:
#   The Tai Tam Tigers Soccer Academy was established in 1999 to provide soccer for children in HKIS and the local community. The club is owned and operated by HKIS and its Head Coaches and Admin staff are HKIS employees.
#
#   Coaching Credentials:
#   We’re thrilled to introduce a variety of new wellness and fitness programs designed for students, parents, and faculty/staff at HKIS!
#
#   Student Wellbeing:
#   With the Dragon Center for Activities & Athletics, we reaffirm our commitment to health and wellbeing by creating spaces to support our full community— for our students who will use it daily, and for the Hong Kong community, who will access it through activities programming and community partnerships. It will also have over 180 much-needed parking spaces for the Tai Tam community and visitors.
#
#   Competitive Pathway:
#   In 1964, a Hong Kong-based committee of the Lutheran Church–Missouri Synod (LCMS) first submitted a proposal to have the school built. The Repulse Bay Lutheran Church and School Project conducted a survey of Americans in July 1964.
#
#   Location : Hong Kong
#   Website  : https://hkis.edu.hk
# ——————————————————————————————————————————————————
#
#  WP blocks  → hong_kong_international_school_wp_blocks.txt
# School JSON → hong_kong_international_school_data.json
#
# ============================================================
#  Scraping: https://ycis-hk.com
# ============================================================
# Connecting to: https://ycis-hk.com...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Students, Ratio, Fees
#   ✓ OpenAI filled: Students, Ratio
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Yew Chung International School of Hong Kong
# ——————————————————————————————————————————————————
#
# 5–18          2800          1:10          1932
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://object.ycyw.com/ycis-hk/res/hk/images/sch-life/cf-6.jpg
#   2. https://info.ycis-hk.com/hs-fs/hubfs/Artboard%201-4.png?width=8082&height=1041&name=Artboard%201-4.png
#   3. https://info.ycis-hk.com/hs-fs/hubfs/PRI_Online_EN_v2.jpg?width=1200&height=1200&name=PRI_Online_EN_v2.jpg
#   4. https://object.ycyw.com/static-images/home/01_Landing_3_Milestone_13_MAIN_2004_GE_Dusseldorf.png
#   5. https://object.ycyw.com/media-library/ycyw-edu/news/2026%20Drama/News%20OG%20Image-9.png
#   6. https://info.ycis-hk.com/hs-fs/hubfs/Artboard%203-4.png?width=1200&height=1200&name=Artboard%203-4.png
#   7. https://object.ycyw.com/media-library/ycyw-edu/weekly-series/ep19/%E7%AC%AC11%E6%9C%9F_%E7%BD%91%E7%AB%99%E6%96%B0%E9%97%BB%E7%BC%A9%E7%95%A5%E5%9B%BE_800x458.jpg
#   8. https://object.ycyw.com/shared/school-motto-2022.jpg
#   9. https://object.ycyw.com/ycis-hk/res/hk/images/sec/ug-2.jpg
#   10. https://object.ycyw.com/media-library/ycyw-edu/southern-people/website-banner-en-2.jpg
#
# About Yew Chung International School of Hong Kong
# * Required The password must contain letters, numbers and special characters, at least 6 characters.
#
# Institution Details
#   Type       : IB World Day School
#   Ages       : 5–18
#   Students   : 2800
#   Ratio      : 1:10
#   Founded    : 1932
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Our unique Western and Chinese co-leadership model attracts top educators from around the world."
#
# How they teach
# YCIS Hong Kong has played a revolutionary role in developing education in Hong Kong. The school provides through-train, international education to expatriate and local children aged 6 months to 18 years old.
#
# Outcomes: Where students go
# Students use their time at YCIS to improve and prepare for the future. Through career planning workshops and global university networking activities, our dedicated guidance counsellors provide individual and in-depth guidance to all students as they embark on the next steps in their lives.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : All admission related fees are listed clearly in our Admissions and Enrolment pack and on the Yew Chung International School Hong Kong (YCIS HK) website. These fees should be paid directly to the official accounts of YCIS HK.
#
# How Yew Chung International School of Hong Kong Performs
#
#   Academic Integration:
#   For some Year levels the students enjoy Learning Communities open plan flexible spaces, which provide multiple learning options depending on the task in-hand.
#
#   Facilities & Resources:
#   YCIS Hong Kong campuses are more than places of education. They are places for students to grow with no boundaries.
#
#   Coaching Credentials:
#   Today, YCIS Hong Kong operates eight campuses across prime locations in Kowloon Tong, along with an additional campus in the heart of Tseung Kwan O. We provide a seamless, world-class educational journey from Early Childhood Education (ECE) through Secondary, welcoming children aged 6 months to 18 years from both local and international families.
#
#   Student Wellbeing:
#   Ms Ingrid Luk Van graduated from the University of Pennsylvania (MPhilEd, MSEd) and the University of Virginia (BA), specialising in mental health counselling and psychology. She co-authored a scientific literature review for Current Diabetes Reports with the University of Virginia’s School of Medicine.
#
#   Competitive Pathway:
#   YCIS Hong Kong is a fully accredited school recognised by the Council of International Schools (CIS) and an approved Cambridge International Examinations testing centre for the International General Certificate of Secondary Education (IGCSE). As an International Baccalaureate World School (IB World School), we are proud to offer the International Baccalaureate (IB) Diploma Programme as part of our international curriculum.
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Hong Kong
#   Website  : https://ycis-hk.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → yew_chung_international_school_of_h_wp_blocks.txt
# School JSON → yew_chung_international_school_of_h_data.json
#
# ============================================================
#  Scraping: https://isf.edu.hk
# ============================================================
# Connecting to: https://isf.edu.hk...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for The ISF Academy
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 8 missing field(s): Founded, Ages, Students, Ratio, Fees, About, Philosophy, Admissions
#   ✓ OpenAI filled: Founded, Ages, Students, Ratio, About, Philosophy, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › The ISF Academy
# ——————————————————————————————————————————————————
#
# 4–18          2000          1:10          2003
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.isf.edu.hk/wp-content/uploads/2022/01/The-ISF-Services_2-scaled.jpg
#   2. https://www.isf.edu.hk/wp-content/uploads/2022/05/Art_Virtue_Shirt.jpg
#   3. https://www.isf.edu.hk/wp-content/uploads/2022/01/The-ISF-Services-1-scaled.jpg
#   4. https://academy.isf.edu.hk/wp-content/uploads/20210812_ISF-9120-scaled.jpg
#   5. https://www.isf.edu.hk/wp-content/uploads/2022/01/The-ISF-Services_4-scaled.jpg
#   6. https://academy.isf.edu.hk/wp-content/uploads/G10-11-Day-2_3-Plogging-scaled-1-500x375.jpg
#   7. https://academy.isf.edu.hk/wp-content/uploads/IMGC2184-scaled.jpg
#   8. https://academy.isf.edu.hk/wp-content/uploads/20210812_ISF-8633-scaled-e1631502178927.jpg
#   9. https://www.isf.edu.hk/wp-content/uploads/2022/01/CKS-2-scaled-1.jpg
#   10. https://www.isf.edu.hk/wp-content/uploads/2022/04/IMG_7015_edited_landing-4.jpg
#
# About The ISF Academy
# The ISF Academy is a bilingual IB World School in Hong Kong, fostering innovation and excellence. It offers a holistic education inspired by Nobel Laureate Professor Charles Kao.
#
# Institution Details
#   Type       : IB World Day School
#   Ages       : 4–18
#   Students   : 2000
#   Ratio      : 1:10
#   Founded    : 2003
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Nurturing global thinkers with a passion for lifelong learning, guided by integrity, respect, and cultural understanding."
#
# How they teach
# The ISF Academy emphasizes a bilingual education, nurturing global citizens with a strong moral compass. It integrates Chinese and Western cultures to develop well-rounded, innovative thinkers.
#
# Outcomes: Where students go
# ISF celebrates outstanding International Baccalaureate Diploma Programme (IBDP) results and an impressive range of tertiary education offers with the 68 graduates from the Class of 2023. “We are inordinately proud of this graduating class for their remarkable resilience and impressive recovery from the disruptions of the pandemic, which remained in force until the final months of their DP studies.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students undergo a comprehensive application process, including assessments and interviews. The Academy seeks students who thrive in a rigorous, bilingual learning environment.
#
# How The ISF Academy Performs
#
#   Coaching Credentials:
#   “We are inordinately proud of this graduating class for their remarkable resilience and impressive recovery from the disruptions of the pandemic, which remained in force until the final months of their DP studies. At the same time, all IBDP standards, expectations, and grade boundaries have been reset to more stringent pre-pandemic standards.
#
#   Student Wellbeing:
#   ISF celebrates outstanding International Baccalaureate Diploma Programme (IBDP) results and an impressive range of tertiary education offers with the 68 graduates from the Class of 2023. “We are inordinately proud of this graduating class for their remarkable resilience and impressive recovery from the disruptions of the pandemic, which remained in force until the final months of their DP studies.
#
#   Academic Integration:
#   N/A
#
#   Competitive Pathway:
#   N/A
#
#   Facilities & Resources:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Hong Kong
#   Website  : https://isf.edu.hk
# ——————————————————————————————————————————————————
#
#  WP blocks  → the_isf_academy_wp_blocks.txt
# School JSON → the_isf_academy_data.json
#
# ============================================================
#  Scraping: https://fis.edu.hk
# ============================================================
# Connecting to: https://fis.edu.hk...
#   ⚠ networkidle failed (Error), retrying…
#   ✗ Failed: Page.goto: net::ERR_CONNECTION_TIMED_OUT at https://fis.edu.hk/
# Call log:
#   - navigating to "https://fis.edu.hk/", waiting until "domcontentloaded"
#
#   ✗ Could not load https://fis.edu.hk, skipping.
#
# ============================================================
#  Scraping: https://hkfc.com
# ============================================================
# Connecting to: https://hkfc.com...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Hong Kong Football Club
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 7 missing field(s): Ages, Ratio, Fees, About, Philosophy, Outcomes, Admissions
#   ✓ OpenAI filled: About, Philosophy, Outcomes, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong Football Club
# ——————————————————————————————————————————————————
#
# N/A           1000          N/A           2025
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://hkfc.com/media/nt5nzx2a/sportsmans-bar_2024_mob.png
#   2. https://hkfc.com/media/n2qez50z/04_facilities-3x.png
#   3. https://hkfc.com/media/whnjqy12/squash-24-2x.png
#   4. https://hkfc.com/media/jp5f3mnd/sportsmans-bar_2024_land.png
#   5. https://hkfc.com/media/msmbqgo3/408x680.jpg
#   6. https://hkfc.com/media/wr3pfcpt/rugby-24-3x.png
#   7. https://hkfc.com/media/rupjc0nh/03-img-2x.jpg
#   8. https://hkfc.com/media/hjcdh1nz/01_squash_header_img_01-2x.png
#   9. https://hkfc.com/media/j1vobz1e/untitled-design-39.png
#   10. https://hkfc.com/media/csgdpiso/smbbackpatio_2024.jpg
#
# About Hong Kong Football Club
# Hong Kong Football Club is a premier sports institution offering top-tier facilities and a wide range of competitive and recreational sports.
#
# Institution Details
#   Type       : Football Club & Academy
#   Ages       : N/A
#   Students   : 1000
#   Ratio      : N/A
#   Founded    : 2025
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Fostering excellence and unity through passion and dedication, we empower every player to reach their potential."
#
# How they teach
# The Club fosters community engagement and athletic excellence across various sports disciplines.
#
# Outcomes: Where students go
# Members benefit from world-class sports facilities and opportunities to compete at high levels.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Interested individuals can visit the website for membership details and application procedures.
#
# How Hong Kong Football Club Performs
#
#   Facilities & Resources:
#   When the Club had the opportunity to build an entirely new complex in 1995, it created some of the finest facilities for sport and recreation you can find.
#
#   Academic Integration:
#   The Club’s Soccer Section aims to compete at the highest level possible, involve the Hong Kong community in as many teams and activities as possible and to contribute to raising the standard of 'the beautiful game' in Hong Kong.
#
#   Competitive Pathway:
#   Lawn Bowls is a sport for all regardless of age, gender, strength or physical ability. As well as its competitive achievements, the Lawn Bowls Section also encourages people to try bowling and participate in the sport as a fun and social activity.
#
#   Coaching Credentials:
#   When you expend so much energy on Sports and Recreation, you need to replace it! When the Club had the opportunity to build an entirely new complex in 1995, it created some of the finest facilities for sport and recreation you can find.
#
#   Student Wellbeing:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Hong Kong
#   Website  : https://hkfc.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → hong_kong_football_club_wp_blocks.txt
# School JSON → hong_kong_football_club_data.json
#
# ============================================================
#  Scraping: https://hkjc.com
# ============================================================
# Connecting to: https://hkjc.com...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Hong Kong Jockey Club
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 15 missing field(s): Founded, Ages, Students, Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ OpenAI filled: Founded, Ages, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong Jockey Club
# ——————————————————————————————————————————————————
#
# 18+           N/A           N/A           1884
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/get-involved/events/stay-connected-supplying-the-globe/stay-connected-supplying-the-globe-thumbnail.jpg?rev=df6e4fc301664ca784621857641c2860&sc_lang=zh-HK
#   2. https://consvc.hkjc.com/-/media/Sites/JCEW/Homepage/images/Discover-HKJC/home-discover-hkjc-cch-mobile.png?rev=4d6cfd9678934b608d8a0260eecfcbe2&sc_lang=zh-HK
#   3. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/about-us/community-facilities/hkust/hkust-thumbnail.png?rev=92898ffb351944f88d4c6445b3587769&sc_lang=zh-HK
#   4. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/about-us/community-projects/ehealth-care-project/senior-friendly-technology-exercise-machine-thumbnail.png?rev=2e6dd499fdb3450dbd8961d0c8d60867&sc_lang=zh-HK
#   5. https://consvc.hkjc.com/-/media/Sites/JCEW/Homepage/images/HKJC-Voices/OurPeople_CherKay_Thumbnail.jpg?rev=fc76692a36364521a903e1c36d744a95&sc_lang=zh-HK
#   6. https://hkjc.com/corporate/common/images/spacer.png
#   7. https://hkjc.com/corporate/common/images/who-we-are/tbn-Charities-c.jpg
#   8. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/about-us/community-facilities/chp/chp-thumbnail.png?rev=7dfa08fd2cde498792523f565f3ca67a&sc_lang=zh-HK
#   9. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/about-us/landing/about-us-kv-mobile.png?rev=343b94958f404f8998f0397b22aeab29&sc_lang=zh-HK
#   10. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/about-us/community-projects/non-tips/non-tips-2/jockey-club-emergency-relief-fund.png?rev=026f9ddf4d8b4e89b32d4bf452a65e18&sc_lang=zh-HK
#
# About Hong Kong Jockey Club
# The Hong Kong Jockey Club is a premier institution offering world-class horse racing, sports, and betting entertainment while being the largest charitable donor in Hong Kong.
#
# Institution Details
#   Type       : Members Club & Sports Organisation
#   Ages       : 18+
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 1884
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Empowering communities through passion, integrity, and excellence, inspiring a future of shared success and well-being."
#
# How they teach
# The Club is committed to excellence in service and community contribution, striving to enhance the quality of life in Hong Kong.
#
# Outcomes: Where students go
# Members enjoy exclusive access to top-tier sporting events and contribute to significant charitable initiatives across the city.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Membership is by invitation and subject to a rigorous selection process, ensuring a community of like-minded individuals.
#
# How Hong Kong Jockey Club Performs
#
#   Coaching Credentials:
#   The Club employs experts with extensive experience in horse racing and sports management. Staff are trained to deliver exceptional service and maintain high standards in all activities.
#
#   Student Wellbeing:
#   The Club prioritizes member satisfaction through personalized services and exclusive amenities. It fosters a supportive environment for social and recreational engagement.
#
#   Academic Integration:
#   The Club offers educational programs on horse racing and sports management. It integrates learning with practical experiences at its world-class venues.
#
#   Competitive Pathway:
#   Members have opportunities to participate in prestigious racing events. The Club supports pathways to excellence in various sports disciplines.
#
#   Facilities & Resources:
#   The Club boasts state-of-the-art racecourses and sports facilities. Members enjoy access to exclusive dining, leisure, and entertainment venues.
#
#   Ongoing Accountability:
#   The Club regularly reviews its operations to ensure quality and member satisfaction. It employs feedback mechanisms to continuously improve services and facilities.
#
#   Location : Hong Kong
#   Website  : https://hkjc.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → hong_kong_jockey_club_wp_blocks.txt
# School JSON → hong_kong_jockey_club_data.json
#
# ============================================================
#  Scraping: https://www.tennishk.org/en/
# ============================================================
# Connecting to: https://www.tennishk.org/en/...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 5 missing field(s): Ages, Ratio, Fees, Outcomes, Admissions
#   ✓ OpenAI filled: Ages, Outcomes, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong, China Tennis Association
# ——————————————————————————————————————————————————
#
# All ages      1985          N/A           1970
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.tennishk.org/wp-content/uploads/2020/03/2014-1.jpg
#   2. https://www.tennishk.org/wp-content/themes/hkta/template/frontend/images/back_to_top.png
#   3. https://www.tennishk.org/wp-content/uploads/2020/03/Oscar-Chow-e1702639032288.jpg
#   4. https://www.tennishk.org/wp-content/uploads/2020/04/Head_1-2.jpg
#   5. https://www.tennishk.org/wp-content/uploads/2024/06/SCAA.png
#   6. https://www.tennishk.org/wp-content/uploads/2024/06/AC.png
#   7. https://www.tennishk.org/wp-content/uploads/2020/03/Lam-Siu-Wai_v1.jpg
#   8. https://www.tennishk.org/wp-content/uploads/2020/03/Willy-Chan_v1.jpg
#   9. https://www.tennishk.org/wp-content/uploads/2024/02/Picture5.png
#   10. https://www.tennishk.org/wp-content/uploads/2021/03/1970.jpg
#
# About Hong Kong, China Tennis Association
# To promote tennis to all through the HKCTA and collaborations with other tennis and Government bodies. To set and maintain the standards of the game to an international level and to nurture talented local players to compete in regional and international tournaments.
#
# Institution Details
#   Type       : Tennis Association
#   Ages       : All ages
#   Students   : 1985
#   Ratio      : N/A
#   Founded    : 1970
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "To raise the standard of tennis by organising local, regional and international competitions."
#
# How they teach
# In the 1950’s frequent exhibition matches were played at HKCC, featuring top Davis Cup players from Australia, USA, Sweden and India, and in 1957 Jack Kramer’s “Circus”, featuring Pancho Segura, Lew Hoad, Ken Rosewall and Kramer himself displayed their skills at Chater Road. However, it was with the arrival of the open era in 1968, with the barrier between amateur and professional tennis being abolished, that tennis became more publicly known and HKLTA launched its first development programmes.
#
# Outcomes: Where students go
# HKCTA nurtures local talent to compete internationally and promotes tennis as a lifelong sport for all ages.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Membership is open to all; interested individuals can apply through the HKCTA website or contact their office for more details.
#
# How Hong Kong, China Tennis Association Performs
#
#   Competitive Pathway:
#   The School Sports Programme (SSP) is organised by various National Sports Associations (NSAs) and subvented by the Leisure and Cultural Services Department (LCSD). The implementation of the SSP is coordinated by the LCSD and the activities are co-organised by the Education Bureau (EDB), the Chinese University of Hong Kong (CUHK) and the Hong Kong Baptist University (HKBU).
#
#   Facilities & Resources:
#   To nurture students’ interest in sports so as to foster a sporting culture on school campuses; to encourage students to participate in sports on a regular basis and develop a healthy and active lifestyle; to raise the sport performance standard among students; and to identify potential student athletes for further training.
#
#   Ongoing Accountability:
#   Purpose: To offer students who have potentials and aspire to make progress in tennis sustainable and systemic training, so as to enhance their skills.
#
#   Coaching Credentials:
#   HKCTA's Tennis Centre at Kowloon Tsai is the first National Training Centre (NTC) in Asia to attain certified recognition from the ITF (Bronze Level status).
#
#   Student Wellbeing:
#   To promote tennis to all through the HKCTA and collaborations with other tennis and Government bodies. To set and maintain the standards of the game to an international level and to nurture talented local players to compete in regional and international tournaments.
#
#   Academic Integration:
#   HKCTA meets its primary objectives through the organisation of a number of local and international tennis events as well as junior and elite development programmes, a corporate training scheme, coaching certification courses, a Tennis-For-All open enrollment programme, and a mini-tennis initiative for young children, amongst other initiatives. Hong Kong Tennis Foundation (HKTF) was formed and started to support many HKTA programmes.
#
#   Location : Hong Kong
#   Website  : https://www.tennishk.org/en/
# ——————————————————————————————————————————————————
#
#  WP blocks  → hong_kong_china_tennis_association_wp_blocks.txt
# School JSON → hong_kong_china_tennis_association_data.json
#
# ============================================================
#  Scraping: https://britishtutors.com
# ============================================================
# Connecting to: https://britishtutors.com...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 5 missing field(s): Ages, Students, Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Ages, Outcomes
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › British Tutors
# ——————————————————————————————————————————————————
#
# 5–18          N/A           N/A           2008
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/1770725706078-XOWINDVWO0QBT7BI66MU/image-asset.jpeg
#   2. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/1710137043357-IXCU5DE4J587VDPB7KIY/vadim-sherbakov-d6ebY-faOO0-unsplash.jpg
#   3. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/60b83c70-12b4-413b-b631-47ec02134965/elephant-sticker-2.png
#   4. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/641e5c6d-fe10-48f1-a777-38d68fd8d0db/elephant-stickers-4.png
#   5. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/58d03aa6-ba0a-48db-8425-6657976c0970/playtimes-280x96-1.png
#   6. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/834b3777-7ff6-4f59-8d19-4bd8cd53d4f6/4L4A5327.jpg?format=2500w
#   7. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/1715652069555-RBDWDK69ZPJTLB8GMURQ/ying-ge--Yo1cWJVKFY-unsplash.jpg
#   8. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/1710136068342-D183D0OCUP9SLB4V25RW/annie-spratt-4-4WPFLVhAY-unsplash.jpg?format=2500w
#   9. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/1711469449776-XHJBDL25TC7RNJFL6YXH/image-asset.jpeg
#   10. https://images.squarespace-cdn.com/content/v1/65a69e9727cdb82a91524455/76023e5d-bfc8-4263-9703-55fa914b8758/tatler.png
#
# About British Tutors
# Founded in 2008, British Tutors is an award-winning private tuition and education consultancy company. We arrange lessons with top tutors in Hong Kong and Singapore, offering academic support in a wide range of subjects.
#
# Institution Details
#   Type       : Tutoring & Education Consultancy
#   Ages       : 5–18
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 2008
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "British Tutors act as teachers and, more importantly, mentors for our children."
#
# How they teach
# June - September: Research the university and attend open days where possible. For some courses, you’ll be required to sit an admissions test, which the university use to assess your academic potential and suitability for the course.
#
# Outcomes: Where students go
# British Tutors helps students gain admission to top universities, including Oxford and Cambridge. Their tailored approach enhances academic performance and builds confidence in a wide range of subjects.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : We are Asia’s experts in preparing students to apply for Oxford and Cambridge Universities. The application is a multi-step process and our team of Oxbridge graduate tutors and advisors can help you with every step of the journey.
#
# How British Tutors Performs
#
#   Competitive Pathway:
#   Both Oxford and Cambridge are known for their prestige, and the competition is certainly fierce. Each year, thousands of talented applicants apply for a limited number of places, so standing out is essential.
#
#   Coaching Credentials:
#   Suzy holds a first class Bachelor of Science degree in Psychology from The Open University, UK. She works to find the perfect tutor for every British Tutors client.
#
#   Student Wellbeing:
#   Founded in 2008, British Tutors is an award-winning private tuition and education consultancy company. We arrange lessons with top tutors in Hong Kong and Singapore, offering academic support in a wide range of subjects.
#
#   Academic Integration:
#   N/A
#
#   Facilities & Resources:
#   Our tutors all have access to our library of British teaching materials, bringing the best of British education to their students in Hong Kong and Singapore. As a company, we specialise in teaching children who are entering the British schooling system, to bridge the gap and ease the transition between the local system and that in the UK.
#
#   Ongoing Accountability:
#   Salina heads the accounts department, liaising with clients in both English and Cantonese. Taking pride in her efficiency and keen eye for detail, she is the point of contact for invoicing and sends on detailed monthly progress reports to clients.
#
#   Location : Hong Kong
#   Website  : https://britishtutors.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → british_tutors_wp_blocks.txt
# School JSON → british_tutors_data.json
#
# ============================================================
#  Scraping: https://haven-edu.com/
# ============================================================
# Connecting to: https://haven-edu.com/...
#   ⚠ networkidle failed (TimeoutError), retrying…
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 6 missing field(s): Founded, Ratio, Fees, Philosophy, Outcomes, Admissions
#   ✓ OpenAI filled: Philosophy, Outcomes, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Haven Education
# ——————————————————————————————————————————————————
#
# 5–18          130           N/A           N/A
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://cdn.prod.website-files.com/6839db09623686bea62165c4/69087980b1d06f38e4f7de1e_puzzle-hero-img_3-1.webp
#   2. https://cdn.prod.website-files.com/6839db09623686bea62165c4/69099ede45249e1afda63bc6_method-storytelling.webp
#   3. https://cdn.prod.website-files.com/6839db09623686bea62165c4/692d6c1ad605958cfc85d425_CDNIS.png
#   4. https://cdn.prod.website-files.com/6839db09623686bea62165c4/69099ede8643d89cc6729d5b_method-mentorship.webp
#   5. https://cdn.prod.website-files.com/6839db09623686bea62165c4/6846c7397396f7b9bec6b5ea_testimonial-sho.webp
#   6. https://cdn.prod.website-files.com/6839db09623686bea62165c4/6909a82d015c4841471f4c63_our-mission-image-2.webp
#   7. https://cdn.prod.website-files.com/6839db09623686bea62165c4/692d6111b0a2b150c3632a39_King-George-V-School.png
#   8. https://maps.gstatic.com/mapfiles/api-3/images/spotlight-poi3_hdpi.png
#   9. https://cdn.prod.website-files.com/6839db09623686bea62165c4/69087980bb9893428a08de5e_puzzle-hero-img_2-1.webp
#   10. https://cdn.prod.website-files.com/6839db09623686bea62165c4/692d6440e429332fa64d0053_SISHK.png
#
# About Haven Education
# Educational syllabi undervalue critical soft skills, empathy, and personal development It started in Hong Kong's classrooms. We kept meeting these incredible students, but their spark was being buried under the constant pressure to perform.We realized the most important thing they were missing wasn't on any syllabus: it was a mentor who actually cared.
#
# Institution Details
#   Type       : Psychology & Wellbeing Practice
#   Ages       : 5–18
#   Students   : 130
#   Ratio      : N/A
#   Founded    : N/A
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Ryan exemplifies dedication, fostering seamless collaboration through thoughtful communication and unwavering commitment to my son's growth."
#
# How they teach
# Haven Education emphasizes holistic development, nurturing empathy and personal growth alongside academic success. We focus on creating a supportive environment where students can thrive beyond traditional metrics.
#
# Outcomes: Where students go
# Students gain confidence and critical soft skills, preparing them for future academic and personal challenges. Our approach fosters resilience and a lifelong love of learning.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students can apply online through our website. Enrollment is open year-round, subject to availability and assessment.
#
# How Haven Education Performs
#
#   Coaching Credentials:
#   Lucas is a seasoned digital strategist at Google with a proven track record of driving growth for leading brands and tech companies. With expertise in go-to-market strategy, digital transformation, and venturebuilding, he advises Haven on scaling its unique educational model and expanding its digital footprint to reach a broader audience.
#
#   Student Wellbeing:
#   Educational syllabi undervalue critical soft skills, empathy, and personal development It started in Hong Kong's classrooms. We kept meeting these incredible students, but their spark was being buried under the constant pressure to perform.We realized the most important thing they were missing wasn't on any syllabus: it was a mentor who actually cared.
#
#   Academic Integration:
#   It started in Hong Kong's classrooms. We kept meeting these incredible students, but their spark was being buried under the constant pressure to perform.We realized the most important thing they were missing wasn't on any syllabus: it was a mentor who actually cared.
#
#   Competitive Pathway:
#   N/A
#
#   Facilities & Resources:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Hong Kong
#   Website  : https://haven-edu.com/
# ——————————————————————————————————————————————————
#
#  WP blocks  → haven_education_wp_blocks.txt
# School JSON → haven_education_data.json
#
# ...
#   4. https://www.mindnlife.com/wp-content/uploads/2022/08/womens-group-mindnlife.jpg
#   5. https://www.mindnlife.com/wp-content/uploads/2025/12/winner-blog-image-1-2048x1152.png
#   6. https://www.mindnlife.com/wp-content/uploads/2022/08/TKPA-20220817-MINDNLIFE-0058HDR-scaled.jpg
#   7. https://www.mindnlife.com/wp-content/uploads/elementor/thumbs/winner-2-r0yps90jyel00qa7oitktpp02h7beasuqus0oju82k.jpeg
#   8. https://www.mindnlife.com/wp-content/uploads/elementor/thumbs/winner-r0yps671dwh51web4zlp48emabl7r7hnqgtk8pyel8.jpeg
#   9. https://www.mindnlife.com/wp-content/uploads/2022/08/about-mindnlife-1-1024x1024.jpg
#   10. https://www.mindnlife.com/wp-content/uploads/elementor/thumbs/readers-choice-awards-2022-r60x6ec55vwlwwg5r1b4xkor10buu3voe65ij9gcbg.png
#
# About MindNLife Psychology Practice
# MindNLife Psychology Practice offers tailored psychological services focusing on mindfulness and wellbeing. We provide personalized support to help clients navigate life's challenges.
#
# Institution Details
#   Type       : Mindfulness & Wellbeing
#   Ages       : 6–12
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 2017
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Empower your journey to balance and clarity, nurturing resilience through mindful presence and compassionate understanding."
#
# How they teach
# We prioritize a client-centered approach, ensuring each individual receives care that respects their unique needs. Our ethos is to empower clients through understanding and compassion.
#
# Outcomes: Where students go
# Clients gain clarity and strategies to manage personal challenges effectively. We aim to enhance overall mental wellbeing and resilience.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective clients can contact us via our website or phone to schedule an initial consultation. We offer flexible appointment times to accommodate diverse schedules.
#
# How MindNLife Psychology Practice Performs
#
#   Facilities & Resources:
#   A decision to end a marriage can be a very challenging decision, and this decision starts a cascade of events that require many more important decisions, one of them is how to actually get the divorce - through Court, Mediation or Collaborative Divorce. This guideline explains why Collaborative Divorce is often the preferred method to ensure a couple divorces with dignity and respect.
#
#   Coaching Credentials:
#   Our team consists of highly qualified psychologists with extensive experience in mindfulness and therapeutic practices. They hold advanced degrees and are registered with professional psychological bodies.
#
#   Student Wellbeing:
#   We provide a safe and supportive environment for clients to explore their concerns. Our services include stress management and emotional regulation techniques.
#
#   Academic Integration:
#   We offer workshops and sessions that integrate psychological principles with practical life skills. Our programs are designed to complement educational and personal development.
#
#   Competitive Pathway:
#   Clients often achieve improved mental health and personal growth. Our practice is known for fostering long-term positive changes in clients' lives.
#
#   Ongoing Accountability:
#   We regularly review client progress through structured feedback sessions. Our commitment to quality ensures continuous improvement and client satisfaction.
#
#   Location : Hong Kong
#   Website  : https://www.mindnlife.com/
# ——————————————————————————————————————————————————
#
#  WP blocks  → mindnlife_psychology_practice_wp_blocks.txt
# School JSON → mindnlife_psychology_practice_data.json
#
# ============================================================
#  Scraping: https://www.rosewoodhotels.com/en/hong-kong/wellness
# ============================================================
# Connecting to: https://www.rosewoodhotels.com/en/hong-kong/wellness...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 6 missing field(s): Ages, Students, Ratio, Fees, Outcomes, Admissions
#   ✓ OpenAI filled: Outcomes, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Rosewood Hong Kong
# ——————————————————————————————————————————————————
#
# N/A           N/A           N/A           1978
# Ages          Students      Ratio         Founded
#
# Images Found: 0
#
# About Rosewood Hong Kong
# Its verticality reveals breathtaking views through some of the city’s largest windows—Kowloon’s cityscape, mountains peaks, the skyline and harbour waters​. A week-long stay at Rosewood Hong Kong offers the perfect blend of comfort and luxury​.
#
# Institution Details
#   Type       : Wellness & Lifestyle Centre
#   Ages       : N/A
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 1978
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "For a holistic approach to well-being, enter Asaya and explore our Private wellness lodges, moonlight yoga and renowned hair styling featuring Rossano Ferretti HairSpa."
#
# How they teach
# Imbued with warmth and personality, dedicated service at Rosewood Hong Kong focuses on making guests' stays as smooth and enjoyable as possible, whether they are traveling for business or leisure. Each of Rosewood Hong Kong’s eleven dining concepts possesses a distinctive character, showcasing creativity and a contemporary interpretation of accessible gastronomy and refined beverage craft.
#
# Outcomes: Where students go
# Rosewood Hong Kong provides a luxurious retreat with personalized services, ensuring a memorable stay. Guests enjoy exquisite dining and breathtaking views, enhancing their overall wellness experience.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Reservations can be made through the Rosewood Hong Kong website or by contacting their concierge. Availability may vary based on season and demand.
#
# How Rosewood Hong Kong Performs
#
#   Coaching Credentials:
#   Its verticality reveals breathtaking views through some of the city’s largest windows—Kowloon’s cityscape, mountains peaks, the skyline and harbour waters​. A week-long stay at Rosewood Hong Kong offers the perfect blend of comfort and luxury​.
#
#   Student Wellbeing:
#   N/A
#
#   Academic Integration:
#   Imbued with warmth and personality, dedicated service at Rosewood Hong Kong focuses on making guests' stays as smooth and enjoyable as possible, whether they are traveling for business or leisure. Each of Rosewood Hong Kong’s eleven dining concepts possesses a distinctive character, showcasing creativity and a contemporary interpretation of accessible gastronomy and refined beverage craft.
#
#   Competitive Pathway:
#   N/A
#
#   Facilities & Resources:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Hong Kong
#   Website  : https://www.rosewoodhotels.com/en/hong-kong/wellness
# ——————————————————————————————————————————————————
#
#  WP blocks  → rosewood_hong_kong_wp_blocks.txt
# School JSON → rosewood_hong_kong_data.json
#
# ============================================================
#  Scraping: https://mindfulkidshk.com
# ============================================================
# Connecting to: https://mindfulkidshk.com...
#   ⚠ networkidle failed (TimeoutError), retrying…
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for MindfulKids®
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 8 missing field(s): Founded, Ages, Students, Ratio, Fees, Philosophy, Outcomes, Admissions
#   ✓ OpenAI filled: Founded, Ages, Students, Ratio, Philosophy, Outcomes, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › MindfulKids®
# ——————————————————————————————————————————————————
#
# 4-18          500           1:10          2015
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://static.wixstatic.com/media/6824df_2e209931f9cf403b98d4586725e26697~mv2.jpg/v1/fill/w_264
#   2. https://static.wixstatic.com/media/0fdef751204647a3bbd7eaa2827ed4f9.png/v1/fill/w_20
#   3. https://mindfulkidshk.com/quality_auto/May%20Chow_edited.jpg
#   4. https://mindfulkidshk.com/quality_auto/Trista%20Law.jpeg
#   5. https://mindfulkidshk.com/quality_auto/WhatsApp%20Image%202024-05-13%20at%2016_39_edited.jpg
#   6. https://static.wixstatic.com/media/01c3aff52f2a4dffa526d7a9843d46ea.png/v1/fill/w_20
#   7. https://mindfulkidshk.com/quality_auto/MindfulKids-with%20word.jpg
#   8. https://static.wixstatic.com/media/6824df_2b88d672bfb84636afd0930613545937~mv2.jpg/v1/crop/x_533
#   9. https://static.wixstatic.com/media/6824df_acd30fcfb7794fe380a6e4a418e2ef73~mv2.jpg/v1/fill/w_165
#   10. https://mindfulkidshk.com/quality_auto/8d6893330740455c96d218258a458aa4.png
#
# About MindfulKids®
# MindfulKids® consists of a highly experienced team of talented psychological professionals to provide quality services to individuals and organizations. Eva Wong is now based in Malaysia, and is the contact point for MindfulKids®️ Malaysia * Ms.
#
# Institution Details
#   Type       : Mindfulness & Wellbeing
#   Ages       : 4-18
#   Students   : 500
#   Ratio      : 1:10
#   Founded    : 2015
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Nurturing young minds with mindfulness, fostering resilience and wellbeing for a brighter future."
#
# How they teach
# MindfulKids® fosters emotional resilience and self-awareness through mindfulness practices tailored for children and their caregivers.
#
# Outcomes: Where students go
# Participants develop enhanced focus, reduced stress, and improved emotional regulation, empowering them to thrive in various aspects of life.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Interested individuals can apply online via the MindfulKids® website, with programs available throughout the year.
#
# How MindfulKids® Performs
#
#   Coaching Credentials:
#   MindfulKids® consists of a highly experienced team of talented psychological professionals to provide quality services to individuals and organizations.
#
#   Student Wellbeing:
#   N/A
#
#   Academic Integration:
#   N/A
#
#   Competitive Pathway:
#   N/A
#
#   Facilities & Resources:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Hong Kong
#   Website  : https://mindfulkidshk.com
# ——————————————————————————————————————————————————
#
#  WP blocks  → mindfulkids_wp_blocks.txt
# School JSON → mindfulkids_data.json
#
# ============================================================
#  Scraping: https://www.hkcchoir.org.hk/en/
# ============================================================
# Connecting to: https://www.hkcchoir.org.hk/en/...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Hong Kong Children's Choir
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Ratio, Outcomes
#
# ——————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong Children's Choir
# ——————————————————————————————————————————————————
#
# 5–15          200           1:25          1969
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.hkcchoir.org.hk/sites/default/files/waccl.png
#   2. https://www.hkcchoir.org.hk/sites/default/files/styles/album_type/public/album/back_cover_260320_0.jpg?itok=3768vF8m
#   3. https://www.hkcchoir.org.hk/sites/default/files/styles/news/public/cover/2020_chamber_youth_thumbnail.jpg?itok=EZv7_kAy
#   4. https://www.hkcchoir.org.hk/sites/all/themes/ntemplate/images/title_video_en.png
#   5. https://www.hkcchoir.org.hk/sites/default/files/styles/useful_link/public/useful/leave_en.png?itok=5t3CkvQo
#   6. https://www.hkcchoir.org.hk/sites/default/files/styles/news/public/cover/2018_dr_ho_interview_thumbnail.png?itok=0L6TT87X
#   7. https://www.hkcchoir.org.hk/sites/default/files/styles/slider2/public/c1.jpg?itok=7cb6C85l
#   8. https://www.hkcchoir.org.hk/sites/default/files/styles/slider2/public/555.jpg?itok=m9Slc5tV
#   9. https://www.hkcchoir.org.hk/sites/default/files/styles/news/public/cover/2019_50th_gala_thumbnail.png?itok=qmkGUj4V
#   10. https://www.hkcchoir.org.hk/sites/default/files/styles/album_type/public/album/web_sportswear_yellow_0.png?itok=gPUHp472
#
# About Hong Kong Children's Choir
# The Hong Kong Children’s Choir (HKCC), founded in 1969, is the first and largest children’s choir in Hong Kong with around 5,000 members. Registered as a non-profit-making charitable organization, HKCC has grown into a diversified arts organization.
#
# Institution Details
#   Type       : Music & Performing Arts Organisation
#   Ages       : 5–15
#   Students   : 200
#   Ratio      : 1:25
#   Founded    : 1969
#   City       : Hong Kong
#   Annual Fee : See website
#
# Quotes
#   "Nurturing young voices and hearts, we inspire harmony and creativity through the universal language of music."
#
# How they teach
# HKCC organizes numerous concerts and performances annually, allowing members to share their love for the arts with the community. In 2019, HKCC presented the “Asia Pacific Choral Summit” which was awarded the 14th HKADC Award for Arts Promotion and the “Hong Kong Choral Conducting Competition” to celebrate its 50th Anniversary.
#
# Outcomes: Where students go
# HKCC nurtures musical talent and fosters a lifelong appreciation for the arts among its members, enhancing their confidence and teamwork skills through diverse performance opportunities.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : As a diversified arts organisation for children, The Hong Kong Children's Choir (HKCC) offers five distinct learning programmes for children with different artistic aspirations and interests, including Choral Programme, Dance Programme, Instrumental Programme, Putonghau Programme and Intelligence-Emotion-Creativity (IEC) Programme. Due to the varying teaching progress and the needs of individual programmes, each programme has its designated admission period and procedures as follows: (Need to meet the age requirement on 1st January for applying the public examinations) (Need to meet the age requirement on 1st July for applying the public examinations) Application via Fax and Email will not be accepted.
#
# How Hong Kong Children's Choir Performs
#
#   Competitive Pathway:
#   Lin was educated at the Music Department of Chinese University of Hong Kong and studied piano performance with Prof David Gwilt. After graduation, she was awarded a scholarship to pursue a Music Master's Degree at the Birmingham Conservatoire in the UK.
#
#   Academic Integration:
#   To further expand The Hong Kong Children’s Choir (HKCC) development in arts education and hence the contribution to society, the HK Children’s Choir Arts Development Fund was officially launched on 30 August 2018. The Fund consists of two main schemes to fully support students who are interested in the arts at various stages and ages.
#
#   Coaching Credentials:
#   The Hong Kong Children’s Choir (HKCC), founded in 1969, is the first and largest children’s choir in Hong Kong with around 5,000 members. Registered as a non-profit-making charitable organization, HKCC has grown into a diversified arts organization.
#
#   Student Wellbeing:
#   N/A
#
#   Facilities & Resources:
#   N/A
#
#   Ongoing Accountability:
#   As a diversified arts organisation for children, The Hong Kong Children's Choir (HKCC) offers five distinct learning programmes for children with different artistic aspirations and interests, including Choral Programme, Dance Programme, Instrumental Programme, Putonghau Programme and Intelligence-Emotion-Creativity (IEC) Programme.
#
#   Location : Hong Kong
#   Website  : https://www.hkcchoir.org.hk/en/
# ——————————————————————————————————————————————————
#
#  WP blocks  → hong_kong_children_s_choir_wp_blocks.txt
# School JSON → hong_kong_children_s_choir_data.json
#
# ============================================================
# All done! 17 schools scraped.
# Master JSON → all_schools_data_hongkong.json
# ============================================================

# %%
import asyncio
import re
import sys
import json
import urllib.request
import os
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from datetime import datetime


# ── SENTENCE-SAFE TRUNCATION ──────────────────────────────────────────────────

def clean_to_sentences(text: str, max_sentences: int = 2) -> str:
    if not text:
        return ""
    text = re.sub(r'\s+', ' ', text).strip()
    sentences = re.split(r'(?<=[.!?])\s+', text)
    good = [
        s.strip() for s in sentences
        if len(s.strip().split()) >= 6 and re.search(r'[.!?]$', s.strip())
    ]
    return " ".join(good[:max_sentences])


# ── API KEY ───────────────────────────────────────────────────────────────────

try:
    from dotenv import load_dotenv
    load_dotenv()
except ImportError:
    pass

def _get_openai_key() -> str:
    return os.environ.get("OPENAI_API_KEY", "")

def _check_key(key: str, name: str) -> bool:
    if not key or key.startswith("YOUR_") or len(key) < 20:
        print(f"  ⚠ {name} not set — add it to your .env file")
        return False
    return True


# ── HELPERS ───────────────────────────────────────────────────────────────────

async def highlight_and_click(page, selector_or_locator, description="Action"):
    try:
        target = (
            page.locator(selector_or_locator).first
            if isinstance(selector_or_locator, str)
            else selector_or_locator
        )
        if await target.is_visible(timeout=2000):
            await target.evaluate(
                "el => { el.style.border = '4px solid #00FF00';"
                " el.style.backgroundColor = 'rgba(0,255,0,0.2)'; }"
            )
            await target.click()
            return True
    except Exception:
        pass
    return False


async def handle_cookies_automatically(page):
    for selector in [
        "text=Accept All", "text=Accept",
        "button:has-text('Accept')", "button:has-text('OK')",
        "button:has-text('I Agree')", "button:has-text('Close')",
        "button:has-text('Got it')", "button:has-text('Agree')",
    ]:
        if await highlight_and_click(page, selector, "Cookie Banner"):
            break


async def smart_goto(page, url, timeout=90000):
    try:
        await page.goto(url, wait_until="networkidle", timeout=timeout)
        return True
    except Exception as e:
        print(f"  ⚠ networkidle failed ({e.__class__.__name__}), retrying…")
    try:
        await page.goto(url, wait_until="domcontentloaded", timeout=timeout)
        await asyncio.sleep(6)
        try:
            await page.wait_for_function(
                "() => document.body && document.body.innerText.trim().length > 200",
                timeout=15000)
        except Exception:
            pass
        return True
    except Exception as e:
        try:
            await page.goto(url, wait_until="commit", timeout=timeout)
            await asyncio.sleep(8)
            return True
        except Exception:
            pass
        print(f"  ✗ Failed: {e}")
        return False


# ── KNOWN NAMES MAP — city locked, always wins over page title ────────────────
# Format: domain_fragment: (correct_name, correct_city)

KNOWN_NAMES_HK = {
    "harrowhongkong.hk":   ("Harrow Hong Kong",                          "Hong Kong"),
    "kellettschool.com":   ("Kellett School",                             "Hong Kong"),
    "hkis.edu.hk":         ("Hong Kong International School",             "Hong Kong"),
    "ycis-hk.com":         ("Yew Chung International School of Hong Kong","Hong Kong"),
    "isf.edu.hk":          ("The ISF Academy",                           "Hong Kong"),
    "fis.edu.hk":          ("French International School Hong Kong",      "Hong Kong"),
    "hkfc.com":            ("Hong Kong Football Club",                   "Happy Valley, Hong Kong"),
    "hkjc.com":            ("Hong Kong Jockey Club",                     "Hong Kong"),
    "tennishk.org":        ("Hong Kong Tennis Association",              "Hong Kong"),
    "britishtutors.com":   ("British Tutors Hong Kong",                  "Hong Kong"),
    "haven-edu.com":       ("Haven Education",                           "Hong Kong"),
    "itseducation.asia":   ("ITS Education Asia",                        "Hong Kong"),
    "balancehealth.com.hk":("Balance Health",                            "Central, Hong Kong"),
    "hkapa.edu":           ("Hong Kong Academy for Performing Arts",     "Wan Chai, Hong Kong"),
    "mindnlife.com":       ("MindNLife Psychology Practice",             "Hong Kong"),
    "rosewoodhotels.com":  ("Rosewood Hong Kong",                        "Tsim Sha Tsui, Hong Kong"),
    "mindfulkidshk.com":   ("MindfulKids HK",                           "Hong Kong"),
    "hkcchoir.org.hk":     ("Hong Kong Children's Choir",               "Hong Kong"),
}

# Hardcoded verified facts — never overwritten by scraping
KNOWN_DATA_HK = {
    # Harrow Hong Kong: British school, ages 3–18, ~1,650 students, opened 2012
    "harrowhongkong.hk": {
        "Ages": "3–18", "Students": "1650", "Founded": "2012",
        "Type": "British Independent School",
    },
    # Kellett School: British international, ages 4–18, ~1,200 students, founded 1976
    "kellettschool.com": {
        "Ages": "4–18", "Students": "1200", "Founded": "1976",
        "Type": "British International School",
    },
    # HKIS: American school, ages 5–18, ~2,800 students, founded 1966
    "hkis.edu.hk": {
        "Ages": "5–18", "Students": "2800", "Founded": "1966",
        "Type": "American Curriculum International School",
    },
    # YCIS: IB bilingual, ages 6 months–18, ~3,000 students, founded 1932
    "ycis-hk.com": {
        "Ages": "0–18", "Students": "3000", "Founded": "1932",
        "Type": "IB World Bilingual Day School",
    },
    # ISF Academy: IB bilingual, ages 4–18, ~2,000 students, founded 2003
    "isf.edu.hk": {
        "Ages": "4–18", "Students": "2000", "Founded": "2003",
        "Type": "IB World Bilingual Day School",
    },
    # French International School: French curriculum, ages 3–18, founded 1953
    "fis.edu.hk": {
        "Ages": "3–18", "Students": "2400", "Founded": "1953",
        "Type": "French International School",
    },
    # HKFC: sports members club, all ages, founded 1886
    "hkfc.com": {
        "Ages": "All ages", "Students": "N/A", "Founded": "1886",
        "Type": "Members Sports Club & Academy",
    },
    # HKJC: members racing club, adults 18+, founded 1884
    "hkjc.com": {
        "Ages": "Adults 18+", "Students": "N/A", "Founded": "1884",
        "Type": "Members Club & Sports Organisation",
    },
    # HKTA: tennis governing body, all ages, founded 1970
    "tennishk.org": {
        "Ages": "All ages", "Students": "N/A", "Founded": "1970",
        "Type": "Tennis Association & Development Organisation",
    },
    # British Tutors HK: tutoring, ages 5–18, founded 2008
    "britishtutors.com": {
        "Ages": "5–18", "Students": "N/A", "Founded": "2008",
        "Type": "Private Tutoring & Education Consultancy",
    },
    # Haven Education: education mentoring, ages 14–22
    "haven-edu.com": {
        "Ages": "14–22", "Students": "N/A", "Founded": "N/A",
        "Type": "Education Mentoring & Personal Development",
    },
    # ITS Education Asia: school placement consultancy, ages 3–18, founded 2007
    "itseducation.asia": {
        "Ages": "3–18", "Students": "N/A", "Founded": "2007",
        "Type": "School Placement & Education Consultancy",
    },
    # Balance Health: holistic health clinic, adults 18+, founded 2005
    "balancehealth.com.hk": {
        "Ages": "Adults 18+", "Students": "N/A", "Founded": "2005",
        "Type": "Holistic Health & Wellness Clinic",
    },
    # HKAPA: performing arts conservatory, ages 18–30, ~1,000 students, founded 1984
    "hkapa.edu": {
        "Ages": "18–30", "Students": "1000", "Founded": "1984",
        "Type": "Performing Arts Conservatory",
    },
    # MindNLife: psychology practice, adults and families, founded 2017
    "mindnlife.com": {
        "Ages": "All ages", "Students": "N/A", "Founded": "2017",
        "Type": "Psychology & Wellbeing Practice",
    },
    # Rosewood Hong Kong: luxury hotel wellness, opened 2019
    "rosewoodhotels.com": {
        "Ages": "Adults 18+", "Students": "N/A", "Founded": "2019",
        "Type": "Luxury Hotel Wellness & Lifestyle Centre",
    },
    # MindfulKids HK: mindfulness for children, ages 4–18, founded 2015
    "mindfulkidshk.com": {
        "Ages": "4–18", "Students": "N/A", "Founded": "2015",
        "Type": "Mindfulness & Wellbeing Programme for Children",
    },
    # HKCC: children's choir, ages 5–15, ~200 members, founded 1969
    "hkcchoir.org.hk": {
        "Ages": "5–15", "Students": "200", "Founded": "1969",
        "Type": "Youth Music & Performing Arts Organisation",
    },
}


# ── SHORT KEYWORDS MAP for WP blocks ──────────────────────────────────────────

PERF_SHORT = {
    "Coaching Credentials":   "Expert Staff",
    "Student Wellbeing":      "Student Care",
    "Academic Integration":   "Curriculum",
    "Competitive Pathway":    "Achievements",
    "Facilities & Resources": "Facilities",
    "Ongoing Accountability": "Progress",
}


# ── GARBAGE SITE DETECTION ────────────────────────────────────────────────────

GARBAGE_SIGNALS = [
    "hugedomains", "domain for sale", "buy this domain", "sedoparking",
    "this domain is for sale", "godaddy", "namecheap parking",
    "page not found", "account suspended", "coming soon",
    "under construction", "website coming soon",
]

def is_garbage_site(name: str, body_text: str) -> bool:
    combined = (name + " " + body_text[:500]).lower()
    return any(sig in combined for sig in GARBAGE_SIGNALS)


# ── JUNK FILTER ───────────────────────────────────────────────────────────────

JUNK_PATTERNS = [
    # Generic UI / navigation
    r"the site you are about to visit", r"page you requested no longer exists",
    r"managed independently", r"beginning of dialog window", r"escape will cancel",
    r"enquire now$", r"apply now$", r"watch the video", r"learn more$",
    r"find out more$", r"read more$", r"click here",
    r"cookie", r"privacy policy", r"gdpr",
    r"please fill out the form", r"fill the registration form",
    r"mailing list.*keep you up to date", r"joining our mailing list",
    r"to progress your application we require",
    r"documents that are mandatory to upload",
    # HK-specific junk from the log
    r"why are we getting a divorce",
    r"confessions of a divorced kid",
    r"i don't want to talk about it",
    r"koko bear",
    r"split children's journey through divorce",
    r"sesame street: little children",
    r"black belt can be worn",
    r"kam lun", r"paul lam tailors",
    r"closed on sundays and statutory",
    r"embed-container", r"\.embed-container",
    r"draw is managed",
    r"single.elimination system",
    # ISF IB results spam
    r"we are inordinately proud of this graduating class.*remarkable resilience",
    r"at the same time, all ibdp standards.*stringent pre-pandemic standards",
    # HKIS junk
    r"if you are an overseas relocating family.*indicate so in the subject line",
    r"aquatics academy is the after-school program.*repulse bay and tai tam campuses",
    r"tai tam tigers soccer academy was established in 1999",
    r"dragon center for activities.*athletics.*reaffirm our commitment",
    r"in 1964, a hong kong-based committee of the lutheran church",
    # Kellett admin junk
    r"tours at pok fu lam and kowloon bay run regularly",
    r"numbers are limited, please contact tours@kellettschool",
    r"for admissions enquiries, please let us know the following information",
    r"you can apply at any time during the year.*waitlists are fluid",
    # HKTA policy text
    r"school sports programme.*ssp.*national sports associations",
    r"implementation of the ssp.*lcsd.*education bureau",
    r"to nurture students' interest in sports.*foster a sporting culture",
    r"purpose: to offer students who have potentials and aspire to make progress in tennis",
    # ITS junk
    r"online\.ibo\.org.*online curriculum centre.*only accessible for subscribers",
    r"it features discussion forums.*coordinators notes",
    r"genius is one percent inspiration and ninety-nine percent perspiration",
    r"usually the answer to this is simple.*nothing.*just carry on with what you had planned",
    r"marko - instructor.*master's degree.*bachelor's degree",
    r"ibo home page - lists addresses of regional offices",
    # Rosewood hotel junk
    r"its verticality reveals breathtaking views.*some of the city's largest windows",
    r"a week-long stay at rosewood hong kong offers the perfect blend",
    r"each of rosewood hong kong's eleven dining concepts",
    # British Tutors junk
    r"june - september: research the university and attend open days",
    r"for some courses, you'll be required to sit an admissions test",
    # MindNLife divorce content
    r"a decision to end a marriage can be a very challenging decision",
    r"this guideline explains why collaborative divorce is often the preferred method",
    # Haven Education junk
    r"lucas is a seasoned digital strategist at google",
    r"with expertise in go-to-market strategy, digital transformation, and venturebuilding",
    # HKCC verbose admissions
    r"application via fax and email will not be accepted",
    r"need to meet the age requirement on 1st january for applying the public examinations",
    # HKAPA
    r"as the academy's deputy director.*administration.*working closely with the director",
    r"professor chan's influence extends beyond institutional leadership.*sought-after keynote speaker",
]

def is_junk(text: str) -> bool:
    if not text:
        return True
    tl = text.lower().strip()
    return any(re.search(p, tl) for p in JUNK_PATTERNS)


# ── IMAGE HARVESTING ──────────────────────────────────────────────────────────

SKIP_IMG = [
    "logo", "icon", "svg", "1x1", "pixel", "spinner", "placeholder",
    "blank", "transparent", "avatar", "flag", "arrow", "bullet",
    "check", "star", "rating", "rs/facebook", "rs/linkedin", "rs/youtube",
    "loupe", "panier", "menu", "profil", "default_image", "black-beacon",
    "weather/128",
    # HK-specific UI noise
    "back_to_top", "title_video_en", "useful_link", "leave_en",  # HKTA UI
    "spacer.png",   # HKJC spacer
    "ribbon-k4", "ribbon-g",  # HKIS ribbons
    "waccl.png",   # HKCC membership badge
    "readers-choice-awards",   # award badge
    "wasc colour",  # HKIS accreditation logo
    "playtimes-280",  # British Tutors press
    "tatler.png",   # British Tutors press
    "elephant-sticker",  # British Tutors illustrations
    "five-e.webp",  # Balance Health infographic
]
EXTS_IMG = [".jpg", ".jpeg", ".png", ".webp"]

async def harvest_images(pg, base_url: str, image_set: set):
    try:
        await pg.evaluate("""async () => {
            await new Promise(resolve => {
                let total = 0;
                const dist = 400;
                const timer = setInterval(() => {
                    window.scrollBy(0, dist);
                    total += dist;
                    if (total >= document.body.scrollHeight) {
                        clearInterval(timer);
                        window.scrollTo(0, 0);
                        resolve();
                    }
                }, 80);
            });
        }""")
        await asyncio.sleep(1)
    except Exception:
        pass

    try:
        for img in await pg.query_selector_all("img"):
            for attr in ["src", "data-src", "data-lazy-src", "data-original",
                         "data-image", "data-bg", "data-lazy", "data-srcset"]:
                c = await img.get_attribute(attr)
                if c:
                    src = c.strip().split(" ")[0].split(",")[0].strip()
                    full = urljoin(base_url, src)
                    if (any(e in full.lower() for e in EXTS_IMG)
                            and not any(s in full.lower() for s in SKIP_IMG)
                            and len(full) > 25):
                        image_set.add(full)
            srcset = await img.get_attribute("srcset")
            if srcset:
                parts = [p.strip().split(" ")[0] for p in srcset.split(",") if p.strip()]
                if parts:
                    full = urljoin(base_url, parts[-1])
                    if (any(e in full.lower() for e in EXTS_IMG)
                            and not any(s in full.lower() for s in SKIP_IMG)):
                        image_set.add(full)

        for sel in ['meta[property="og:image"]', 'meta[name="twitter:image"]',
                    'meta[property="og:image:url"]']:
            try:
                for og in await pg.evaluate(
                    f"() => Array.from(document.querySelectorAll('{sel}')).map(m=>m.content)"
                ):
                    if og and og.strip() and not any(s in og.lower() for s in SKIP_IMG):
                        image_set.add(og.strip())
            except Exception:
                pass

        bg_urls = await pg.evaluate("""() => {
            const hits = [];
            const sels = [
                '[style*="background-image"]','[class*="hero"]','[class*="banner"]',
                '[class*="slider"]','[class*="slide"]','[class*="bg-image"]',
                '[class*="cover"]','section','header'
            ];
            sels.forEach(sel => {
                try {
                    document.querySelectorAll(sel).forEach(el => {
                        const s = el.style.backgroundImage ||
                                  getComputedStyle(el).backgroundImage || '';
                        const m = s.match(/url\\(["']?([^"')]+)["']?\\)/);
                        if (m && m[1]) hits.push(m[1]);
                    });
                } catch(e) {}
            });
            return [...new Set(hits)];
        }""")
        for bg in bg_urls:
            if bg:
                full = urljoin(base_url, bg.strip())
                if (any(e in full.lower() for e in EXTS_IMG)
                        and not any(s in full.lower() for s in SKIP_IMG)):
                    image_set.add(full)
    except Exception:
        pass


# ── QUOTE SCRAPER ─────────────────────────────────────────────────────────────

def _word_count(text):
    return len(text.split())

def scrape_quote_from_soup(soup):
    SKIP_PHRASES = [
        "cookie", "menu", "nav", "©", "privacy", "terms",
        "subscribe", "sign up", "click", "read more", "javascript",
        "watch the video", "watch video", "listen to", "share",
        "follow us", "contact us", "apply now", "find out more",
        "learn more", "get in touch", "download", "register",
        "book a", "visit us", "dialog window", "escape will cancel",
        "site you are about to visit", "no longer exists",
        # HK-specific quote junk
        "for admissions enquiries, please let us know",
        "to raise the standard of tennis by organising",
        "genius is one percent inspiration",
        "we are inordinately proud of this graduating class",
        "a decision to end a marriage",
        "for a holistic approach to well-being, enter asaya",
    ]
    selectors = [
        "blockquote", "q",
        "[class*='quote']", "[class*='pullquote']", "[class*='callout']",
        "[class*='hero'] p", "[class*='banner'] p",
        "[class*='mission'] p", "[class*='vision'] p",
        "figcaption",
    ]
    candidates = []
    for sel in selectors:
        for el in soup.select(sel):
            text = re.sub(r'\s+', ' ', el.get_text()).strip()
            text = text.strip('\u201c\u201d\u2018\u2019"\'')
            wc   = _word_count(text)
            if wc < 8 or wc > 35:
                continue
            if any(x in text.lower() for x in SKIP_PHRASES):
                continue
            if is_junk(text):
                continue
            if not re.search(r'[.!?]$', text):
                continue
            candidates.append(text)
    if not candidates:
        return ""
    candidates.sort(key=lambda t: _word_count(t))
    return candidates[0]


# ── AI QUOTE ──────────────────────────────────────────────────────────────────

def generate_ai_quote(school_name, school_type, city, about_text):
    key = _get_openai_key()
    if not _check_key(key, "OPENAI_API_KEY"):
        return f"Excellence, integrity, and curiosity — the pillars of {school_name}."
    prompt = (
        f"Write ONE short inspirational quote (1 sentence, 10–20 words) "
        f"that reflects the philosophy of {school_name}, a {school_type} in {city}. "
        f"Context: {about_text[:300]}. "
        f"Sound like the organisation's mission statement. "
        f"Return ONLY the quote text — no quotation marks, no attribution, no explanation."
    )
    payload = json.dumps({
        "model": "gpt-4o", "max_tokens": 60, "temperature": 0.7,
        "messages": [{"role": "user", "content": prompt}],
    }).encode("utf-8")
    req = urllib.request.Request(
        "https://api.openai.com/v1/chat/completions", data=payload,
        headers={"Content-Type": "application/json",
                 "Authorization": f"Bearer {key}"}, method="POST",
    )
    try:
        with urllib.request.urlopen(req, timeout=15) as resp:
            data  = json.loads(resp.read())
            quote = data["choices"][0]["message"]["content"].strip().strip('"\'')
            words = quote.split()
            if len(words) > 25:
                quote = " ".join(words[:25])
            print(f"  ✓ AI quote generated for {school_name}")
            return quote
    except Exception as e:
        print(f"  ⚠ AI quote failed: {e}")
    return f"Excellence, integrity, and curiosity — the pillars of {school_name}."


# ── OPENAI FORCE-FILL ALL PERFORMANCE FIELDS ──────────────────────────────────

def openai_force_fill_performance(results: dict) -> dict:
    """
    Force-fills ALL 6 performance fields.
    Blank, N/A, too short (<12 words), or junk → AI generates 2 unique sentences.
    Never overwrites a genuinely good scraped value.
    """
    key = _get_openai_key()
    if not _check_key(key, "OPENAI_API_KEY"):
        return results

    name        = results.get("Name", "this institution")
    entity_type = results.get("Type", "Independent School")
    city        = results.get("City", "Hong Kong")
    about       = results.get("About", "")
    philosophy  = results.get("Philosophy", "")

    ctx_parts = [f"Name: {name}", f"Type: {entity_type}", f"City: {city}"]
    if about:
        ctx_parts.append(f"About: {about}")
    if philosophy:
        ctx_parts.append(f"Philosophy: {philosophy}")
    for k in ["Founded", "Ages", "Students", "Fees", "Outcomes", "Admissions"]:
        v = results.get(k, "")
        if v and v not in ("N/A", "See website", ""):
            ctx_parts.append(f"{k}: {v}")
    context = "\n".join(ctx_parts)

    PERF_PROMPTS = {
        "Coaching Credentials": (
            f"2 sentences (≤35 words total) about the qualifications, expertise, or professional "
            f"background of staff/coaches/teachers at {name}, a {entity_type} in {city}. "
            f"Mention specific credentials, training, degrees, or international experience. Be specific."
        ),
        "Student Wellbeing": (
            f"2 sentences (≤35 words total) about how {name} supports the mental, emotional, "
            f"or physical wellbeing of students/members/clients. Mention pastoral care, counselling, "
            f"community building, or wellness programmes in Hong Kong. Be specific."
        ),
        "Academic Integration": (
            f"2 sentences (≤35 words total) about the curriculum, programmes, or learning approach "
            f"at {name}. Mention specific qualifications (IB, IGCSE, A-Levels, DSE, AP), "
            f"subjects, or teaching methods used in Hong Kong context. Be specific."
        ),
        "Competitive Pathway": (
            f"2 sentences (≤35 words total) about the results, achievements, university "
            f"destinations, or career pathways of graduates from {name} in Hong Kong. "
            f"Mention university acceptance rates, exam scores, or competition wins. Be specific."
        ),
        "Facilities & Resources": (
            f"2 sentences (≤35 words total) about the physical facilities, campus spaces, "
            f"or resources at {name} in {city}. "
            f"Mention specific amenities — studios, labs, sports halls, pools, courts, equipment. Be specific."
        ),
        "Ongoing Accountability": (
            f"2 sentences (≤35 words total) about how {name} tracks student/client progress, "
            f"provides feedback, or maintains quality in Hong Kong. "
            f"Mention progress reports, parent communication, accreditation, or review cycles. Be specific."
        ),
    }

    PERF_JUNK_PHRASES = [
        "why are we getting a divorce", "confessions of a divorced kid",
        "i don't want to talk about it", "koko bear",
        "split children's journey through divorce",
        "sesame street: little children",
        "black belt can be worn", "kam lun", "paul lam tailors",
        "closed on sundays and statutory",
        "embed-container", ".embed-container",
        "draw is managed", "single-elimination system",
        "we are inordinately proud of this graduating class.*remarkable resilience",
        "at the same time, all ibdp standards.*stringent pre-pandemic standards",
        "if you are an overseas relocating family.*indicate so in the subject line",
        "aquatics academy is the after-school program",
        "tai tam tigers soccer academy was established in 1999",
        "dragon center for activities.*athletics",
        "in 1964, a hong kong-based committee of the lutheran church",
        "tours at pok fu lam and kowloon bay run regularly",
        "for admissions enquiries, please let us know the following information",
        "school sports programme.*ssp.*national sports associations",
        "implementation of the ssp.*lcsd.*education bureau",
        "to nurture students' interest in sports.*foster a sporting culture",
        "purpose: to offer students who have potentials and aspire to make progress in tennis",
        "online.ibo.org.*online curriculum centre.*only accessible for subscribers",
        "genius is one percent inspiration and ninety-nine percent perspiration",
        "usually the answer to this is simple.*nothing.*just carry on with what you had planned",
        "marko - instructor.*master's degree.*bachelor's degree",
        "ibo home page - lists addresses of regional offices",
        "its verticality reveals breathtaking views.*some of the city's largest windows",
        "a week-long stay at rosewood hong kong offers the perfect blend",
        "each of rosewood hong kong's eleven dining concepts",
        "june - september: research the university and attend open days",
        "a decision to end a marriage can be a very challenging decision",
        "this guideline explains why collaborative divorce is often the preferred method",
        "lucas is a seasoned digital strategist at google",
        "application via fax and email will not be accepted",
        "need to meet the age requirement on 1st january",
        "as the academy's deputy director.*administration",
        "professor chan's influence extends beyond institutional leadership.*sought-after keynote speaker",
        "cookie", "privacy policy", "gdpr",
    ]

    def needs_fill(val: str) -> bool:
        if not val or val.strip() in ("N/A", "", "N/a", "See website"):
            return True
        clean = re.sub(r'\s+', ' ', val).strip()
        if len(clean.split()) < 12:
            return True
        cl = clean.lower()
        return any(re.search(p, cl) for p in PERF_JUNK_PHRASES) or is_junk(clean)

    missing = {
        metric: prompt
        for metric, prompt in PERF_PROMPTS.items()
        if needs_fill(results.get("Performance", {}).get(metric, ""))
    }

    if not missing:
        print("  ✓ All performance fields complete — no AI fill needed.")
        return results

    print(f"  → AI force-filling {len(missing)} performance field(s): {', '.join(missing.keys())}")

    field_lines = "\n".join(f'  "{k}": {v}' for k, v in missing.items())
    prompt = f"""You are an expert on Hong Kong educational institutions, sports clubs, wellness centres, performing arts organisations, and psychology practices.

KNOWN DATA about this institution:
{context}

Generate UNIQUE, FACTUAL, SPECIFIC content for ONLY these fields.
Each field must:
- Be exactly 2 sentences, ≤35 words total
- Describe a DIFFERENT aspect from the other fields
- Sound professional and informative (not generic)
- Use your knowledge of {name} in Hong Kong to be accurate
- Reference Hong Kong education context (IB, DSE, IGCSE, ESF, local schools) where relevant
- Never repeat facts from another field

Reply ONLY with valid JSON, keys exactly as shown below. No markdown, no extra keys:

{field_lines}

Return format: {{"field name": "2 sentence content here.", ...}}"""

    payload = json.dumps({
        "model": "gpt-4o",
        "max_tokens": 1200,
        "temperature": 0.4,
        "messages": [{"role": "user", "content": prompt}],
    }).encode("utf-8")

    req = urllib.request.Request(
        "https://api.openai.com/v1/chat/completions", data=payload,
        headers={"Content-Type": "application/json",
                 "Authorization": f"Bearer {key}"}, method="POST",
    )

    try:
        with urllib.request.urlopen(req, timeout=40) as resp:
            data   = json.loads(resp.read())
            raw    = data["choices"][0]["message"]["content"].strip()
            raw    = re.sub(r"^```(?:json)?\s*", "", raw, flags=re.M)
            raw    = re.sub(r"\s*```$",           "", raw, flags=re.M).strip()
            filled = json.loads(raw)

            filled_keys = []
            seen_vals   = set()
            for metric, val in filled.items():
                if not val or val.strip() in ("N/A", ""):
                    continue
                key_short = re.sub(r'\s+', ' ', val.strip().lower())[:100]
                if key_short in seen_vals:
                    continue
                seen_vals.add(key_short)
                if metric in PERF_PROMPTS and needs_fill(
                    results["Performance"].get(metric, "")
                ):
                    results["Performance"][metric] = str(val).strip()
                    filled_keys.append(metric)

            if filled_keys:
                print(f"  ✓ AI filled performance: {', '.join(filled_keys)}")
            else:
                print("  ✓ AI performance: nothing new added.")

    except json.JSONDecodeError as e:
        print(f"  ⚠ AI performance JSON error: {e}")
    except Exception as e:
        print(f"  ⚠ AI performance fill failed: {e}")

    return results


# ── OPENAI MAIN FIELDS GAP-FILL ───────────────────────────────────────────────

def openai_fill_missing_fields(results: dict) -> dict:
    key = _get_openai_key()
    if not _check_key(key, "OPENAI_API_KEY"):
        return results

    entity_type = results.get("Type", "Independent School")
    is_school   = any(w in entity_type.lower()
                      for w in ["school", "academy", "college", "education",
                                "conservatory", "programme", "program", "choir",
                                "tutoring", "tuition", "consultancy"])
    name = results.get("Name", "this institution")
    city = results.get("City", "Hong Kong")

    FILL_FIELDS = {
        "Founded":    "Year this institution was founded (just the 4-digit year). If unknown reply N/A.",
        "Ages":       ("Student age range (e.g. '4–18'). If unknown reply N/A." if is_school
                       else "Age range of members/clients (e.g. 'All ages', 'Adults 18+', '5–18')."),
        "Students":   ("Approximate enrolled students. If unknown reply N/A." if is_school
                       else "Approximate annual members/participants/clients. If unknown reply N/A."),
        "Ratio":      "Staff-to-student or instructor-to-client ratio (e.g. '1:8'). If unknown reply N/A.",
        "Fees":       ("Annual tuition in HKD. HK international school range HK$100,000–HK$200,000/year. "
                       "If unknown reply 'See website'."),
        "About":      f"2 sentences (30–45 words) describing {name}'s core identity, mission, and what makes it distinctive in Hong Kong.",
        "Philosophy": f"2 sentences (30–45 words) on {name}'s specific teaching, coaching, or organisational approach in Hong Kong.",
        "Outcomes":   f"2 sentences (30–45 words) on concrete outcomes from {name} — university placements, awards, competition results.",
        "Admissions": f"2 sentences (30–45 words) on how to apply or join {name} — process, timeline, requirements.",
        "Tagline":    f"One compelling tagline (≤20 words) for {name}.",
    }

    ctx_lines = []
    for k in ["Name", "Type", "City", "URL", "Tagline", "About", "Philosophy",
              "Outcomes", "Admissions", "Founded", "Ages", "Students", "Ratio", "Fees"]:
        v = results.get(k, "")
        if v:
            ctx_lines.append(f"{k}: {v}")
    context = "\n".join(ctx_lines) or f"URL: {results.get('URL', '')}"

    def _needs(val):
        return not val or str(val).strip() in ("N/A", "See website", "Rolling admissions",
                                                "Year-round", "", "N/a")

    def _needs_para(field, val):
        if _needs(val):
            return True
        if field in ("About", "Philosophy", "Outcomes", "Admissions"):
            if len(str(val).split()) < 20:
                return True
            return is_junk(str(val))
        return False

    missing = {}
    for f, p in FILL_FIELDS.items():
        v = results.get(f, "")
        if f in ("About", "Philosophy", "Outcomes", "Admissions"):
            if _needs_para(f, v):
                missing[f] = p
        elif _needs(v):
            missing[f] = p

    if not missing:
        return results

    print(f"  → OpenAI filling {len(missing)} main field(s): {', '.join(missing.keys())}")

    field_instructions = "\n".join(f'  "{k}": {v}' for k, v in missing.items())
    prompt = f"""You are a Hong Kong education, sports, arts, and wellness expert with deep knowledge of HK institutions.
Use the known data AND your knowledge to fill missing fields accurately for {name} in {city}.

KNOWN DATA:
{context}

Fill ONLY these fields (reply with a JSON object, keys exactly as shown):
{field_instructions}

Rules:
- Use factual knowledge of this specific Hong Kong institution.
- Fees: HKD and per year. HK international schools: HK$100,000–HK$200,000/year.
- Ages: always provide a range (e.g. '4–18', 'All ages', 'Adults 18+').
- Paragraph fields (About, Philosophy, Outcomes, Admissions): 2 full sentences, 30–45 words total. Never write fewer than 25 words.
- Each paragraph must be specific and substantive — not generic filler.
- Reference Hong Kong context (IB, DSE, IGCSE, ESF, HK university pathway) where relevant.
- Do NOT add commentary, markdown fences, or extra keys.
- Reply with valid JSON only."""

    payload = json.dumps({
        "model": "gpt-4o", "max_tokens": 1800, "temperature": 0.3,
        "messages": [{"role": "user", "content": prompt}],
    }).encode("utf-8")

    req = urllib.request.Request(
        "https://api.openai.com/v1/chat/completions", data=payload,
        headers={"Content-Type": "application/json",
                 "Authorization": f"Bearer {key}"}, method="POST",
    )

    try:
        with urllib.request.urlopen(req, timeout=30) as resp:
            data   = json.loads(resp.read())
            raw    = data["choices"][0]["message"]["content"].strip()
            raw    = re.sub(r"^```(?:json)?\s*", "", raw, flags=re.M)
            raw    = re.sub(r"\s*```$",           "", raw, flags=re.M).strip()
            filled = json.loads(raw)

            filled_keys = []
            for fkey, val in filled.items():
                if not val or str(val).strip() in ("N/A", "See website", ""):
                    continue
                if fkey in FILL_FIELDS:
                    v = results.get(fkey, "")
                    if fkey in ("About", "Philosophy", "Outcomes", "Admissions"):
                        if _needs_para(fkey, v):
                            results[fkey] = str(val).strip()
                            filled_keys.append(fkey)
                    elif _needs(v):
                        results[fkey] = str(val).strip()
                        filled_keys.append(fkey)

            if filled_keys:
                print(f"  ✓ OpenAI filled: {', '.join(filled_keys)}")
            else:
                print("  ✓ OpenAI: nothing new to fill.")
    except Exception as e:
        print(f"  ⚠ OpenAI main fill failed: {e}")

    return results


# ── WP BLOCKS GENERATOR (6 images + PERF_SHORT keywords) ─────────────────────

def generate_wp_blocks(r):
    school_name  = r.get("Name", "")
    description  = r.get("Tagline", "")
    age          = r.get("Ages", "")
    students     = r.get("Students", "")
    ratio        = r.get("Ratio", "")
    founded      = r.get("Founded", "")
    school_type  = r.get("Type", "")
    city         = r.get("City", "")
    annual_fee   = r.get("Fees", "")
    about        = r.get("About", "")
    philosophy   = r.get("Philosophy", "")
    outcomes     = r.get("Outcomes", "")
    quote        = r.get("Quote", "")
    website_url  = r.get("URL", "")
    admissions   = r.get("Admissions", "")
    images       = r.get("Images", [])
    perf         = r.get("Performance", {})
    enquiry_open = r.get("EnquiryOpen", "Year-round")
    app_deadline = r.get("AppDeadline", "Rolling admissions")

    website_display = website_url.replace("https://", "").replace("http://", "").rstrip("/")
    city_slug  = city.lower().replace(", ", "-").replace(" ", "-").replace(",", "")
    city_short = city.split(",")[0].strip()

    # Always 6 image slots — pad with img0 if needed
    imgs = [img for img in images if img]
    while len(imgs) < 6:
        imgs.append(imgs[0] if imgs else "")
    img0, img1, img2, img3, img4, img5 = imgs[0], imgs[1], imgs[2], imgs[3], imgs[4], imgs[5]

    coaching       = perf.get("Coaching Credentials", "")
    wellbeing      = perf.get("Student Wellbeing", "")
    academic       = perf.get("Academic Integration", "")
    competitive    = perf.get("Competitive Pathway", "")
    facilities     = perf.get("Facilities & Resources", "")
    accountability = perf.get("Ongoing Accountability", "")

    kw_coaching       = PERF_SHORT["Coaching Credentials"]
    kw_wellbeing      = PERF_SHORT["Student Wellbeing"]
    kw_academic       = PERF_SHORT["Academic Integration"]
    kw_competitive    = PERF_SHORT["Competitive Pathway"]
    kw_facilities     = PERF_SHORT["Facilities & Resources"]
    kw_accountability = PERF_SHORT["Ongoing Accountability"]

    wp = f"""<!-- wp:image {{"id":440,"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img0}" alt="{school_name}" class="wp-image-440"/></figure>
<!-- /wp:image -->

<!-- wp:paragraph -->
<p><a href="elite-home.html">Elite</a> &#8250; <a href="elite-city-{city_slug}.html">{city_short}</a> &#8250; <a href="elite-program-academic.html">Elite Academic Programs</a></p>
<!-- /wp:paragraph -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Kidrovia Elite — Listed</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Elite Academic Programs</h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":1}} -->
<h1 class="wp-block-heading"><em>{school_name}</em></h1>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{description}</p>
<!-- /wp:paragraph -->

<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph --><p>{age}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Ages</h5><!-- /wp:heading --></div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph --><p>{students}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Students</h5><!-- /wp:heading --></div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph --><p>{ratio}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Ratio</h5><!-- /wp:heading --></div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph --><p>{founded}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Founded</h5><!-- /wp:heading --></div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column {{"width":"66.66%"}} -->
<div class="wp-block-column" style="flex-basis:66.66%">
<!-- wp:heading --><h2 class="wp-block-heading">About <em>{school_name}</em></h2><!-- /wp:heading -->
<!-- wp:paragraph --><p>{about}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
<!-- wp:column {{"width":"33.33%"}} -->
<div class="wp-block-column" style="flex-basis:33.33%">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Institution Details</h5><!-- /wp:heading -->
<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Type</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Ages</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Students</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Ratio</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Founded</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">City</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Annual Fee</h5><!-- /wp:heading -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{school_type}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{age}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{students}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{ratio}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{founded}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{city}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{annual_fee}</h5><!-- /wp:heading -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Contact &amp; Enquiry</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading"><a href="{website_url}" target="_blank" rel="noreferrer noopener">{website_display} &#8594;</a></h5><!-- /wp:heading -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->

<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">Quote</h5>
<!-- /wp:heading -->
<!-- wp:paragraph {{"align":"center"}} -->
<p class="has-text-align-center">&ldquo;{quote}&rdquo;</p>
<!-- /wp:paragraph -->
<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">— {school_name}</h5>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Philosophy</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">How they <em>teach</em></h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{philosophy}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Outcomes</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">Where students <em>go</em></h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{outcomes}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:image {{"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img1}" alt="{school_name} campus"/></figure>
<!-- /wp:image -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:image {{"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img2}" alt="{school_name} students"/></figure>
<!-- /wp:image -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:image {{"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img3}" alt="{school_name} activities"/></figure>
<!-- /wp:image -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->
<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:image {{"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img4}" alt="{school_name} facilities"/></figure>
<!-- /wp:image -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:image {{"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img5}" alt="{school_name} community"/></figure>
<!-- /wp:image -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":4}} -->
<h4 class="wp-block-heading">Our Assessment</h4>
<!-- /wp:heading -->
<!-- wp:heading -->
<h2 class="wp-block-heading"><strong>How {school_name} performs</strong></h2>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{kw_coaching}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">Coaching Credentials</h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{coaching}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{kw_wellbeing}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">Student Wellbeing</h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{wellbeing}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{kw_academic}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">Academic Integration</h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{academic}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{kw_competitive}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">Competitive Pathway</h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{competitive}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{kw_facilities}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">Facilities &amp; Resources</h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{facilities}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">{kw_accountability}</h5><!-- /wp:heading -->
<!-- wp:heading {{"level":3}} --><h3 class="wp-block-heading">Ongoing Accountability</h3><!-- /wp:heading -->
<!-- wp:paragraph --><p>{accountability}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns">
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading --><h2 class="wp-block-heading">Admissions &amp;<br><em>How to Apply</em></h2><!-- /wp:heading -->
<!-- wp:paragraph --><p>{admissions}</p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
<!-- wp:column -->
<div class="wp-block-column">
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Enquiries Open</h5><!-- /wp:heading -->
<!-- wp:paragraph --><p>{enquiry_open}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Application Deadline</h5><!-- /wp:heading -->
<!-- wp:paragraph --><p>{app_deadline}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Annual Fee</h5><!-- /wp:heading -->
<!-- wp:paragraph --><p>{annual_fee}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Location</h5><!-- /wp:heading -->
<!-- wp:paragraph --><p>{city}</p><!-- /wp:paragraph -->
<!-- wp:heading {{"level":5}} --><h5 class="wp-block-heading">Website</h5><!-- /wp:heading -->
<!-- wp:paragraph --><p><a href="{website_url}" target="_blank" rel="noreferrer noopener">{website_display}</a></p><!-- /wp:paragraph -->
</div>
<!-- /wp:column -->
</div>
<!-- /wp:columns -->

<!-- wp:paragraph {{"align":"center"}} -->
<p class="has-text-align-center">&ldquo;{quote}&rdquo;</p>
<!-- /wp:paragraph -->
<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">— {school_name}</h5>
<!-- /wp:heading -->
"""
    return wp


# ── MAIN SCRAPER ──────────────────────────────────────────────────────────────

async def extract_school_data(url):
    async with async_playwright() as p:
        import platform
        headless = os.environ.get(
            "HEADLESS",
            "true" if platform.system() == "Linux" else "false"
        ).lower() == "true"
        browser = await p.chromium.launch(headless=headless, slow_mo=0 if headless else 200)
        context = await browser.new_context(viewport={"width": 1280, "height": 800})
        page    = await context.new_page()

        results = {
            "Name": "", "Tagline": "", "Founded": "", "City": "",
            "Ages": "", "Students": "", "Ratio": "", "Fees": "",
            "Type": "Independent School",
            "About": "", "Philosophy": "", "Outcomes": "",
            "Admissions": "", "Quote": "",
            "EnquiryOpen": "Year-round",
            "AppDeadline": "Rolling admissions",
            "Performance": {}, "URL": url, "Images": [],
        }

        global_text_pool = []

        # ── STEP 0: Lock name, city, and known data from domain map ──────────
        domain = url.split("/")[2].replace("www.", "")
        known_entry = next(
            ((k, v) for k, v in KNOWN_NAMES_HK.items() if k in domain or k in url),
            None
        )
        known_domain_key = None
        if known_entry:
            k_fragment, (k_name, k_city) = known_entry
            results["Name"] = k_name
            results["City"] = k_city   # CITY LOCK
            known_domain_key = next(
                (dk for dk in KNOWN_DATA_HK if dk in domain or dk in url), None
            )
            if known_domain_key:
                for field, val in KNOWN_DATA_HK[known_domain_key].items():
                    results[field] = val
            print(f"  ✓ Known institution: {k_name} | City locked: {results['City']}")

        FALLBACKS = {
            "Founded": "", "Ages": "", "Students": "", "Ratio": "N/A", "Fees": "See website",
        }

        fee_patterns = [
            (r'HK\$\s*([\d,]+)(?:\.\d{2})?\s*per\s*(?:year|annum)', 50000, 300000),
            (r'HKD\s*([\d,]+)(?:\.\d{2})?\s*per\s*(?:year|annum)', 50000, 300000),
            (r'HK\$\s*([\d,]+)', 50000, 300000),
        ]

        def extract_fee_validated(text: str) -> str:
            for pat, min_val, max_val in fee_patterns:
                for m in re.finditer(pat, text, re.I):
                    try:
                        num = int(m.group(1).replace(',', ''))
                        if min_val <= num <= max_val:
                            return m.group(0).strip()
                    except (IndexError, ValueError):
                        pass
            return ""

        ratio_patterns = [
            r'(\d+\s*:\s*\d+)\s*(?:student[- ]to[- ](?:faculty|teacher)|teacher[- ]to[- ]student|ratio)',
            r'ratio\s*(?:of\s*)?(\d+\s*:\s*\d+)',
            r'(\d+\s*:\s*\d+)\s*ratio',
            r'1\s*(?:teacher|member of staff|coach|instructor)\s+(?:to|per|:)\s+(\d+)\s*(?:students?|pupils?|learners?)',
            r'(\d+)\s*(?:students?|pupils?|learners?)\s+(?:per|to)\s+(?:every\s+)?(?:1\s+)?(?:teacher|tutor|coach)',
        ]

        age_patterns = [
            r'students?\s+aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'ages?\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'from\s+age\s+(\d+)\s+to\s+(\d+)',
            r'(\d+)\s*[\u2013\-]\s*(\d+)\s*year[s\-]\s*old',
            r'children\s+aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'grade[s]?\s+(\d+)\s*(?:through|to|-)\s*(\d+)',
            r'(?:year|form)\s+(\d+)\s*(?:to|-)\s*(?:year|form)?\s*(\d+)',
        ]

        student_patterns = [
            r'(\d[\d,]+)\s*(?:\+)?\s*(?:pupils?|students?|boys|girls|young people|learners?|scholars?|members?)',
            r'(?:approximately|around|about|some|over|more than)\s+(\d[\d,]+)\s*(?:pupils?|students?|learners?|members?)',
            r'school\s+of\s+(?:approximately|around|about)?\s*(\d[\d,]+)',
            r'enroll(?:ment|ing)\s+(?:of\s+)?(?:approximately|about)?\s*(\d[\d,]+)',
            r'community\s+of\s+(?:over\s+)?(\d[\d,]+)\s*(?:students?|learners?|members?)',
        ]

        print(f"Connecting to: {url}...")
        loaded = await smart_goto(page, url)
        if not loaded:
            print(f"  ✗ Could not load {url}, skipping.")
            await browser.close()
            return None

        try:
            await handle_cookies_automatically(page)

            og_site   = await page.evaluate("() => { const m = document.querySelector('meta[property=\"og:site_name\"]'); return m ? m.content : ''; }")
            og_title  = await page.evaluate("() => { const m = document.querySelector('meta[property=\"og:title\"]'); return m ? m.content : ''; }")
            raw_title = await page.title()

            REJECT_NAMES   = {
                "home", "welcome", "homepage", "index", "main", "",
                "welcome to", "isf landing", "wellness", "mindfulness for children",
            }
            REJECT_STARTS  = ("welcome to ", "home -", "home |", "visit ")
            REJECT_PHRASES = ["balance health home page"]

            def clean_name(candidate: str) -> str:
                parts = re.split(r'\s*[|—]\s*', candidate)
                parts = [p.strip() for p in parts if p.strip()]
                GENERIC = {"home","welcome","index","main","accueil","page","site","portal",""}
                n = parts[0] if parts else candidate.strip()
                if n.lower() in GENERIC and len(parts) > 1:
                    n = parts[-1].strip()
                for prefix in ("welcome to ", "visit "):
                    if n.lower().startswith(prefix):
                        n = n[len(prefix):].strip()
                # Remove registered trademark symbol
                n = n.replace("®", "").strip()
                return n

            # Known name always wins
            if not results["Name"]:
                for candidate in [og_site, og_title, raw_title]:
                    name = clean_name(candidate)
                    if (name
                            and name.lower() not in REJECT_NAMES
                            and not any(name.lower().startswith(p) for p in REJECT_STARTS)
                            and not any(bad in name.lower() for bad in REJECT_PHRASES)
                            and len(name.split()) <= 10
                            and not re.search(r'[\u4e00-\u9fff]', name)):
                        results["Name"] = name
                        break
                if not results["Name"]:
                    domain_part = domain.split(".")[0].replace("-", " ").title()
                    results["Name"] = domain_part

            body_text = await page.inner_text("body")

            if len(body_text.strip()) < 300:
                print("  ⚠ Page body too short — scrolling to trigger JS render…")
                try:
                    await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
                    await asyncio.sleep(3)
                    await page.evaluate("window.scrollTo(0, 0)")
                    await asyncio.sleep(2)
                    body_text = await page.inner_text("body")
                except Exception:
                    pass

            # Only set city from body if not already locked
            if not results["City"]:
                results["City"] = _detect_city_from_body(body_text, url)

            if is_garbage_site(results["Name"], body_text):
                print(f"  ✗ Garbage/parked site detected — skipping {url}")
                await browser.close()
                return None

            def extract(pattern):
                m = re.search(pattern, body_text, re.IGNORECASE)
                return m.group(1).strip() if m else ""

            current_year = datetime.now().year

            def extract_founded_from_text(text, existing_candidates=None):
                STRONG_KWS = [
                    "founded in", "established in", "was founded", "founding year",
                    "founded by", "charter", "incorporated in", "opened in",
                    "opened its doors", "since", "est.",
                ]
                WEAK_KWS   = ["founded", "established", "foundation", "history", "began"]
                SKIP_WORDS = ["copyright", "©", "reserved", "updated", "class of",
                               "alumni", "graduate", "batch of"]
                FOREIGN_CTX = ["in the uk", "in england", "parent school", "sister school"]
                cands = existing_candidates if existing_candidates is not None else []
                clean = re.sub(r'\s+', ' ', text.lower())
                clean = re.sub(r'(copyright|©).*?\d{4}', '', clean)
                for sent in re.split(r'[.!?\n]', clean):
                    if any(w in sent for w in SKIP_WORDS):
                        continue
                    has_strong = any(k in sent for k in STRONG_KWS)
                    has_weak   = any(k in sent for k in WEAK_KWS)
                    if not (has_strong or has_weak):
                        continue
                    is_foreign = any(ctx in sent for ctx in FOREIGN_CTX)
                    for y in re.findall(r'\b(1[6-9]\d{2}|20[012]\d)\b', sent):
                        year = int(y)
                        if not (1600 <= year <= current_year - 1):
                            continue
                        score = 3 if has_strong else 1
                        if is_foreign:
                            score -= 3
                        if year >= current_year - 2:
                            score -= 6
                        cands.append((score, year))
                return cands

            # Only scrape Founded if not locked
            if not results.get("Founded"):
                founded_candidates = extract_founded_from_text(body_text)
                if founded_candidates:
                    founded_candidates.sort(key=lambda x: (-x[0], x[1]))
                    results["Founded"] = str(founded_candidates[0][1])

            # Only scrape Ages if not locked
            if not results.get("Ages"):
                age_candidates = []
                for pat in age_patterns:
                    for m in re.finditer(pat, body_text, re.I):
                        try:
                            g = m.groups()
                            if len(g) >= 2 and g[0] and g[1]:
                                lo, hi = int(g[0]), int(g[1])
                                if lo < hi and lo >= 2 and hi <= 25:
                                    age_candidates.append((lo, hi))
                        except Exception:
                            pass
                if age_candidates:
                    best = max(age_candidates, key=lambda x: x[1] - x[0])
                    results["Ages"] = f"{best[0]}–{best[1]}"

                if not results["Ages"]:
                    AGE_MAP = {
                        "playgroup": (2, 3), "nursery": (2, 4),
                        "k1": (3, 4), "k2": (4, 5), "k3": (5, 6), "kindergarten": (3, 6),
                        "p1": (6, 7), "p6": (11, 12), "primary": (6, 12),
                        "form 1": (12, 13), "form 6": (17, 18), "secondary": (12, 18),
                        "year 7": (11, 12), "year 13": (17, 18),
                        "sixth form": (16, 18), "a-level": (16, 18),
                        "grade 1": (6, 7), "grade 12": (17, 18),
                    }
                    tl = body_text.lower()
                    fy = [v for k, v in AGE_MAP.items() if k in tl]
                    results["Ages"] = f"{min(x[0] for x in fy)}–{max(x[1] for x in fy)}" if fy else ""

            # Only scrape Students if not locked
            if not results.get("Students"):
                for pat in student_patterns:
                    for m in re.finditer(pat, body_text, re.I):
                        num_str = re.sub(r'[\s,]', '', m.group(1))
                        try:
                            num = int(num_str)
                            if not (50 <= num <= 50000):
                                continue
                            if 1900 <= num <= 2100:
                                continue   # reject years
                            ctx = body_text[max(0, m.start()-8):m.end()+8]
                            if '%' in ctx:
                                continue
                            results["Students"] = num_str + ("+" if "+" in m.group(0) else "")
                            break
                        except ValueError:
                            pass
                    if results["Students"]:
                        break

            if not results.get("Ratio"):
                for pat in ratio_patterns:
                    m = re.search(pat, body_text, re.I)
                    if m:
                        results["Ratio"] = m.group(1).replace(" ", "")
                        break

            results["Fees"] = results.get("Fees") or extract_fee_validated(body_text)

            # Type detection — only if not locked
            if not results.get("Type") or results["Type"] == "Independent School":
                tl    = body_text.lower()
                url_l = url.lower()
                if "hkjc.com" in url_l or "jockey club" in tl:
                    results["Type"] = "Members Club & Sports Organisation"
                elif "hkapa.edu" in url_l or "academy for performing arts" in tl:
                    results["Type"] = "Performing Arts Conservatory"
                elif "rosewoodhotels.com" in url_l:
                    results["Type"] = "Luxury Hotel Wellness & Lifestyle Centre"
                elif "mindfulkidshk.com" in url_l or "mindfulness" in tl:
                    results["Type"] = "Mindfulness & Wellbeing Programme for Children"
                elif "mindnlife.com" in url_l:
                    results["Type"] = "Psychology & Wellbeing Practice"
                elif "balancehealth.com" in url_l:
                    results["Type"] = "Holistic Health & Wellness Clinic"
                elif "hkfc.com" in url_l:
                    results["Type"] = "Members Sports Club & Academy"
                elif "tennishk.org" in url_l:
                    results["Type"] = "Tennis Association & Development Organisation"
                elif "hkcchoir.org" in url_l or "choir" in tl:
                    results["Type"] = "Youth Music & Performing Arts Organisation"
                elif "britishtutors.com" in url_l or "haven-edu.com" in url_l or "itseducation.asia" in url_l:
                    results["Type"] = "Private Tutoring & Education Consultancy"
                elif "ib world" in tl or "international baccalaureate" in tl:
                    results["Type"] = "IB World Bilingual Day School" if "bilingual" in tl else "IB World Day School"
                elif "british curriculum" in tl or "igcse" in tl or "a-level" in tl:
                    results["Type"] = "British International School"
                elif "american curriculum" in tl or "ap courses" in tl:
                    results["Type"] = "American Curriculum International School"
                elif "french curriculum" in tl or "baccalauréat" in tl:
                    results["Type"] = "French International School"
                elif "all-girls" in tl or "girls' school" in tl:
                    results["Type"] = "Independent All-Girls School"
                elif "all-boys" in tl or "boys' school" in tl:
                    results["Type"] = "Independent All-Boys School"
                elif "boarding" in tl and "day" in tl:
                    results["Type"] = "Independent Boarding & Day School"
                elif "performing arts" in tl or "conservatory" in tl:
                    results["Type"] = "Performing Arts Academy"
                elif "tennis" in tl and ("academy" in tl or "club" in tl):
                    results["Type"] = "Tennis Academy"
                elif "yoga" in tl or "wellness" in tl:
                    results["Type"] = "Wellness & Lifestyle Centre"
                elif "tutor" in tl and ("centre" in tl or "center" in tl or "company" in tl):
                    results["Type"] = "Private Tutoring & Education Consultancy"
                else:
                    results["Type"] = "Independent International School"

            soup_home = BeautifulSoup(await page.content(), "html.parser")
            for attr in [{"name": "description"}, {"property": "og:description"}]:
                tag = soup_home.find("meta", attr)
                if tag and tag.get("content"):
                    content = tag["content"][:200]
                    if not is_junk(content):
                        results["Tagline"] = content
                        break
            if not results["Tagline"]:
                candidate = extract(r"([A-Z][^.]{30,150}\.)")
                if candidate and not is_junk(candidate):
                    results["Tagline"] = candidate

            scraped_quote = scrape_quote_from_soup(soup_home)
            if scraped_quote and not is_junk(scraped_quote):
                results["Quote"] = scraped_quote

            image_set = set()
            await harvest_images(page, url, image_set)
            results["Images"] = [img for img in image_set if img][:10]

        except Exception as e:
            print(f"Home page error: {e}")
            await browser.close()
            return None

        # ── SUBPAGE CRAWL ─────────────────────────────────────────────────────
        soup  = BeautifulSoup(await page.content(), "html.parser")
        links = soup.find_all("a", href=True)
        queue     = []
        seen_urls = {url.rstrip("/")}
        base_domain = url.split("/")[2]

        targets = {
            "about": ["about", "history", "welcome", "mission", "who-we-are",
                      "our-story", "overview", "vision", "values", "ethos"],
            "outcomes": ["results", "destination", "university", "leavers", "beyond",
                         "college", "achievements", "academic-results",
                         "ib-results", "exam-results"],
            "fees": ["fees", "tuition", "financial", "cost", "charges",
                     "fee-structure", "school-fees", "annual-fees", "pricing"],
            "admission": ["admissions", "apply", "entry", "register", "enroll",
                          "how-to-apply", "application", "join-us", "registration",
                          "enrolment", "open-day"],
            "facilities": ["facilities", "campus", "co-curriculum", "sport", "arts",
                           "library", "infrastructure", "resources", "activities",
                           "co-curricular", "extracurricular", "programs"],
        }

        for link in links:
            href, text = link["href"], link.get_text().lower().strip()
            full_url   = urljoin(url, href).split("#")[0].rstrip("/")
            if full_url not in seen_urls and base_domain in full_url:
                if any(k in text or k in href.lower() for cat in targets.values() for k in cat):
                    queue.append((full_url, text))
                    seen_urls.add(full_url)

        used_sentences: set = set()

        def _register(text: str):
            if not text:
                return
            for s in re.split(r'(?<=[.!?])\s+', text.strip()):
                key = re.sub(r'\s+', ' ', s.strip().lower())
                if key and len(key) > 20:
                    used_sentences.add(key)

        def dedup_text(text: str) -> str:
            if not text:
                return text
            parts = re.split(r'(?<=[.!?])\s+', text.strip())
            fresh = []
            for s in parts:
                key = re.sub(r'\s+', ' ', s.strip().lower())
                if key and key not in used_sentences and not is_junk(s):
                    fresh.append(s.strip())
                    used_sentences.add(key)
            return " ".join(fresh)

        def assign_field(field_name: str, text: str, max_sent: int = 2):
            if results.get(field_name) and not is_junk(results[field_name]):
                return
            cleaned = dedup_text(clean_to_sentences(text, max_sent))
            if cleaned and not is_junk(cleaned):
                results[field_name] = cleaned

        for _field in ["About", "Tagline", "Philosophy", "Outcomes", "Admissions", "Quote"]:
            _register(results.get(_field, ""))

        used_paras_global: set = set()

        PERF_KWS = {
            "Coaching Credentials":   [
                "qualified", "certified", "credential", "faculty", "expertise",
                "experienced teacher", "master", "phd", "trained",
                "professional development", "degree in", "teaching background",
            ],
            "Student Wellbeing":      [
                "wellbeing", "mental health", "counselor", "advisory",
                "pastoral", "house system", "support program", "community",
                "belonging", "wellness program", "school counsellor",
            ],
            "Academic Integration":   [
                "curriculum", "coursework", "program of study", "academic program",
                "learning outcomes", "course offerings", "ib diploma",
                "igcse", "a-level", "dse", "ap course",
                "core curriculum",
            ],
            "Competitive Pathway":    [
                "university placement", "accepted to", "graduates attend",
                "alumni", "top university", "competition winner",
                "scholarship", "award winner", "oxbridge", "russell group",
                "ib score", "dse results",
            ],
            "Facilities & Resources": [
                "gymnasium", "theater", "theatre", "laboratory", "library",
                "swimming pool", "pool", "studio", "auditorium",
                "science lab", "art studio", "music room", "sports hall",
                "campus", "playing fields",
            ],
            "Ongoing Accountability": [
                "progress report", "parent conference", "student assessment",
                "feedback", "portfolio", "transcript", "grade report",
                "parent communication", "accreditation", "review",
                "annual review", "parent portal",
            ],
        }

        PERF_SKIP = [
            "we are inordinately proud of this graduating class.*remarkable resilience",
            "if you are an overseas relocating family.*indicate so in the subject line",
            "aquatics academy is the after-school program",
            "tai tam tigers soccer academy was established in 1999",
            "in 1964, a hong kong-based committee of the lutheran church",
            "tours at pok fu lam and kowloon bay run regularly",
            "for admissions enquiries, please let us know the following information",
            "school sports programme.*ssp.*national sports associations",
            "implementation of the ssp.*lcsd.*education bureau",
            "purpose: to offer students who have potentials and aspire to make progress in tennis",
            "online.ibo.org.*online curriculum centre",
            "genius is one percent inspiration",
            "usually the answer to this is simple.*nothing.*just carry on",
            "marko - instructor.*master's degree.*bachelor's degree",
            "ibo home page - lists addresses of regional offices",
            "its verticality reveals breathtaking views",
            "a decision to end a marriage",
            "lucas is a seasoned digital strategist at google",
            "application via fax and email will not be accepted",
            "as the academy's deputy director.*administration",
        ]

        for target_url, link_text in queue[:15]:
            try:
                await page.goto(target_url, wait_until="domcontentloaded", timeout=30000)
                await asyncio.sleep(2)
                main          = page.locator("main").first
                content_scope = main if await main.is_visible() else page
                paragraphs    = await content_scope.locator("p").all_text_contents()
                clean_paras   = [
                    t.strip() for t in paragraphs
                    if len(t.strip()) >= 60
                    and not any(x in t.lower() for x in
                                ["cookie", "privacy", "menu", "navigation", "footer"])
                    and not is_junk(t)
                ]
                global_text_pool.extend(clean_paras)
                full_text = " ".join(clean_paras)
                page_text = await page.inner_text("body")
                sub_soup  = BeautifulSoup(await page.content(), "html.parser")

                await harvest_images(page, url, image_set)
                results["Images"] = [img for img in image_set if img][:10]

                if any(k in link_text or k in target_url for k in targets["about"]):
                    clean_about = [p for p in clean_paras
                                   if not is_junk(p)
                                   and not p.lower().startswith((
                                       "please fill", "click here",
                                       "the admissions team", "fill the",
                                   ))]
                    assign_field("About", " ".join(clean_about), 2)
                    teach_kws = ["curriculum", "teaching", "learning", "approach",
                                 "education", "ethos", "method", "ib", "igcse",
                                 "philosophy", "program", "pedagogy", "bilingual"]
                    teach_para = [p for p in clean_paras
                                  if any(k in p.lower() for k in teach_kws)
                                  and not is_junk(p)]
                    assign_field("Philosophy", " ".join(teach_para), 2)
                    if not results["Quote"]:
                        q = scrape_quote_from_soup(sub_soup)
                        if q and not is_junk(q):
                            results["Quote"] = q
                    if not results.get("Founded"):
                        sub_cands = extract_founded_from_text(page_text)
                        if sub_cands:
                            sub_cands.sort(key=lambda x: (-x[0], x[1]))
                            results["Founded"] = str(sub_cands[0][1])

                if not results.get("Students"):
                    for pat in student_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            num_str = m.group(1).replace(",", "")
                            try:
                                num = int(num_str)
                                if 50 <= num <= 50000 and not (1900 <= num <= 2100):
                                    results["Students"] = num_str + ("+" if "+" in m.group(0) else "")
                                    break
                            except ValueError:
                                pass

                if not results.get("Ratio"):
                    for pat in ratio_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            results["Ratio"] = m.group(1).replace(" ", "")
                            break

                if any(k in link_text or k in target_url for k in targets["outcomes"]):
                    outcome_kws = ["university", "accepted", "acceptance", "placement",
                                   "graduate", "alumni", "destination", "scholarship",
                                   "ib score", "dse", "oxbridge", "russell group",
                                   "russell group", "admission", "enroll"]
                    outcome_paras = [p for p in clean_paras
                                     if any(k in p.lower() for k in outcome_kws)
                                     and not is_junk(p)]
                    assign_field("Outcomes", " ".join(outcome_paras) or full_text, 2)
                    if not results["Quote"]:
                        q = scrape_quote_from_soup(sub_soup)
                        if q and not is_junk(q):
                            results["Quote"] = q

                if any(k in link_text or k in target_url for k in targets["fees"]):
                    fee_val = extract_fee_validated(page_text)
                    if fee_val and not results.get("Fees"):
                        results["Fees"] = fee_val

                if any(k in link_text or k in target_url for k in targets["admission"]):
                    adm_kws = ["apply", "application", "admission", "register",
                               "assessment", "entry", "enroll", "enrolment",
                               "registration", "open day", "inquiry"]
                    filtered = [p for p in clean_paras
                                if any(k in p.lower() for k in adm_kws)
                                and not is_junk(p)]
                    assign_field("Admissions", " ".join(filtered), 2)
                    dl = re.search(
                        r'(?:deadline|closes?|closing date)\s*[:\-]?\s*([^\n.]{10,60})',
                        page_text, re.I
                    )
                    if dl and results["AppDeadline"].startswith("Rolling"):
                        val = dl.group(1).strip()[:80]
                        has_month = re.search(
                            r'\b(january|february|march|april|may|june|july|august|'
                            r'september|october|november|december|jan|feb|mar|apr|'
                            r'jun|jul|aug|sep|oct|nov|dec)\b', val, re.I)
                        if has_month and not is_junk(val):
                            results["AppDeadline"] = val
                    if not results.get("Ages"):
                        for pat in age_patterns:
                            m = re.search(pat, page_text, re.I)
                            if m:
                                try:
                                    g = m.groups()
                                    if len(g) >= 2 and g[0] and g[1]:
                                        lo, hi = int(g[0]), int(g[1])
                                        if lo < hi and lo >= 2 and hi <= 25:
                                            results["Ages"] = f"{lo}–{hi}"
                                except Exception:
                                    pass
                                if results["Ages"]:
                                    break

                if any(k in link_text or k in target_url for k in targets["facilities"]):
                    for metric, kws in PERF_KWS.items():
                        if not results["Performance"].get(metric):
                            matched = [
                                p for p in clean_paras
                                if any(k in p.lower() for k in kws)
                                and p not in used_paras_global
                                and not is_junk(p)
                                and not any(re.search(sk, p.lower()) for sk in PERF_SKIP)
                                and len(p.split()) >= 15
                            ]
                            if matched:
                                chosen = matched[:1]
                                val    = dedup_text(clean_to_sentences(" ".join(chosen), 2))
                                if val and len(val.split()) >= 12 and not is_junk(val):
                                    results["Performance"][metric] = val
                                    used_paras_global.update(chosen)
                    if not results["Quote"]:
                        q = scrape_quote_from_soup(sub_soup)
                        if q and not is_junk(q):
                            results["Quote"] = q

            except Exception as e:
                print(f"  Skipping {target_url}: {e}")
                continue

        results["Images"] = list(image_set)[:10]
        for field, fallback in FALLBACKS.items():
            if not results.get(field):
                results[field] = fallback
        if not results["City"]:
            results["City"] = "Hong Kong"

        if not results["Quote"]:
            print(f"  No quote found — generating AI quote…")
            results["Quote"] = generate_ai_quote(
                results["Name"], results["Type"], results["City"], results["About"]
            )

        await browser.close()

        # ── STEP 1: Fill main fields ──────────────────────────────────────────
        print(f"\n  Running OpenAI main field gap-fill…")
        results = openai_fill_missing_fields(results)

        # ── STEP 2: Force-fill ALL 6 performance fields ───────────────────────
        print(f"\n  Running AI force-fill for performance fields…")
        results = openai_force_fill_performance(results)

        # ── POST SANITIZATION ─────────────────────────────────────────────────
        for field in ["Name", "Tagline", "Founded", "City", "Ages", "Students",
                      "Ratio", "Fees", "Type", "About", "Philosophy", "Outcomes",
                      "Admissions", "Quote"]:
            if results.get(field):
                results[field] = re.sub(r'\s+', ' ', str(results[field])).strip()
        for field in ["About", "Philosophy", "Outcomes", "Admissions"]:
            if results.get(field) and len(results[field].split()) > 60:
                results[field] = clean_to_sentences(results[field], 2)
        PERF_METRICS = ["Coaching Credentials", "Student Wellbeing", "Academic Integration",
                        "Competitive Pathway", "Facilities & Resources", "Ongoing Accountability"]
        for metric in PERF_METRICS:
            val = results["Performance"].get(metric, "")
            if val and len(val.split()) > 50:
                results["Performance"][metric] = clean_to_sentences(val, 2)

        # ── PRINT SUMMARY ─────────────────────────────────────────────────────
        SEP        = "—" * 55
        city_short = results["City"].split(",")[0]
        print(f"\n{SEP}")
        print(f"Elite › {city_short} › {results['Name']}")
        print(SEP)
        print(f"\n  Type       : {results['Type']}")
        print(f"  Ages       : {results['Ages'] or 'N/A'}")
        print(f"  Students   : {results['Students'] or 'N/A'}")
        print(f"  Ratio      : {results['Ratio'] or 'N/A'}")
        print(f"  Founded    : {results['Founded'] or 'N/A'}")
        print(f"  City       : {results['City']}")
        print(f"  Annual Fee : {results['Fees']}")
        print(f"  Images     : {len(results['Images'])} found")
        for i, img in enumerate(results["Images"], 1):
            print(f"    {i}. {img}")
        print(f"\n  About      : {results['About']}")
        print(f"\n  Quote      : \"{results['Quote']}\"")
        print(f"\n  Philosophy : {results['Philosophy']}")
        print(f"\n  Outcomes   : {results['Outcomes']}")
        print(f"\n  Admissions : {results['Admissions']}")
        print(f"\nPerformance Metrics:")
        for k, v in results["Performance"].items():
            kw = PERF_SHORT.get(k, k)
            print(f"\n  [{kw}] {k}:")
            print(f"  {v or ' STILL MISSING'}")
        print(f"\n  Website : {results['URL']}")
        print(SEP)

        # ── SAVE ──────────────────────────────────────────────────────────────
        wp_code     = generate_wp_blocks(results)
        school_slug = re.sub(r"[^a-z0-9]+", "_", results["Name"].lower())[:40].strip("_")
        out_wp      = f"{school_slug}_wp_blocks.txt"
        out_json    = f"{school_slug}_data.json"

        with open(out_wp, "w", encoding="utf-8") as f:
            f.write(wp_code)

        save_data               = {k: v for k, v in results.items() if k != "Images"}
        save_data["ImageCount"] = len(results.get("Images", []))
        save_data["ImageURLs"]  = results.get("Images", [])
        with open(out_json, "w", encoding="utf-8") as f:
            json.dump(save_data, f, ensure_ascii=False, indent=2)

        print(f"\n  WP blocks  → {out_wp}")
        print(f"  JSON data  → {out_json}")
        return results


# ── CITY FALLBACK ─────────────────────────────────────────────────────────────

HK_BODY_HINTS = {
    "kowloon tong":    "Kowloon Tong, Hong Kong",
    "tsim sha tsui":   "Tsim Sha Tsui, Hong Kong",
    "wan chai":        "Wan Chai, Hong Kong",
    "central":         "Central, Hong Kong",
    "causeway bay":    "Causeway Bay, Hong Kong",
    "sai kung":        "Sai Kung, Hong Kong",
    "tai tam":         "Tai Tam, Hong Kong",
    "pok fu lam":      "Pok Fu Lam, Hong Kong",
    "happy valley":    "Happy Valley, Hong Kong",
    "repulse bay":     "Repulse Bay, Hong Kong",
    "tseung kwan o":   "Tseung Kwan O, Hong Kong",
    "kowloon bay":     "Kowloon Bay, Hong Kong",
    "kowloon":         "Hong Kong, Kowloon",
    "new territories": "Hong Kong, New Territories",
    "hong kong":       "Hong Kong",
    ".hk":             "Hong Kong",
    # Other Asia fallbacks
    "singapore":       "Singapore",
    "tokyo":           "Tokyo, Japan",
    "shanghai":        "Shanghai, China",
}

def _detect_city_from_body(body_text: str, url: str) -> str:
    url_lower = url.lower()
    for hint in sorted(HK_BODY_HINTS, key=len, reverse=True):
        if hint in url_lower:
            return HK_BODY_HINTS[hint]
    sample = body_text[:5000].lower()
    for hint in sorted(HK_BODY_HINTS, key=len, reverse=True):
        if hint in sample:
            return HK_BODY_HINTS[hint]
    if ".hk" in url_lower:
        return "Hong Kong"
    return "Hong Kong"


# ── URLS ──────────────────────────────────────────────────────────────────────

school_urls = [
    "https://www.harrowhongkong.hk/",
    "https://kellettschool.com",
    "https://hkis.edu.hk",
    "https://ycis-hk.com",
    "https://isf.edu.hk",
    "https://fis.edu.hk",
    "https://hkfc.com",
    "https://hkjc.com",
    "https://www.tennishk.org/en/",
    "https://britishtutors.com",
    "https://haven-edu.com/",
    "https://itseducation.asia",
    "https://balancehealth.com.hk",
    "https://hkapa.edu",
    "https://www.mindnlife.com/",
    "https://www.rosewoodhotels.com/en/hong-kong/wellness",
    "https://mindfulkidshk.com",
    "https://www.hkcchoir.org.hk/en/",
]


async def run_multiple_schools():
    all_results = []
    for url in school_urls:
        print(f"\n{'=' * 60}")
        print(f"  Scraping: {url}")
        print(f"{'=' * 60}")
        try:
            result = await extract_school_data(url)
            if result:
                all_results.append(result)
            await asyncio.sleep(3)
        except Exception as e:
            print(f"  Failed: {url} → {e}")

    master_file = "all_schools_data_hongkong.json"
    with open(master_file, "w", encoding="utf-8") as f:
        json.dump(all_results, f, ensure_ascii=False, indent=2)
    print(f"\n{'=' * 60}")
    print(f"All done! {len(all_results)} institutions scraped.")
    print(f"Master JSON → {master_file}")
    print(f"{'=' * 60}")
    return all_results


if __name__ == "__main__":
    if sys.platform == "win32":
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    try:
        loop = asyncio.get_running_loop()
        import nest_asyncio
        nest_asyncio.apply()
        import concurrent.futures
        with concurrent.futures.ThreadPoolExecutor() as pool:
            future   = pool.submit(asyncio.run, run_multiple_schools())
            all_data = future.result()
    except RuntimeError:
        asyncio.run(run_multiple_schools())
# Out:
# ============================================================
#   Scraping: https://www.harrowhongkong.hk/
# ============================================================
#   ✓ Known institution: Harrow Hong Kong | City locked: Hong Kong
# Connecting to: https://www.harrowhongkong.hk/...
#   No quote found — generating AI quote…
#   ✓ AI quote generated for Harrow Hong Kong
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 6 main field(s): Ratio, Fees, About, Philosophy, Outcomes, Admissions
#   ✓ OpenAI filled: Ratio, About, Philosophy, Outcomes, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 6 performance field(s): Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ AI filled performance: Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › Harrow Hong Kong
# ———————————————————————————————————————————————————————
#
#   Type       : British Independent School
#   Ages       : 3–18
#   Students   : 1650
#   Ratio      : 1:10
#   Founded    : 2012
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 0 found
#
#   About      : Harrow Hong Kong is renowned for its rigorous British curriculum, fostering academic excellence and holistic development. It stands out for its emphasis on leadership and character building, preparing students for global success.
#
#   Quote      : "Empowering leaders with courage, compassion, and creativity to shape a better world for tomorrow."
#
#   Philosophy : Harrow Hong Kong's educational approach integrates traditional academic rigor with innovative teaching methods, nurturing critical thinking and creativity. The school emphasizes leadership skills, encouraging students to become responsible global citizens.
#
#   Outcomes   : Harrow Hong Kong boasts impressive university placements, with graduates attending top institutions like Oxford, Cambridge, and Ivy League schools. Students consistently achieve high scores in IGCSE and A-Level examinations, reflecting the school's academic excellence.
#
#   Admissions : Prospective students can apply through the school's online portal, with applications typically opening a year in advance. The process includes an assessment and interview, ensuring a good fit with Harrow's academic and community values.
#
# Performance Metrics:
#
#   [Expert Staff] Coaching Credentials:
#   Teachers at Harrow Hong Kong hold advanced degrees from prestigious institutions and possess international teaching certifications, ensuring a high standard of education. Many have extensive experience in British and international curricula, enhancing their pedagogical expertise.
#
#   [Student Care] Student Wellbeing:
#   Harrow Hong Kong prioritizes student wellbeing through comprehensive pastoral care and counseling services, fostering a supportive community. The school offers wellness programs and workshops, promoting mental health and resilience among students.
#
#   [Curriculum] Academic Integration:
#   Harrow Hong Kong delivers a robust curriculum featuring IGCSE and A-Level qualifications, emphasizing critical thinking and creativity. The school integrates innovative teaching methods and interdisciplinary projects, preparing students for diverse global challenges.
#
#   [Achievements] Competitive Pathway:
#   Graduates from Harrow Hong Kong achieve outstanding results, with high acceptance rates to top universities worldwide, including Oxbridge and Ivy League schools. Students consistently excel in IGCSE and A-Level exams, reflecting academic excellence.
#
#   [Facilities] Facilities & Resources:
#   Harrow Hong Kong boasts state-of-the-art facilities, including science labs, art studios, and a performing arts center. The campus features extensive sports amenities, such as swimming pools, tennis courts, and a fitness center.
#
#   [Progress] Ongoing Accountability:
#   Harrow Hong Kong maintains high educational standards through regular progress reports and parent-teacher meetings, ensuring transparent communication. The school undergoes periodic reviews and holds prestigious international accreditations, affirming its commitment to excellence.
#
#   Website : https://www.harrowhongkong.hk/
# ———————————————————————————————————————————————————————
#
#   WP blocks  → harrow_hong_kong_wp_blocks.txt
#   JSON data  → harrow_hong_kong_data.json
#
# ============================================================
#   Scraping: https://kellettschool.com
# ============================================================
#   ✓ Known institution: Kellett School | City locked: Hong Kong
# Connecting to: https://kellettschool.com...
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 5 main field(s): Ratio, Fees, About, Philosophy, Admissions
#   ✓ OpenAI filled: Ratio, About, Philosophy, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 1 performance field(s): Competitive Pathway
#   ✓ AI filled performance: Competitive Pathway
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › Kellett School
# ———————————————————————————————————————————————————————
#
#   Type       : British International School
#   Ages       : 4–18
#   Students   : 1200
#   Ratio      : 1:10
#   Founded    : 1976
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://newsletter.kellettschool.com/a/f/2676464-c196634141ab98842a83ddbf5ea81aed/795483/6814b9f1149310776ac962393d164432.jpg
#     2. https://www.kellettschool.com/userfiles/kellettv2mvc/image/covers/_mg_7530.jpg?command_1=resize&width_1=400
#     3. https://kellettschool.com/userfiles/kellettv2mvc/Image/Reception.jpg
#     4. https://www.kellettschool.com/userfiles/kellettv2mvc/image/header/front%20page/50th%20banner.jpg?command_1=resize&width_1=1200
#     5. https://www.kellettschool.com/userfiles/kellettv2mvc/image/header/kellett-senior-si9th-x.jpg?command_1=resize&width_1=400
#     6. https://www.kellettschool.com/userfiles/kellettv2mvc/image/header/kellet-history.jpg?command_1=resize&width_1=400
#     7. https://kellettschool.com/userfiles/kellettv2mvc/Image/Covers/kellett-cover.png
#     8. https://kellettschool.com/userfiles/kellettv2mvc/Image/_MG_5071.jpg?command_1=resize&width_1=500&webp=true
#     9. https://kellettschool.com/userfiles/kellettv2mvc/Image/IMG_7655.JPG
#     10. https://kellettschool.com/userfiles/kellettv2mvc/Image/stats/coin-2.png
#
#   About      : Kellett School is a prestigious British international school in Hong Kong, offering a rigorous curriculum that prepares students for IGCSE and A-levels. It is renowned for fostering a nurturing environment that encourages academic excellence and personal growth.
#
#   Quote      : "Our classes for the 2026/27 academic year are now full. Please contact admissions@kellettschool.com for further information."
#
#   Philosophy : Kellett School embraces a student-centered approach, emphasizing individualized learning and holistic development. We integrate British educational standards with local cultural context, ensuring students are well-prepared for global challenges and opportunities.
#
#   Outcomes   : Congratulations to our students on another fantastic set of A-level results! As grade boundaries this year were recalibrated, we are proud to say that 88% of our cohort got accepted into their first choice or insurance universities.
#
#   Admissions : Prospective families are encouraged to apply early for the 2026/27 academic year, as spaces are limited. The application process includes submission of academic records, an interview, and a campus tour to ensure the best fit for each student.
#
# Performance Metrics:
#
#   [Facilities] Facilities & Resources:
#   Kellett School has two campuses, the Pok Fu Lam campus on Hong Kong Island and Kowloon Bay campus just over the harbour in the Kowloon Peninsula.
#
#   [Student Care] Student Wellbeing:
#   ☀️💦 Our #KellettY11 students took to the Sky Pitch for a game of "wet" rounders today. Let’s just say some were more interested in the water than the wickets, but it was the perfect way to soak up the sun before embarking on their study leave.
#
#   [Curriculum] Academic Integration:
#   Physical Education and Sport are an integral part of student life at Kellett. Great importance is placed on the value of these areas as a core element of a balanced education, which is delivered through both the curriculum and extra curricular activities.
#
#   [Expert Staff] Coaching Credentials:
#   These beautiful facilities form just part of the excellence that makes up the Expressive Arts at Kellett School. The breadth of the curriculum, the extensive extra-curricular activities offered and the strength in teaching expertise in this area give Expressive Arts at Kellett School its strong and enviable reputation.
#
#   [Progress] Ongoing Accountability:
#   Kicking off last Friday's @kellettexpressivearts WiLD, our Y10-13 Media students were treated to a chat with @tatlerhongkong Content Director and Head of VIP, Tatler Hong Kong @tarasobti. Tara shared a bit about her experience working in media and gave amazing career advice to our @kellett_sixthform & @kellettklbsenior students.
#
#   [Achievements] Competitive Pathway:
#   Kellett School graduates consistently achieve outstanding IGCSE and A-level results, with many gaining admission to prestigious universities worldwide. In 2023, 88% secured places at their first choice or insurance universities, reflecting their academic excellence.
#
#   Website : https://kellettschool.com
# ———————————————————————————————————————————————————————
#
#   WP blocks  → kellett_school_wp_blocks.txt
#   JSON data  → kellett_school_data.json
#
# ============================================================
#   Scraping: https://hkis.edu.hk
# ============================================================
#   ✓ Known institution: Hong Kong International School | City locked: Hong Kong
# Connecting to: https://hkis.edu.hk...
#   ⚠ Page body too short — scrolling to trigger JS render…
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 3 main field(s): Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Ratio, Outcomes
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 4 performance field(s): Student Wellbeing, Academic Integration, Competitive Pathway, Ongoing Accountability
#   ✓ AI filled performance: Student Wellbeing, Academic Integration, Competitive Pathway, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong International School
# ———————————————————————————————————————————————————————
#
#   Type       : American Curriculum International School
#   Ages       : 5–18
#   Students   : 2800
#   Ratio      : 1:10
#   Founded    : 1966
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://hkis.edu.hk/userfiles/hkismvc/images/body/01-about-hkis/Our%20Facilities/History%20Wall_2.jpg
#     2. https://hkis.edu.hk/Images/1px.jpg?command_1=url&url_1=https%3A%2F%2Fmedia.licdn.com%2Fdms%2Fimage%2Fv2%2FD5622AQGVw9dj500SuQ%2Ffeedshare-shrink_1280%2FB56Z3N3XBaJwAM-%2F0%2F1777275335158%3Fe%3D1778716800%26v%3Dbeta%26t%3D5jASgZbJON-EiDNDjrYA7mf9mNFQl2JGrRkongQrTNA&command_2=resize&width_2=380&command_3=default&default_3=/Images/default-thumbs/facebook.jpg&webp=true
#     3. https://hkis.edu.hk/userfiles/hkismvc/images/body/01-about-hkis/Our%20Facilities/DCAA/Gymnasium.jpg?command_1=resize&width_1=500&webp=true
#     4. https://hkis.edu.hk/Images/assets/ribbons/ribbon-a.png
#     5. https://hkis.edu.hk/userfiles/hkismvc/images/body/01-about-hkis/Our%20Facilities/DCAA/Golf%20Center.jpg?command_1=resize&width_1=500&webp=true
#     6. https://hkis.edu.hk/userfiles/hkismvc/images/cards/HS-Card-Chinese%20Studies.jpg?command_1=resize&width_1=500&webp=true
#     7. https://hkis.edu.hk/userfiles/hkismvc/images/body/01-about-hkis/Our%20Facilities/History%20%26%20Future_2.jpg
#     8. https://hkis.edu.hk/Images/assets/ribbons/ribbon-b.png
#     9. https://hkis.edu.hk/userfiles/hkismvc/images/promos/Promo%20-%20About%20HKIS.jpg
#     10. https://hkis.edu.hk/userfiles/hkismvc/images/body/01-about-hkis/Our%20Facilities/DCAA/Climbing%20Wall.jpg?command_1=resize&width_1=500&webp=true
#
#   About      : In-person tours are available annually from mid-October through early-April and are led by student or parent ambassadors, followed by an info session with the Director of Enrollment Management. In the meantime, please explore our virtual tours below.
#
#   Quote      : "Dedicating our minds to inquiry, our hearts to compassion, and our lives to service and global understanding. An American-style education grounded in the Christian faith and respecting the spiritual lives of all."
#
#   Philosophy : Each student’s ability to achieve success in an atmosphere of high expectations and an environment of self-discipline and responsibility to the school community is carefully assessed. HKIS implements a Dual Language Immersion program starting in the 2025-2026 school year.
#
#   Outcomes   : Hong Kong International School graduates are accepted into prestigious universities worldwide, including Ivy League schools. Students excel in international competitions, showcasing their talents in academics, arts, and sports, reflecting the school's commitment to holistic development.
#
#   Admissions : Thank you for your interest in applying to Hong Kong International School. We serve students from Reception One (pre-kindergarten) to Grade 12 across four divisions.
#
# Performance Metrics:
#
#   [Facilities] Facilities & Resources:
#   Similar to its curricular goals and practice, students in the Academy are offered swim lessons and a variety of aquatics activities at their level & ability, thus ensuring students experience success, enjoyment, improvement of their skills, and development of their knowledge & understanding of water safety concepts & skills.
#
#   [Expert Staff] Coaching Credentials:
#   We’re thrilled to introduce a variety of new wellness and fitness programs designed for students, parents, and faculty/staff at HKIS!
#
#   [Student Care] Student Wellbeing:
#   Hong Kong International School offers a comprehensive pastoral care program, including counseling services and wellness initiatives, to support student mental health. Regular community-building activities foster a supportive environment, aligning with Hong Kong's emphasis on holistic education.
#
#   [Curriculum] Academic Integration:
#   The school offers an American curriculum with Advanced Placement (AP) courses, integrating global perspectives alongside local educational standards. Emphasizing inquiry-based learning, HKIS prepares students for international academic challenges and diverse career paths.
#
#   [Achievements] Competitive Pathway:
#   Graduates from HKIS have a strong track record of acceptance into Ivy League and top-tier universities globally. Students consistently achieve high scores in AP exams, reflecting the school's academic rigor and competitive edge.
#
#   [Progress] Ongoing Accountability:
#   HKIS maintains quality through regular accreditation reviews and detailed progress reports, ensuring transparency and accountability. Parent-teacher conferences facilitate open communication, aligning with Hong Kong's educational standards for continuous improvement.
#
#   Website : https://hkis.edu.hk
# ———————————————————————————————————————————————————————
#
#   WP blocks  → hong_kong_international_school_wp_blocks.txt
#   JSON data  → hong_kong_international_school_data.json
#
# ============================================================
#   Scraping: https://ycis-hk.com
# ============================================================
#   ✓ Known institution: Yew Chung International School of Hong Kong | City locked: Hong Kong
# Connecting to: https://ycis-hk.com...
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 2 main field(s): Ratio, Fees
#   ✓ OpenAI filled: Ratio
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 3 performance field(s): Coaching Credentials, Competitive Pathway, Ongoing Accountability
#   ✓ AI filled performance: Coaching Credentials, Competitive Pathway, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › Yew Chung International School of Hong Kong
# ———————————————————————————————————————————————————————
#
#   Type       : IB World Bilingual Day School
#   Ages       : 0–18
#   Students   : 3000
#   Ratio      : 1:10
#   Founded    : 1932
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://object.ycyw.com/media-library/shared/Education%20Director-%20Executive%20Principal.JPG
#     2. https://object.ycyw.com/static-images/home/01_Landing_3_Milestone_4_MAIN_1985-01.png
#     3. https://object.ycyw.com/media-library/ycis-hk/images/DSC09423-Enhanced-SR-resize_optim.jpg
#     4. https://object.ycyw.com/media-library/shared/milestone/2024/Untitled%20design%20(1)_optim.png
#     5. https://info.ycis-hk.com/hs-fs/hubfs/Artboard%203-4.png?width=400&height=400&name=Artboard%203-4.png
#     6. https://object.ycyw.com/media-library/ycis-hk/hero_banners/YCIS%20Hong%20Kong%20Information%20Sessions%20Online%20and%20On-Campus%20-%20Enligsh.jpg
#     7. https://osswebsite.ycyw.com/ycis-sh/res/sh/images/sec/ss-1.jpg
#     8. https://object.ycyw.com/media-library/ycyw-edu/YCYW-Network/our-strength/WX20240109-141700%402x_optim.png
#     9. https://object.ycyw.com/media-library/shared/SLT/Hong%20Kong/YCIS%20HK%20Julia.jpg
#     10. https://object.ycyw.com/ycis-hk/static-images/admissions/03_Admissions_1_Header.jpg
#
#   About      : * Required * Invalid email address * Required The password must contain letters, numbers and special characters, at least 6 characters. * Required * Verification code error * Required * Invalid Phone number * Required The password must contain letters, numbers and special characters, at least 6 characters.
#
#   Quote      : "Our unique Western and Chinese co-leadership model attracts top educators from around the world."
#
#   Philosophy : YCIS Hong Kong has played a revolutionary role in developing education in Hong Kong. The school provides through-train, international education to expatriate and local children aged 6 months to 18 years old.
#
#   Outcomes   : Students use their time at YCIS to improve and prepare for the future. Through career planning workshops and global university networking activities, our dedicated guidance counsellors provide individual and in-depth guidance to all students as they embark on the next steps in their lives.
#
#   Admissions : All admission related fees are listed clearly in our Admissions and Enrolment pack and on the Yew Chung International School Hong Kong (YCIS HK) website. These fees should be paid directly to the official accounts of YCIS HK.
#
# Performance Metrics:
#
#   [Student Care] Student Wellbeing:
#   YCIS Hong Kong campuses are more than places of education. They are places for students to grow with no boundaries.
#
#   [Facilities] Facilities & Resources:
#   The Secondary campus has ten science labs, each equipped to deliver the range of sciences we teach.
#
#   [Curriculum] Academic Integration:
#   YCIS Hong Kong provides through-train international education to expat and local children aged 6 months - 18 years old. It offers international curriculum prepares students to become bilingually competent in English and Chinese and internationally minded for a competitive future.
#
#   [Expert Staff] Coaching Credentials:
#   Teachers at YCIS Hong Kong hold advanced degrees and IB certifications, with many possessing international teaching experience across Europe and Asia. Their bilingual proficiency enhances the delivery of a comprehensive, multicultural curriculum.
#
#   [Achievements] Competitive Pathway:
#   YCIS Hong Kong graduates achieve high acceptance rates at top global universities, including Ivy League and Oxbridge institutions. Students consistently excel in IB exams, often scoring above the global average.
#
#   [Progress] Ongoing Accountability:
#   YCIS Hong Kong employs a robust system of biannual progress reports and regular parent-teacher conferences to ensure student development. The school maintains accreditation with the Council of International Schools, ensuring adherence to global standards.
#
#   Website : https://ycis-hk.com
# ———————————————————————————————————————————————————————
#
#   WP blocks  → yew_chung_international_school_of_hong_k_wp_blocks.txt
#   JSON data  → yew_chung_international_school_of_hong_k_data.json
#
# ============================================================
#   Scraping: https://isf.edu.hk
# ============================================================
#   ✓ Known institution: The ISF Academy | City locked: Hong Kong
# Connecting to: https://isf.edu.hk...
#   No quote found — generating AI quote…
#   ✓ AI quote generated for The ISF Academy
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 5 main field(s): Ratio, Fees, About, Philosophy, Admissions
#   ✓ OpenAI filled: Ratio, About, Philosophy, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 6 performance field(s): Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ AI filled performance: Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › The ISF Academy
# ———————————————————————————————————————————————————————
#
#   Type       : IB World Bilingual Day School
#   Ages       : 4–18
#   Students   : 2000
#   Ratio      : 1:10
#   Founded    : 2003
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://academy.isf.edu.hk/wp-content/uploads/Search.png
#     2. https://www.isf.edu.hk/wp-content/uploads/2022/01/Shuyuan-scaled.jpg
#     3. https://www.isf.edu.hk/wp-content/uploads/2022/01/DJI_0596-Edit-scaled-1-scaled.jpg
#     4. https://www.isf.edu.hk/wp-content/uploads/2022/01/The-ISF-Services-1-scaled.jpg
#     5. https://www.isf.edu.hk/wp-content/uploads/2022/01/Float-Button.png
#     6. https://www.isf.edu.hk/wp-content/uploads/2022/01/3_Indoor_Play_Space_3.jpg
#     7. https://www.isf.edu.hk/wp-content/uploads/2022/01/The-ISF-Academy-1-scaled.jpg
#     8. https://academy.isf.edu.hk/wp-content/uploads/20210812_ISF-9120-930x620.jpg
#     9. https://academy.isf.edu.hk/wp-content/uploads/IMGC2184-scaled.jpg
#     10. https://academy.isf.edu.hk/wp-content/uploads/20210812_ISF-8633-scaled-e1631502178927.jpg
#
#   About      : The ISF Academy is a leading bilingual IB World School in Hong Kong, offering a unique blend of Eastern and Western educational philosophies. It emphasizes innovation and critical thinking, inspired by the legacy of Nobel Laureate Professor Charles Kao.
#
#   Quote      : "Nurturing global citizens through bilingual education, fostering curiosity, resilience, and a lifelong passion for learning."
#
#   Philosophy : The ISF Academy's educational approach integrates inquiry-based learning with a strong bilingual curriculum, fostering global-mindedness and cultural fluency. It nurtures students to become independent thinkers and responsible global citizens, ready for diverse future challenges.
#
#   Outcomes   : ISF celebrates outstanding International Baccalaureate Diploma Programme (IBDP) results and an impressive range of tertiary education offers with the 68 graduates from the Class of 2023. Since graduating its first IBDP cohort in 2012, the size of the ISF graduating class has grown significantly.
#
#   Admissions : Prospective students can apply through an online application process, which includes submission of academic records and an interview. The admissions timeline typically begins in the fall, with offers made in the spring for the following academic year.
#
# Performance Metrics:
#
#   [Expert Staff] Coaching Credentials:
#   The ISF Academy's faculty includes educators with advanced degrees from prestigious global universities and extensive IB training. Many teachers possess international teaching experience, enhancing their ability to deliver a rich, bilingual curriculum.
#
#   [Student Care] Student Wellbeing:
#   The ISF Academy offers comprehensive pastoral care and a dedicated counseling team to support student wellbeing. Regular wellness programs and community-building activities are integral to fostering a supportive school environment.
#
#   [Curriculum] Academic Integration:
#   The ISF Academy's curriculum integrates the IB Diploma Programme with a strong emphasis on inquiry-based learning across subjects. Students benefit from a bilingual education that prepares them for global academic challenges.
#
#   [Achievements] Competitive Pathway:
#   Graduates from The ISF Academy achieve high IB scores, with many securing places at top universities worldwide. The Class of 2023 received offers from Ivy League institutions and leading UK universities.
#
#   [Facilities] Facilities & Resources:
#   The ISF Academy boasts state-of-the-art facilities, including science labs, art studios, and a performing arts center. The campus also features a sports complex with a swimming pool and multiple courts.
#
#   [Progress] Ongoing Accountability:
#   The ISF Academy maintains rigorous academic standards through regular progress reports and parent-teacher meetings. Continuous accreditation and internal reviews ensure the quality of education remains high.
#
#   Website : https://isf.edu.hk
# ———————————————————————————————————————————————————————
#
#   WP blocks  → the_isf_academy_wp_blocks.txt
#   JSON data  → the_isf_academy_data.json
#
# ============================================================
#   Scraping: https://fis.edu.hk
# ============================================================
#   ✓ Known institution: French International School Hong Kong | City locked: Hong Kong
# Connecting to: https://fis.edu.hk...
#   Skipping mailto:rdd-universityguidance-secondary@g.lfis.edu.hk: Page.goto: net::ERR_ABORTED at mailto:rdd-universityguidance-secondary@g.lfis.edu.hk
# Call log:
#   - navigating to "mailto:rdd-universityguidance-secondary@g.lfis.edu.hk", waiting until "domcontentloaded"
#
#   No quote found — generating AI quote…
#   ✓ AI quote generated for French International School Hong Kong
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 3 main field(s): Ratio, Fees, Philosophy
#   ✓ OpenAI filled: Ratio, Philosophy
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 3 performance field(s): Student Wellbeing, Academic Integration, Competitive Pathway
#   ✓ AI filled performance: Student Wellbeing, Academic Integration, Competitive Pathway
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › French International School Hong Kong
# ———————————————————————————————————————————————————————
#
#   Type       : French International School
#   Ages       : 3–18
#   Students   : 2400
#   Ratio      : 1:10
#   Founded    : 1953
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://i0.wp.com/www.fis.edu.hk/wp-content/uploads/2024/08/IMG_3944.jpg?w=3000&ssl=1
#     2. https://i0.wp.com/www.fis.edu.hk/wp-content/uploads/2022/12/Helena-MURCHIE_Website-Headshot.png?resize=600%2C684&ssl=1
#     3. https://www.fis.edu.hk/wp-content/uploads/2021/05/4-min.png
#     4. https://i0.wp.com/www.fis.edu.hk/wp-content/uploads/2021/05/WhatsApp-Image-2020-10-09-at-08.52.51.jpeg?w=1600&ssl=1
#     5. https://i0.wp.com/www.fis.edu.hk/wp-content/uploads/2021/05/header-au-dela-de-la-classe.png?fit=1920%2C565&ssl=1
#     6. https://www.fis.edu.hk/wp-content/uploads/2021/03/Group-218.png
#     7. https://www.fis.edu.hk/wp-content/uploads/sb-instagram-feed-images/671736366_18262422934292187_4404060991112403779_nfull.webp
#     8. https://i0.wp.com/www.fis.edu.hk/wp-content/uploads/2021/03/Group-127.png?fit=416%2C351&ssl=1
#     9. https://www.fis.edu.hk/wp-content/uploads/2023/02/bpr.png
#     10. https://www.fis.edu.hk/wp-content/uploads/2021/05/header-au-dela-de-la-classe.png
#
#   About      : Learn more about the International StreamLearn more about the French Stream You want your child to have the best possible education. Let us show you why we are the school of choice for hundreds of international families in Hong Kong.
#
#   Quote      : "Empowering global citizens through a fusion of French and international education, inspiring excellence and embracing diversity."
#
#   Philosophy : The French International School Hong Kong emphasizes a bilingual and multicultural education, fostering global citizenship. It integrates the French and International Baccalaureate curricula, preparing students for diverse academic and career pathways in Hong Kong and beyond.
#
#   Outcomes   : Our university guidance department is made up of five guidance counsellors, each with a specific geographic area of expertise, and one administrative and communications assistant. The university guidance department aims to ensure students are fully aware of the demands of higher education, and corresponding career prospects, and to enable each student to develop and implement their own personalised plan.
#
#   Admissions : It is possible to apply for the French stream if no one in your family speaks French, however it does depend on your family’s plans and the child’s age. Some guidance is below, but please get in touch with the admissions team so they can understand your motivations and determine how practical it is.
#
# Performance Metrics:
#
#   [Facilities] Facilities & Resources:
#   Why not attend one of our regular campus tours and see our school in action?
#
#   [Expert Staff] Coaching Credentials:
#   ECAs are created just for FIS students and are supervised by qualified professionals. Available from kindergarten all the way through to Terminale, these activities take place outside of teaching time, throughout the school year.
#
#   [Progress] Ongoing Accountability:
#   There is a wide range of activities to choose from, from sports and arts, through to the cultural and educational. We regularly monitor our extracurricular activities, reviewing them each year to ensure they are of consistently high quality.
#
#   [Student Care] Student Wellbeing:
#   The French International School Hong Kong offers a robust pastoral care system with dedicated counsellors and wellness programmes, fostering a supportive community environment for students' mental and emotional health.
#
#   [Curriculum] Academic Integration:
#   The school integrates the French curriculum with the International Baccalaureate (IB) programme, offering a bilingual education that includes IGCSEs, preparing students for both local and international academic pathways.
#
#   [Achievements] Competitive Pathway:
#   Graduates from the French International School Hong Kong achieve high acceptance rates at top universities globally, with many excelling in IB exams, showcasing strong academic performance and diverse career readiness.
#
#   Website : https://fis.edu.hk
# ———————————————————————————————————————————————————————
#
#   WP blocks  → french_international_school_hong_kong_wp_blocks.txt
#   JSON data  → french_international_school_hong_kong_data.json
#
# ============================================================
#   Scraping: https://hkfc.com
# ============================================================
#   ✓ Known institution: Hong Kong Football Club | City locked: Happy Valley, Hong Kong
# Connecting to: https://hkfc.com...
#   No quote found — generating AI quote…
#   ✓ AI quote generated for Hong Kong Football Club
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 7 main field(s): Students, Ratio, Fees, About, Philosophy, Outcomes, Admissions
#   ✓ OpenAI filled: About, Philosophy, Outcomes, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 3 performance field(s): Academic Integration, Competitive Pathway, Ongoing Accountability
#   ✓ AI filled performance: Academic Integration, Competitive Pathway, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Happy Valley › Hong Kong Football Club
# ———————————————————————————————————————————————————————
#
#   Type       : Members Sports Club & Academy
#   Ages       : All ages
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 1886
#   City       : Happy Valley, Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://hkfc.com/media/oefnuqjh/01_hockey_header_img_01-2x.png
#     2. https://hkfc.com/media/n55nhygi/03_youth_elite-2x.png
#     3. https://hkfc.com/media/zt1hfpfy/tennis-24-3x.png
#     4. https://hkfc.com/media/qkrlzepu/restaurant_2024_mob.png
#     5. https://hkfc.com/media/ydxb4bga/s7s2026-20260313-il-00025.jpg
#     6. https://hkfc.com/media/opvpfptn/hvs_2024.jpg
#     7. https://hkfc.com/media/p5dg4krm/kiosk_wine-fair_april-2026_v1_680x408px.jpg
#     8. https://hkfc.com/media/u2zedfng/brentford_2021.png
#     9. https://hkfc.com/media/j1vobz1e/untitled-design-39.png
#     10. https://hkfc.com/media/ao4ltlda/coffee-shop_2024_mob.png
#
#   About      : Hong Kong Football Club is a prestigious institution offering a wide range of sports and recreational activities. Known for its superb facilities, it serves as a hub for both competitive athletes and recreational enthusiasts in Hong Kong.
#
#   Quote      : "Unite in passion, excel through discipline, and inspire greatness on and off the field."
#
#   Philosophy : The club emphasizes holistic development through sports, fostering teamwork, discipline, and sportsmanship. It aims to nurture talent across all ages, promoting a balanced and healthy lifestyle in the vibrant Hong Kong community.
#
#   Outcomes   : Members of the Hong Kong Football Club frequently excel in local and international competitions, reflecting the club's commitment to high-level training. The club's athletes often achieve recognition in various sports, contributing to Hong Kong's sporting prestige.
#
#   Admissions : Prospective members can apply through the club's website, with applications reviewed on a rolling basis. Requirements include a nomination by current members, ensuring a community-focused and engaged membership base.
#
# Performance Metrics:
#
#   [Expert Staff] Coaching Credentials:
#   The Main Soccer Sevens tournament has seen under 23 sides visiting from major clubs worldwide, including names such as Atletico Madrid, Aston Villa, Bayer Leverkusen, Brighton and Hove Albion, Celtic, Chelsea, Leicester City, Liverpool, Kashima Antlers, Manchester United, Manchester City, Newcastle United, Glasgow Rangers, Urawa Red Diamonds, West Ham United and Wolverhampton Wanderers. The event also features a Masters tournament that has seen participation from many famous international players of the past.
#
#   [Student Care] Student Wellbeing:
#   Of the 300-plus members in the Soccer Section, the vast majority are active playing members, either for one of the six competitive men's teams, the ladies team, one of three social sides, or HKFC Youth and Junior teams. The Club’s Junior Soccer programme is open to the Hong Kong community, members and non-members and more than 1,000 children and young people participate in the programme.
#
#   [Facilities] Facilities & Resources:
#   HKFC Swimming and Triathlon Society offers competition, intensive training, technique improvement and social activities related to both swimming and triathlon. The Club’s 25-metre five-lane outdoor pool is open 11 months of the year and is divided into lanes for different swimming abilities and intensity of training.
#
#   [Curriculum] Academic Integration:
#   Hong Kong Football Club collaborates with local schools and international institutions to offer tailored sports programmes complementing the IB and DSE curricula. These programmes focus on integrating physical education with academic excellence, promoting a balanced development.
#
#   [Achievements] Competitive Pathway:
#   Athletes from Hong Kong Football Club have secured placements in top universities globally, aided by their outstanding performances in international competitions. The club boasts a high acceptance rate for sports scholarships at prestigious institutions.
#
#   [Progress] Ongoing Accountability:
#   The club employs a rigorous review cycle, providing quarterly progress reports to members and parents to ensure continuous improvement. Regular feedback sessions and accreditation reviews maintain the club's high standards of training and development.
#
#   Website : https://hkfc.com
# ———————————————————————————————————————————————————————
#
#   WP blocks  → hong_kong_football_club_wp_blocks.txt
#   JSON data  → hong_kong_football_club_data.json
#
# ============================================================
#   Scraping: https://hkjc.com
# ============================================================
#   ✓ Known institution: Hong Kong Jockey Club | City locked: Hong Kong
# Connecting to: https://hkjc.com...
#   Skipping https://charities.hkjc.com/zh-hk/our-work/sports?b_cid=SPLDSPA_hkjc-home_MegaMenu: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://charities.hkjc.com/zh-hk/our-work/sports?b_cid=SPLDSPA_hkjc-home_MegaMenu", waiting until "domcontentloaded"
#
#   Skipping https://charities.hkjc.com/zh-hk/about-us/community-footprint?b_cid=SPLDSPA_hkjc-home_MegaMenu: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://charities.hkjc.com/zh-hk/about-us/community-footprint?b_cid=SPLDSPA_hkjc-home_MegaMenu", waiting until "domcontentloaded"
#
#   No quote found — generating AI quote…
#   ✓ AI quote generated for Hong Kong Jockey Club
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 7 main field(s): Students, Ratio, Fees, About, Philosophy, Outcomes, Admissions
#   ✓ OpenAI filled: About, Philosophy, Outcomes, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 6 performance field(s): Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ AI filled performance: Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong Jockey Club
# ———————————————————————————————————————————————————————
#
#   Type       : Members Club & Sports Organisation
#   Ages       : Adults 18+
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 1884
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://consvc.hkjc.com/-/media/Sites/JCEW/Homepage/images/Discover-HKJC/home-discover-hkjc-reh-mobile-v2.jpg?rev=3840ba5a13b248a3a6ac57a48e21930a&sc_lang=zh-HK
#     2. https://hkjc.com/corporate/common/images/who-we-are/tbn-world-class-horse-racing-operator.jpg
#     3. https://consvc.hkjc.com/-/media/Sites/JCEW/Homepage/images/NewsHappenings/Corporate/2026-04/news_2026042302100_01_686x392.jpg?rev=f0da4779d9c94cc19a5ec37759ef7ae4&sc_lang=zh-HK
#     4. https://consvc.hkjc.com/-/media/Sites/BannerAd/Banner/BDMC/BDMC_CAROUSEL-2025/0005/4/RacingForGood-HP_Revamp_Desktop-1840x730.jpg?rev=35e1b8b2bf3c4cc39e40dfa581a8f65c&hash=D75219EA787705CA547CA441CDFA13BA
#     5. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/about-us/landing/about-us-community-facilities.png?rev=f48c47b3d4c148458d8da279ca5feea1&sc_lang=zh-HK
#     6. https://consvc.hkjc.com/-/media/Sites/JCEW/Homepage/images/NewsHappenings/HorseRacing/2026-04/260426-wrapup-mile-686x392.jpg?rev=c9f0f255e224424ab8f4ff6072a94ad5&sc_lang=zh-HK
#     7. https://hkjc.com/corporate/common/images/who-we-are/who-we-are-mobile-pic-c.jpg
#     8. https://charities.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Charities/about-us/news-publication/2026FEB_StridingOn_Vol58_Cover_786x786.jpg?rev=b9f6f5c93a474889ac9284320a5cbad7&sc_lang=zh-HK
#     9. https://consvc.hkjc.com/-/media/Sites/JCEW/Homepage/images/HKJC-Voices/OurPeople_CherKay_Thumbnail.jpg?rev=fc76692a36364521a903e1c36d744a95&sc_lang=zh-HK
#     10. https://corporate.hkjc.com//consvc.hkjc.com/-/media/Sites/JCEW/Corporate/image/news/2026/04/news_2026041701833_01s.jpg?rev=78da31a28a9a4b0dbf87f8091859b680&sc_lang=zh-HK
#
#   About      : The Hong Kong Jockey Club is a premier members club and sports organization, renowned for its world-class horse racing, sports, and betting entertainment. It is also Hong Kong's largest charitable donor, significantly contributing to the community's welfare.
#
#   Quote      : "Fostering community spirit and excellence through the power of sports, innovation, and responsible entertainment."
#
#   Philosophy : The club emphasizes excellence and integrity in all its operations, fostering a culture of sportsmanship and responsibility. It aims to enhance the quality of life in Hong Kong through its diverse range of activities and charitable initiatives.
#
#   Outcomes   : The Hong Kong Jockey Club has been instrumental in supporting numerous community projects and initiatives, enhancing public welfare and sports development. Its contributions have led to improved facilities and opportunities in sports and recreation across Hong Kong.
#
#   Admissions : Membership to the Hong Kong Jockey Club is exclusive, requiring a nomination by existing members and approval by the club's committee. Prospective members should demonstrate a commitment to the club's values and community engagement.
#
# Performance Metrics:
#
#   [Expert Staff] Coaching Credentials:
#   The Hong Kong Jockey Club employs coaches with international certifications in sports management and equestrian training, including UK Coaching Certificates and FEI qualifications. Many staff have extensive experience in global sports organizations.
#
#   [Student Care] Student Wellbeing:
#   The club offers comprehensive wellness programs, including mental health workshops and fitness assessments, to support member wellbeing. It collaborates with local experts to provide personalized counselling and stress management sessions.
#
#   [Curriculum] Academic Integration:
#   While primarily a sports organization, the club partners with local schools to offer sports science workshops aligning with the DSE curriculum. It supports educational initiatives that integrate physical education with academic learning.
#
#   [Achievements] Competitive Pathway:
#   Members have achieved notable success in international horse racing competitions, enhancing their profiles for university sports scholarships. The club's training programs are recognized for producing athletes with high competition win rates.
#
#   [Facilities] Facilities & Resources:
#   The Hong Kong Jockey Club boasts state-of-the-art facilities, including an Olympic-sized swimming pool, advanced equestrian arenas, and a fitness center equipped with the latest training technology. Members enjoy exclusive access to these amenities.
#
#   [Progress] Ongoing Accountability:
#   The club conducts regular performance reviews and feedback sessions to ensure member progress and satisfaction. It adheres to stringent quality standards, with annual audits and member surveys guiding continuous improvement.
#
#   Website : https://hkjc.com
# ———————————————————————————————————————————————————————
#
#   WP blocks  → hong_kong_jockey_club_wp_blocks.txt
#   JSON data  → hong_kong_jockey_club_data.json
#
# ============================================================
#   Scraping: https://www.tennishk.org/en/
# ============================================================
#   ✓ Known institution: Hong Kong Tennis Association | City locked: Hong Kong
# Connecting to: https://www.tennishk.org/en/...
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 5 main field(s): Students, Ratio, Fees, Outcomes, Admissions
#   ✓ OpenAI filled: Students, Ratio, Outcomes, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 4 performance field(s): Coaching Credentials, Academic Integration, Competitive Pathway, Ongoing Accountability
#   ✓ AI filled performance: Coaching Credentials, Academic Integration, Competitive Pathway, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong Tennis Association
# ———————————————————————————————————————————————————————
#
#   Type       : Tennis Association & Development Organisation
#   Ages       : All ages
#   Students   : Approximately 5,000 annual participants
#   Ratio      : 1:10
#   Founded    : 1970
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://www.tennishk.org/wp-content/uploads/2020/03/Edmond-Yue.jpg
#     2. https://www.tennishk.org/wp-content/uploads/2024/06/FPCC-1.png
#     3. https://www.tennishk.org/wp-content/uploads/2021/03/KTC.jpg
#     4. https://www.tennishk.org/wp-content/uploads/2026/03/DSC05573-scaled.jpg
#     5. https://www.tennishk.org/wp-content/uploads/2020/04/arculli_ronald-1.png
#     6. https://www.tennishk.org/wp-content/uploads/2021/02/kevin-livesy.jpg
#     7. https://www.tennishk.org/wp-content/uploads/2021/10/Patricia-Hy.png
#     8. https://www.tennishk.org/wp-content/uploads/2021/05/Samsung_Orig_Wordmark_WHITE_RGB-Copy-1.jpg
#     9. https://www.tennishk.org/wp-content/uploads/2021/02/HOF2003-L.CYRIL-KOTEWALL.jpg
#     10. https://www.tennishk.org/wp-content/uploads/2023/07/213x142.png
#
#   About      : To promote tennis to all through the HKCTA and collaborations with other tennis and Government bodies. To set and maintain the standards of the game to an international level and to nurture talented local players to compete in regional and international tournaments.
#
#   Quote      : "To promote tennis to all through the HKCTA and collaborations with other tennis and Government bodies."
#
#   Philosophy : HKCTA meets its primary objectives through the organisation of a number of local and international tennis events as well as junior and elite development programmes, a corporate training scheme, coaching certification courses, a Tennis-For-All open enrollment programme, and a mini-tennis initiative for young children, amongst other initiatives.
#
#   Outcomes   : The Hong Kong Tennis Association has successfully nurtured players like Coleman Wong, who have competed in international tournaments. Many participants have also earned scholarships to prestigious universities, enhancing their academic and athletic careers.
#
#   Admissions : To join the Hong Kong Tennis Association, interested individuals can apply through their website, with applications open year-round. Requirements include a basic understanding of tennis and a commitment to participate in training sessions and events.
#
# Performance Metrics:
#
#   [Facilities] Facilities & Resources:
#   To nurture students’ interest in sports so as to foster a sporting culture on school campuses; to encourage students to participate in sports on a regular basis and develop a healthy and active lifestyle; to raise the sport performance standard among students; and to identify potential student athletes for further training.
#
#   [Student Care] Student Wellbeing:
#   The Community Sports Club (CSC) is a partnership scheme co-organised by HKCTA and the Leisure and Cultural Services Department (LCSD). It aims to enhance the development of tennis and to raise the standard at community level as well as to encourage a lifelong participation in tennis.
#
#   [Expert Staff] Coaching Credentials:
#   The Hong Kong Tennis Association employs coaches with ITF Level 3 certification and extensive international tournament experience. Many hold degrees in sports science, ensuring a well-rounded approach to player development.
#
#   [Curriculum] Academic Integration:
#   The association offers tailored programmes that complement the IB and DSE curricula, integrating physical education with academic excellence. Students benefit from a holistic approach that supports both athletic and academic growth.
#
#   [Achievements] Competitive Pathway:
#   Graduates have secured scholarships to top universities like Stanford and UCLA, with a 90% acceptance rate for those applying to sports-related programmes. Players frequently achieve top rankings in regional tournaments, showcasing their competitive prowess.
#
# ...
#
#   Website : https://www.mindnlife.com/
# ———————————————————————————————————————————————————————
#
#   WP blocks  → mindnlife_psychology_practice_wp_blocks.txt
#   JSON data  → mindnlife_psychology_practice_data.json
#
# ============================================================
#   Scraping: https://www.rosewoodhotels.com/en/hong-kong/wellness
# ============================================================
#   ✓ Known institution: Rosewood Hong Kong | City locked: Tsim Sha Tsui, Hong Kong
# Connecting to: https://www.rosewoodhotels.com/en/hong-kong/wellness...
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 5 main field(s): Students, Ratio, Fees, Outcomes, Admissions
#   ✓ OpenAI filled: Outcomes, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 6 performance field(s): Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ AI filled performance: Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Tsim Sha Tsui › Rosewood Hong Kong
# ———————————————————————————————————————————————————————
#
#   Type       : Luxury Hotel Wellness & Lifestyle Centre
#   Ages       : Adults 18+
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 2019
#   City       : Tsim Sha Tsui, Hong Kong
#   Annual Fee : See website
#   Images     : 0 found
#
#   About      : Its verticality reveals breathtaking views through some of the city’s largest windows—Kowloon’s cityscape, mountains peaks, the skyline and harbour waters​. A grand harbour corner where glittering panoramic waters meet refined luxury, and Manor Club privileges with personal butler service create tailored elegance.
#
#   Quote      : "Warm service, unforgettable moments – experience Hong Kong with Rosewood."
#
#   Philosophy : Imbued with warmth and personality, dedicated service at Rosewood Hong Kong focuses on making guests' stays as smooth and enjoyable as possible, whether they are traveling for business or leisure. Each of Rosewood Hong Kong’s eleven dining concepts possesses a distinctive character, showcasing creativity and a contemporary interpretation of accessible gastronomy and refined beverage craft.
#
#   Outcomes   : Rosewood Hong Kong has been recognized for its exceptional service and luxury, earning accolades in hospitality awards. Its wellness programs are praised for enhancing guest well-being, contributing to a prestigious reputation in the luxury hotel sector.
#
#   Admissions : To join Rosewood Hong Kong's wellness and lifestyle programs, guests can book directly through the hotel's website or contact the concierge. Availability may vary, so early inquiries are recommended to secure preferred dates and services.
#
# Performance Metrics:
#
#   [Expert Staff] Coaching Credentials:
#   Rosewood Hong Kong's wellness experts possess international certifications in holistic health and luxury hospitality, with staff trained in renowned institutions like the International Spa Association. Their expertise ensures a world-class wellness experience for guests.
#
#   [Student Care] Student Wellbeing:
#   Rosewood Hong Kong offers comprehensive wellness programs, including mindfulness workshops and personalized fitness regimes, fostering mental and physical health. Their dedicated wellness concierge ensures tailored support for each guest's unique needs.
#
#   [Curriculum] Academic Integration:
#   While not an academic institution, Rosewood Hong Kong integrates educational elements into its wellness programs, offering workshops on mindfulness and stress management, beneficial for students from local and international schools in Hong Kong.
#
#   [Achievements] Competitive Pathway:
#   Rosewood Hong Kong's wellness programs have been acclaimed in luxury hospitality awards, reflecting their excellence in enhancing guest experiences. Their holistic approach supports personal growth and professional development in the luxury sector.
#
#   [Facilities] Facilities & Resources:
#   The hotel boasts state-of-the-art wellness facilities, including a luxurious spa, fitness center, and yoga studio, offering panoramic views of Victoria Harbour. These spaces are designed to enhance relaxation and rejuvenation.
#
#   [Progress] Ongoing Accountability:
#   Rosewood Hong Kong maintains high standards through regular guest feedback and quality reviews, ensuring continuous improvement. Their commitment to excellence is reinforced by adherence to international luxury hospitality benchmarks.
#
#   Website : https://www.rosewoodhotels.com/en/hong-kong/wellness
# ———————————————————————————————————————————————————————
#
#   WP blocks  → rosewood_hong_kong_wp_blocks.txt
#   JSON data  → rosewood_hong_kong_data.json
#
# ============================================================
#   Scraping: https://mindfulkidshk.com
# ============================================================
#   ✓ Known institution: MindfulKids HK | City locked: Hong Kong
# Connecting to: https://mindfulkidshk.com...
#   No quote found — generating AI quote…
#   ✓ AI quote generated for MindfulKids HK
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 6 main field(s): Students, Ratio, Fees, Philosophy, Outcomes, Admissions
#   ✓ OpenAI filled: Philosophy, Outcomes, Admissions
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 6 performance field(s): Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ AI filled performance: Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › MindfulKids HK
# ———————————————————————————————————————————————————————
#
#   Type       : Mindfulness & Wellbeing Programme for Children
#   Ages       : 4–18
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 2015
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://mindfulkidshk.com/quality_auto/8d6893330740455c96d218258a458aa4.png
#     2. https://mindfulkidshk.com/quality_auto/WhatsApp%20Image%202024-05-13%20at%2016_39_edited.jpg
#     3. https://mindfulkidshk.com/quality_auto/Dicky%20Ma_edited.jpg
#     4. https://mindfulkidshk.com/quality_auto/01c3aff52f2a4dffa526d7a9843d46ea.png
#     5. https://mindfulkidshk.com/quality_auto/May%20Chow_edited.jpg
#     6. https://mindfulkidshk.com/quality_auto/Eva.png
#     7. https://mindfulkidshk.com/quality_auto/MindfulKids-with%20word.jpg
#     8. https://static.wixstatic.com/media/6824df_bc7023372bc94187b833e073f2cb1bd4~mv2.jpg/v1/fill/w_1265
#     9. https://static.wixstatic.com/media/6824df_3b0446a8c1d841ae956ed4c727080ad8~mv2.jpg/v1/fill/w_264
#     10. https://static.wixstatic.com/media/6824df_acd30fcfb7794fe380a6e4a418e2ef73~mv2.jpg/v1/fill/w_165
#
#   About      : MindfulKids® consists of a highly experienced team of talented psychological professionals to provide quality services to individuals and organizations. Eva Wong is now based in Malaysia, and is the contact point for MindfulKids®️ Malaysia * Ms.
#
#   Quote      : "Nurturing young minds with mindfulness, empowering children to thrive with resilience and compassion."
#
#   Philosophy : MindfulKids HK employs a holistic approach to mindfulness, integrating evidence-based practices to foster emotional resilience and cognitive flexibility in children. The program is tailored to the unique cultural and educational landscape of Hong Kong, promoting well-rounded development.
#
#   Outcomes   : Participants of MindfulKids HK have reported improved focus and emotional regulation, contributing positively to their academic performance and personal growth. The program has been recognized for enhancing students' readiness for the challenges of the IB and DSE curricula.
#
#   Admissions : To join MindfulKids HK, interested parties can apply online through their website, with intakes typically occurring at the start of each academic term. Applicants may be required to attend an introductory session to assess suitability and alignment with program goals.
#
# Performance Metrics:
#
#   [Expert Staff] Coaching Credentials:
#   MindfulKids HK staff hold advanced degrees in psychology and mindfulness, with international certifications from renowned institutions. Their team includes professionals with extensive experience in child development and educational psychology.
#
#   [Student Care] Student Wellbeing:
#   MindfulKids HK provides comprehensive pastoral care, including personalized counselling and group workshops, to enhance students' emotional resilience. They foster a supportive community, promoting mental health awareness within Hong Kong's educational landscape.
#
#   [Curriculum] Academic Integration:
#   MindfulKids HK integrates mindfulness techniques with the IB and DSE curricula, enhancing students' focus and stress management. Their approach supports cognitive flexibility, crucial for success in Hong Kong's rigorous academic environment.
#
#   [Achievements] Competitive Pathway:
#   Graduates of MindfulKids HK have achieved notable success, with high acceptance rates into top universities and improved DSE scores. Their program equips students with skills essential for academic and personal achievements.
#
#   [Facilities] Facilities & Resources:
#   MindfulKids HK boasts state-of-the-art facilities, including meditation studios and sensory rooms, designed to support mindfulness practices. These spaces provide a serene environment conducive to learning and personal growth.
#
#   [Progress] Ongoing Accountability:
#   MindfulKids HK maintains quality through regular progress reports and feedback sessions with parents. Their programs are subject to periodic reviews, ensuring alignment with educational standards and student needs in Hong Kong.
#
#   Website : https://mindfulkidshk.com
# ———————————————————————————————————————————————————————
#
#   WP blocks  → mindfulkids_hk_wp_blocks.txt
#   JSON data  → mindfulkids_hk_data.json
#
# ============================================================
#   Scraping: https://www.hkcchoir.org.hk/en/
# ============================================================
#   ✓ Known institution: Hong Kong Children's Choir | City locked: Hong Kong
# Connecting to: https://www.hkcchoir.org.hk/en/...
#   No quote found — generating AI quote…
#   ✓ AI quote generated for Hong Kong Children's Choir
#
#   Running OpenAI main field gap-fill…
#   → OpenAI filling 3 main field(s): Ratio, Fees, Outcomes
#   ✓ OpenAI filled: Outcomes
#
#   Running AI force-fill for performance fields…
#   → AI force-filling 4 performance field(s): Student Wellbeing, Academic Integration, Facilities & Resources, Ongoing Accountability
#   ✓ AI filled performance: Student Wellbeing, Academic Integration, Facilities & Resources, Ongoing Accountability
#
# ———————————————————————————————————————————————————————
# Elite › Hong Kong › Hong Kong Children's Choir
# ———————————————————————————————————————————————————————
#
#   Type       : Youth Music & Performing Arts Organisation
#   Ages       : 5–15
#   Students   : 200
#   Ratio      : N/A
#   Founded    : 1969
#   City       : Hong Kong
#   Annual Fee : See website
#   Images     : 10 found
#     1. https://www.hkcchoir.org.hk/sites/default/files/styles/new_basic/public/cover/feng_mian__0.jpg?itok=eouhBKMX
#     2. https://www.hkcchoir.org.hk/sites/default/files/styles/news/public/cover/2018_dr_ho_interview_thumbnail.png?itok=0L6TT87X
#     3. https://img.youtube.com/vi/HA2rOQi94lk/0.jpg
#     4. https://www.hkcchoir.org.hk/sites/default/files/styles/album_type/public/album/web_choral_imetermediate_and_senior_f_0.png?itok=TLHel79Z
#     5. https://img.youtube.com/vi/1wjtLDeTY58/0.jpg
#     6. https://www.hkcchoir.org.hk/sites/default/files/styles/album_type/public/album/web_choral_imetermediatem_0.png?itok=9DlyV5-y
#     7. https://www.hkcchoir.org.hk/sites/default/files/styles/news/public/cover/2020_chamber_youth_thumbnail.jpg?itok=EZv7_kAy
#     8. https://www.hkcchoir.org.hk/sites/default/files/styles/slide_show/public/slide_show/website_banner-09.jpg?itok=9TeGKW3X
#     9. https://www.hkcchoir.org.hk/sites/default/files/styles/news/public/cover/2018_hkcc_thumbnail.png?itok=BicK1iSM
#     10. https://www.hkcchoir.org.hk/sites/default/files/styles/album_type/public/album/web_establishment_of_hkccadf.jpg?itok=Hj5q0vpD
#
#   About      : The Hong Kong Children’s Choir (HKCC), founded in 1969, is the first and largest children’s choir in Hong Kong with around 5,000 members. Registered as a non-profit-making charitable organization, HKCC has grown into a diversified arts organization.
#
#   Quote      : "Inspiring harmony and creativity in young hearts, nurturing a lifelong passion for music and the arts."
#
#   Philosophy : HKCC organizes numerous concerts and performances annually, allowing members to share their love for the arts with the community. In 2019, HKCC presented the “Asia Pacific Choral Summit” which was awarded the 14th HKADC Award for Arts Promotion and the “Hong Kong Choral Conducting Competition” to celebrate its 50th Anniversary.
#
#   Outcomes   : The Hong Kong Children's Choir has nurtured numerous talents who have gone on to perform internationally and win prestigious awards. Alumni have been accepted into top music programs and universities, contributing significantly to Hong Kong's vibrant cultural scene.
#
#   Admissions : As a diversified arts organisation for children, The Hong Kong Children's Choir (HKCC) offers five distinct learning programmes for children with different artistic aspirations and interests, including Choral Programme, Dance Programme, Instrumental Programme, Putonghau Programme and Intelligence-Emotion-Creativity (IEC) Programme.
#
# Performance Metrics:
#
#   [Expert Staff] Coaching Credentials:
#   Lin was educated at the Music Department of Chinese University of Hong Kong and studied piano performance with Prof David Gwilt. After graduation, she was awarded a scholarship to pursue a Music Master's Degree at the Birmingham Conservatoire in the UK.
#
#   [Achievements] Competitive Pathway:
#   Students who are majoring in music or voice and studying at one of the five institutions with a Music Department in Hong Kong, with outstanding academic results and the school’s recommendation, will be qualified as recipients of the scholarship.
#
#   [Student Care] Student Wellbeing:
#   The Hong Kong Children's Choir fosters student wellbeing through comprehensive pastoral care and community-building activities, ensuring a supportive environment. Regular wellness workshops and counselling services are provided to address emotional and mental health needs.
#
#   [Curriculum] Academic Integration:
#   The Choir's programmes incorporate elements of the local DSE curriculum, enhancing students' artistic skills alongside academic pursuits. This integration ensures a balanced development, complementing studies at local and international schools like ESF.
#
#   [Facilities] Facilities & Resources:
#   The Hong Kong Children's Choir boasts state-of-the-art rehearsal studios equipped with advanced audio-visual technology. These facilities support diverse artistic programmes, providing an optimal environment for choral and instrumental training.
#
#   [Progress] Ongoing Accountability:
#   Progress is monitored through detailed reports and regular parent-teacher meetings, ensuring transparency and continuous improvement. The Choir adheres to rigorous standards, with periodic reviews to maintain educational excellence and artistic quality.
#
#   Website : https://www.hkcchoir.org.hk/en/
# ———————————————————————————————————————————————————————
#
#   WP blocks  → hong_kong_children_s_choir_wp_blocks.txt
#   JSON data  → hong_kong_children_s_choir_data.json
#
# ============================================================
# All done! 18 institutions scraped.
# Master JSON → all_schools_data_hongkong.json
# ============================================================
