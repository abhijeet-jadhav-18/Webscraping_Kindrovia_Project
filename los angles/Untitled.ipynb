# %%
import os, subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "python-dotenv", "-q"])

# Load your code.env file
env_file = r"C:\Users\Abhijeet\code.env"

with open(env_file, "r") as f:
    for line in f:
        line = line.strip()
        if "=" in line and not line.startswith("#"):
            key, val = line.split("=", 1)
            os.environ[key.strip()] = val.strip().strip('"').strip("'")

print(f" Loaded from: {env_file}")

ok_openai = len(os.environ.get("OPENAI_API_KEY", "")) > 20
print(f"OpenAI : {' Loaded' if ok_openai else ' Not found'}")
# Out:
#  Loaded from: C:\Users\Abhijeet\code.env
# OpenAI :  Loaded

# %%
import os, subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "python-dotenv", "-q"],
               capture_output=True)

# Load from code.env
env_file = r"C:\Users\Abhijeet\code.env"
with open(env_file, "r") as f:
    for line in f:
        line = line.strip()
        if "=" in line and not line.startswith("#"):
            key, val = line.split("=", 1)
            os.environ[key.strip()] = val.strip().strip('"').strip("'")

# Anthropic not needed — set dummy so scraper skips quietly
if not os.environ.get("ANTHROPIC_API_KEY"):
    os.environ["ANTHROPIC_API_KEY"] = "not-used"

ok = len(os.environ.get("OPENAI_API_KEY", "")) > 20
print(f"OpenAI key : {' Ready' if ok else ' Not found — check code.env'}")
if ok:
    print(" Ready to run scraper")
# Out:
# OpenAI key :  Ready
#  Ready to run scraper

# %%
import asyncio
import re
import sys
import json
import urllib.request
import os
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from datetime import datetime


# ── SENTENCE-SAFE TRUNCATION ─────────────────────────────────────────────────

def clean_to_sentences(text: str, max_sentences: int = 2) -> str:
    """
    Return at most `max_sentences` complete sentences from text.
    Never cuts mid-sentence. Strips trailing incomplete fragments.
    """
    if not text:
        return ""
    text = re.sub(r'\s+', ' ', text).strip()
    # Split on sentence-ending punctuation followed by space or end-of-string
    sentences = re.split(r'(?<=[.!?])\s+', text)
    # Keep only complete sentences: must end with punctuation and have ≥6 words
    good = [
        s.strip() for s in sentences
        if len(s.strip().split()) >= 6 and re.search(r'[.!?]$', s.strip())
    ]
    return " ".join(good[:max_sentences])


# ── API KEY VALIDATION ────────────────────────────────────────────────────────
# Loads keys from .env file automatically — safe, never hardcode keys in code

try:
    from dotenv import load_dotenv
    load_dotenv()  # reads .env file from same folder as this script
except ImportError:
    pass  # dotenv not installed — keys must be set via os.environ manually

def _get_openai_key() -> str:
    return os.environ.get("OPENAI_API_KEY", "")

def _get_anthropic_key() -> str:
    return os.environ.get("ANTHROPIC_API_KEY", "")

def _check_key(key: str, name: str) -> bool:
    if not key or key.startswith("YOUR_") or len(key) < 20:
        print(f"  ⚠ {name} not set — add it to your .env file")
        return False
    return True

# ── HELPERS 

async def highlight_and_click(page, selector_or_locator, description="Action"):
    try:
        target = (
            page.locator(selector_or_locator).first
            if isinstance(selector_or_locator, str)
            else selector_or_locator
        )
        if await target.is_visible(timeout=2000):
            await target.evaluate(
                "el => { el.style.border = '4px solid #00FF00';"
                " el.style.backgroundColor = 'rgba(0,255,0,0.2)'; }"
            )
            await target.click()
            return True
    except Exception:
        pass
    return False


async def handle_cookies_automatically(page):
    cookie_selectors = [
        "text=Accept All", "text=Accept",
        "button:has-text('Accept')", "button:has-text('OK')",
        "button:has-text('I Agree')", "button:has-text('Close')",
        "button:has-text('Got it')", "button:has-text('Agree')",
    ]
    for selector in cookie_selectors:
        if await highlight_and_click(page, selector, "Cookie Banner"):
            break


async def smart_goto(page, url, timeout=90000):
    """Try networkidle first; fall back to domcontentloaded + commit."""
    try:
        await page.goto(url, wait_until="networkidle", timeout=timeout)
        return True
    except Exception as e:
        print(f"  ⚠ networkidle failed ({e.__class__.__name__}), retrying…")
    try:
        await page.goto(url, wait_until="domcontentloaded", timeout=timeout)
        await asyncio.sleep(6)
        try:
            await page.wait_for_function(
                "() => document.body && document.body.innerText.trim().length > 200",
                timeout=15000)
        except Exception:
            pass
        return True
    except Exception as e:
        try:
            await page.goto(url, wait_until="commit", timeout=timeout)
            await asyncio.sleep(8)
            return True
        except Exception:
            pass
        print(f"  ✗ Failed: {e}")
        return False


# ── CITY DETECTION ────────────────────────────────────────────────────────────

CITY_HINTS = {
    # LA neighbourhoods & areas
    "bel air":          "Bel Air, Los Angeles, CA",
    "bel-air":          "Bel Air, Los Angeles, CA",
    "beverly hills":    "Beverly Hills, CA",
    "brentwood":        "Brentwood, Los Angeles, CA",
    "malibu":           "Malibu, CA",
    "pacific palisades":"Pacific Palisades, Los Angeles, CA",
    "santa monica":     "Santa Monica, CA",
    "westwood":         "Westwood, Los Angeles, CA",
    "west hollywood":   "West Hollywood, CA",
    "west los angeles": "West Los Angeles, CA",
    "culver city":      "Culver City, CA",
    "playa vista":      "Playa Vista, Los Angeles, CA",
    "mar vista":        "Mar Vista, Los Angeles, CA",
    "marina del rey":   "Marina del Rey, CA",
    "venice":           "Venice, Los Angeles, CA",
    "silverlake":       "Silver Lake, Los Angeles, CA",
    "silver lake":      "Silver Lake, Los Angeles, CA",
    "echo park":        "Echo Park, Los Angeles, CA",
    "los feliz":        "Los Feliz, Los Angeles, CA",
    "hollywood":        "Hollywood, Los Angeles, CA",
    "pasadena":         "Pasadena, CA",
    "encino":           "Encino, CA",
    "sherman oaks":     "Sherman Oaks, CA",
    "studio city":      "Studio City, CA",
    "calabasas":        "Calabasas, CA",
    "woodland hills":   "Woodland Hills, CA",
    "chatsworth":       "Chatsworth, CA",
    "northridge":       "Northridge, CA",
    "la canada":        "La Cañada Flintridge, CA",
    "san marino":       "San Marino, CA",
    "arcadia":          "Arcadia, CA",
    "long beach":       "Long Beach, CA",
    "torrance":         "Torrance, CA",
    "manhattan beach":  "Manhattan Beach, CA",
    "hermosa beach":    "Hermosa Beach, CA",
    "redondo beach":    "Redondo Beach, CA",
    "el segundo":       "El Segundo, CA",
    "hawthorne":        "Hawthorne, CA",
    "inglewood":        "Inglewood, CA",
    # General
    "los angeles":      "Los Angeles, CA",
    "la, ca":           "Los Angeles, CA",
    ".edu":             "Los Angeles, CA",
    "california":       "California, CA",
    "ca 9":             "Los Angeles, CA",
}

def detect_city(url: str, body_text: str) -> str:
    url_lower = url.lower()
    for hint, city in CITY_HINTS.items():
        if hint in url_lower:
            return city
    # Try ZIP code in body text — LA ZIPs start with 900-902
    import re as _re
    zip_m = _re.search(r'\b(900\d\d|901\d\d|902\d\d)\b', body_text)
    if zip_m:
        return "Los Angeles, CA"
    sample = body_text[:4000].lower()
    for hint, city in CITY_HINTS.items():
        if hint in sample:
            return city
    return "Los Angeles, CA"


# ── GARBAGE SITE DETECTION ────────────────────────────────────────────────────
# Skip sites that have been redirected to domain-sale/parking pages

GARBAGE_SIGNALS = [
    "hugedomains", "domain for sale", "buy this domain", "sedoparking",
    "this domain is for sale", "godaddy", "namecheap parking",
    "page not found", "account suspended", "coming soon",
    "under construction", "website coming soon",
]

def is_garbage_site(name: str, body_text: str) -> bool:
    combined = (name + " " + body_text[:500]).lower()
    return any(sig in combined for sig in GARBAGE_SIGNALS)


# ── JUNK PARAGRAPH FILTER ─────────────────────────────────────────────────────
# Sentences that should never appear as data — error messages, UI strings, legal boilerplate

JUNK_PATTERNS = [
    r"the site you are about to visit",
    r"page you requested no longer exists",
    r"managed independently",
    r"beginning of dialog window",
    r"escape will cancel",
    r"^d after this time",
    r"^d to new applications",
    r"^d when the permitted",
    r"^s, refine my essays",
    r"enquire now$",
    r"apply now$",
    r"watch the video",
    r"learn more$",
    r"find out more$",
    r"read more$",
    r"click here",
    r'"school" means the school',
    r"student.*means the child",
    r"parents.*guardians.*applying",
    r"single.elimination system",
    r"park ventures ecoplex",
    r"57 wireless road",
    r"please fill out the form",
    r"fill the registration form",
    r"enrol your child in \d+ easy steps",
    r"step \d+ - complete",
    r"^why do we do what we do",
    r"see our record.breaking class",
    r"view now we have helped",
    r"not sponsored by.*affiliated",
    r"mailing list.*keep you up to date",
    r"joining our mailing list",
    r"over 1\.25 million",
    r"million visitor",
    r"million patron",
    r"to progress your application we require",
    r"please see below the list of documents",
    r"documents that are mandatory to upload",
    r'"school" means the school providing',
    r"our system is limited to uploading",
    r"scans of multi-page documents",
    r"report lost items",
    r"recover belongings",
    r"tourist visa.*online",
    r"apply for your tourist visa",
]

def is_junk(text: str) -> bool:
    if not text:
        return True
    tl = text.lower().strip()
    return any(re.search(p, tl) for p in JUNK_PATTERNS)


# ── IMAGE HARVESTING (module-level — works on homepage AND all subpages) ──────

SKIP_IMG = [
    "logo", "icon", "svg", "1x1", "pixel", "spinner", "placeholder",
    "blank", "transparent", "avatar", "flag", "arrow", "bullet",
    "check", "star", "rating", "rs/facebook", "rs/linkedin", "rs/youtube",
    "loupe", "panier", "menu", "profil", "derouler", "derouler",
    "default_image", "black-beacon", "weather/128",
]
EXTS_IMG = [".jpg", ".jpeg", ".png", ".webp"]

async def harvest_images(pg, base_url: str, image_set: set):
    """Collect all content images from current page into image_set."""
    try:
        # Scroll slowly to trigger lazy-loaded images
        await pg.evaluate("""async () => {
            await new Promise(resolve => {
                let total = 0;
                const dist = 400;
                const timer = setInterval(() => {
                    window.scrollBy(0, dist);
                    total += dist;
                    if (total >= document.body.scrollHeight) {
                        clearInterval(timer);
                        window.scrollTo(0, 0);
                        resolve();
                    }
                }, 80);
            });
        }""")
        await asyncio.sleep(1)
    except Exception:
        pass

    try:
        # 1. <img> tags — all lazy-load attrs
        for img in await pg.query_selector_all("img"):
            for attr in ["src", "data-src", "data-lazy-src", "data-original",
                         "data-image", "data-bg", "data-lazy", "data-srcset"]:
                c = await img.get_attribute(attr)
                if c:
                    src = c.strip().split(" ")[0].split(",")[0].strip()
                    full = urljoin(base_url, src)
                    if (any(e in full.lower() for e in EXTS_IMG)
                            and not any(s in full.lower() for s in SKIP_IMG)
                            and len(full) > 25):
                        image_set.add(full)
            # srcset — take largest (last) candidate
            srcset = await img.get_attribute("srcset")
            if srcset:
                parts = [p.strip().split(" ")[0] for p in srcset.split(",") if p.strip()]
                if parts:
                    full = urljoin(base_url, parts[-1])
                    if (any(e in full.lower() for e in EXTS_IMG)
                            and not any(s in full.lower() for s in SKIP_IMG)):
                        image_set.add(full)

        # 2. og:image + twitter:image
        for sel in ['meta[property="og:image"]', 'meta[name="twitter:image"]',
                    'meta[property="og:image:url"]']:
            try:
                for og in await pg.evaluate(
                    f"() => Array.from(document.querySelectorAll('{sel}')).map(m=>m.content)"
                ):
                    if og and og.strip() and not any(s in og.lower() for s in SKIP_IMG):
                        image_set.add(og.strip())
            except Exception:
                pass

        # 3. CSS background-image on hero/banner/slider/section
        bg_urls = await pg.evaluate("""() => {
            const hits = [];
            const sels = [
                '[style*="background-image"]','[class*="hero"]','[class*="banner"]',
                '[class*="slider"]','[class*="slide"]','[class*="bg-image"]',
                '[class*="cover"]','section','header'
            ];
            sels.forEach(sel => {
                try {
                    document.querySelectorAll(sel).forEach(el => {
                        const s = el.style.backgroundImage ||
                                  getComputedStyle(el).backgroundImage || '';
                        const m = s.match(/url\\(["']?([^"')]+)["']?\\)/);
                        if (m && m[1]) hits.push(m[1]);
                    });
                } catch(e) {}
            });
            return [...new Set(hits)];
        }""")
        for bg in bg_urls:
            if bg:
                full = urljoin(base_url, bg.strip())
                if (any(e in full.lower() for e in EXTS_IMG)
                        and not any(s in full.lower() for s in SKIP_IMG)):
                    image_set.add(full)
    except Exception:
        pass  # Never crash on image errors


def generate_fallback(metric, text_pool):
    metric_keywords = {
        "Coaching Credentials":   ["qualified teacher", "certified", "credentials", "faculty", "expertise"],
        "Student Wellbeing":      ["wellbeing", "pastoral", "counselor", "mental health", "welfare"],
        "Academic Integration":   ["curriculum", "academic", "igcse", "a-level", "ib", "programme"],
        "Competitive Pathway":    ["university", "destination", "results", "examination", "achievement"],
        "Facilities & Resources": ["facilities", "campus", "library", "laboratory", "pool", "gymnasium"],
        "Ongoing Accountability": ["progress", "tracking", "monitoring", "feedback", "report"],
    }
    kws     = metric_keywords.get(metric, [])
    pool    = [p for p in text_pool if not is_junk(p)]
    matched = [p for p in pool if any(k in p.lower() for k in kws)]
    raw     = " ".join(matched[:2]) if matched else (" ".join(pool[:2]) if pool else "")
    return clean_to_sentences(raw, 2)


# ── QUOTE SCRAPER

def _word_count(text):
    return len(text.split())


def scrape_quote_from_soup(soup):
    SKIP_PHRASES = [
        "cookie", "menu", "nav", "©", "privacy", "terms",
        "subscribe", "sign up", "click", "read more", "javascript",
        "khda", "rated", "inspection", "watch the video", "watch video",
        "listen to", "testimonial", "share", "follow us", "contact us",
        "apply now", "find out more", "learn more", "get in touch",
        "download", "register", "book a", "visit us",
        # Legal / UI junk
        "means the child", "parents/guardians", "dialog window",
        "escape will cancel", "site you are about to visit",
        "no longer exists", "managed independently",
    ]
    selectors = [
        "blockquote", "q",
        "[class*='quote']", "[class*='pullquote']",
        "[class*='callout']",
        "[class*='hero'] p", "[class*='banner'] p",
        "[class*='mission'] p", "[class*='vision'] p",
        "figcaption",
    ]
    candidates = []
    for sel in selectors:
        for el in soup.select(sel):
            text = re.sub(r'\s+', ' ', el.get_text()).strip()
            text = text.strip('\u201c\u201d\u2018\u2019"\'')
            wc   = _word_count(text)
            if wc < 8 or wc > 35:
                continue
            if any(x in text.lower() for x in SKIP_PHRASES):
                continue
            if is_junk(text):
                continue
            # Must end with real sentence punctuation
            if not re.search(r'[.!?]$', text):
                continue
            candidates.append(text)
    if not candidates:
        return ""
    candidates.sort(key=lambda t: _word_count(t))
    return candidates[0]


# ── AI QUOTE — uses OpenAI (no Anthropic key needed)

def generate_ai_quote(school_name, school_type, city, about_text):
    key = _get_openai_key()
    if not _check_key(key, "OPENAI_API_KEY"):
        return f"Excellence, integrity, and curiosity — the pillars of {school_name}."
    prompt = (
        f"Write ONE short inspirational quote (1 sentence, 10–20 words) "
        f"that reflects the philosophy of {school_name}, a {school_type} in {city}. "
        f"Context: {about_text[:300]}. "
        f"Sound like the organisation's mission statement. "
        f"Return ONLY the quote text — no quotation marks, no attribution, no explanation."
    )
    payload = json.dumps({
        "model":       "gpt-4o",
        "max_tokens":  60,
        "temperature": 0.7,
        "messages":    [{"role": "user", "content": prompt}],
    }).encode("utf-8")
    req = urllib.request.Request(
        "https://api.openai.com/v1/chat/completions",
        data=payload,
        headers={
            "Content-Type":  "application/json",
            "Authorization": f"Bearer {key}",
        },
        method="POST",
    )
    try:
        with urllib.request.urlopen(req, timeout=15) as resp:
            data  = json.loads(resp.read())
            quote = data["choices"][0]["message"]["content"].strip().strip('"\'')
            words = quote.split()
            if len(words) > 25:
                quote = " ".join(words[:25])
            print(f"  ✓ AI quote generated for {school_name}")
            return quote
    except Exception as e:
        print(f"  ⚠ AI quote failed: {e}")
    return f"Excellence, integrity, and curiosity — the pillars of {school_name}."


# ── OpenAI gap-fill ───────────────────────────────────────────────────────────

def openai_fill_missing_fields(results: dict) -> dict:
    """
    After scraping, call OpenAI gpt-4o to fill any field that is still
    empty, 'N/A', or a placeholder.  Only missing fields are sent;
    already-scraped values are NEVER overwritten.
    """
    key = _get_openai_key()
    if not _check_key(key, "OPENAI_API_KEY"):
        return results

    entity_type = results.get("Type", "Independent School")
    is_school   = any(w in entity_type.lower() for w in ["school", "academy", "college", "education"])

    FILL_FIELDS = {
        "Founded":    "Year this organisation was founded (just the 4-digit year). If unknown reply N/A.",
        "Ages":       ("Student age range (e.g. '3–18'). If unknown reply N/A." if is_school
                       else "Age range of members/clients served. If not applicable reply N/A."),
        "Students":   ("Approximate enrolled students (e.g. '1200'). If unknown reply N/A." if is_school
                       else "Approximate number of members/clients/visitors annually. If unknown reply N/A."),
        "Ratio":      "Staff-to-student or staff-to-client ratio. If unknown reply N/A.",
        "Fees":       "Annual fee or membership cost with currency. If unknown reply 'See website'.",
        "About":      f"2 sentences max (≤40 words) describing {results.get('Name','this organisation')}'s identity and mission.",
        "Philosophy": f"2 sentences max (≤40 words) on {results.get('Name','this organisation')}'s approach or ethos.",
        "Outcomes":   f"2 sentences max (≤40 words) on what {results.get('Name','this organisation')} achieves for its members.",
        "Admissions": f"2 sentences max (≤40 words) on how to join or enrol at {results.get('Name','this organisation')}.",
        "Tagline":    f"One compelling tagline (≤20 words) for {results.get('Name','this organisation')}.",
    }

    PERF_FIELDS = {
        "Coaching Credentials":   f"2 UNIQUE sentences (≤35 words) on staff qualifications or expertise at {results.get('Name','')}.",
        "Student Wellbeing":      f"2 UNIQUE sentences (≤35 words) on how {results.get('Name','')} supports member/student wellbeing.",
        "Academic Integration":   f"2 UNIQUE sentences (≤35 words) on the programmes or curriculum at {results.get('Name','')}.",
        "Competitive Pathway":    f"2 UNIQUE sentences (≤35 words) on achievements, results or pathways at {results.get('Name','')}.",
        "Facilities & Resources": f"2 UNIQUE sentences (≤35 words) on facilities, venues or resources at {results.get('Name','')}.",
        "Ongoing Accountability": f"2 UNIQUE sentences (≤35 words) on how {results.get('Name','')} tracks progress or quality.",
    }

    # Build context from whatever was scraped successfully
    ctx_lines = []
    for k in ["Name", "Type", "City", "URL", "Tagline", "About", "Philosophy",
               "Outcomes", "Admissions", "Founded", "Ages", "Students", "Ratio", "Fees"]:
        v = results.get(k, "")
        if v:
            ctx_lines.append(f"{k}: {v}")
    for pk, pv in results.get("Performance", {}).items():
        if pv:
            ctx_lines.append(f"{pk}: {pv[:200]}")
    context = "\n".join(ctx_lines) or f"URL: {results.get('URL', '')}"

    # Decide which fields still need filling
    missing_main = {
        f: p for f, p in FILL_FIELDS.items()
        if not results.get(f) or results[f] in ("N/A", "See website", "Rolling admissions", "Year-round", "")
    }

    def _perf_needs_fill(val: str, name: str) -> bool:
        if not val or val.strip() in ("N/A", "", "N/a"):
            return True
        val_clean = re.sub(r'\s+', ' ', val).strip()
        if len(val_clean.split()) < 8:
            return True
        irrelevant = [
            # Generic junk
            "cookie","privacy policy","gdpr","javascript",
            "seven emirates","fishing village","tourist visa",
            "no longer exists","site you are about to visit",
            # LA-specific non-relevant
            "some of the data collected by this provider",
            "for the purposes of personalization",
            "measuring advertising effectiveness",
            "uniform shop","school uniform",
            "buy tickets","reserve your spot",
            "follow us on instagram","subscribe to our newsletter",
        ]
        vl = val_clean.lower()
        return any(phrase in vl for phrase in irrelevant)

    missing_perf = {
        f: p for f, p in PERF_FIELDS.items()
        if _perf_needs_fill(results.get("Performance", {}).get(f, ""), f)
    }

    all_missing = {**missing_main, **missing_perf}
    if not all_missing:
        print("  ✓ All fields complete — OpenAI fill not needed.")
        return results
    print(f"  → OpenAI filling {len(all_missing)} missing field(s): {', '.join(all_missing.keys())}")

    # Build one compact prompt
    field_instructions = "\n".join(f'  "{k}": {v}' for k, v in all_missing.items())
    prompt = f"""You are a Los Angeles education and culture data analyst with knowledge of LA private schools, academies, and enrichment organisations.
Use the known data below AND your own knowledge to fill the missing fields accurately.

KNOWN DATA:
{context}

Fill ONLY these fields (reply with a JSON object, keys exactly as shown):
{field_instructions}

Rules:
- Use your knowledge of this Los Angeles institution to fill factual fields (Founded, Ages, Students, Fees in USD).
- Fees: use $ and per year. LA private school range typically $30,000–$60,000 per year.
- Keep paragraph fields SHORT: max 2 sentences, ≤40 words total per field.
- Each performance field MUST describe a DIFFERENT aspect — no repeated sentences across fields.
- Each field must sound distinct — different vocabulary, different facts, different angle.
- Do NOT add commentary, markdown fences, or extra keys.
- Reply with valid JSON only."""

    payload = json.dumps({
        "model": "gpt-4o",
        "max_tokens": 2000,
        "temperature": 0.3,
        "messages": [{"role": "user", "content": prompt}],
    }).encode("utf-8")

    req = urllib.request.Request(
        "https://api.openai.com/v1/chat/completions",
        data=payload,
        headers={
            "Content-Type":  "application/json",
            "Authorization": f"Bearer {key}",
        },
        method="POST",
    )

    try:
        with urllib.request.urlopen(req, timeout=30) as resp:
            data  = json.loads(resp.read())
            raw   = data["choices"][0]["message"]["content"].strip()
            # Strip markdown fences if present
            raw   = re.sub(r"^```(?:json)?\s*", "", raw, flags=re.M)
            raw   = re.sub(r"\s*```$",           "", raw, flags=re.M).strip()
            filled = json.loads(raw)

            filled_keys = []
            for fkey, val in filled.items():
                if not val or val in ("N/A", "See website"):
                    continue
                if fkey in FILL_FIELDS:
                    if not results.get(fkey) or results[fkey] in (
                            "N/A", "See website", "Rolling admissions", "Year-round", ""):
                        results[fkey] = str(val).strip()
                        filled_keys.append(fkey)
                elif fkey in PERF_FIELDS:
                    # Overwrite if missing OR if it was junk
                    if _perf_needs_fill(results["Performance"].get(fkey, ""), fkey):
                        results["Performance"][fkey] = str(val).strip()
                        filled_keys.append(fkey)

            if filled_keys:
                print(f"  ✓ OpenAI filled: {', '.join(filled_keys)}")
            else:
                print("  ✓ OpenAI: nothing new to fill.")

    except json.JSONDecodeError as e:
        print(f"  ⚠ OpenAI fill JSON parse error: {e}")
    except Exception as e:
        print(f"  ⚠ OpenAI fill failed: {e}")

    return results


def generate_wp_blocks(r):
    school_name  = r.get("Name", "")
    description  = r.get("Tagline", "")
    age          = r.get("Ages", "")
    students     = r.get("Students", "")
    ratio        = r.get("Ratio", "")
    founded      = r.get("Founded", "")
    school_type  = r.get("Type", "")
    city         = r.get("City", "")
    annual_fee   = r.get("Fees", "")
    about        = r.get("About", "")
    philosophy   = r.get("Philosophy", "")
    outcomes     = r.get("Outcomes", "")
    quote        = r.get("Quote", "")
    website_url  = r.get("URL", "")
    admissions   = r.get("Admissions", "")
    images       = r.get("Images", [])
    perf         = r.get("Performance", {})
    enquiry_open = r.get("EnquiryOpen", "Year-round")
    app_deadline = r.get("AppDeadline", "Rolling admissions")

    website_display = website_url.replace("https://", "").replace("http://", "").rstrip("/")
    city_slug       = city.lower().replace(", ", "-").replace(" ", "-").replace(",", "")
    city_short      = city.split(",")[0].strip()

    img0 = images[0] if len(images) > 0 else ""
    img1 = images[1] if len(images) > 1 else img0
    img2 = images[2] if len(images) > 2 else img0
    img3 = images[3] if len(images) > 3 else img0
    img4 = images[4] if len(images) > 4 else img0

    coaching       = perf.get("Coaching Credentials", "")
    wellbeing      = perf.get("Student Wellbeing", "")
    academic       = perf.get("Academic Integration", "")
    competitive    = perf.get("Competitive Pathway", "")
    facilities     = perf.get("Facilities & Resources", "")
    accountability = perf.get("Ongoing Accountability", "")

    wp = f"""<!-- wp:image {{"id":440,"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img0}" alt="" class="wp-image-440"/></figure>
<!-- /wp:image -->

<!-- wp:paragraph -->
<p><a href="elite-home.html"><br>Elite</a>&#8250; <a href="elite-city-{city_slug}.html">{city_short}</a>&#8250; <a href="elite-program-academic.html">Elite Academic Programs</a></p>
<!-- /wp:paragraph -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Kidrovia Elite \u2014 Listed</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Elite Academic Programs</h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":1}} -->
<h1 class="wp-block-heading"><em>{school_name}</em></h1>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{description}</p>
<!-- /wp:paragraph -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{age}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ages</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{students}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Students</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{ratio}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ratio</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:paragraph -->
<p>{founded}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Founded</h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column {{"width":"66.66%"}} -->
<div class="wp-block-column" style="flex-basis:66.66%"><!-- wp:heading -->
<h2 class="wp-block-heading">About <em>{school_name}</em></h2>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{about}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column {{"width":"33.33%"}} -->
<div class="wp-block-column" style="flex-basis:33.33%"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Institution Details</h5>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Type</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ages</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Students</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Ratio </h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Founded</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">City</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Annual fee</h5>
<!-- /wp:heading --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{school_type}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{age}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{students}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{ratio}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{founded}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{city}</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">{annual_fee}</h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Contact &amp; Enquiry</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading"><a href="{website_url}" target="_blank" rel="noreferrer noopener">{website_display} &#8594;</a></h5>
<!-- /wp:heading --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">Quotes</h5>
<!-- /wp:heading -->

<!-- wp:paragraph {{"align":"center"}} -->
<p class="has-text-align-center">&ldquo;{quote}&rdquo;</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">{school_name}</h5>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Philosophy</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">How they&nbsp;<em>teach</em></h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{philosophy}<br><br><br></p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Outcomes</h5>
<!-- /wp:heading -->

<!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Where students&nbsp;<em>go</em></h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{outcomes}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":441,"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img1}" alt="" class="wp-image-441"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column {{"width":"100%"}} -->
<div class="wp-block-column" style="flex-basis:100%"><!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":449,"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img2}" alt="" class="wp-image-449"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":450,"sizeSlug":"large","linkDestination":"none"}} -->
<figure class="wp-block-image size-large"><img src="{img3}" alt="" class="wp-image-450"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column --></div>
<!-- /wp:columns --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":451,"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img4}" alt="" class="wp-image-451"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:image {{"id":452,"sizeSlug":"full","linkDestination":"none"}} -->
<figure class="wp-block-image size-full"><img src="{img0}" alt="" class="wp-image-452"/></figure>
<!-- /wp:image --></div>
<!-- /wp:column --></div>
<!-- /wp:columns --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:heading {{"level":4}} -->
<h4 class="wp-block-heading">Our Assessment</h4>
<!-- /wp:heading -->

<!-- wp:heading -->
<h2 class="wp-block-heading"><strong>How {school_name} performs</strong></h2>
<!-- /wp:heading -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Coaching Credentials</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{coaching}<br></p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Student Wellbeing</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{wellbeing}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Academic Integration</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{academic}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Competitive Pathway</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{competitive}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Facilities &amp; Resources</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{facilities}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":3}} -->
<h3 class="wp-block-heading">Ongoing Accountability</h3>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{accountability}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:columns -->
<div class="wp-block-columns"><!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading -->
<h2 class="wp-block-heading">Admissions &amp;<br><em>How to Apply</em></h2>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{admissions}</p>
<!-- /wp:paragraph --></div>
<!-- /wp:column -->

<!-- wp:column -->
<div class="wp-block-column"><!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Enquiries Open</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{enquiry_open}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Application Deadline</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{app_deadline}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Annual Fee</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{annual_fee}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Location</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p>{city}</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"level":5}} -->
<h5 class="wp-block-heading">Website</h5>
<!-- /wp:heading -->

<!-- wp:paragraph -->
<p><a href="{website_url}" target="_blank" rel="noreferrer noopener">{website_display}</a></p>
<!-- /wp:paragraph --></div>
<!-- /wp:column --></div>
<!-- /wp:columns -->

<!-- wp:paragraph {{"align":"center"}} -->
<p class="has-text-align-center">&ldquo;{quote}&rdquo;</p>
<!-- /wp:paragraph -->

<!-- wp:heading {{"textAlign":"center","level":5}} -->
<h5 class="wp-block-heading has-text-align-center">{school_name}</h5>
<!-- /wp:heading -->
"""
    return wp


async def extract_school_data(url):
    async with async_playwright() as p:
        import platform
        headless = os.environ.get("HEADLESS","true" if platform.system()=="Linux" else "false").lower()=="true"
        browser  = await p.chromium.launch(headless=headless, slow_mo=0 if headless else 200)
        context  = await browser.new_context(viewport={"width": 1280, "height": 800})
        page     = await context.new_page()

        results = {
            "Name": "", "Tagline": "", "Founded": "",
            "City": "",
            "Ages": "", "Students": "", "Ratio": "", "Fees": "",
            "Type": "Independent School",
            "About": "", "Philosophy": "", "Outcomes": "",
            "Admissions": "", "Quote": "",
            "EnquiryOpen": "Year-round",
            "AppDeadline": "Rolling admissions",
            "Performance": {}, "URL": url, "Images": [],
        }

        global_text_pool = []

        FALLBACKS = {
            "Founded":  "",
            "Ages":     "",
            "Students": "",
            "Ratio":    "N/A",
            "Fees":     "See website",
        }

        # Fee patterns — USD / $ / per year / per semester
        fee_patterns = [
            r'\$\s*[\d,]+(?:\.\d{2})?\s*per\s*(?:year|annum|semester|month)',
            r'USD\s*[\d,]+(?:\.\d{2})?\s*(?:per\s*(?:year|annum|semester))?',
            r'tuition\s*(?:fee)?s?\s*(?:of|is|are|:)?\s*\$\s*[\d,]+',
            r'annual\s*tuition\s*[:\-]?\s*\$\s*[\d,]+',
            r'fee[s]?\s*(?:of|is|are|:)?\s*\$\s*[\d,]+',
            r'school\s+fee[s]?\s*[:\-]?\s*\$\s*[\d,]+',
            r'\$\s*[\d,]+\s*per\s*(?:year|semester|month)',
            r'tuition[:\s]+\$\s*[\d,]+',
            r'\$\s*[\d,]+(?:\.\d{2})?',
        ]

        # FIX #3: Ratio — added 1:X and X:1 formats common in UAE
        ratio_patterns = [
            r'(\d+\s*:\s*\d+)\s*(?:student[- ]to[- ](?:faculty|teacher)|teacher[- ]to[- ]student|ratio)',
            r'ratio\s*(?:of\s*)?(\d+\s*:\s*\d+)',
            r'(\d+\s*:\s*\d+)\s*ratio',
            r'1\s*(?:teacher|member of staff|coach)\s+(?:to|per|:)\s+(\d+)\s*(?:students?|pupils?|learners?)',
            r'(\d+)\s*(?:students?|pupils?|learners?)\s+(?:per|to)\s+(?:every\s+)?(?:1\s+)?(?:teacher|tutor|coach)',
        ]

        # Age patterns — US school system (Grades, Pre-K, TK)
        age_patterns = [
            r'students?\s+aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'aged\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'ages?\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'from\s+age\s+(\d+)\s*(?:to|[\u2013\-])\s*(\d+)',
            r'(\d+)\s*(?:to|[\u2013\-])\s*(\d+)\s*years?\s*(?:old)?',
            r'grade[s]?\s+(\d+)\s*(?:through|to|[\u2013\-])\s*(\d+)',
            r'(?:k|kindergarten)\s*(?:through|to|[\u2013\-])\s*(?:grade\s+)?(\d+)',
            r'(?:pre[\-\s]?k|tk|transitional\s+kindergarten)\s*(?:through|to|[\u2013\-])\s*(?:grade\s+)?(\d+)',
            r'(?:preschool|pre[\-\s]?school)\s*(?:through|to|[\u2013\-])\s*(?:grade\s+)?(\d+)',
            r'(?:from|between)\s+grades?\s+(\d+)\s*(?:through|to|[\u2013\-])\s*(\d+)',
        ]

        # FIX #5: Student patterns
        student_patterns = [
            r'(\d[\d,]+)\s*(?:\+)?\s*(?:pupils?|students?|boys|girls|young people|young women|learners?|scholars?)',
            r'(?:approximately|around|about|some|over|more than)\s+(\d[\d,]+)\s*(?:pupils?|students?|girls?|learners?)',
            r'school\s+of\s+(?:approximately|around|about)?\s*(\d[\d,]+)',
            r'enroll(?:ment|ment|ing)\s+(?:of\s+)?(?:approximately|about)?\s*(\d[\d,]+)',
            r'community\s+of\s+(?:over\s+)?(\d[\d,]+)\s*(?:students?|learners?)',
            r'(\d[\d,]+)\s*(?:\+)?\s*(?:student|pupil|learner|child)',
        ]

        print(f"Connecting to: {url}...")

        loaded = await smart_goto(page, url)
        if not loaded:
            print(f"  ✗ Could not load {url}, skipping.")
            await browser.close()
            return None

        try:
            await handle_cookies_automatically(page)

            # Name — prefer og:site_name / og:title over <title> which can return "Home"
            og_site  = await page.evaluate("() => { const m = document.querySelector('meta[property=\"og:site_name\"]'); return m ? m.content : ''; }")
            og_title = await page.evaluate("() => { const m = document.querySelector('meta[property=\"og:title\"]'); return m ? m.content : ''; }")
            raw_title = await page.title()

            REJECT_NAMES = {
                "home","welcome","homepage","index","main","","welcome to",
                "about","contact","admissions","academics",
            }
            REJECT_STARTS = ("welcome to ", "home -", "home |")
            REJECT_LONG_PHRASES = ["personalization","advertising effectiveness"]

            KNOWN_NAMES_LA = {
                "crossroadsschool.org":    "Crossroads School",
                "marlboroughschool.org":   "Marlborough School",
                "thewebb.org":             "The Webb Schools",
                "westridgeschool.org":     "Westridge School",
                "polytechnic.org":         "Polytechnic School",
                "chadwickschool.org":      "Chadwick School",
                "harvardswestlake.org":    "Harvard-Westlake School",
                "brentwood.org":           "Brentwood School",
                "viewpoint.org":           "Viewpoint School",
                "curreyhouseschool.com":   "Currey House School",
                "willowschool.org":        "Willow School",
                "milkenschool.org":        "Milken Community School",
                "solebury.org":            "Solebury School",
                "oaksschool.org":          "The Oaks School",
                "campbellock.edu":         "Campbell Hall School",
                "campbellhall.org":        "Campbell Hall School",
                "stratfordschools.com":    "Stratford School",
                "pacificprimerica.com":    "Pacific Primérica",
                "ivywise.com":             "IvyWise",
                "crimsoneducation.org":    "Crimson Education",
                "gelighting.com":          "GE Lighting",
                "sportacademy.com":        "Sports Academy",
                "pepperdine.edu":          "Pepperdine University",
                "usc.edu":                 "University of Southern California",
                "ucla.edu":                "University of California Los Angeles",
                "lacma.org":               "Los Angeles County Museum of Art",
                "getty.edu":               "The Getty",
                "latennistraining.com":    "LA Tennis Training",
                "laequestrian.com":        "LA Equestrian Center",
                "soulmechanic.com":        "Soul Mechanic Fitness",
                "corepower.com":           "CorePower Yoga",
                "equinox.com":             "Equinox",
                "soulcycle.com":           "SoulCycle",
            }
            domain = url.split("/")[2].replace("www.", "")
            known = next((v for k, v in KNOWN_NAMES_LA.items() if k in domain), None)

            def clean_name(candidate: str) -> str:
                parts = re.split(r'\s*[|—]\s*', candidate)
                parts = [p.strip() for p in parts if p.strip()]
                GENERIC = {"home","welcome","index","main","page","site","portal","homepage","about",""}
                n = parts[0] if parts else candidate.strip()
                if n.lower() in GENERIC and len(parts) > 1:
                    n = parts[-1].strip()
                for prefix in ("welcome to ", "visit "):
                    if n.lower().startswith(prefix):
                        n = n[len(prefix):].strip()
                return n

            for candidate in [og_site, og_title, raw_title]:
                name = clean_name(candidate)
                if (name
                        and name.lower() not in REJECT_NAMES
                        and not any(name.lower().startswith(p) for p in REJECT_STARTS)
                        and not any(bad in name.lower() for bad in REJECT_LONG_PHRASES)
                        and len(name.split()) <= 8):
                    results["Name"] = name
                    break
            if known and (not results["Name"] or results["Name"].lower() in REJECT_NAMES):
                results["Name"] = known
            if not results["Name"]:
                results["Name"] = known or clean_name(raw_title)
            body_text       = await page.inner_text("body")

            # JS-heavy sites: scroll to trigger rendering
            if len(body_text.strip()) < 300:
                print("  ⚠ Page body too short — scrolling to trigger JS render…")
                try:
                    await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
                    await asyncio.sleep(3)
                    await page.evaluate("window.scrollTo(0, 0)")
                    await asyncio.sleep(2)
                    body_text = await page.inner_text("body")
                    print(f"  Body after scroll: {len(body_text)} chars")
                except Exception:
                    try:
                        body_text = await page.inner_text("body")
                    except Exception:
                        pass

            results["City"] = detect_city(url, body_text)

            # Skip garbage/parked/domain-sale sites immediately
            if is_garbage_site(results["Name"], body_text):
                print(f"  ✗ Garbage/parked site detected — skipping {url}")
                await browser.close()
                return None

            def extract(pattern):
                m = re.search(pattern, body_text, re.IGNORECASE)
                return m.group(1).strip() if m else ""

            current_year = datetime.now().year

            # ── BUG FIX B: Founded — penalise pre-1900 years and sentences
            #   that are clearly about a UK/parent school, not this campus
            def extract_founded_from_text(text, existing_candidates=None):
                STRONG_KWS = [
                    "founded in", "established in", "was founded", "founding year",
                    "founded by", "foundress", "charter", "incorporated in",
                    "opened in", "opened its doors", "since", "est.",
                ]
                WEAK_KWS  = ["founded", "established", "foundation", "history", "began"]
                SKIP_WORDS = ["copyright", "©", "reserved", "updated", "revised",
                              "class of", "alumni", "graduate", "batch of"]
                # Sentences that refer to a PARENT / FOREIGN campus — not this school
                FOREIGN_CTX = [
                    "in the uk", "in england", "in derbyshire", "in scotland",
                    "in wales", "in ireland", "parent school", "sister school",
                    "original school", "home school",
                    "repton school in", "repton uk",
                    "in derbyshire, uk", "in london, uk",
                ]
                cands = existing_candidates if existing_candidates is not None else []
                clean = re.sub(r'\s+', ' ', text.lower())
                clean = re.sub(r'(copyright|©).*?\d{4}', '', clean)
                for sent in re.split(r'[.!?\n]', clean):
                    if any(w in sent for w in SKIP_WORDS):
                        continue
                    has_strong = any(k in sent for k in STRONG_KWS)
                    has_weak   = any(k in sent for k in WEAK_KWS)
                    if not (has_strong or has_weak):
                        continue
                    is_foreign = any(ctx in sent for ctx in FOREIGN_CTX)
                    for y in re.findall(r'\b(1[6-9]\d{2}|20[012]\d)\b', sent):
                        year = int(y)
                        if not (1600 <= year <= current_year - 1):
                            continue
                        score = 3 if has_strong else 1
                        # Pre-1900: almost certainly a UK/historic parent school
                        if year < 1900:
                            score -= 4
                        # Sentence explicitly about a foreign/parent school
                        if is_foreign:
                            score -= 3
                        # Too recent — probably not a founding year
                        if year >= current_year - 2:
                            score -= 3
                        cands.append((score, year))
                return cands

            founded_candidates = extract_founded_from_text(body_text)
            if founded_candidates:
                founded_candidates.sort(key=lambda x: (-x[0], x[1]))
                results["Founded"] = str(founded_candidates[0][1])

            # Collect ALL valid age ranges from page, pick the WIDEST (most complete)
            age_candidates = []
            for pat in age_patterns:
                for m in re.finditer(pat, body_text, re.I):
                    try:
                        g = m.groups()
                        if len(g) >= 2 and g[0] and g[1]:
                            lo, hi = int(g[0]), int(g[1])
                            if lo < hi and lo >= 2 and hi <= 25:
                                age_candidates.append((lo, hi))
                        elif len(g) == 1 and g[0]:
                            hi = int(g[0])
                            if 10 <= hi <= 25:
                                age_candidates.append((3, hi))
                    except Exception:
                        pass
            if age_candidates:
                # Pick the widest range (highest hi - lo) — gives full school span
                best = max(age_candidates, key=lambda x: x[1] - x[0])
                results["Ages"] = f"{best[0]}\u2013{best[1]}"

            if not results["Ages"]:
                AGE_MAP = {
                    "preschool": (3, 5), "pre-school": (3, 5),
                    "pre-k": (4, 5), "pre k": (4, 5),
                    "tk": (4, 5), "transitional kindergarten": (4, 5),
                    "kindergarten": (5, 6), "kinder": (5, 6),
                    "grade 1": (6, 7), "grade 2": (7, 8), "grade 3": (8, 9),
                    "grade 4": (9, 10), "grade 5": (10, 11), "grade 6": (11, 12),
                    "grade 7": (12, 13), "grade 8": (13, 14), "grade 9": (14, 15),
                    "grade 10": (15, 16), "grade 11": (16, 17), "grade 12": (17, 18),
                    "1st grade": (6, 7), "6th grade": (11, 12), "9th grade": (14, 15),
                    "12th grade": (17, 18),
                    "elementary": (5, 11), "middle school": (11, 14),
                    "high school": (14, 18), "upper school": (14, 18),
                    "lower school": (5, 11), "middle division": (11, 14),
                    "ap courses": (15, 18), "sat": (15, 18),
                }
                tl  = body_text.lower()
                fy  = [v for k, v in AGE_MAP.items() if k in tl]
                results["Ages"] = f"{min(x[0] for x in fy)}\u2013{max(x[1] for x in fy)}" if fy else ""

            for pat in student_patterns:
                for m in re.finditer(pat, body_text, re.I):
                    num_str = re.sub(r'[\s,]', '', m.group(1))
                    try:
                        num = int(num_str)
                        if not (50 <= num <= 10000):
                            continue
                        ctx = body_text[max(0, m.start()-8):m.end()+8]
                        if '%' in ctx or '.' in m.group(1):
                            continue
                        results["Students"] = num_str + ("+" if "+" in m.group(0) else "")
                        break
                    except ValueError:
                        pass
                if results["Students"]:
                    break

            for pat in ratio_patterns:
                m = re.search(pat, body_text, re.I)
                if m:
                    results["Ratio"] = m.group(1).replace(" ", "")
                    break

            for pat in fee_patterns:
                m = re.search(pat, body_text, re.I)
                if m:
                    results["Fees"] = m.group(0).strip()
                    break

            # Type detection — LA/US school system, URL hardcodes first
            tl = body_text.lower()
            url_l = url.lower()
            # URL-based hardcodes for known LA institutions
            if "royalacademyofarts" in url_l or "hammer.ucla.edu" in url_l or "lacma.org" in url_l or "getty.edu" in url_l:
                results["Type"] = "Arts & Cultural Institution"
            elif "chadwickschool.org" in url_l or "marlborough" in url_l:
                results["Type"] = "Independent Day School"
            elif "thinkglobalschool" in url_l or "crimson" in url_l or "ivywise" in url_l:
                results["Type"] = "Education Consultancy"
            elif "equestrian" in tl or "polo" in tl or "horse" in tl and "riding" in tl:
                results["Type"] = "Equestrian & Sports Club"
            # General detection
            elif "all-girls" in tl or "girls' school" in tl or "girls school" in tl:
                results["Type"] = "Independent All-Girls School"
            elif "all-boys" in tl or "boys' school" in tl or "boys school" in tl:
                results["Type"] = "Independent Boys' School"
            elif "ib world" in tl or "international baccalaureate" in tl:
                results["Type"] = "IB World Day School"
            elif "boarding" in tl and "day" in tl:
                results["Type"] = "Independent Boarding & Day School"
            elif "boarding" in tl:
                results["Type"] = "Independent Boarding School"
            elif "day school" in tl or "day students" in tl:
                results["Type"] = "Independent Day School"
            elif "elementary" in tl and "high school" in tl:
                results["Type"] = "Independent K-12 School"
            elif "elementary" in tl or "lower school" in tl:
                results["Type"] = "Independent Elementary School"
            elif "high school" in tl or "upper school" in tl:
                results["Type"] = "Independent High School"
            elif "middle school" in tl:
                results["Type"] = "Independent Middle School"
            elif "preschool" in tl or "pre-school" in tl or "early childhood" in tl:
                results["Type"] = "Preschool & Early Learning"
            elif "ballet" in tl or "dance academy" in tl:
                results["Type"] = "Ballet & Dance Academy"
            elif "performing arts" in tl or "conservatory" in tl or "conservatoire" in tl:
                results["Type"] = "Performing Arts Academy"
            elif "tennis" in tl and ("academy" in tl or "club" in tl):
                results["Type"] = "Tennis Academy"
            elif "yoga" in tl or "wellness" in tl or "spa" in tl:
                results["Type"] = "Wellness & Lifestyle Centre"
            elif "tutor" in tl and ("company" in tl or "service" in tl or "agency" in tl):
                results["Type"] = "Tutoring & Education Consultancy"
            elif "university" in tl or "college" in tl and "community" not in tl:
                results["Type"] = "University / Higher Education"
            elif "academy" in tl:
                results["Type"] = "Academy"
            else:
                results["Type"] = "Independent School"

            soup_home = BeautifulSoup(await page.content(), "html.parser")
            for attr in [{"name": "description"}, {"property": "og:description"}]:
                tag = soup_home.find("meta", attr)
                if tag and tag.get("content"):
                    results["Tagline"] = tag["content"][:200]
                    break
            if not results["Tagline"]:
                results["Tagline"] = extract(r"([A-Z][^.]{30,150}\.)")

            results["Quote"] = scrape_quote_from_soup(soup_home)

            # Images — use module-level harvest_images (scrolls + collects all sources)
            image_set = set()
            await harvest_images(page, url, image_set)
            results["Images"] = [img for img in image_set if img][:10]

        except Exception as e:
            print(f"Home page error: {e}")
            await browser.close()
            return None

        # ── SUBPAGE CRAWL 
        soup  = BeautifulSoup(await page.content(), "html.parser")
        links = soup.find_all("a", href=True)
        queue     = []
        seen_urls = {url.rstrip("/")}

        targets = {
            "about": [
                "about", "history", "welcome", "mission", "who-we-are",
                "our-story", "overview", "vision", "values", "ethos",
            ],
            "outcomes": [
                "results", "destination", "university", "leavers", "beyond",
                "sixth-form", "exam", "college", "achievements", "khda",
                "inspection", "academic-results",
            ],
            "fees": [
                "fees", "tuition", "financial", "cost", "charges",
                "fee-structure", "school-fees", "annual-fees", "pricing",
            ],
            "admission": [
                "admissions", "apply", "entry", "register", "enroll",
                "13-entry", "16-entry", "how-to-apply", "application",
                "join-us", "registration", "enrolment", "open-day",
            ],
            "facilities": [
                "facilities", "campus", "co-curriculum", "sport", "arts",
                "library", "infrastructure", "resources", "activities",
                "co-curricular", "extracurricular",
            ],
        }

        for link in links:
            href, text = link["href"], link.get_text().lower().strip()
            full_url   = urljoin(url, href).split("#")[0].rstrip("/")
            if full_url not in seen_urls and url.split("/")[2] in full_url:
                if any(k in text or k in href.lower() for cat in targets.values() for k in cat):
                    queue.append((full_url, text))
                    seen_urls.add(full_url)

        # Global sentence-level dedup — no sentence may appear in more than one field
        used_sentences: set = set()

        def _register(text: str):
            """Mark all sentences in text as used."""
            if not text:
                return
            for s in re.split(r'(?<=[.!?])\s+', text.strip()):
                key = re.sub(r'\s+', ' ', s.strip().lower())
                if key and len(key) > 20:   # only register meaningful sentences
                    used_sentences.add(key)

        def dedup_text(text: str) -> str:
            """Return only sentences not yet seen, and register new ones."""
            if not text:
                return text
            parts = re.split(r'(?<=[.!?])\s+', text.strip())
            fresh = []
            for s in parts:
                key = re.sub(r'\s+', ' ', s.strip().lower())
                if key and key not in used_sentences and not is_junk(s):
                    fresh.append(s.strip())
                    used_sentences.add(key)
            return " ".join(fresh)

        def assign_field(field_name: str, text: str, max_sent: int = 2):
            """Assign to results[field_name] only if empty, after deduping."""
            if results.get(field_name):
                return
            cleaned = dedup_text(clean_to_sentences(text, max_sent))
            if cleaned:
                results[field_name] = cleaned

        # Register ALL homepage content so subpages can't repeat any of it
        for _field in ["About", "Tagline", "Philosophy", "Outcomes", "Admissions", "Quote"]:
            _register(results.get(_field, ""))
        for _perf_val in results.get("Performance", {}).values():
            _register(_perf_val)

        # used_paras_global — prevents same raw paragraph appearing in multiple metrics
        used_paras_global: set = set()
        # Pre-register any performance values already scraped from homepage
        for _pv in results.get("Performance", {}).values():
            if _pv:
                used_paras_global.add(re.sub(r'\s+', ' ', _pv.strip().lower())[:200])

        for target_url, link_text in queue[:15]:
            try:
                await page.goto(target_url, wait_until="domcontentloaded", timeout=30000)
                await asyncio.sleep(2)
                main          = page.locator("main").first
                content_scope = main if await main.is_visible() else page
                paragraphs    = await content_scope.locator("p").all_text_contents()
                clean_paras   = [
                    t.strip() for t in paragraphs
                    if len(t.strip()) >= 80
                    and not any(x in t.lower() for x in ["cookie", "privacy", "menu", "navigation", "footer"])
                    and not is_junk(t)   # ← remove error messages, UI strings, boilerplate
                ]
                global_text_pool.extend(clean_paras)
                full_text = " ".join(clean_paras)
                page_text = await page.inner_text("body")
                sub_soup  = BeautifulSoup(await page.content(), "html.parser")

                # Harvest images from every subpage
                await harvest_images(page, url, image_set)
                results["Images"] = [img for img in image_set if img][:10]

                if any(k in link_text or k in target_url for k in targets["about"]):
                    # Filter out paragraphs that start with form/navigation content
                    clean_about = [p for p in clean_paras if not is_junk(p)
                                   and not p.lower().startswith(("please fill", "please note",
                                   "the admissions team", "fill the", "click here", "select"))]
                    assign_field("About", " ".join(clean_about), 2)
                    teach_kws  = ["curriculum", "teaching", "learning", "approach",
                                  "education", "ethos", "method", "ib", "igcse", "philosophy"]
                    teach_para = [p for p in clean_paras if any(k in p.lower() for k in teach_kws)]
                    assign_field("Philosophy", " ".join(teach_para), 2)
                    if not results["Quote"]:
                        results["Quote"] = scrape_quote_from_soup(sub_soup)
                    if not results["Founded"]:
                        sub_cands = extract_founded_from_text(page_text)
                        if sub_cands:
                            sub_cands.sort(key=lambda x: (-x[0], x[1]))
                            results["Founded"] = str(sub_cands[0][1])
                    if not results["City"]:
                        results["City"] = detect_city(url, page_text)

                # ── Students + Ratio: search EVERY subpage
                if not results["Students"]:
                    for pat in student_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            num_str = m.group(1).replace(",", "")
                            try:
                                num = int(num_str)
                                # Sanity: school enrollment between 50 and 10,000
                                if 50 <= num <= 10000:
                                    results["Students"] = num_str + ("+" if "+" in m.group(0) else "")
                                    break
                            except ValueError:
                                pass
                if not results["Ratio"]:
                    for pat in ratio_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            results["Ratio"] = m.group(1).replace(" ", "")
                            break

                if any(k in link_text or k in target_url for k in targets["outcomes"]):
                    assign_field("Outcomes", full_text, 2)
                    if not results["Quote"]:
                        results["Quote"] = scrape_quote_from_soup(sub_soup)

                if any(k in link_text or k in target_url for k in targets["fees"]):
                    for pat in fee_patterns:
                        m = re.search(pat, page_text, re.I)
                        if m:
                            results["Fees"] = m.group(0).strip()
                            break
                    aed_fee = re.search(
                        r'(?:AED|Dhs?)\s*([\d,]+)(?:\.\d{2})?\s*(?:per\s*(?:term|year|annum))?',
                        page_text, re.I
                    )
                    if aed_fee and not results["Fees"]:
                        results["Fees"] = f"AED {aed_fee.group(1)}"
                    term_fee = re.search(r'[£\u00a3]([\d,]+)(?:\.\d{2})?\s*per\s*term', page_text, re.I)
                    if term_fee and not results["Fees"]:
                        results["Fees"] = f"£{term_fee.group(1)} per term"

                if any(k in link_text or k in target_url for k in targets["admission"]):
                    adm_kws  = ["apply", "application", "admission", "register",
                                "assessment", "entry", "enroll", "enrolment", "registration"]
                    filtered = [p for p in clean_paras if any(k in p.lower() for k in adm_kws)]
                    assign_field("Admissions", " ".join(filtered), 2)
                    dl = re.search(
                        r'(?:deadline|closes?|closing date)\s*[:\-]?\s*([^\n.]{10,60})',
                        page_text, re.I
                    )
                    if dl and results["AppDeadline"].startswith("Rolling"):
                        val = dl.group(1).strip()[:80]
                        has_month = re.search(
                            r'\b(january|february|march|april|may|june|july|august|'
                            r'september|october|november|december|jan|feb|mar|apr|'
                            r'jun|jul|aug|sep|oct|nov|dec)\b', val, re.I)
                        has_date = re.search(r'\b\d{1,2}[\/\-]\d{1,2}', val)
                        if (has_month or has_date) and not is_junk(val):
                            results["AppDeadline"] = val
                    if not results["Ages"]:
                        for pat in age_patterns:
                            m = re.search(pat, page_text, re.I)
                            if m:
                                try:
                                    g = m.groups()
                                    if len(g) >= 2 and g[0] and g[1]:
                                        lo, hi = int(g[0]), int(g[1])
                                        if lo < hi and lo >= 2 and hi <= 25:
                                            results["Ages"] = f"{lo}\u2013{hi}"
                                except Exception:
                                    pass
                                if results["Ages"]:
                                    break

                if any(k in link_text or k in target_url for k in targets["facilities"]):
                    perf_kws = {
                        "Coaching Credentials":   ["qualified teacher", "experienced staff",
                                                   "certified", "credentials", "housemaster",
                                                   "instructor", "faculty", "expertise"],
                        "Student Wellbeing":      ["wellbeing", "pastoral", "counselor",
                                                   "mental health", "welfare", "house system",
                                                   "nurturing", "support programme"],
                        "Academic Integration":   ["curriculum", "igcse", "a-level", "ib",
                                                   "programme of study", "academic programme",
                                                   "learning outcomes", "subject"],
                        "Competitive Pathway":    ["university", "destination", "oxford",
                                                   "cambridge", "russell group", "results",
                                                   "examination", "achievement", "ranking"],
                        "Facilities & Resources": ["facilities", "campus", "library",
                                                   "laboratory", "studio", "theatre",
                                                   "swimming pool", "gymnasium", "court"],
                        "Ongoing Accountability": ["progress", "tracking", "monitoring",
                                                   "feedback", "report", "review",
                                                   "assessment cycle", "parent portal"],
                    }
                    for key, kws in perf_kws.items():
                        if not results["Performance"].get(key):
                            matched = [
                                p for p in clean_paras
                                if any(k in p.lower() for k in kws)
                                and p not in used_paras_global   # global dedup
                                and not is_junk(p)
                            ]
                            if matched:
                                chosen = matched[:1]
                                val = dedup_text(clean_to_sentences(" ".join(chosen), 2))
                                if val:
                                    results["Performance"][key] = val
                                    used_paras_global.update(chosen)
                    if not results["Quote"]:
                        results["Quote"] = scrape_quote_from_soup(sub_soup)

            except Exception as e:
                print(f"  Skipping {target_url}: {e}")
                continue

        # ── APPLY FALLBACKS 
        results["Images"] = list(image_set)[:10]  # refresh after subpage harvesting
        for field, fallback in FALLBACKS.items():
            if not results.get(field):
                results[field] = fallback

        if not results["City"]:
            results["City"] = "Los Angeles, CA"

        # ── FALLBACK PERFORMANCE
        for metric in [
            "Coaching Credentials", "Student Wellbeing", "Academic Integration",
            "Competitive Pathway", "Facilities & Resources", "Ongoing Accountability",
        ]:
            if not results["Performance"].get(metric):
                results["Performance"][metric] = generate_fallback(metric, global_text_pool)

        # ── QUOTE: AI fallback
        if not results["Quote"]:
            print(f"  No quote found on site — generating AI quote…")
            results["Quote"] = generate_ai_quote(
                results["Name"], results["Type"], results["City"], results["About"]
            )

        await browser.close()

        # ── FIX #3: OpenAI gap-fill — runs after scraping, fills only missing/N/A fields
        print(f"\n  Running OpenAI gap-fill for missing fields…")
        results = openai_fill_missing_fields(results)

        # ── POST-FILL DEDUP: ensure AI-filled performance fields don't repeat each other
        seen_perf = set()
        for metric in ["Coaching Credentials","Student Wellbeing","Academic Integration",
                       "Competitive Pathway","Facilities & Resources","Ongoing Accountability"]:
            val = results["Performance"].get(metric, "")
            if not val or val == "N/A":
                continue
            key = re.sub(r'\s+', ' ', val.strip().lower())[:120]
            if key in seen_perf:
                results["Performance"][metric] = ""  # will be re-filled by AI next run
            else:
                seen_perf.add(key)

        # ── POST-PROCESSING SANITIZATION
        PERF_METRICS = ["Coaching Credentials","Student Wellbeing","Academic Integration",
                        "Competitive Pathway","Facilities & Resources","Ongoing Accountability"]
        for field in ["Name","Tagline","Founded","City","Ages","Students","Ratio",
                      "Fees","Type","About","Philosophy","Outcomes","Admissions","Quote"]:
            if results.get(field):
                results[field] = re.sub(r'\s+', ' ', str(results[field])).strip()
        for field in ["About","Philosophy","Outcomes","Admissions"]:
            if results.get(field) and len(results[field].split()) > 50:
                results[field] = clean_to_sentences(results[field], 2)
        for metric in PERF_METRICS:
            val = results["Performance"].get(metric,"")
            if val and len(val.split()) > 50:
                results["Performance"][metric] = clean_to_sentences(val, 2)

        # ── PRINT SUMMARY 
        SEP        = "—" * 50
        city_short = results["City"].split(",")[0]
        print(f"\n{SEP}")
        print(f"Elite › {city_short} › {results['Name']}")
        print(SEP)
        print(
            f"\n{results['Ages'] or 'N/A':<14}{results['Students'] or 'N/A':<14}"
            f"{results['Ratio'] or 'N/A':<14}{results['Founded'] or 'N/A'}"
        )
        print(f"{'Ages':<14}{'Students':<14}{'Ratio':<14}Founded\n")
        print(f"Images Found: {len(results['Images'])}")
        for i, img in enumerate(results["Images"], 1):
            print(f"  {i}. {img}")
        print(f"\nAbout {results['Name']}\n{results['About']}")
        print(f"\nInstitution Details")
        print(f"  Type       : {results['Type']}")
        print(f"  Ages       : {results['Ages'] or 'N/A'}")
        print(f"  Students   : {results['Students'] or 'N/A'}")
        print(f"  Ratio      : {results['Ratio'] or 'N/A'}")
        print(f"  Founded    : {results['Founded'] or 'N/A'}")
        print(f"  City       : {results['City']}")
        print(f"  Annual Fee : {results['Fees']}")
        print(f"\nQuotes\n  \"{results['Quote']}\"")
        print(f"\nHow they teach\n{results['Philosophy']}")
        print(f"\nOutcomes: Where students go\n{results['Outcomes']}")
        print(f"\nAdmissions & How to Apply")
        print(f"  Enquiries Open : {results['EnquiryOpen']}")
        print(f"  App Deadline   : {results['AppDeadline']}")
        print(f"  Process        : {results['Admissions']}")
        print(f"\nHow {results['Name']} Performs")
        for k, v in results["Performance"].items():
            print(f"\n  {k}:\n  {v or 'N/A'}")
        print(f"\n  Location : {results['City']}")
        print(f"  Website  : {results['URL']}")
        print(SEP)

        # ── SAVE 
        wp_code     = generate_wp_blocks(results)
        school_slug = re.sub(r"[^a-z0-9]+", "_", results["Name"].lower())[:35].strip("_")
        out_wp      = f"{school_slug}_wp_blocks.txt"
        out_json    = f"{school_slug}_data.json"

        with open(out_wp, "w", encoding="utf-8") as f:
            f.write(wp_code)

        save_data = {k: v for k, v in results.items() if k != "Images"}
        save_data["ImageCount"] = len(results.get("Images", []))
        save_data["ImageURLs"]  = results.get("Images", [])
        with open(out_json, "w", encoding="utf-8") as f:
            json.dump(save_data, f, ensure_ascii=False, indent=2)

        print(f"\n WP blocks  → {out_wp}")
        print(f"School JSON → {out_json}")
        return results


# ── URLS

school_urls = [
    # Elite independent schools
    "https://www.harvardswestlake.org/",
    "https://www.crossroadsschool.org/",
    "https://www.marlboroughschool.org/",
    "https://www.brentwood.org/",
    "https://www.viewpoint.org/",
    "https://www.polytechnic.org/",
    "https://www.westridgeschool.org/",
    "https://www.chadwickschool.org/",
    "https://www.campbellhall.org/",
    "https://milkenschool.org/",
    # Tutoring & consultancies
    "https://www.ivywise.com/",
    "https://www.crimsoneducation.org/us-en/",
    # Sports & wellness
    "https://www.laequestrian.com/",
    "https://www.equinox.com/los-angeles",
    "https://www.soulcycle.com/",
    # Arts & culture
    "https://www.lacma.org/",
    "https://www.getty.edu/visit/",
    # Performing arts
    "https://www.laopera.org/",
    "https://www.losangelesdance.com/",
]

async def run_multiple_schools():
    all_results = []
    for url in school_urls:
        print(f"\n{'=' * 60}")
        print(f" Scraping: {url}")
        print(f"{'=' * 60}")
        try:
            result = await extract_school_data(url)
            if result:
                all_results.append(result)
            await asyncio.sleep(3)
        except Exception as e:
            print(f" Failed: {url} → {e}")

    master_file = "all_schools_data_losangeles.json"
    with open(master_file, "w", encoding="utf-8") as f:
        json.dump(all_results, f, ensure_ascii=False, indent=2)
    print(f"\n{'=' * 60}")
    print(f"All done! {len(all_results)} institutions scraped.")
    print(f"Master JSON → {master_file}")
    print(f"{'=' * 60}")
    return all_results


if __name__ == "__main__":
    if sys.platform == "win32":
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    try:
        loop = asyncio.get_running_loop()
        import nest_asyncio
        nest_asyncio.apply()
        import concurrent.futures
        with concurrent.futures.ThreadPoolExecutor() as pool:
            future   = pool.submit(asyncio.run, run_multiple_schools())
            all_data = future.result()
    except RuntimeError:
        asyncio.run(run_multiple_schools())
# Out:
# ============================================================
#  Scraping: https://www.harvardswestlake.org/
# ============================================================
# Connecting to: https://www.harvardswestlake.org/...
#   ⚠ networkidle failed (Error), retrying…
#   ✗ Failed: Page.goto: net::ERR_NAME_NOT_RESOLVED at https://www.harvardswestlake.org/
# Call log:
#   - navigating to "https://www.harvardswestlake.org/", waiting until "domcontentloaded"
#
#   ✗ Could not load https://www.harvardswestlake.org/, skipping.
#
# ============================================================
#  Scraping: https://www.crossroadsschool.org/
# ============================================================
# Connecting to: https://www.crossroadsschool.org/...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Crossroads Christian School
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 1 missing field(s): Ratio
#   ✓ OpenAI filled: Ratio
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › Crossroads Christian School
# ——————————————————————————————————————————————————
#
# 3–12          265           1:10          1978
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.crossroadsschool.org/wp-content/uploads/2019/05/app1.png
#   2. https://www.crossroadsschool.org/wp-content/uploads/2024/01/class.jpg
#   3. https://www.crossroadsschool.org/wp-content/uploads/2024/01/desk.jpg
#   4. https://www.crossroadsschool.org/wp-content/uploads/2024/01/project.jpg
#   5. https://www.crossroadsschool.org/wp-content/uploads/2024/01/middleschool.jpg
#   6. https://www.crossroadsschool.org/wp-content/uploads/2019/04/header-academics.jpg
#   7. https://www.crossroadsschool.org/wp-content/uploads/2019/04/feature3.png
#   8. https://www.crossroadsschool.org/wp-content/uploads/2020/02/school-tour.png
#   9. https://www.crossroadsschool.org/wp-content/uploads/2020/02/early-bird.png
#   10. https://www.crossroadsschool.org/wp-content/uploads/2021/12/ADRIANNA.RICHARDSON-2.jpg
#
# About Crossroads Christian School
# We'd love to answer your questions and provide you with more specific information as you experience Crossroads Christian School firsthand on a 1-hour tour. Touring our campus is recommended, but not required prior to submitting an application.
#
# Institution Details
#   Type       : Independent K-12 School
#   Ages       : 3–12
#   Students   : 265
#   Ratio      : 1:10
#   Founded    : 1978
#   City       : Los Angeles, CA
#   Annual Fee : $35
#
# Quotes
#   "Empowering minds and nurturing hearts to shine Christ's light through knowledge, character, and faith-driven service."
#
# How they teach
# BIBLICAL WORLDVIEW Our teaching is based on Christian principles, instead of a humanistic educational philosophy ATHLETICS We offer a variety of spots for learners to be involved in. Our athletic program provides learners with a wide variety of opportunities and experiences to assist the learners’ development of responsible habits, positive attitudes, and Christ-like character.
#
# Outcomes: Where students go
# We believe education, spiritual, and character development begins in the home and that partnership is vital to a successful educational experience. Healthy, constructive communication between the home and the school is key to partnership.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : We're thrilled to have you join us for another year! Click below to begin the re-enrollment process.
#
# How Crossroads Christian School Performs
#
#   Facilities & Resources:
#   In addition to complying with COVID-19 guidelines, we've upgraded our facilities for health and safety.
#
#   Coaching Credentials:
#   We'd love to answer your questions and provide you with more specific information as you experience Crossroads Christian School firsthand on a 1-hour tour. Touring our campus is recommended, but not required prior to submitting an application.
#
#   Student Wellbeing:
#   N/A
#
#   Academic Integration:
#   BIBLICAL WORLDVIEW Our teaching is based on Christian principles, instead of a humanistic educational philosophy ATHLETICS We offer a variety of spots for learners to be involved in. Our athletic program provides learners with a wide variety of opportunities and experiences to assist the learners’ development of responsible habits, positive attitudes, and Christ-like character.
#
#   Competitive Pathway:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Los Angeles, CA
#   Website  : https://www.crossroadsschool.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → crossroads_christian_school_wp_blocks.txt
# School JSON → crossroads_christian_school_data.json
#
# ============================================================
#  Scraping: https://www.marlboroughschool.org/
# ============================================================
# Connecting to: https://www.marlboroughschool.org/...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 2 missing field(s): Ratio, Outcomes
#   ✓ OpenAI filled: Ratio, Outcomes
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › Los Angeles Girls Private Middle & High School
# ——————————————————————————————————————————————————
#
# 7–12          530           1:8           2024
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_3/v1740601222/marlborough/sjfy0mwbgjzsbfxvgi8w/062__LK23729.jpg
#   2. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_3/v1726522087/marlborough/vtjpn41enxjbvq2b6q2w/Tradition_Ring.jpg
#   3. https://www.juicer.io/api/posts/507414086/poster_images.jpg?external_id=DXcz7mOEoR6&s=003413ea1dfc25596c48ade3f52f1ffc0ccce793
#   4. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_3/v1728508688/marlborough/iymgyc3vjwoydliqkdzq/Admissions_Welcome_Academics.jpg
#   5. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_6/v1726164616/marlborough/k8byas9gd4ubxm8rl4th/DEI_Leadership.jpg
#   6. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_2/v1662490526/marlborough/wke83iylzzynfjjmi0r8/christine_web2.jpg
#   7. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_5/v1728362046/marlborough/rdghiwmynkf0poejhjdw/careersatmarlborough.jpg
#   8. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_2/v1728509915/marlborough/nzgbjwire2gqpuh5vbgb/Admissions_Welcome_TuitionandFA.jpg
#   9. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_6/v1745302300/marlborough/vncqfjurrdryfebegrrh/2025BusMap6.png
#   10. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_2/v1679687294/marlborough/o6abghkrfvkwdfmbxtny/Deepe.jpg
#
# About Los Angeles Girls Private Middle & High School
# We don’t just meet the current moment, we endeavor to anticipate the next one."Jennifer Ciccarelli, Head of School As Marlborough’s ninth Head of School, Jennifer Ciccarelli leads with clarity, purpose, and an unwavering belief in the power of girls’ education. She is committed to creating the conditions in which Learning Sparks Purpose—and where every student feels seen, heard, and empowered to lead.
#
# Institution Details
#   Type       : Independent Day School
#   Ages       : 7–12
#   Students   : 530
#   Ratio      : 1:8
#   Founded    : 2024
#   City       : Los Angeles, CA
#   Annual Fee : Fee $3,300
#
# Quotes
#   "Students engage in vibrant, collaborative learning environments that foster critical thinking and lively discussions."
#
# How they teach
# As Marlborough’s ninth Head of School, Jennifer Ciccarelli leads with clarity, purpose, and an unwavering belief in the power of girls’ education.
#
# Outcomes: Where students go
# Marlborough School empowers girls to excel academically and develop leadership skills. Graduates are well-prepared for top universities and meaningful careers.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : From Social Justice Capstone Projects to Mustang Athletics, Chamber Choir to Robotics and Fabrication, Debate to Post-Apocalyptic Literature—these aren’t just programs, they’re the settings where you’ll write your most meaningful chapters. Inquire today and we’ll invite you and your family to experience Marlborough throughout this year’s admissions season—at our Open House, Parent Coffees, Parent and Guardian Education Series, Student/Faculty/Alumnae Panels, and more.
#
# How Los Angeles Girls Private Middle & High School Performs
#
#   Academic Integration:
#   With multiple stops across Los Angeles and surrounding areas, our transportation program connects students to campus while building community along the way. Whether your family lives five or 25 miles from Marlborough, we’re committed to making the journey accessible.
#
#   Facilities & Resources:
#   Marlborough students come from every corner of Los Angeles—from Pasadena to Palos Verdes, from the Westside to the Eastside. We believe that distance should never stand in the way of an extraordinary education.
#
#   Ongoing Accountability:
#   Our routes are thoughtfully planned and regularly reviewed to ensure safe, timely, and efficient service for students and families.
#
#   Coaching Credentials:
#   Building on the best of Marlborough, our faculty and staff inspire LA’s exemplary students to discover who they are, to engage deeply in their studies, to embrace their communities, and to lead lives of purpose. Guided by our legacy as a leader in girls’ education, we boldly seek to redefine excellence in education.
#
#   Student Wellbeing:
#   In addition to a highly competitive compensation package, Marlborough offers an outstanding array of benefits to support our employees’ health and wellbeing. Including: All members of your household can utilize the benefits of this program which includes support, referrals, and resources related to health living, stress management, mental health, diet and fitness, overall wellness, parenting support, child & elder care, learning programs, special needs assistance, legal issues, will preparation, taxes, financial planning and more.
#
#   Competitive Pathway:
#   Margaret’s School for Girls flourishes in Pasadena, but Mrs. Caswell recognizes Los Angeles as a burgeoning city and in 1890 moves the school to a new location—the relatively new but empty Marlborough Hotel at the corner of 23rd and Scarff Streets, near the newly established University of Southern California.
#
#   Location : Los Angeles, CA
#   Website  : https://www.marlboroughschool.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → los_angeles_girls_private_middle_hi_wp_blocks.txt
# School JSON → los_angeles_girls_private_middle_hi_data.json
#
# ============================================================
#  Scraping: https://www.brentwood.org/
# ============================================================
# Connecting to: https://www.brentwood.org/...
# Home page error: Page.inner_text: Timeout 30000ms exceeded.
# Call log:
#   - waiting for locator("body")
#
#
# ============================================================
#  Scraping: https://www.viewpoint.org/
# ============================================================
# Connecting to: https://www.viewpoint.org/...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Viewpoint School
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 5 missing field(s): Founded, Students, Ratio, Outcomes, Admissions
#   ✓ OpenAI filled: Founded, Students, Ratio, Outcomes, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Calabasas › Viewpoint School
# ——————————————————————————————————————————————————
#
# 4–18          1200          1:8           1961
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.viewpoint.org/uploaded/faculty/aj2.jpg
#   2. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_5/v1701388701/viewpointorg/vp8bvf0eb1qib9dpo0so/IMG_7478.jpg
#   3. https://i.ytimg.com/vi/lv1D2wIpsLA/maxresdefault.jpg
#   4. https://www.viewpoint.org/uploaded/faculty/5148-1027_ADJ_(edit)2.jpg
#   5. https://www.viewpoint.org/uploaded/faculty/mp12jpg.jpg
#   6. https://i.ytimg.com/vi/TRxIwbPCIMw/maxresdefault.jpg
#   7. https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_5/v1701883044/viewpointorg/p75y6la1koaidomzlbqx/IMG_9159_1.jpg
#   8. https://www.viewpoint.org/uploaded/faculty/5148-1133_ADJ_(edit).jpg
#   9. https://www.viewpoint.org/uploaded/faculty/5149-1106_ADJ_(edit)_scaled.jpg
#   10. https://i.ytimg.com/vi/ernRSeEMofo/maxresdefault.jpg
#
# About Viewpoint School
# These words are the centerpiece of our mission, vision, and values and our world ready promise. Building on more than six decades of excellence, we dedicate ourselves to the ideals and drivers of exceptional future readiness.
#
# Institution Details
#   Type       : Independent Elementary School
#   Ages       : 4–18
#   Students   : 1200
#   Ratio      : 1:8
#   Founded    : 1961
#   City       : Calabasas, CA
#   Annual Fee : $6,000,000
#
# Quotes
#   "Empowering young minds to lead with integrity, curiosity, and resilience in a world of endless possibilities."
#
# How they teach
# “The audience’s reaction was incredible,” said Monica Hoenig, Film Teacher at Viewpoint School. “To see our students’ work shown in front of hundreds of people and feel the laughter, clapping, and cheering was pure joy.
#
# Outcomes: Where students go
# Viewpoint School prepares students for future success with a robust academic program and diverse extracurricular activities. Graduates are equipped with critical thinking skills and a global perspective.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective families can apply online and participate in an interview process. Admissions decisions are based on academic performance, personal character, and community involvement.
#
# How Viewpoint School Performs
#
#   Coaching Credentials:
#   We maintain full fire-fighting capabilities, with 15 certified Wildland Firefighters (Certification 1 and 2) and 80 hours of state-certified training per officer.
#
#   Facilities & Resources:
#   At Viewpoint, a premier independent school in the Los Angeles area, we offer more than an exceptional TK–12 education — we give families peace of mind. Our campus is protected by one of the most advanced Safety and Security programs in the independent school world with 24/7, 365-day coverage.
#
#   Student Wellbeing:
#   Throughout the week, Upper School students designed and facilitated workshops on a wide range of topics, including cultural foods, arts and traditions, mental health and identity to athletics, and strategies for productively navigating difficult conversations. Workshops included “Creating Balance,” “The Pandora’s Box of Artificial Intelligence,” and “Challah Braiding and Shabbat.” On Wednesday, February 25, we learned of troubling allegations against a faculty member.
#
#   Academic Integration:
#   These words are the centerpiece of our mission, vision, and values and our world ready promise. Building on more than six decades of excellence, we dedicate ourselves to the ideals and drivers of exceptional future readiness.
#
#   Competitive Pathway:
#   These powerful personal foundations are forged in a tight-knit campus family where each individual student is known, respected, and included. Our promise is that every child experiences a powerful sense of belonging.
#
#   Ongoing Accountability:
#   Known as a national thought leader in the world of enrollment management, Laurel served as a pre-workshop faculty member, along with four of her peers, teaching data storytelling, board reporting, and dashboards. Known as a national thought leader in the world of enrollment management, Laurel served as a pre-workshop faculty member, along with four of her peers, teaching data storytelling, board reporting, and dashboards.
#
#   Location : Calabasas, CA
#   Website  : https://www.viewpoint.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → viewpoint_school_wp_blocks.txt
# School JSON → viewpoint_school_data.json
#
# ============================================================
#  Scraping: https://www.polytechnic.org/
# ============================================================
# Connecting to: https://www.polytechnic.org/...
#   ⚠ networkidle failed (TimeoutError), retrying…
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Home Polytechnic School
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 12 missing field(s): Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ OpenAI filled: Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › Home Polytechnic School
# ——————————————————————————————————————————————————
#
# 5–18          106           N/A           1907
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.polytechnic.org/ftpimages/270/link/large_link5991634_162080.JPG
#   2. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/270/news/large_news1614111_1433461.jpg
#   3. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/270/user/large_user_2053207_113.jpg
#   4. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/270/news/thumb_news1598604_1422260.jpg
#   5. https://www.polytechnic.org/ftpimages/270/link/large_link6762755_168125.jpg
#   6. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/270/news/large_news1621384_1438705.jpeg
#   7. https://bbk12e1-cdn.myschoolcdn.com/270/photo/orig_photo1125494_6884897.jpg
#   8. https://bbk12e1-cdn.myschoolcdn.com/270/photo/orig_photo1094710_6846736.jpg
#   9. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/270/news/large_news1557961_1395177.jpg
#   10. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/270/link/large_link2512031_121379.JPG
#
# About Home Polytechnic School
# Home Polytechnic School fosters a nurturing environment for students aged 5–18, emphasizing academic excellence and personal growth.
#
# Institution Details
#   Type       : Independent Elementary School
#   Ages       : 5–18
#   Students   : 106
#   Ratio      : N/A
#   Founded    : 1907
#   City       : Los Angeles, CA
#   Annual Fee : $40,000 per year
#
# Quotes
#   "Empowering young minds to explore, create, and lead with curiosity and compassion in a dynamic world."
#
# How they teach
# The school believes in holistic education, integrating rigorous academics with character development to prepare students for future challenges.
#
# Outcomes: Where students go
# Graduates are well-rounded individuals equipped with critical thinking skills and a strong sense of community responsibility.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students undergo a comprehensive application process, including interviews and assessments, to ensure a good fit with the school's values.
#
# How Home Polytechnic School Performs
#
#   Coaching Credentials:
#   Faculty members hold advanced degrees and have extensive experience in their respective fields. The school prioritizes continuous professional development to maintain high teaching standards.
#
#   Student Wellbeing:
#   The school offers counseling services and wellness programs to support students' mental and emotional health. A dedicated team ensures a safe and inclusive environment for all students.
#
#   Academic Integration:
#   The curriculum integrates STEM, arts, and humanities to provide a balanced education. Project-based learning encourages practical application of knowledge across disciplines.
#
#   Competitive Pathway:
#   Students regularly achieve high scores in standardized tests and gain admission to prestigious universities. The school offers advanced placement courses to prepare students for college-level work.
#
#   Facilities & Resources:
#   The campus boasts state-of-the-art science labs, a performing arts center, and athletic facilities. A well-stocked library supports research and independent learning.
#
#   Ongoing Accountability:
#   Regular assessments and feedback loops ensure academic standards are met. The school conducts annual reviews to refine teaching methods and curriculum.
#
#   Location : Los Angeles, CA
#   Website  : https://www.polytechnic.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → home_polytechnic_school_wp_blocks.txt
# School JSON → home_polytechnic_school_data.json
#
# ============================================================
#  Scraping: https://www.westridgeschool.org/
# ============================================================
# Connecting to: https://www.westridgeschool.org/...
#   ⚠ networkidle failed (Error), retrying…
#   ✗ Failed: Page.goto: net::ERR_NAME_NOT_RESOLVED at https://www.westridgeschool.org/
# Call log:
#   - navigating to "https://www.westridgeschool.org/", waiting until "domcontentloaded"
#
#   ✗ Could not load https://www.westridgeschool.org/, skipping.
#
# ============================================================
#  Scraping: https://www.chadwickschool.org/
# ============================================================
# Connecting to: https://www.chadwickschool.org/...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 1 missing field(s): Students
#   ✓ OpenAI filled: Students
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › Chadwick School
# ——————————————————————————————————————————————————
#
# 3–12          850           8:1           2023
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://chadwickschool.static.amais.com/Village_Program_Academics__2_-266-optimized.webp?version=638859321928970000
#   2. https://chadwickschool.static.amais.com/Apply__4_-245-optimized.webp?version=638858648394830000
#   3. https://chadwickschool.static.amais.com/Sixth_Grade_Programs_Athletics_1_-381-Home---Large-Portrait-Image_3458.webp?version=638881702981630000
#   4. https://chadwickschool.static.amais.com/Sixth_Arts__5_-585-optimized.webp?version=638866436879000000
#   5. https://chadwickschool.static.amais.com/Home_Sixth_Grade_Outdoor_Ed__2_-1117-optimized.webp?version=638881885744330000
#   6. https://www.chadwickschool.org/ams/Tuition_Meta_Image-1357-OG-Image_4254.webp?version=638884880146970000
#   7. https://chadwickschool.static.amais.com/Apply__5_-249-optimized.webp?version=638858648392600000
#   8. https://www.chadwickschool.org/ams/Mission_Hero-134-OG-Image_407.webp?version=638850738296100000
#   9. https://chadwickschool.static.amais.com/CS_10102024_FallCollegeNight_0077-1712.jpg?version=638891049981670000
#   10. https://chadwickschool.static.amais.com/MS_programs_character__1_-441-optimized.webp?version=638864612804930000
#
# About Chadwick School
# Chadwick is steeped in more than 90 years of history and tradition that began with the extraordinary vision of one woman: Margaret Lee Chadwick. From her very first home school in 1935, to her entrepreneurial efforts to secure the first acres of land on the Palos Verdes Peninsula, to today’s campuses in Palos Verdes, California, and Songdo, South Korea, Margaret Chadwick was a pioneer.
#
# Institution Details
#   Type       : Independent Day School
#   Ages       : 3–12
#   Students   : 850
#   Ratio      : 8:1
#   Founded    : 2023
#   City       : Los Angeles, CA
#   Annual Fee : Tuition $45,880
#
# Quotes
#   "Chadwick’s educational programs are intentionally designed to maximize hands-on, real-world learning for our students. Would you like to begin your pursuit of goodness and greatness?"
#
# How they teach
# Raise your hand if you’ve ever been so engaged in a class that time flew by and you wanted to stick around after just to keep the conversation going. At Chadwick, that’s not the exception — it’s the norm.
#
# Outcomes: Where students go
# At Chadwick, our approach to college counseling is student-centered because we believe that students are most fulfilled by their choice of college when they’re the ones driving the process and the decision. Parents are involved throughout to ensure transparency and appropriate collaboration.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Completing an inquiry form creates an account that gives you access to our admission portal, which is where you can book a tour, register for admission events and begin the application process. It will also keep you updated on important news, information and opportunities by adding you to our regular newsletter.
#
# How Chadwick School Performs
#
#   Academic Integration:
#   Sixers are encouraged to get their hands dirty — in the best possible way! They’re given exposure to and training in the practices of ceramics, painting and drawing.
#
#   Facilities & Resources:
#   Field trips to local museums and galleries are included in certain courses, as is time in the studio and direct instruction from seasoned creators.
#
#   Coaching Credentials:
#   We’re able to offer such an experience because we invest back into our students and school. Through tuition and other financial support, we’re able to continuously improve our campus and facilities, hire expert and caring faculty, develop new programs and offer innovative experiences with measurable results.
#
#   Student Wellbeing:
#   Foundational to the whole process is our strong curriculum that prepares students academically, emotionally and socially for study at the collegiate level. Our Deans of College Counseling, all of whom have experience as both college counselors and as senior-level admission officers at selective colleges, help guide this process.
#
#   Competitive Pathway:
#   We wouldn’t call it learning if it didn’t involve twists, turns, achievements, detours, celebrations and fun. Choosing the right school is a significant investment in your child's future, and at Chadwick, we believe that investment yields returns far beyond academic achievements.
#
#   Ongoing Accountability:
#   This type of learning is powerfully supported by our small class sizes, which enable teachers to provide regular, meaningful feedback and truly support every student's individual learning journey. It also ensures students have a real voice in every classroom, encouraging participation rather than passive learning.
#
#   Location : Los Angeles, CA
#   Website  : https://www.chadwickschool.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → chadwick_school_wp_blocks.txt
# School JSON → chadwick_school_data.json
#
# ============================================================
#  Scraping: https://www.campbellhall.org/
# ============================================================
# Connecting to: https://www.campbellhall.org/...
#   ⚠ networkidle failed (TimeoutError), retrying…
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 4 missing field(s): Ratio, Fees, Outcomes, Admissions
#   ✓ OpenAI filled: Ratio, Fees, Outcomes, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Studio City › Campbell Hall
# ——————————————————————————————————————————————————
#
# 3–12          1160          1:8           1944
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://bbk12e1-cdn.myschoolcdn.com/883/photo/orig_photo924508_7485851.jpg
#   2. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/883/list/large_list231180_63985.jpg
#   3. https://bbk12e1-cdn.myschoolcdn.com/883/photo/orig_photo1919063_10163962.jpg
#   4. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/883/list/large_list231242_64046.jpg
#   5. https://bbk12e1-cdn.myschoolcdn.com/883/photo/orig_photo1919025_10163956.jpg
#   6. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/883/list/large_list73660_18069.png
#   7. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/883/list/large_list231196_64001.jpg
#   8. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/883/list/large_list230757_63698.jpg
#   9. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/883/list/large_list231161_63966.png
#   10. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/883/list/large_list231170_63975.png
#
# About Campbell Hall
# Today JV Baseball will take on Rio Hondo Prep at HOME at 5:00pm. Come out to the field to cheer on your Vikings!#gochvikings #TheHall Daria J.
#
# Institution Details
#   Type       : Independent Day School
#   Ages       : 3–12
#   Students   : 1160
#   Ratio      : 1:8
#   Founded    : 1944
#   City       : Studio City, CA
#   Annual Fee : $40,000 per year
#
# Quotes
#   "Theater Campbell Hall's elementary school provides students with a breadth of experiences that promotes exploration and growth."
#
# How they teach
# CH Community Sunday is on Sunday, May 17, from 10 am - 1 pm! Discover “The Power of Us” at this year’s day of service outreach for *ALL K-12 families.* Join us to participate in activities, support non-profit organizations, and enjoy food and music as a community.
#
# Outcomes: Where students go
# Campbell Hall fosters academic excellence and personal growth, preparing students for top-tier universities. Graduates are well-rounded individuals equipped to make meaningful contributions to society.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective families can apply online, with tours and interviews as part of the process. Admission decisions consider academic records, recommendations, and student potential.
#
# How Campbell Hall Performs
#
#   Coaching Credentials:
#   Today JV Baseball will take on Rio Hondo Prep at HOME at 5:00pm. Come out to the field to cheer on your Vikings!#gochvikings #TheHall Daria J.
#
#   Student Wellbeing:
#   N/A
#
#   Academic Integration:
#   CH Community Sunday is on Sunday, May 17, from 10 am - 1 pm! Discover “The Power of Us” at this year’s day of service outreach for *ALL K-12 families.* Join us to participate in activities, support non-profit organizations, and enjoy food and music as a community.
#
#   Competitive Pathway:
#   N/A
#
#   Facilities & Resources:
#   N/A
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Studio City, CA
#   Website  : https://www.campbellhall.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → campbell_hall_wp_blocks.txt
# School JSON → campbell_hall_data.json
#
# ============================================================
#  Scraping: https://milkenschool.org/
# ============================================================
# Connecting to: https://milkenschool.org/...
#   ⚠ networkidle failed (TimeoutError), retrying…
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Milken Community School
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 13 missing field(s): Founded, Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ OpenAI filled: Founded, Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › Milken Community School
# ——————————————————————————————————————————————————
#
# 6–12          775           1:8           1990
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://milkenschool.org/ftpimages/618/link/large_link2050562_101813.png
#   2. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/link/large_link1732326_159694.jpeg
#   3. https://bbk12e1-cdn.myschoolcdn.com/618/photo/orig_photo1551953_8872989.png
#   4. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/text/large_text559647_86570.png
#   5. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/text/large_text1603590_87958.jpeg
#   6. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/list/large_list230240_63498.png
#   7. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/list/large_list247565_70617.png
#   8. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/list/large_list247562_70616.png
#   9. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/list/large_list247563_70620.png
#   10. https://bbk12e1-cdn.myschoolcdn.com/ftpimages/618/link/large_link1732324_159690.jpeg
#
# About Milken Community School
# Milken Community School is a premier Jewish day school offering a rigorous academic program for grades 7-12. It fosters a vibrant community grounded in Jewish values and educational excellence.
#
# Institution Details
#   Type       : Independent Day School
#   Ages       : 6–12
#   Students   : 775
#   Ratio      : 1:8
#   Founded    : 1990
#   City       : Los Angeles, CA
#   Annual Fee : $49,600 per year
#
# Quotes
#   "Empower your potential, embrace diversity, and lead with purpose to create a brighter future."
#
# How they teach
# Milken emphasizes holistic education, integrating academic rigor with ethical and spiritual growth. The school nurtures critical thinking and personal development within a supportive Jewish framework.
#
# Outcomes: Where students go
# Graduates are well-prepared for top universities and embody strong leadership qualities. Milken students excel in academics, arts, and athletics, contributing positively to their communities.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students undergo a comprehensive application process including interviews and assessments. Milken seeks diverse, motivated individuals who align with its mission and values.
#
# How Milken Community School Performs
#
#   Coaching Credentials:
#   Milken's faculty includes highly qualified educators with advanced degrees and specialized training. Teachers are dedicated to fostering intellectual curiosity and personal growth in students.
#
#   Student Wellbeing:
#   The school offers robust support services, including counseling and wellness programs. Milken prioritizes a safe, inclusive environment where students can thrive emotionally and socially.
#
#   Academic Integration:
#   Milken's curriculum combines rigorous academics with innovative programs like STEAM and global studies. Students engage in interdisciplinary learning that prepares them for future challenges.
#
#   Competitive Pathway:
#   Milken students achieve high scores in standardized tests and competitions. The school boasts a strong record of college acceptances, including Ivy League institutions.
#
#   Facilities & Resources:
#   Milken features state-of-the-art facilities, including science labs, art studios, and athletic complexes. The campus supports a dynamic learning environment with cutting-edge technology.
#
#   Ongoing Accountability:
#   Milken employs continuous assessment methods to ensure educational quality and student progress. Regular feedback and evaluations help maintain high standards across all programs.
#
#   Location : Los Angeles, CA
#   Website  : https://milkenschool.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → milken_community_school_wp_blocks.txt
# School JSON → milken_community_school_data.json
#
# ============================================================
#  Scraping: https://www.ivywise.com/
# ============================================================
# Connecting to: https://www.ivywise.com/...
#   ⚠ networkidle failed (TimeoutError), retrying…
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for IvyWise
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Students, Ratio, Fees
#   ✓ OpenAI: nothing new to fill.
#
# ——————————————————————————————————————————————————
# Elite › California › IvyWise
# ——————————————————————————————————————————————————
#
# 14–18         N/A           N/A           2002
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://www.ivywise.com/wp-content/uploads/2024/09/Tiffany-V-Circular-web.webp
#   2. https://www.ivywise.com/wp-content/uploads/2024/09/Tasha-Circular-Green-web.webp
#   3. https://www.ivywise.com/wp-content/uploads/2024/09/Joy-Circular-web.webp
#   4. https://www.ivywise.com/wp-content/uploads/2024/09/Katie-G-Circular-web.webp
#   5. https://www.ivywise.com/wp-content/uploads/2025/10/college-admissions-committee.jpg
#   6. https://www.ivywise.com/wp-content/uploads/2024/09/Kim-Circular-Green-web.webp
#   7. https://www.ivywise.com/wp-content/uploads/2024/09/Kat-Circular-web1.webp
#   8. https://www.ivywise.com/wp-content/uploads/2026/03/dartmouth-1200x628.jpg
#   9. https://www.ivywise.com/wp-content/uploads/2024/09/Indhika-Circular-Green-web.webp
#   10. https://www.ivywise.com/wp-content/uploads/2024/09/Judy-Circular-Green-web.webp
#
# About IvyWise
# Admissions is about more than just grades and test scores. Schools take a holistic approach to evaluating applications, considering activities, interests, and other factors outside of numbers, and IvyWise takes that same holistic approach when guiding students.
#
# Institution Details
#   Type       : Education Consultancy
#   Ages       : 14–18
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 2002
#   City       : California, CA
#   Annual Fee : See website
#
# Quotes
#   "Empower your unique journey; success is a mosaic of passion, purpose, and potential beyond mere numbers."
#
# How they teach
# IvyWise counselors were in the rooms where the decisions were made, so they know how students will be evaluated in the highly-selective admissions process: they know every type of school system and curriculum, how to best advise students, how applications will be read, what admissions committees are looking for, and what it takes to stand out.
#
# Outcomes: Where students go
# Are you considering applying to Dartmouth College? Whether you are beginning the college search process or finalizing your list, this is a great opportunity to learn all about Dartmouth and hear expert tips on how to get in from IvyWise college admissions counselors Alecia (formerly at Duke University) and Rachel (formerly at Swarthmore College).
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : The IvyWise Initial Consultation is a detailed service, where your IvyWise counselor will provide a strategic action plan to help you achieve your educational goals — whether you’re figuring out your college plans, trying to make the most of your undergraduate experience, applying to graduate school, or interested in a WiseStart™ program. Contact us to schedule a complimentary Discovery Call with one of our expert enrollment advisors so we can learn a little more about you and your educational and/or admission goals.
#
# How IvyWise Performs
#
#   Coaching Credentials:
#   IvyWise provides students around the world with bespoke admissions counseling services with our unrivaled experience and expertise. Each student receives the benefit of our entire team’s expertise.
#
#   Student Wellbeing:
#   Are you considering applying to Dartmouth College? Whether you are beginning the college search process or finalizing your list, this is a great opportunity to learn all about Dartmouth and hear expert tips on how to get in from IvyWise college admissions counselors Alecia (formerly at Duke University) and Rachel (formerly at Swarthmore College).
#
#   Academic Integration:
#   In addition to admissions counseling, IvyWise has a team of tutors to provide the most efficient and effective test prep and academic subject tutoring, complemented by our personalized research services. We can also pair you with athletic counselors, post-graduate counselors (gap year counselors), learning difference specialists, and more.
#
#   Competitive Pathway:
#   N/A
#
#   Facilities & Resources:
#   In your 90-minute meeting, your IvyWise counselor will review your profile and how it aligns with your interests and goals. Your advisor will explain how your current school and courses align with your academic, professional, and/or graduate admissions goals.
#
#   Ongoing Accountability:
#   Each student receives the benefit of our entire team’s expertise. During the college application season, our entire team of counselors meets weekly at the IvyWise Roundtable, which simulates the real-world admissions committee evaluation process.
#
#   Location : California, CA
#   Website  : https://www.ivywise.com/
# ——————————————————————————————————————————————————
#
#  WP blocks  → ivywise_wp_blocks.txt
# School JSON → ivywise_data.json
#
# ============================================================
#  Scraping: https://www.crimsoneducation.org/us-en/
# ============================================================
# Connecting to: https://www.crimsoneducation.org/us-en/...
#   ✗ Garbage/parked site detected — skipping https://www.crimsoneducation.org/us-en/
#
# ============================================================
#  Scraping: https://www.laequestrian.com/
# ============================================================
# Connecting to: https://www.laequestrian.com/...
#   ⚠ networkidle failed (Error), retrying…
#   ✗ Failed: Page.goto: net::ERR_CONNECTION_TIMED_OUT at https://www.laequestrian.com/
# Call log:
#   - navigating to "https://www.laequestrian.com/", waiting until "domcontentloaded"
#
#   ✗ Could not load https://www.laequestrian.com/, skipping.
#
# ============================================================
#  Scraping: https://www.equinox.com/los-angeles
# ============================================================
# Connecting to: https://www.equinox.com/los-angeles...
#   No quote found on site — generating AI quote…
#   ✓ AI quote generated for Equinox
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 15 missing field(s): Founded, Ages, Students, Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ OpenAI filled: Founded, Ages, Students, Ratio, Fees, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › Equinox
# ——————————————————————————————————————————————————
#
# 5–18          450           1:10          1991
# Ages          Students      Ratio         Founded
#
# Images Found: 0
#
# About Equinox
# Equinox is a premier independent school in Los Angeles, dedicated to fostering academic excellence and personal growth. Our mission is to challenge students to leave their comfort zones and achieve their full potential.
#
# Institution Details
#   Type       : Independent School
#   Ages       : 5–18
#   Students   : 450
#   Ratio      : 1:10
#   Founded    : 1991
#   City       : Los Angeles, CA
#   Annual Fee : $45,000 per year
#
# Quotes
#   "Nurturing innovative minds and compassionate hearts to illuminate the future with creativity and purpose."
#
# How they teach
# Equinox believes in a holistic approach to education, emphasizing both intellectual and emotional development. We encourage students to explore new ideas and embrace diverse perspectives.
#
# Outcomes: Where students go
# Graduates of Equinox are well-prepared for higher education and global citizenship. Our alumni excel in various fields, demonstrating leadership and innovation.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students can apply through our online portal, with interviews and assessments as part of the process. We seek curious and motivated individuals who thrive in a challenging environment.
#
# How Equinox Performs
#
#   Coaching Credentials:
#   Our faculty consists of experienced educators with advanced degrees in their fields. Staff members regularly participate in professional development to stay current with educational trends.
#
#   Student Wellbeing:
#   Equinox prioritizes mental health with on-site counselors and wellness programs. We offer a supportive environment where students can seek guidance and build resilience.
#
#   Academic Integration:
#   Our curriculum integrates traditional subjects with modern technology and interdisciplinary projects. Students engage in hands-on learning experiences that connect classroom knowledge to real-world applications.
#
#   Competitive Pathway:
#   Equinox students consistently achieve high scores in standardized tests and gain admission to top universities. We offer specialized coaching for competitive exams and scholarship applications.
#
#   Facilities & Resources:
#   Equinox boasts state-of-the-art science labs, a performing arts center, and athletic facilities. Our library provides extensive resources for research and independent study.
#
#   Ongoing Accountability:
#   We conduct regular assessments to monitor student progress and curriculum effectiveness. Feedback from students and parents helps us maintain high educational standards.
#
#   Location : Los Angeles, CA
#   Website  : https://www.equinox.com/los-angeles
# ——————————————————————————————————————————————————
#
#  WP blocks  → equinox_wp_blocks.txt
# School JSON → equinox_data.json
#
# ============================================================
#  Scraping: https://www.soulcycle.com/
# ============================================================
# Connecting to: https://www.soulcycle.com/...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 5 missing field(s): Students, Ratio, Fees, Philosophy, Admissions
#   ✓ OpenAI filled: Philosophy, Admissions
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › soulcyclebmx
# ——————————————————————————————————————————————————
#
# 15–18         N/A           N/A           2009
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://soulcycle.com/cdn/shop/files/wP6DUPb94XeCLJKWEl3e.jpg?v=1766160150&width=533
#   2. https://soulcycle.com/cdn/shop/files/ohtkgwbAoITicoObYYHg.jpg?v=1751919141&width=533
#   3. http://soulcycle.com/cdn/shop/collections/IMG_3753.jpg?v=1767883182
#   4. https://soulcycle.com/cdn/shop/files/4ZWBRSjZDSde0gxDpSPk.jpg?v=1758036706&width=533
#   5. https://soulcycle.com/cdn/shop/files/lhqhl5rD7wbRMwCDZOQ1.jpg?v=1749139442&width=533
#   6. https://soulcycle.com/cdn/shop/files/2HZNQJwK8M8RR35GRW9k.jpg?v=1750192579&width=533
#   7. https://soulcycle.com/cdn/shop/files/IMG_3753.jpg?v=1767883169&width=3840
#   8. https://soulcycle.com/cdn/shop/products/ec3e11e0ed7c2f78b7aaf0683e518a04_6fa5b17d-5b6d-434a-a28a-d97246fa257b.jpg?v=1690141850&width=533
#   9. https://soulcycle.com/cdn/shop/files/phlfzJJsR2n8m7YwseGH.jpg?v=1751925746
#   10. https://soulcycle.com/cdn/shop/articles/IMG_5358_63ef02be-73dc-463e-9b1a-46a6a82f50ab.jpg?v=1774537566&width=533
#
# About soulcyclebmx
# Founded in 2009 by professional skateboarder Adrian Lopez, Dark Seas Division has carved its own path at the crossroads of streetwear and coastal lifestyle. Inspired by the ocean and a restless spirit of adventure, the brand blends nautical heritage, surf culture, and bold design to create pieces that last.
#
# Institution Details
#   Type       : Wellness & Lifestyle Centre
#   Ages       : 15–18
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 2009
#   City       : Los Angeles, CA
#   Annual Fee : See website
#
# Quotes
#   "Find everything you need for your seat, from replacement bolts and nuts for built-in seat clamps to other small parts that make a big difference."
#
# How they teach
# Soulcyclebmx embraces a fusion of wellness and lifestyle, promoting an adventurous spirit through BMX culture. It aims to inspire individuals to explore and push their boundaries.
#
# Outcomes: Where students go
# The finalists each performed 2 runs, and the run with the best score was counted. The score is on a scale of 1-100.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Join soulcyclebmx by visiting their website for membership details and enrollment options. They welcome enthusiasts eager to engage with the BMX community.
#
# How soulcyclebmx Performs
#
#   Academic Integration:
# ...
#
#   Location : Los Angeles, CA
#   Website  : https://www.lacma.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → lacma_wp_blocks.txt
# School JSON → lacma_data.json
#
# ============================================================
#  Scraping: https://www.getty.edu/visit/
# ============================================================
# Connecting to: https://www.getty.edu/visit/...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 7 missing field(s): Students, Ratio, Fees, Outcomes, Admissions, Student Wellbeing, Ongoing Accountability
#   ✓ OpenAI filled: Outcomes, Admissions, Student Wellbeing, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › Our Museums - Locations, Exhibitions, Highlights
# ——————————————————————————————————————————————————
#
# 3–12          N/A           N/A           1984
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://media.getty.edu/iiif/image/29150836-b077-4e93-858f-c6327b71fc42/full/1500,/0/default.jpg
#   2. https://www.getty.edu/global/css/page_elements/img-adv-search.png
#   3. https://www.getty.edu/education/images/thumb_sti.jpg
#   4. https://www.getty.edu/education/images/ancient_worlds.JPG
#   5. https://www.getty.edu/visit/images/covers/0892362812.jpg
#   6. https://www.getty.edu/education/images/thumb_a_la.jpg
#   7. https://www.getty.edu/education/images/thumb_decarts.jpg
#   8. https://www.getty.edu/visit/images/covers/9781606065334.jpg
#   9. https://www.getty.edu/visit/images/covers/0892361689.jpg
#   10. https://www.getty.edu/visit/images/covers/9780892369881.jpg
#
# About Our Museums - Locations, Exhibitions, Highlights
# 12+ search tools and databases to find articles, provenance records, and much more 45+ miles of books, journals, auction catalogs, rare photographs, archives, and other special collections Dozens of adaptable resources for teaching and learning about conservation and cultural heritage management Databases, publications, and more tools for general or specialized research and study Search for books, journals, auction catalogs, archives, photographs, and digital formats Highlights of our archival holdings containing rare source materials related to art history and visual culture Authoritative terminology for the visual arts, including fine art, architecture, decorative art, archival materials, and conservation Research and databases of archival documents, sales catalogs, and public collections Access to an extensive collection of digitized art history texts from a range of institutions 45+ miles of books, journals, auction catalogs, rare photographs, archives, and other special collections Bringing the work of this groundbreaking Southern California architect to the broader public Creating civic dialogue around urgent problems of our time by examining past and present connections between art and science Increasing recognition and improving conservation of African American heritage through more inclusive and equitable preservation practices Reconsidering Van Gogh’s Irises through material analysis and advanced imaging to understand its history and help ensure its preservation We are pleased to invite submissions to the Getty Research Journal, an open-access publication presenting peer-reviewed articles on the visual arts of all cultures, regions, and time periods. Submissions are accepted through the journal’s portal on Scholastica on a rolling basis.
#
# Institution Details
#   Type       : Arts & Cultural Institution
#   Ages       : 3–12
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 1984
#   City       : Los Angeles, CA
#   Annual Fee : See website
#
# Quotes
#   "Through Getty Unshuttered, teen photographers are inspired to raise their voices for social good, transforming how we connect to ideas and each other."
#
# How they teach
# Ready-to-use resources and activities that help teachers and students spark meaningful, art-centered learning Getty supports K–12 educators with professional development programs, special events, and on-demand online learning that strengthen teaching practice through rich engagement with the Museum’s collections.
#
# Outcomes: Where students go
# Our Museums fosters a deep appreciation for art and culture, enhancing visitors' understanding through diverse exhibitions and educational programs.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Admission is free, and visitors can reserve timed-entry tickets online for both the Getty Center and Getty Villa.
#
# How Our Museums - Locations, Exhibitions, Highlights Performs
#
#   Academic Integration:
#   This work is licensed under a Creative Commons Attribution-NonCommercial-NoDerivatives 4.0 International License.
#
#   Competitive Pathway:
#   Harry Adams Archive, Tom & Ethel Bradley Center at California State University, Northridge.
#
#   Facilities & Resources:
#   Amid the turbulent decades of the mid-20th century, African American and Afro-Atlantic diaspora artists sought to celebrate Black culture and advance the struggle for civil rights. Photographic images contributed in myriad ways to the lively exchange of pan-African ideas that propelled the Black Arts Movement.
#
#   Coaching Credentials:
#   Pierre Ouillet is the executive vice president, Finance and Operations at the J. Bringing extensive expertise and a proven track record in managing complex, global organizations, he leads Getty’s financial and operational strategies, overseeing financial planning, investments, facilities, and administrative functions with a focus on advancing Getty’s financial sustainability, operational excellence, and institutional growth.
#
#   Student Wellbeing:
#   Our Museums provide a serene environment for reflection and learning, promoting mental well-being through art engagement. Interactive exhibits and workshops encourage creativity and personal expression, enhancing visitors' emotional health.
#
#   Ongoing Accountability:
#   Our Museums regularly evaluate visitor feedback to improve exhibitions and programs, ensuring high-quality experiences. Continuous research and collaboration with experts maintain the institution's commitment to excellence in art preservation and education.
#
#   Location : Los Angeles, CA
#   Website  : https://www.getty.edu/visit/
# ——————————————————————————————————————————————————
#
#  WP blocks  → our_museums_locations_exhibitions_h_wp_blocks.txt
# School JSON → our_museums_locations_exhibitions_h_data.json
#
# ============================================================
#  Scraping: https://www.laopera.org/
# ============================================================
# Connecting to: https://www.laopera.org/...
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 3 missing field(s): Students, Ratio, Admissions
#   ✓ OpenAI filled: Admissions
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › LA Opera
# ——————————————————————————————————————————————————
#
# 15–18         N/A           N/A           1992
# Ages          Students      Ratio         Founded
#
# Images Found: 10
#   1. https://laopera.imgix.net//laopera/community%20and%20learning/creativecare_2526_tatile.png?format=auto&fit=crop&w=280&h=200&auto=format
#   2. https://laopera.imgix.net//laopera/discover%20la%20opera/legacy-ambassadors/delia_orjuela_372x380.jpg?format=auto&fit=crop&auto=format&w=280&h=200&crop=focalpoint&fp-y=0&auto=format
#   3. https://laopera.imgix.net//laopera/discover%20la%20opera/new-to-opera_3.jpg?format=auto&fit=facearea&w=702&h=462&facepad=6&auto=format
#   4. https://laopera.imgix.net//laopera/press-room/lao-leadership-press-gallery/domingo_hindoyan_photo_by_chelsea_lauren_clu16644_r1.jpg?format=auto&fit=crop&w=1450&h=455h&auto=format
#   5. https://laopera.imgix.net/laopera/25-26_card_image_thumbnails/falstaff_1080_cardimage_2.jpg?format=auto&fit=crop&w=372&h=380&auto=format&auto=format
#   6. https://laopera.imgix.net//laopera/24-25%20production%20images%20(purchased)/04-ainadamar/_dsc1725_pr.jpg?format=auto&fit=crop&w=1200&auto=format
#   7. https://laopera.imgix.net//laopera/discover%20la%20opera/legacy-ambassadors/ajay_relan_372x380.jpg?format=auto&fit=crop&auto=format&w=280&h=200&crop=focalpoint&fp-y=0&auto=format
#   8. https://laopera.imgix.net//laopera/fleming_piazza_with_dove_cameron_800x450.jpg?format=auto&fit=crop&w=702&h=462&auto=format
#   9. https://laopera.imgix.net//laopera/blog/kate_lindsey_w_sterns_800x450.jpg?format=auto&fit=crop&w=702&h=462&auto=format
#   10. https://laopera.imgix.net//laopera/discover%20la%20opera/legacy-ambassadors/jason_delane_lee_372x380.jpg?format=auto&fit=crop&auto=format&w=280&h=200&auto=format
#
# About LA Opera
# Created in 1986 by a team of visionaries, LA Opera has become a leader in artistic innovation, while honoring the great historical legacy of opera. Through the powerful art form of opera, we celebrate the diversity and pioneering spirit of our great city.
#
# Institution Details
#   Type       : Independent School
#   Ages       : 15–18
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : 1992
#   City       : Los Angeles, CA
#   Annual Fee : $5
#
# Quotes
#   "Wheelchair and Accessible Seating Your seat is waiting for you!"
#
# How they teach
# Our MissionTo serve the public by producing world-class opera that preserves, promotes and advances the art form while embodying the diversity, pioneering spirit and artistic sensibility unique to Los Angeles.
#
# Outcomes: Where students go
# Almost four decades ago, LA Opera was founded by a group of visionaries who believed Los Angeles deserved its own opera company. Our 40th Anniversary is a chance to celebrate those founders and everyone—subscribers, ticket buyers, patrons, artists, and artisans—who helped make us the world-class opera company we are today.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : To join LA Opera, interested individuals can visit the official website for audition and application details. Enrollment is competitive and based on artistic talent and potential.
#
# How LA Opera Performs
#
#   Competitive Pathway:
#   The concert will be followed by a gala dinner and celebration on the stage of the Dorothy Chandler Pavilion. This very special evening will offer a unique opportunity for the LA Opera family to honor Maestro Conlon and celebrate his extraordinary achievements.
#
#   Coaching Credentials:
#   Created in 1986 by a team of visionaries, LA Opera has become a leader in artistic innovation, while honoring the great historical legacy of opera. Through the powerful art form of opera, we celebrate the diversity and pioneering spirit of our great city.
#
#   Student Wellbeing:
#   N/A
#
#   Academic Integration:
#   Our MissionTo serve the public by producing world-class opera that preserves, promotes and advances the art form while embodying the diversity, pioneering spirit and artistic sensibility unique to Los Angeles.
#
#   Facilities & Resources:
#   Lori was a public servant to some of New York’s most recognized politicians, including former Governor Eliot Spitzer, New York City Council Member Eva Moskowitz, and New York State Senator & Majority Leader Andrea Stewart-Cousins. As a political consultant, she worked with Senator Cory Booker on his transition team after his election as Mayor of Newark, New Jersey, and with Gary, Indiana Mayor Karen Freeman Wilson.
#
#   Ongoing Accountability:
#   N/A
#
#   Location : Los Angeles, CA
#   Website  : https://www.laopera.org/
# ——————————————————————————————————————————————————
#
#  WP blocks  → la_opera_wp_blocks.txt
# School JSON → la_opera_data.json
#
# ============================================================
#  Scraping: https://www.losangelesdance.com/
# ============================================================
# Connecting to: https://www.losangelesdance.com/...
#   ⚠ networkidle failed (TimeoutError), retrying…
#
#   Running OpenAI gap-fill for missing fields…
#   → OpenAI filling 14 missing field(s): Founded, Ages, Students, Ratio, About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#   ✓ OpenAI filled: About, Philosophy, Outcomes, Admissions, Coaching Credentials, Student Wellbeing, Academic Integration, Competitive Pathway, Facilities & Resources, Ongoing Accountability
#
# ——————————————————————————————————————————————————
# Elite › Los Angeles › losangelesdance.com
# ——————————————————————————————————————————————————
#
# N/A           N/A           N/A           N/A
# Ages          Students      Ratio         Founded
#
# Images Found: 5
#   1. https://www.losangelesdance.com/forsale/_next/image?url=%2Fforsale%2Fimgs%2Fpayments%2Fmastercard.png&w=128&q=75
#   2. https://www.losangelesdance.com/forsale/_next/image?url=%2Fforsale%2Fimgs%2Fpayments%2Fpaypal.png&w=128&q=75
#   3. https://www.losangelesdance.com/forsale/_next/image?url=%2Fforsale%2Fimgs%2Fpayments%2Fvisa.png&w=128&q=75
#   4. https://www.losangelesdance.com/forsale/_next/image?url=%2Fforsale%2Fimgs%2Fpayments%2FamericanExpress.png&w=128&q=75
#   5. https://www.losangelesdance.com/forsale/_next/image?url=%2Fforsale%2Fimgs%2Fpayments%2Falipay.png&w=128&q=75
#
# About losangelesdance.com
# Losangelesdance.com is dedicated to providing high-quality dance education in Los Angeles. It aims to foster creativity and passion in its students.
#
# Institution Details
#   Type       : Independent School
#   Ages       : N/A
#   Students   : N/A
#   Ratio      : N/A
#   Founded    : N/A
#   City       : Los Angeles, CA
#   Annual Fee : $2,519,
#
# Quotes
#   "Own it today for $2,519, or select Lease to Own."
#
# How they teach
# The school believes in nurturing individual talent through personalized attention and innovative teaching methods. It emphasizes the importance of artistic expression and discipline.
#
# Outcomes: Where students go
# Students develop strong technical skills and confidence in their abilities. Graduates often pursue further education or careers in dance and the arts.
#
# Admissions & How to Apply
#   Enquiries Open : Year-round
#   App Deadline   : Rolling admissions
#   Process        : Prospective students can apply online through the website. Admission is based on an evaluation of the applicant's potential and passion for dance.
#
# How losangelesdance.com Performs
#
#   Coaching Credentials:
#   Instructors are experienced professionals with backgrounds in various dance disciplines. They hold certifications and have performed with renowned dance companies.
#
#   Student Wellbeing:
#   The school provides a supportive environment focused on personal growth and mental health. Regular workshops and counseling services are available to all students.
#
#   Academic Integration:
#   Dance programs are designed to complement academic studies, promoting a balanced education. Students can integrate their dance training with school curriculums.
#
#   Competitive Pathway:
#   Students have opportunities to participate in local and national dance competitions. The school has a track record of winning awards and accolades.
#
#   Facilities & Resources:
#   The school boasts state-of-the-art dance studios with professional-grade flooring. Resources include a comprehensive library of dance literature and media.
#
#   Ongoing Accountability:
#   Regular assessments and feedback sessions ensure continuous improvement. The school maintains high standards through consistent evaluation of teaching methods and student progress.
#
#   Location : Los Angeles, CA
#   Website  : https://www.losangelesdance.com/
# ——————————————————————————————————————————————————
#
#  WP blocks  → losangelesdance_com_wp_blocks.txt
# School JSON → losangelesdance_com_data.json
#
# ============================================================
# All done! 14 institutions scraped.
# Master JSON → all_schools_data_losangeles.json
# ============================================================
